# %% [markdown]
# # Imports

# %%
#Standard Packages
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pickle
import warnings
warnings.filterwarnings(action='ignore') 

# Packages used for API calls and data processing
import requests
import json
def get_keys(path):
    with open(path) as f:
        return json.load(f)
import ast
import time
import http.client, urllib.request, urllib.parse, urllib.error, base64
api_key = 'ceeaacb7cf024c7485e00ef8457e42dc'
gamertag = 'Drymander'
from tqdm import tqdm
# !pip install isodate
import isodate

# %%
# Preprocessing tools
from sklearn.model_selection import train_test_split,cross_val_predict,cross_validate
from sklearn.preprocessing import MinMaxScaler,StandardScaler,OneHotEncoder
scaler = StandardScaler()
from sklearn import metrics

# Models & Utilities
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score
from sklearn import svm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
# Prepare gamertag for API
def gamertag_for_api(gamertag):
    
    # Replace spaces with '+'
    gamertag = gamertag.replace(' ','+')
    return gamertag

# Testing the function
gamertag_for_api('this is a test')
# Out:
# 'this+is+a+test'

# %%
# Function to pull most recent match stats into JSON format
# Uses two separate API calls, one from player history and another from match details
def pull_recent_match(how_recent, api_key=api_key, explore=False, gamertag='Drymander'):
    
    # Use gamertag_for_api function to remove any spaces
    gamertag = gamertag_for_api(gamertag)
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': api_key,
    }
    # Pulls from arena mode, how_recent is how far to go back in the match history
    # 'count' refers to the number of matches to pull
    params = urllib.parse.urlencode({
        # Request parameters
        'modes': 'arena',
        'start': how_recent,
        'count': 1,
        'include-times': True,
    })
    
    # Try this, otherwise return error message
    try:
        
        # Connect to API and pull most recent match for specified gamer
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/players/{gamertag}/matches?%s" % params, "{body}", headers)
        response = conn.getresponse()
        latest_match = json.loads(response.read())
        
        # Identify match ID and match date
        match_id = latest_match['Results'][0]['Id']['MatchId']
        match_date = latest_match['Results'][0]['MatchCompletedDate']['ISO8601Date']
        
        # Rest for 1.01 seconds to not get blocked by API
        time.sleep(1.01)
        
        # Using match_id, pull details from match
        conn.request("GET", f"/stats/h5/arena/matches/{match_id}?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        
        # Option to return as byte string for alternative viewing
        if explore == True:
            print(data)
        else:
            # Append match ID and date from player history API call
            match_results = json.loads(data)
            match_results['MatchId'] = match_id
            match_results['Date'] = match_date
        conn.close()
    
    # Print error if issue with calling API
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    # Return match results as JSON
    return match_results

# Show result
match_results = pull_recent_match(0, explore=False, gamertag='Drymander')
match_results
# Out:
# {'PlayerStats': [{'XpInfo': {'PrevSpartanRank': 138,
#     'SpartanRank': 138,
#     'PrevTotalXP': 6187181,
#     'TotalXP': 6189035,
#     'SpartanRankMatchXPScalar': 2.238,
#     'PlayerTimePerformanceXPAward': 529,
#     'PerformanceXP': 99,
#     'PlayerRankXPAward': 200,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 10,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Drymander', 'TotalKills': 6},
#     {'GamerTag': 'SixKnifeWalker', 'TotalKills': 8},
#     {'GamerTag': 'Bophodes', 'TotalKills': 5},
#     {'GamerTag': 'cryptolockerSD', 'TotalKills': 1}],
#    'KilledByOpponentDetails': [{'GamerTag': 'Bophodes', 'TotalKills': 4},
#     {'GamerTag': 'Drymander', 'TotalKills': 1},
#     {'GamerTag': 'SixKnifeWalker', 'TotalKills': 5},
#     {'GamerTag': 'cryptolockerSD', 'TotalKills': 2}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 20},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 1},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 12},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 4},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 20}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT6M25.40466S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 876,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 375,
#     'TimePlayedAmount': 500.8916480147141,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 29240,
#      'Progress': 29260},
#     {'Id': '4f65785e-78e0-4296-80d4-55b316f60ec5',
#      'PreviousProgress': 192,
#      'Progress': 196},
#     {'Id': 'e1203a73-2067-4479-9a47-2abccb0069ae',
#      'PreviousProgress': 4112,
#      'Progress': 4117},
#     {'Id': '07653860-9949-4a12-b341-90c8b9653165',
#      'PreviousProgress': 12217,
#      'Progress': 12220},
#     {'Id': '2d5080e0-62ee-42d9-a2dd-364d101832ea',
#      'PreviousProgress': 2098,
#      'Progress': 2101},
#     {'Id': '73d0b012-4747-4fe3-90b7-04818ec3d807',
#      'PreviousProgress': 523,
#      'Progress': 528},
#     {'Id': '1d32707e-9bbc-4cbe-af33-fdc0c8bd64b2',
#      'PreviousProgress': 2001,
#      'Progress': 2002},
#     {'Id': '82b2df6c-a2a2-41be-9858-e85e310b3aba',
#      'PreviousProgress': 139,
#      'Progress': 140},
#     {'Id': '178cf53a-7686-445c-ba6d-a3e76788b2f1',
#      'PreviousProgress': 391,
#      'Progress': 394},
#     {'Id': '2504f345-c751-448f-9bfd-e51af30e93ff',
#      'PreviousProgress': 432,
#      'Progress': 433},
#     {'Id': '49b744bf-ec46-47aa-bb16-0042cbf49614',
#      'PreviousProgress': 219,
#      'Progress': 220},
#     {'Id': 'd3b6b1ce-c5f0-4cbf-b443-ca76c2917b77',
#      'PreviousProgress': 726,
#      'Progress': 727},
#     {'Id': 'be522e1e-eada-4ec7-aba9-7ee0c0d6732a',
#      'PreviousProgress': 5,
#      'Progress': 6},
#     {'Id': 'a61833aa-b90a-4fa8-83d3-b6a0e94d2866',
#      'PreviousProgress': 107,
#      'Progress': 108}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'Dimension vv', 'Xuid': None},
#    'TeamId': 0,
#    'Rank': 1,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT23.5717586S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': 20,
#    'GameEndStatus': 3,
#    'TotalKills': 20,
#    'TotalHeadshots': 4,
#    'TotalWeaponDamage': 2721.3309975862503,
#    'TotalShotsFired': 493,
#    'TotalShotsLanded': 235,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 907086443,
#      'Attachments': []},
#     'TotalShotsFired': 93,
#     'TotalShotsLanded': 61,
#     'TotalHeadshots': 4,
#     'TotalKills': 6,
#     'TotalDamageDealt': 817.0,
#     'TotalPossessionTime': 'PT1M8.3499S'},
#    'TotalMeleeKills': 0,
#    'TotalMeleeDamage': 0.0,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 85.81793212890625,
#    'TotalPowerWeaponKills': 17,
#    'TotalPowerWeaponDamage': 2263.513065457344,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT4M11.6167S',
#    'TotalDeaths': 12,
#    'TotalAssists': 1,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT6M25.40466S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 2078758684, 'Count': 5},
#     {'MedalId': 3925170236, 'Count': 3},
#     {'MedalId': 1986137636, 'Count': 1},
#     {'MedalId': 848240062, 'Count': 3},
#     {'MedalId': 2977773352, 'Count': 1},
#     {'MedalId': 876932011, 'Count': 1},
#     {'MedalId': 466059351, 'Count': 1},
#     {'MedalId': 824733727, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT4.3167S'},
#     {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#      'TotalShotsFired': 93,
#      'TotalShotsLanded': 22,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 37.40000915527344,
#      'TotalPossessionTime': 'PT6.3667S'},
#     {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#      'TotalShotsFired': 112,
#      'TotalShotsLanded': 35,
#      'TotalHeadshots': 0,
#      'TotalKills': 4,
#      'TotalDamageDealt': 434.19903564453125,
#      'TotalPossessionTime': 'PT36.35S'},
#     {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#      'TotalShotsFired': 93,
#      'TotalShotsLanded': 61,
#      'TotalHeadshots': 4,
#      'TotalKills': 6,
#      'TotalDamageDealt': 817.0,
#      'TotalPossessionTime': 'PT1M8.3499S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 5,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT9.6333S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 5,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT7.1S'},
#     {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#      'TotalShotsFired': 122,
#      'TotalShotsLanded': 63,
#      'TotalHeadshots': 0,
#      'TotalKills': 5,
#      'TotalDamageDealt': 562.2000122070312,
#      'TotalPossessionTime': 'PT38.4833S'},
#     {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.5333S'},
#     {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.2833S'},
#     {'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#      'TotalShotsFired': 3,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 205.0,
#      'TotalPossessionTime': 'PT17.3S'},
#     {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 5.512502193450928,
#      'TotalPossessionTime': 'PT5.1167S'},
#     {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#      'TotalShotsFired': 18,
#      'TotalShotsLanded': 16,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 126.20149993896484,
#      'TotalPossessionTime': 'PT21.9334S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.15S'},
#     {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT12.05S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.0667S'},
#     {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT10.9667S'},
#     {'WeaponId': {'StockId': 4108759423, 'Attachments': []},
#      'TotalShotsFired': 19,
#      'TotalShotsLanded': 13,
#      'TotalHeadshots': 0,
#      'TotalKills': 3,
#      'TotalDamageDealt': 281.0,
#      'TotalPossessionTime': 'PT27.4667S'},
#     {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0.7667S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 15,
#      'TotalShotsLanded': 14,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 91.0,
#      'TotalPossessionTime': 'PT3.2333S'},
#     {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 76.00000631809235,
#      'TotalPossessionTime': 'PT16.7167S'},
#     {'WeaponId': {'StockId': 2140505068, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT13.2667S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 85.81793212890625,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 20,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 148,
#     'SpartanRank': 148,
#     'PrevTotalXP': 15539108,
#     'TotalXP': 15540354,
#     'SpartanRankMatchXPScalar': 2.248,
#     'PlayerTimePerformanceXPAward': 529,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 25,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 10,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Dimension vv', 'TotalKills': 1},
#     {'GamerTag': 'SourStarfish28', 'TotalKills': 3},
#     {'GamerTag': 'Nefarious', 'TotalKills': 2},
#     {'GamerTag': 'Nottheeddu', 'TotalKills': 2}],
#    'KilledByOpponentDetails': [{'GamerTag': 'Nottheeddu', 'TotalKills': 2},
#     {'GamerTag': 'Dimension vv', 'TotalKills': 6},
#     {'GamerTag': 'Nefarious', 'TotalKills': 5},
#     {'GamerTag': 'SourStarfish28', 'TotalKills': 2}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 8},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 4},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 15},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 1},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 8}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT6M25.4036625S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 726,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 225,
#     'TimePlayedAmount': 500.8912988897201,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 74699,
#      'Progress': 74707},
#     {'Id': '2504f345-c751-448f-9bfd-e51af30e93ff',
#      'PreviousProgress': 3739,
#      'Progress': 3740},
#     {'Id': '6f770f69-62a9-4c8b-a5a8-bcc5d4950492',
#      'PreviousProgress': 6793,
#      'Progress': 6794},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 2918,
#      'Progress': 2919},
#     {'Id': 'af609abb-c6e2-4e97-826f-5aca4fccf70c',
#      'PreviousProgress': 2105,
#      'Progress': 2106},
#     {'Id': '2eb4257c-9058-46e7-a40f-b9307f3553d9',
#      'PreviousProgress': 1939,
#      'Progress': 1940},
#     {'Id': '7d05bc12-7328-44fe-913e-1a64fe6a2a64',
#      'PreviousProgress': 4708,
#      'Progress': 4710},
#     {'Id': '3910e201-f2e0-417b-bbc1-8ed0a1fbd442',
#      'PreviousProgress': 464,
#      'Progress': 465}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'Drymander', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 7,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT19.7628408S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': 8,
#    'GameEndStatus': 1,
#    'TotalKills': 8,
#    'TotalHeadshots': 1,
#    'TotalWeaponDamage': 953.272590637207,
#    'TotalShotsFired': 286,
#    'TotalShotsLanded': 105,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 4054937266,
#      'Attachments': []},
#     'TotalShotsFired': 48,
#     'TotalShotsLanded': 18,
#     'TotalHeadshots': 0,
#     'TotalKills': 2,
#     'TotalDamageDealt': 248.59295654296875,
#     'TotalPossessionTime': 'PT32.75S'},
#    'TotalMeleeKills': 1,
#    'TotalMeleeDamage': 174.0,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 0.0,
#    'TotalPowerWeaponKills': 5,
#    'TotalPowerWeaponDamage': 865.036994934082,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT4M16.8831S',
#    'TotalDeaths': 15,
#    'TotalAssists': 4,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT6M25.4036625S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 250435527, 'Count': 1},
#     {'MedalId': 285057226, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#      'TotalShotsFired': 12,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 25.5,
#      'TotalPossessionTime': 'PT23.9833S'},
#     {'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.0833S'},
#     {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#      'TotalShotsFired': 16,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 82.5,
#      'TotalPossessionTime': 'PT6.6167S'},
#     {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT15.5667S'},
#     {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.5S'},
#     {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#      'TotalShotsFired': 3,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 1,
#      'TotalKills': 1,
#      'TotalDamageDealt': 115.0,
#      'TotalPossessionTime': 'PT38.0666S'},
#     {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#      'TotalShotsFired': 27,
#      'TotalShotsLanded': 7,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 65.2796401977539,
#      'TotalPossessionTime': 'PT23.7S'},
#     {'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.5833S'},
#     {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#      'TotalShotsFired': 31,
#      'TotalShotsLanded': 13,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 195.0,
#      'TotalPossessionTime': 'PT32.8333S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT3.1167S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 174.0,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0.2167S'},
#     {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#      'TotalShotsFired': 5,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 53.399993896484375,
#      'TotalPossessionTime': 'PT15.6833S'},
#     {'WeaponId': {'StockId': 723523180, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0.3833S'},
#     {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#      'TotalShotsFired': 68,
#      'TotalShotsLanded': 37,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 81.0440444946289,
#      'TotalPossessionTime': 'PT56.9333S'},
#     {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.3167S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 48,
#      'TotalShotsLanded': 18,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 248.59295654296875,
#      'TotalPossessionTime': 'PT32.75S'},
#     {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.1S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 13.0,
#      'TotalPossessionTime': 'PT5.35S'},
#     {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT4.5166S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.1667S'},
#     {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT12.3833S'},
#     {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.2167S'},
#     {'WeaponId': {'StockId': 2140505068, 'Attachments': []},
#      'TotalShotsFired': 60,
#      'TotalShotsLanded': 8,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 64.0,
#      'TotalPossessionTime': 'PT15.3833S'},
#     {'WeaponId': {'StockId': 47178948, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 9.955955505371094,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 6,
#      'TotalShotsLanded': 5,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 8,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 151,
#     'SpartanRank': 151,
#     'PrevTotalXP': 47129356,
#     'TotalXP': 47130660,
#     'SpartanRankMatchXPScalar': 2.251,
#     'PlayerTimePerformanceXPAward': 529,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 50,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 10,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Nefarious', 'TotalKills': 6},
#     {'GamerTag': 'Nottheeddu', 'TotalKills': 2},
#     {'GamerTag': 'SourStarfish28', 'TotalKills': 3},
#     {'GamerTag': 'Dimension vv', 'TotalKills': 2}],
#    'KilledByOpponentDetails': [{'GamerTag': 'Nottheeddu', 'TotalKills': 1},
#     {'GamerTag': 'Nefarious', 'TotalKills': 2},
#     {'GamerTag': 'SourStarfish28', 'TotalKills': 4},
#     {'GamerTag': 'Dimension vv', 'TotalKills': 1}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 13},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 2},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 8},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 0},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 13}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT6M25.4026623S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 751,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 250,
#     'TimePlayedAmount': 500.890948819726,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '1d32707e-9bbc-4cbe-af33-fdc0c8bd64b2',
#      'PreviousProgress': 19902,
#      'Progress': 19904},
#     {'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 195383,
#      'Progress': 195396},
#     {'Id': '82b2df6c-a2a2-41be-9858-e85e310b3aba',
#      'PreviousProgress': 6895,
#      'Progress': 6896},
#     {'Id': '79b6e993-ff9b-4a53-9789-cccaf86a4e22',
#      'PreviousProgress': 6917,
#      'Progress': 6918},
#     {'Id': '4f65785e-78e0-4296-80d4-55b316f60ec5',
#      'PreviousProgress': 5605,
#      'Progress': 5606},
#     {'Id': '57af1780-0f64-4fba-ae4e-201760d83611',
#      'PreviousProgress': 15937,
#      'Progress': 15940},
#     {'Id': '73d0b012-4747-4fe3-90b7-04818ec3d807',
#      'PreviousProgress': 10037,
#      'Progress': 10039},
#     {'Id': '5b194ecd-b079-4410-acde-ddfac14e6b2e',
#      'PreviousProgress': 9927,
#      'Progress': 9932},
#     {'Id': '750783af-3332-4c7d-b5b5-26aa8800655a',
#      'PreviousProgress': 5844,
#      'Progress': 5845},
#     {'Id': 'e1203a73-2067-4479-9a47-2abccb0069ae',
#      'PreviousProgress': 30638,
#      'Progress': 30639}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'cryptolockerSD', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 5,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT40.8844156S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': 13,
#    'GameEndStatus': 1,
#    'TotalKills': 13,
#    'TotalHeadshots': 0,
#    'TotalWeaponDamage': 1758.4250683784485,
#    'TotalShotsFired': 513,
#    'TotalShotsLanded': 288,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 2899979324,
#      'Attachments': []},
#     'TotalShotsFired': 297,
#     'TotalShotsLanded': 210,
#     'TotalHeadshots': 0,
#     'TotalKills': 5,
#     'TotalDamageDealt': 532.2496337890625,
#     'TotalPossessionTime': 'PT1M22.3833S'},
#    'TotalMeleeKills': 0,
#    'TotalMeleeDamage': 0.0,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 138.5310821533203,
#    'TotalPowerWeaponKills': 12,
#    'TotalPowerWeaponDamage': 1447.7939834594727,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT4M28.7667S',
#    'TotalDeaths': 8,
#    'TotalAssists': 2,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT6M25.4026623S',
#    'TotalGrenadeKills': 1,
#    'MedalAwards': [{'MedalId': 824733727, 'Count': 2},
#     {'MedalId': 3925170236, 'Count': 1},
#     {'MedalId': 2430242797, 'Count': 1},
#     {'MedalId': 2078758684, 'Count': 1},
#     {'MedalId': 876932011, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 5,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 163.99436950683594,
#      'TotalPossessionTime': 'PT46.25S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 15,
#      'TotalShotsLanded': 8,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 138.5310821533203,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT4.7833S'},
#     {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#      'TotalShotsFired': 32,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 66.27871704101562,
#      'TotalPossessionTime': 'PT31.35S'},
#     {'WeaponId': {'StockId': 723523180, 'Attachments': []},
#      'TotalShotsFired': 5,
#      'TotalShotsLanded': 5,
#      'TotalHeadshots': 0,
#      'TotalKills': 3,
#      'TotalDamageDealt': 409.9634094238281,
#      'TotalPossessionTime': 'PT1M16.5834S'},
#     {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.6S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT4.6833S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 15,
#      'TotalShotsLanded': 8,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 61.60000228881836,
#      'TotalPossessionTime': 'PT11.5167S'},
#     {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#      'TotalShotsFired': 100,
#      'TotalShotsLanded': 31,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 275.30785369873047,
#      'TotalPossessionTime': 'PT22.65S'},
#     {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#      'TotalShotsFired': 297,
#      'TotalShotsLanded': 210,
#      'TotalHeadshots': 0,
#      'TotalKills': 5,
#      'TotalDamageDealt': 532.2496337890625,
#      'TotalPossessionTime': 'PT1M22.3833S'},
#     {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#      'TotalShotsFired': 11,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT29.4833S'},
#     {'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.4667S'},
#     {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.7S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 27,
#      'TotalShotsLanded': 17,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 110.50000047683716,
#      'TotalPossessionTime': 'PT12.6333S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 642449794, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 13,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 146,
#     'SpartanRank': 146,
#     'PrevTotalXP': 9757943,
#     'TotalXP': 9759188,
#     'SpartanRankMatchXPScalar': 2.246,
#     'PlayerTimePerformanceXPAward': 529,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 25,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 10,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Dimension vv', 'TotalKills': 4},
#     {'GamerTag': 'Nefarious', 'TotalKills': 1},
#     {'GamerTag': 'Nottheeddu', 'TotalKills': 1}],
#    'KilledByOpponentDetails': [{'GamerTag': 'Nefarious', 'TotalKills': 5},
#     {'GamerTag': 'Dimension vv', 'TotalKills': 5},
#     {'GamerTag': 'Nottheeddu', 'TotalKills': 1}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 6},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 0},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 11},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 1},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 1},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 6}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT6M25.4026623S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 726,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 225,
#     'TimePlayedAmount': 500.890948819726,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 61018,
#      'Progress': 61024},
#     {'Id': '2eb4257c-9058-46e7-a40f-b9307f3553d9',
#      'PreviousProgress': 1246,
#      'Progress': 1247},
#     {'Id': '57af1780-0f64-4fba-ae4e-201760d83611',
#      'PreviousProgress': 4443,
#      'Progress': 4444},
#     {'Id': '79b6e993-ff9b-4a53-9789-cccaf86a4e22',
#      'PreviousProgress': 1224,
#      'Progress': 1225},
#     {'Id': '4f65785e-78e0-4296-80d4-55b316f60ec5',
#      'PreviousProgress': 1442,
#      'Progress': 1443},
#     {'Id': '1d32707e-9bbc-4cbe-af33-fdc0c8bd64b2',
#      'PreviousProgress': 4691,
#      'Progress': 4692},
#     {'Id': 'c43149a6-7b14-4cfd-8d4e-4b5f0b1c91bd',
#      'PreviousProgress': 689,
#      'Progress': 690},
#     {'Id': '664b927f-3684-48c5-8653-dfa6938ceac6',
#      'PreviousProgress': 1493,
#      'Progress': 1494},
#     {'Id': '24e0ba42-59df-4c45-9fe6-d4fb739aeadc',
#      'PreviousProgress': 2334,
#      'Progress': 2335},
#     {'Id': '07653860-9949-4a12-b341-90c8b9653165',
#      'PreviousProgress': 5847,
#      'Progress': 5848},
#     {'Id': '2d5080e0-62ee-42d9-a2dd-364d101832ea',
#      'PreviousProgress': 2879,
#      'Progress': 2880}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'Bophodes', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 8,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT25.9643366S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': 6,
#    'GameEndStatus': 1,
#    'TotalKills': 6,
#    'TotalHeadshots': 1,
#    'TotalWeaponDamage': 1056.5444388389587,
#    'TotalShotsFired': 184,
#    'TotalShotsLanded': 41,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 4106030681,
#      'Attachments': []},
#     'TotalShotsFired': 7,
#     'TotalShotsLanded': 5,
#     'TotalHeadshots': 0,
#     'TotalKills': 1,
#     'TotalDamageDealt': 306.1709899902344,
#     'TotalPossessionTime': 'PT0S'},
#    'TotalMeleeKills': 0,
#    'TotalMeleeDamage': 0.0,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 306.1709899902344,
#    'TotalPowerWeaponKills': 4,
#    'TotalPowerWeaponDamage': 562.8880081176758,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT2M51.9001S',
#    'TotalDeaths': 11,
#    'TotalAssists': 0,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT6M25.4026623S',
#    'TotalGrenadeKills': 1,
#    'MedalAwards': [{'MedalId': 824733727, 'Count': 1},
#     {'MedalId': 2838259753, 'Count': 1},
#     {'MedalId': 848240062, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 115.0,
#      'TotalPossessionTime': 'PT12.9167S'},
#     {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT3.5333S'},
#     {'WeaponId': {'StockId': 723523180, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 161.54342651367188,
#      'TotalPossessionTime': 'PT35.8833S'},
#     {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 56.344581604003906,
#      'TotalPossessionTime': 'PT17.4667S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 7,
#      'TotalShotsLanded': 5,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 306.1709899902344,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0.2S'},
#     {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#      'TotalShotsFired': 40,
#      'TotalShotsLanded': 11,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 115.0,
#      'TotalPossessionTime': 'PT16.8833S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 43,
#      'TotalShotsLanded': 10,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 71.68544149398804,
#      'TotalPossessionTime': 'PT36.4833S'},
#     {'WeaponId': {'StockId': 669296699, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 1,
#      'TotalKills': 1,
#      'TotalDamageDealt': 115.0,
#      'TotalPossessionTime': 'PT12.6S'},
#     {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT28.1167S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 22,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT19.5167S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 7,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT14.6667S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 20,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 30.799999237060547,
#      'TotalPossessionTime': 'PT48.9999S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.3167S'},
#     {'WeaponId': {'StockId': 4108759423, 'Attachments': []},
#      'TotalShotsFired': 21,
#      'TotalShotsLanded': 5,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 85.0,
#      'TotalPossessionTime': 'PT30.6333S'},
#     {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT10.55S'},
#     {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.3167S'},
#     {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#      'TotalShotsFired': 3,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT7.5833S'},
#     {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT11.9167S'},
#     {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#      'TotalShotsFired': 12,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [{'Id': 2556889090, 'Count': 1}],
#    'TotalSpartanKills': 6,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 151,
#     'SpartanRank': 151,
#     'PrevTotalXP': 37537896,
#     'TotalXP': 37539144,
#     'SpartanRankMatchXPScalar': 2.251,
#     'PlayerTimePerformanceXPAward': 529,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 25,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 10,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Nottheeddu', 'TotalKills': 3},
#     {'GamerTag': 'SourStarfish28', 'TotalKills': 2},
#     {'GamerTag': 'Nefarious', 'TotalKills': 2},
#     {'GamerTag': 'Dimension vv', 'TotalKills': 5}],
#    'KilledByOpponentDetails': [{'GamerTag': 'Dimension vv', 'TotalKills': 8},
#     {'GamerTag': 'Nottheeddu', 'TotalKills': 2},
#     {'GamerTag': 'Nefarious', 'TotalKills': 4},
#     {'GamerTag': 'SourStarfish28', 'TotalKills': 2}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 12},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 3},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 16},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 0},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 12}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT6M25.4026623S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 726,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 225,
#     'TimePlayedAmount': 500.890948819726,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 226474,
#      'Progress': 226486},
#     {'Id': '4fe355fc-eff3-4ec6-878f-5b83fc76bd2f',
#      'PreviousProgress': 1856,
#      'Progress': 1859},
#     {'Id': '1d32707e-9bbc-4cbe-af33-fdc0c8bd64b2',
#      'PreviousProgress': 17422,
#      'Progress': 17423},
#     {'Id': '5b194ecd-b079-4410-acde-ddfac14e6b2e',
#      'PreviousProgress': 1133,
#      'Progress': 1136},
#     {'Id': 'e1203a73-2067-4479-9a47-2abccb0069ae',
#      'PreviousProgress': 21354,
#      'Progress': 21355},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 27119,
#      'Progress': 27121},
#     {'Id': 'af609abb-c6e2-4e97-826f-5aca4fccf70c',
#      'PreviousProgress': 12834,
#      'Progress': 12835}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'SixKnifeWalker', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 6,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT18.0552674S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': 12,
#    'GameEndStatus': 1,
#    'TotalKills': 12,
#    'TotalHeadshots': 0,
#    'TotalWeaponDamage': 1814.9805183410645,
#    'TotalShotsFired': 725,
#    'TotalShotsLanded': 335,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 524558978,
#      'Attachments': []},
#     'TotalShotsFired': 170,
#     'TotalShotsLanded': 136,
#     'TotalHeadshots': 0,
#     'TotalKills': 4,
#     'TotalDamageDealt': 696.9473400115967,
#     'TotalPossessionTime': 'PT1M25.7333S'},
#    'TotalMeleeKills': 2,
#    'TotalMeleeDamage': 206.5999984741211,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 224.92735290527344,
#    'TotalPowerWeaponKills': 6,
#    'TotalPowerWeaponDamage': 657.7058258056641,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT2M31.8166S',
#    'TotalDeaths': 16,
#    'TotalAssists': 3,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT6M25.4026623S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 824733727, 'Count': 1},
#     {'MedalId': 2078758684, 'Count': 1},
#     {'MedalId': 3925170236, 'Count': 1},
#     {'MedalId': 250435527, 'Count': 1},
#     {'MedalId': 2287626681, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 2140505068, 'Attachments': []},
#      'TotalShotsFired': 355,
#      'TotalShotsLanded': 55,
#      'TotalHeadshots': 0,
#      'TotalKills': 3,
#      'TotalDamageDealt': 334.49999237060547,
#      'TotalPossessionTime': 'PT54.8333S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.35S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT4.1333S'},
#     {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT15.25S'},
#     {'WeaponId': {'StockId': 4108759423, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 23.399999618530273,
#      'TotalPossessionTime': 'PT19.9166S'},
#     {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT3.6333S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 206.5999984741211,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT3.7333S'},
#     {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#      'TotalShotsFired': 170,
#      'TotalShotsLanded': 136,
#      'TotalHeadshots': 0,
#      'TotalKills': 4,
#      'TotalDamageDealt': 696.9473400115967,
#      'TotalPossessionTime': 'PT1M25.7333S'},
#     {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.0167S'},
#     {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#      'TotalShotsFired': 162,
#      'TotalShotsLanded': 119,
#      'TotalHeadshots': 0,
#      'TotalKills': 3,
#      'TotalDamageDealt': 323.2058334350586,
#      'TotalPossessionTime': 'PT55.6667S'},
#     {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.4833S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.05S'},
#     {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT6.3833S'},
#     {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#      'TotalShotsFired': 21,
#      'TotalShotsLanded': 9,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 212.0,
#      'TotalPossessionTime': 'PT25.55S'},
#     {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT6.1667S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 10,
#      'TotalShotsLanded': 12,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 224.92735290527344,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 12,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 144,
# ...
#      'TotalPossessionTime': 'PT0.7833S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 12,
#      'TotalShotsLanded': 9,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 69.30000305175781,
#      'TotalPossessionTime': 'PT20.2167S'},
#     {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 8,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 53.5930061340332,
#      'TotalPossessionTime': 'PT35.9333S'},
#     {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT28.8S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0.4833S'},
#     {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 39.417701721191406,
#      'TotalPossessionTime': 'PT12.75S'},
#     {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0.9167S'},
#     {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 115.0,
#      'TotalPossessionTime': 'PT8.35S'},
#     {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 112.97301483154297,
#      'TotalPossessionTime': 'PT12.25S'},
#     {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT23.9S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 11,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT18.6667S'},
#     {'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT3.3833S'},
#     {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT10.0834S'},
#     {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT7.7667S'},
#     {'WeaponId': {'StockId': 669296699, 'Attachments': []},
#      'TotalShotsFired': 13,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 2,
#      'TotalKills': 3,
#      'TotalDamageDealt': 482.6000061035156,
#      'TotalPossessionTime': 'PT1M14.65S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 39,
#      'TotalShotsLanded': 17,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 98.11772918701172,
#      'TotalPossessionTime': 'PT10.45S'},
#     {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 115.0,
#      'TotalPossessionTime': 'PT6.95S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#      'TotalShotsFired': 122,
#      'TotalShotsLanded': 28,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 225.5,
#      'TotalPossessionTime': 'PT35.2833S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.0833S'},
#     {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT12.8833S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 8,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 8,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 150,
#     'SpartanRank': 150,
#     'PrevTotalXP': 27262125,
#     'TotalXP': 27264909,
#     'SpartanRankMatchXPScalar': 2.25,
#     'PlayerTimePerformanceXPAward': 529,
#     'PerformanceXP': 99,
#     'PlayerRankXPAward': 50,
#     'BoostAmount': 559,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 10,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Drymander', 'TotalKills': 2},
#     {'GamerTag': 'SixKnifeWalker', 'TotalKills': 2},
#     {'GamerTag': 'cryptolockerSD', 'TotalKills': 1},
#     {'GamerTag': 'Bophodes', 'TotalKills': 1}],
#    'KilledByOpponentDetails': [{'GamerTag': 'SixKnifeWalker', 'TotalKills': 3},
#     {'GamerTag': 'cryptolockerSD', 'TotalKills': 2},
#     {'GamerTag': 'Bophodes', 'TotalKills': 1},
#     {'GamerTag': 'Drymander', 'TotalKills': 2}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 6},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 3},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 8},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 1},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 1},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 6}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT6M25.4026623S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 751,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 250,
#     'TimePlayedAmount': 500.890948819726,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 54442,
#      'Progress': 54448},
#     {'Id': '0007253f-ac80-4ed8-bfa9-8690a1b49cae',
#      'PreviousProgress': 894,
#      'Progress': 895},
#     {'Id': '6f770f69-62a9-4c8b-a5a8-bcc5d4950492',
#      'PreviousProgress': 2188,
#      'Progress': 2190},
#     {'Id': 'c9bcb904-607f-42ea-acae-4cbdcdf65143',
#      'PreviousProgress': 985,
#      'Progress': 986},
#     {'Id': '07653860-9949-4a12-b341-90c8b9653165',
#      'PreviousProgress': 9181,
#      'Progress': 9182},
#     {'Id': 'ad36d0cd-7e44-49a2-8a2c-c103a38f17d8',
#      'PreviousProgress': 572,
#      'Progress': 573},
#     {'Id': '2eb4257c-9058-46e7-a40f-b9307f3553d9',
#      'PreviousProgress': 1141,
#      'Progress': 1142},
#     {'Id': '3910e201-f2e0-417b-bbc1-8ed0a1fbd442',
#      'PreviousProgress': 466,
#      'Progress': 467},
#     {'Id': '2d5080e0-62ee-42d9-a2dd-364d101832ea',
#      'PreviousProgress': 2288,
#      'Progress': 2289},
#     {'Id': 'd3b6b1ce-c5f0-4cbf-b443-ca76c2917b77',
#      'PreviousProgress': 656,
#      'Progress': 657},
#     {'Id': 'be522e1e-eada-4ec7-aba9-7ee0c0d6732a',
#      'PreviousProgress': 15,
#      'Progress': 16},
#     {'Id': 'a61833aa-b90a-4fa8-83d3-b6a0e94d2866',
#      'PreviousProgress': 1487,
#      'Progress': 1488}],
#    'BoostInfo': {'DefinitionId': '76def815-634a-42cd-b9ca-4c539205b863',
#     'CardConsumed': True},
#    'Player': {'Gamertag': 'Nottheeddu', 'Xuid': None},
#    'TeamId': 0,
#    'Rank': 4,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT41.2234232S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': 6,
#    'GameEndStatus': 3,
#    'TotalKills': 6,
#    'TotalHeadshots': 1,
#    'TotalWeaponDamage': 1161.0823936462402,
#    'TotalShotsFired': 171,
#    'TotalShotsLanded': 74,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 4086418184,
#      'Attachments': []},
#     'TotalShotsFired': 36,
#     'TotalShotsLanded': 19,
#     'TotalHeadshots': 0,
#     'TotalKills': 2,
#     'TotalDamageDealt': 230.0,
#     'TotalPossessionTime': 'PT33.85S'},
#    'TotalMeleeKills': 0,
#    'TotalMeleeDamage': 0.0,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 76.69255065917969,
#    'TotalPowerWeaponKills': 4,
#    'TotalPowerWeaponDamage': 629.1523475646973,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT3M19.3999S',
#    'TotalDeaths': 8,
#    'TotalAssists': 3,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT6M25.4026623S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 3001183151, 'Count': 1},
#     {'MedalId': 3400287617, 'Count': 1},
#     {'MedalId': 370413844, 'Count': 1},
#     {'MedalId': 2782465081, 'Count': 1},
#     {'MedalId': 2494364276, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#      'TotalShotsFired': 6,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 153.1733741760254,
#      'TotalPossessionTime': 'PT14.1833S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.5833S'},
#     {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.15S'},
#     {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#      'TotalShotsFired': 32,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 32.069725036621094,
#      'TotalPossessionTime': 'PT15.4S'},
#     {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#      'TotalShotsFired': 36,
#      'TotalShotsLanded': 19,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 230.0,
#      'TotalPossessionTime': 'PT33.85S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 36,
#      'TotalShotsLanded': 12,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 90.0,
#      'TotalPossessionTime': 'PT33.9333S'},
#     {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#      'TotalShotsFired': 5,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 118.0,
#      'TotalPossessionTime': 'PT26.0333S'},
#     {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.1833S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.2667S'},
#     {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.05S'},
#     {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 80.0,
#      'TotalPossessionTime': 'PT15.2833S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 8,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 1,
#      'TotalKills': 1,
#      'TotalDamageDealt': 132.2375030517578,
#      'TotalPossessionTime': 'PT32.9833S'},
#     {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 2.0269851684570312,
#      'TotalPossessionTime': 'PT34.3167S'},
#     {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 131.88226318359375,
#      'TotalPossessionTime': 'PT1M5.6833S'},
#     {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT16.55S'},
#     {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#      'TotalShotsFired': 24,
#      'TotalShotsLanded': 10,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 114.99999237060547,
#      'TotalPossessionTime': 'PT33.6S'},
#     {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0.75S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 7,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 76.69255065917969,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [{'Id': 3174430457, 'Count': 1}],
#    'TotalSpartanKills': 6,
#    'FastestMatchWin': None}],
#  'TeamStats': [{'TeamId': 0,
#    'Score': 50,
#    'Rank': 1,
#    'RoundStats': [{'RoundNumber': 1, 'Rank': 1, 'Score': 50}]},
#   {'TeamId': 1,
#    'Score': 39,
#    'Rank': 2,
#    'RoundStats': [{'RoundNumber': 1, 'Rank': 2, 'Score': 39}]}],
#  'IsMatchOver': True,
#  'TotalDuration': 'PT6M25.4056637S',
#  'MapVariantId': '6b306cc8-1d60-41ae-9e95-464fdbe1288b',
#  'GameVariantId': '706e4bb2-ff9b-4e64-81b9-a0c15e536a30',
#  'PlaylistId': 'f0c9ef9a-48bd-4b24-9db3-2c76b4e23450',
#  'MapId': 'caacb800-f206-11e4-81ab-24be05e24f7e',
#  'GameBaseVariantId': '257a305e-4dd3-41f1-9824-dfe7e8bd59e1',
#  'IsTeamGame': True,
#  'SeasonId': '',
#  'GameVariantResourceId': {'ResourceType': 2,
#   'ResourceId': '706e4bb2-ff9b-4e64-81b9-a0c15e536a30',
#   'OwnerType': 3,
#   'Owner': ''},
#  'MapVariantResourceId': {'ResourceType': 3,
#   'ResourceId': '6b306cc8-1d60-41ae-9e95-464fdbe1288b',
#   'OwnerType': 3,
#   'Owner': ''},
#  'MatchId': '2eecaf00-ba9f-432e-b144-bc1c90b29430',
#  'Date': '2021-07-22T21:00:59.258Z'}

# %%
# Function to build the base dataframe for a single match
# Designed to take in the JSON provided by the pull_recent_match function
def build_base_dataframe(match_results, gamertag):
    
    # Build empty base match dataframe
    df = pd.DataFrame()
    columns = [
        'Finished'
        'TeamId',
        'Gamertag',
        'SpartanRank',
        'PrevTotalXP',
    ]
    df = pd.DataFrame(columns = columns)
    
    # Populate base match dataframe with player stats for each player
    i = 0
    for player in match_results['PlayerStats']:

        player_dic = {}
        # Team ID
        player_dic['DNF'] = match_results['PlayerStats'][i]['DNF']
        player_dic['TeamId'] = match_results['PlayerStats'][i]['TeamId']
        # Team Color
        player_dic['TeamColor'] = match_results['PlayerStats'][i]['TeamId']
        # Gamer Tag
        player_dic['Gamertag'] = match_results['PlayerStats'][i]['Player']['Gamertag']
        # Spartan Rank
        player_dic['SpartanRank'] = match_results['PlayerStats'][i]['XpInfo']['SpartanRank']
        # Previous Total XP
        player_dic['PrevTotalXP'] = match_results['PlayerStats'][i]['XpInfo']['PrevTotalXP']
        df = df.append(player_dic, ignore_index=True)
        i += 1
    
    ########## DATE, GAME VARIANT, MAP ID, MATCH ID, PLAYLIST ID ##########
    df['Date'] = match_results['Date']
    df['Date'] = pd.to_datetime(df['Date']).dt.tz_convert(None)
#     df['Date'] = df['Date'].floor('T')
    df['MatchId'] = match_results['MatchId']
    df['GameBaseVariantId'] = match_results['GameBaseVariantId']
    df['MapVariantId'] = match_results['MapVariantId']
    df['PlaylistId'] = match_results['PlaylistId']
    
    ########## DEFINE PLAYER TEAM ##########
    playerteam = df.loc[df['Gamertag'] == gamertag, 'TeamId'].values[0]
    if playerteam == 0:
        enemyteam = 1   
    else:
        enemyteam = 0
        
    df['PlayerTeam'] = df['TeamId'].map({playerteam:'Player', enemyteam:'Enemy'})
    
    if match_results['TeamStats'][0]['TeamId'] == playerteam:
        playerteam_stats = match_results['TeamStats'][0]
        enemyteam_stats = match_results['TeamStats'][1]
    else: 
        playerteam_stats = match_results['TeamStats'][1]
        enemyteam_stats = match_results['TeamStats'][0]
    
    ########## DETERMINE WINNER ##########
    # Tie
    if playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 1:
        df['Winner'] = 'Tie'
    # Player wins
    elif playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 2:
        df['Winner'] = df['TeamId'].map({playerteam:'Victory', enemyteam:'Defeat'})
    # Enemy wins
    elif playerteam_stats['Rank'] == 2 and enemyteam_stats['Rank'] == 1:
        df['Winner'] = df['TeamId'].map({enemyteam:'Victory', playerteam:'Defeat'})
    # Error handling
    else:
        winner = 'Error determining winner'
    
    ########## TEAM COLOR ##########
    df['TeamColor'] = df['TeamId'].map({0:'Red', 1:'Blue'})
    
    # Set columns
    df = df[['Date', 'MatchId', 'GameBaseVariantId', 'PlaylistId', 'MapVariantId', 'DNF',
             'TeamId', 'PlayerTeam', 'Winner', 'TeamColor', 
             'Gamertag', 'SpartanRank', 'PrevTotalXP',
            ]]
    # Sort match by winning team
    df = df.sort_values(by=['Winner'], ascending=False)
    
    return df

df = build_base_dataframe(pull_recent_match(8), 'Drymander')

df
# Out:
#                      Date                               MatchId  \
# 1 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 2 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 3 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 4 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 8 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 0 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 5 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 6 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
# 7 2021-07-22 19:57:51.588  829493b0-9eb4-4c07-a0b1-e5c7d2c33159
#
#                       GameBaseVariantId                            PlaylistId  \
# 1  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 2  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 3  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 4  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 8  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 5  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 6  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 7  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
#
#                            MapVariantId  DNF  TeamId PlayerTeam   Winner  \
# 1  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     1.0     Player  Victory
# 2  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     1.0     Player  Victory
# 3  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  1.0     1.0     Player  Victory
# 4  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     1.0     Player  Victory
# 8  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     1.0     Player  Victory
# 0  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     0.0      Enemy   Defeat
# 5  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     0.0      Enemy   Defeat
# 6  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     0.0      Enemy   Defeat
# 7  e669aabf-1a6f-4b77-b79c-e9c03a1fbb54  0.0     0.0      Enemy   Defeat
#
#   TeamColor         Gamertag SpartanRank PrevTotalXP
# 1      Blue         er0sking         150    33709649
# 2      Blue      ANuNNaKI Vs          50      844650
# 3      Blue  S H I N I N MEX          49      792836
# 4      Blue        Drymander         148    15522876
# 8      Blue    CDAxXB4RD0KXx          94     2862704
# 0       Red  LiLmeFromDaFutr         150    27622353
# 5       Red     JubiPrincess          75     1869267
# 6       Red       maneth 007         146    10332365
# 7       Red  BeardedDirdMirm         150    33032060

# %%
# Function to combine all gamertags from the match and prepare them in string
# format for the next API call
def get_player_list(df):
    
    # Create list from our df['Gamertag'] column and remove the brackets
    player_list = str(list(df['Gamertag']))[1:-1]
    
    # Format string for API
    player_list = player_list.replace(', ',',')
    player_list = player_list.replace("'",'')
    player_list = player_list.replace(' ','+')
    
    # Return in one full string
    return player_list

get_player_list(df)
# Out:
# 'er0sking,ANuNNaKI+Vs,S+H+I+N+I+N+MEX,Drymander,CDAxXB4RD0KXx,LiLmeFromDaFutr,JubiPrincess,maneth+007,BeardedDirdMirm'

# %%
# Function to pull more informative information about each player in the match
# This information is not available in the two previous API calls
def get_player_history(df, readable=False):
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': str(api_key),
    }
    params = urllib.parse.urlencode({
    })
    # Use our function in the block above the prepare the gamertags for the API
    player_list_api = get_player_list(df)
    
    # Try calling service records API using our player list
    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/servicerecords/arena?players={player_list_api}&%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        player_history = json.loads(data)
        conn.close()
    
    # Return error if issue with API
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    # Option to view in byte string readable format
    if readable == False:
        return player_history
    else:
        return data

# Show result
player_history = get_player_history(df)
player_history
# Out:
# {'Results': [{'Id': 'er0sking',
#    'ResultCode': 0,
#    'Result': {'ArenaStats': {'ArenaPlaylistStats': [],
#      'HighestCsrAttained': {'Tier': 5,
#       'DesignationId': 4,
#       'Csr': 0,
#       'PercentToNextTier': 0,
#       'Rank': None},
#      'ArenaGameBaseVariantStats': [{'FlexibleStats': {'MedalStatCounts': [{'Id': '2b151d0f-cde6-4471-9f1d-d0f8e8644471',
#           'Count': 205},
#          {'Id': 'f0d50d01-6197-4d0d-a3a5-a86110997e40', 'Count': 100},
#          {'Id': 'dcd5ff64-4b49-4020-96d0-88ba3fb28a56', 'Count': 125},
#          {'Id': '74365be9-d515-4229-9561-bfaac5bab089', 'Count': 113}],
#         'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#           'Count': 542},
#          {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 209},
#          {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 406},
#          {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 28}],
#         'MedalTimelapses': [],
#         'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#           'Timelapse': 'PT5H9M15.1211669S'}]},
#        'GameBaseVariantId': '1571fdac-e0b4-4ebc-a73a-6e13001b71d3',
#        'TotalKills': 543,
#        'TotalHeadshots': 234,
#        'TotalWeaponDamage': 62957.174944877625,
#        'TotalShotsFired': 10842,
#        'TotalShotsLanded': 4737,
#        'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#          'Attachments': []},
#         'TotalShotsFired': 3909,
#         'TotalShotsLanded': 1817,
#         'TotalHeadshots': 188,
#         'TotalKills': 237,
#         'TotalDamageDealt': 32230.083792686462,
#         'TotalPossessionTime': 'PT2H8M13.549S'},
#        'TotalMeleeKills': 37,
#        'TotalMeleeDamage': 4765.384586811066,
#        'TotalAssassinations': 4,
#        'TotalGroundPoundKills': 3,
#        'TotalGroundPoundDamage': 95.0,
#        'TotalShoulderBashKills': 1,
#        'TotalShoulderBashDamage': 95.0,
#        'TotalGrenadeDamage': 514.3270883560181,
#        'TotalPowerWeaponKills': 39,
#        'TotalPowerWeaponDamage': 5461.777580738068,
#        'TotalPowerWeaponGrabs': 21,
#        'TotalPowerWeaponPossessionTime': 'PT13M33.9836S',
#        'TotalDeaths': 406,
#        'TotalAssists': 209,
#        'TotalGamesCompleted': 48,
#        'TotalGamesWon': 20,
#        'TotalGamesLost': 28,
#        'TotalGamesTied': 0,
#        'TotalTimePlayed': 'PT5H9M15.1211669S',
#        'TotalGrenadeKills': 44,
#        'MedalAwards': [{'MedalId': 1637841390, 'Count': 54},
#         {'MedalId': 3565443938, 'Count': 205},
#         {'MedalId': 1351381581, 'Count': 125},
#         {'MedalId': 3261908037, 'Count': 194},
#         {'MedalId': 3001183151, 'Count': 17},
#         {'MedalId': 2916014239, 'Count': 100},
#         {'MedalId': 2105198095, 'Count': 113},
#         {'MedalId': 2838259753, 'Count': 27},
#         {'MedalId': 824733727, 'Count': 20},
#         {'MedalId': 3653057799, 'Count': 21},
#         {'MedalId': 2078758684, 'Count': 38},
#         {'MedalId': 1080468863, 'Count': 5},
#         {'MedalId': 3698887726, 'Count': 3},
#         {'MedalId': 2494364276, 'Count': 5},
#         {'MedalId': 3400287617, 'Count': 34},
#         {'MedalId': 2430242797, 'Count': 16},
#         {'MedalId': 2251767925, 'Count': 1},
#         {'MedalId': 2782465081, 'Count': 12},
#         {'MedalId': 2287626681, 'Count': 31},
#         {'MedalId': 2896365521, 'Count': 6},
#         {'MedalId': 285057226, 'Count': 7},
#         {'MedalId': 250435527, 'Count': 6},
#         {'MedalId': 3354395650, 'Count': 8},
#         {'MedalId': 2564994165, 'Count': 2},
#         {'MedalId': 492192256, 'Count': 3},
#         {'MedalId': 2966496172, 'Count': 1},
#         {'MedalId': 3270120991, 'Count': 3},
#         {'MedalId': 2766284219, 'Count': 2},
#         {'MedalId': 2683910456, 'Count': 7},
#         {'MedalId': 194124164, 'Count': 1},
#         {'MedalId': 2366628262, 'Count': 4},
#         {'MedalId': 2763748638, 'Count': 3},
#         {'MedalId': 370413844, 'Count': 2},
#         {'MedalId': 298813630, 'Count': 1},
#         {'MedalId': 3744028405, 'Count': 1},
#         {'MedalId': 2531822079, 'Count': 1},
#         {'MedalId': 515648662, 'Count': 1}],
#        'DestroyedEnemyVehicles': [{'Enemy': {'BaseId': 1063919886,
#           'Attachments': []},
#          'TotalKills': 1}],
#        'EnemyKills': [],
#        'WeaponStats': [{'WeaponId': {'StockId': 313138863, 'Attachments': []},
#          'TotalShotsFired': 4045,
#          'TotalShotsLanded': 1614,
#          'TotalHeadshots': 0,
#          'TotalKills': 96,
#          'TotalDamageDealt': 12300.868403434753,
#          'TotalPossessionTime': 'PT40M53.8987S'},
#         {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#          'TotalShotsFired': 819,
#          'TotalShotsLanded': 291,
#          'TotalHeadshots': 0,
#          'TotalKills': 17,
#          'TotalDamageDealt': 2266.1174659729004,
#          'TotalPossessionTime': 'PT5M51.0329S'},
#         {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#          'TotalShotsFired': 48,
#          'TotalShotsLanded': 13,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 161.2256851196289,
#          'TotalPossessionTime': 'PT33.0334S'},
#         {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#          'TotalShotsFired': 3909,
#          'TotalShotsLanded': 1817,
#          'TotalHeadshots': 188,
#          'TotalKills': 237,
#          'TotalDamageDealt': 32230.083792686462,
#          'TotalPossessionTime': 'PT2H8M13.549S'},
#         {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#          'TotalShotsFired': 64,
#          'TotalShotsLanded': 20,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 203.3333282470703,
#          'TotalPossessionTime': 'PT1M20.1833S'},
#         {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#          'TotalShotsFired': 222,
#          'TotalShotsLanded': 106,
#          'TotalHeadshots': 8,
#          'TotalKills': 13,
#          'TotalDamageDealt': 2073.6912603378296,
#          'TotalPossessionTime': 'PT5M41.8999S'},
#         {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#          'TotalShotsFired': 45,
#          'TotalShotsLanded': 35,
#          'TotalHeadshots': 0,
#          'TotalKills': 41,
#          'TotalDamageDealt': 479.5856065750122,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#          'TotalShotsFired': 43,
#          'TotalShotsLanded': 32,
#          'TotalHeadshots': 3,
#          'TotalKills': 20,
#          'TotalDamageDealt': 2366.3747749328613,
#          'TotalPossessionTime': 'PT5M57.2666S'},
#         {'WeaponId': {'StockId': 4108759423, 'Attachments': []},
#          'TotalShotsFired': 89,
#          'TotalShotsLanded': 45,
#          'TotalHeadshots': 6,
#          'TotalKills': 6,
#          'TotalDamageDealt': 584.5549468994141,
#          'TotalPossessionTime': 'PT1M46.85S'},
#         {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#          'TotalShotsFired': 1025,
#          'TotalShotsLanded': 514,
#          'TotalHeadshots': 26,
#          'TotalKills': 29,
#          'TotalDamageDealt': 4351.029806137085,
#          'TotalPossessionTime': 'PT15M2.4999S'},
#         {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#          'TotalShotsFired': 35,
#          'TotalShotsLanded': 3,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 34.74148178100586,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#          'TotalShotsFired': 2,
#          'TotalShotsLanded': 2,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 45,
#          'TotalDamageDealt': 4955.384586811066,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#          'TotalShotsFired': 88,
#          'TotalShotsLanded': 34,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 368.5999984741211,
#          'TotalPossessionTime': 'PT1M3.6001S'},
#         {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#          'TotalShotsFired': 86,
#          'TotalShotsLanded': 33,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 440.206506729126,
#          'TotalPossessionTime': 'PT1M32.0667S'},
#         {'WeaponId': {'StockId': 2492868984, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT26.2327S'},
#         {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#          'TotalShotsFired': 46,
#          'TotalShotsLanded': 28,
#          'TotalHeadshots': 3,
#          'TotalKills': 5,
#          'TotalDamageDealt': 716.7156982421875,
#          'TotalPossessionTime': 'PT1M25.3334S'},
#         {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#          'TotalShotsFired': 14,
#          'TotalShotsLanded': 9,
#          'TotalHeadshots': 0,
#          'TotalKills': 3,
#          'TotalDamageDealt': 496.68017578125,
#          'TotalPossessionTime': 'PT1M22.7167S'},
#         {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#          'TotalShotsFired': 12,
#          'TotalShotsLanded': 4,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 224.0556640625,
#          'TotalPossessionTime': 'PT24.9833S'},
#         {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#          'TotalShotsFired': 167,
#          'TotalShotsLanded': 87,
#          'TotalHeadshots': 0,
#          'TotalKills': 4,
#          'TotalDamageDealt': 669.0957870483398,
#          'TotalPossessionTime': 'PT1M2.9668S'},
#         {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#          'TotalShotsFired': 60,
#          'TotalShotsLanded': 28,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 1749.6696782112122,
#          'TotalPossessionTime': 'PT3M58.4834S'},
#         {'WeaponId': {'StockId': 47178948, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 5,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 1609865982, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT5M58.7334S'},
#         {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#          'TotalShotsFired': 23,
#          'TotalShotsLanded': 22,
#          'TotalHeadshots': 0,
#          'TotalKills': 7,
#          'TotalDamageDealt': 1104.1389870643616,
#          'TotalPossessionTime': 'PT2M40.9501S'},
#         {'WeaponId': {'StockId': 1063919886, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 136.40589714050293,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT9.8333S'}],
#        'Impulses': [{'Id': 1408036107, 'Count': 8},
#         {'Id': 2556889090, 'Count': 27},
#         {'Id': 3174430457, 'Count': 28}],
#        'TotalSpartanKills': 542,
#        'FastestMatchWin': 'PT45.1407115S'},
#       {'FlexibleStats': {'MedalStatCounts': [{'Id': '10d1690e-9820-4d98-a7a6-361173370f40',
#           'Count': 0},
#          {'Id': 'f2d6cbeb-fbf6-44d5-b321-9edb8cb2e3bc', 'Count': 1}],
#         'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#           'Count': 38},
#          {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 28},
#          {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 29},
#          {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 1},
#          {'Id': '7cda10c8-04c4-4916-8d6e-71a426a61de8', 'Count': 1},
#          {'Id': '6e1e4e2c-1a57-4f64-a893-f594974b3f1f', 'Count': 0},
#          {'Id': '5262f1d7-4273-48c3-8d2f-edfcb36a1617', 'Count': 4},
#          {'Id': '53ea3e8c-ac2a-4644-b6e2-4ac45e721cca', 'Count': 16},
#          {'Id': 'ded6e97f-575a-4511-833b-62bf5489a2c1', 'Count': 27},
#          {'Id': 'f12a007b-3f27-45a1-87f5-816b6aca060d', 'Count': 0}],
#         'MedalTimelapses': [],
#         'ImpulseTimelapses': [{'Id': 'a3fd8c22-a921-4662-a92b-1f7e965df8fd',
#           'Timelapse': 'PT44.7385289S'},
#          {'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#           'Timelapse': 'PT1H15M25.3571249S'}]},
#        'GameBaseVariantId': '1e473914-46e4-408d-af26-178fb115de76',
#        'TotalKills': 51,
#        'TotalHeadshots': 1,
#        'TotalWeaponDamage': 11436.118502616882,
#        'TotalShotsFired': 2114,
#        'TotalShotsLanded': 751,
#        'WeaponWithMostKills': {'WeaponId': {'StockId': 3227919741,
#          'Attachments': []},
#         'TotalShotsFired': 1555,
#         'TotalShotsLanded': 631,
#         'TotalHeadshots': 0,
#         'TotalKills': 22,
#         'TotalDamageDealt': 7575.422630310059,
#         'TotalPossessionTime': 'PT7M31.5S'},
#        'TotalMeleeKills': 0,
#        'TotalMeleeDamage': 0.0,
#        'TotalAssassinations': 0,
#        'TotalGroundPoundKills': 0,
#        'TotalGroundPoundDamage': 0.0,
#        'TotalShoulderBashKills': 0,
#        'TotalShoulderBashDamage': 0.0,
#        'TotalGrenadeDamage': 99.87366580963135,
#        'TotalPowerWeaponKills': 0,
#        'TotalPowerWeaponDamage': 0.0,
#        'TotalPowerWeaponGrabs': 0,
#        'TotalPowerWeaponPossessionTime': 'PT25.6334S',
#        'TotalDeaths': 29,
#        'TotalAssists': 28,
#        'TotalGamesCompleted': 23,
#        'TotalGamesWon': 11,
#        'TotalGamesLost': 12,
#        'TotalGamesTied': 0,
#        'TotalTimePlayed': 'PT1H15M25.3571249S',
#        'TotalGrenadeKills': 3,
#        'MedalAwards': [{'MedalId': 2078758684, 'Count': 1},
#         {'MedalId': 2782465081, 'Count': 1},
#         {'MedalId': 1494478183, 'Count': 1},
#         {'MedalId': 3886151616, 'Count': 1},
#         {'MedalId': 3261908037, 'Count': 1},
#         {'MedalId': 824733727, 'Count': 1},
#         {'MedalId': 3392925967, 'Count': 1},
#         {'MedalId': 35545941, 'Count': 2},
#         {'MedalId': 68187090, 'Count': 1},
#         {'MedalId': 3440416044, 'Count': 12},
#         {'MedalId': 615190505, 'Count': 11},
#         {'MedalId': 1212900805, 'Count': 3},
#         {'MedalId': 2421706731, 'Count': 1},
#         {'MedalId': 1326375333, 'Count': 1},
#         {'MedalId': 3698887726, 'Count': 1},
#         {'MedalId': 979431049, 'Count': 1}],
#        'DestroyedEnemyVehicles': [{'Enemy': {'BaseId': 1730553442,
#           'Attachments': []},
#          'TotalKills': 2},
#         {'Enemy': {'BaseId': 3227919741, 'Attachments': []},
#          'TotalKills': 11}],
#        'EnemyKills': [],
#        'WeaponStats': [{'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#          'TotalShotsFired': 52,
#          'TotalShotsLanded': 18,
#          'TotalHeadshots': 1,
#          'TotalKills': 2,
#          'TotalDamageDealt': 341.4499969482422,
#          'TotalPossessionTime': 'PT2M50.0333S'},
#         {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#          'TotalShotsFired': 200,
#          'TotalShotsLanded': 50,
#          'TotalHeadshots': 0,
#          'TotalKills': 3,
#          'TotalDamageDealt': 377.2500333786011,
#          'TotalPossessionTime': 'PT3M50.8501S'},
#         {'WeaponId': {'StockId': 2244200496, 'Attachments': []},
#          'TotalShotsFired': 2,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT41.7167S'},
#         {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#          'TotalShotsFired': 23,
#          'TotalShotsLanded': 9,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 165.6324920654297,
#          'TotalPossessionTime': 'PT1M11.8333S'},
#         {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#          'TotalShotsFired': 2,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT25.6334S'},
#         {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#          'TotalShotsFired': 30,
#          'TotalShotsLanded': 10,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 52.12366580963135,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#          'TotalShotsFired': 24,
#          'TotalShotsLanded': 5,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 47.75,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#          'TotalShotsFired': 11,
#          'TotalShotsLanded': 4,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 40.21083450317383,
#          'TotalPossessionTime': 'PT17.4834S'},
#         {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#          'TotalShotsFired': 195,
#          'TotalShotsLanded': 11,
#          'TotalHeadshots': 0,
#          'TotalKills': 15,
#          'TotalDamageDealt': 49.50001049041748,
#          'TotalPossessionTime': 'PT9M34.6001S'},
#         {'WeaponId': {'StockId': 1730553442, 'Attachments': []},
#          'TotalShotsFired': 20,
#          'TotalShotsLanded': 13,
#          'TotalHeadshots': 0,
#          'TotalKills': 4,
#          'TotalDamageDealt': 2786.778839111328,
#          'TotalPossessionTime': 'PT7M17.35S'},
#         {'WeaponId': {'StockId': 3227919741, 'Attachments': []},
#          'TotalShotsFired': 1555,
#          'TotalShotsLanded': 631,
#          'TotalHeadshots': 0,
#          'TotalKills': 22,
#          'TotalDamageDealt': 7575.422630310059,
#          'TotalPossessionTime': 'PT7M31.5S'}],
#        'Impulses': [{'Id': 4191318012, 'Count': 18},
#         {'Id': 1039658009, 'Count': 3},
#         {'Id': 3435524855, 'Count': 17},
#         {'Id': 540014008, 'Count': 25},
#         {'Id': 3060032974, 'Count': 27},
#         {'Id': 415845940, 'Count': 3},
#         {'Id': 2944278681, 'Count': 1},
#         {'Id': 3930101026, 'Count': 4},
#         {'Id': 938151029, 'Count': 2},
#         {'Id': 2512065773, 'Count': 16},
#         {'Id': 1408036107, 'Count': 3}],
#        'TotalSpartanKills': 38,
#        'FastestMatchWin': 'PT3M2.8270309S'},
#       {'FlexibleStats': {'MedalStatCounts': [],
#         'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#           'Count': 3278},
#          {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 1197},
#          {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 2232},
#          {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 26},
#          {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 1047},
#          {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 132},
#          {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 163},
#          {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 83},
#          {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#         'MedalTimelapses': [],
#         'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#           'Timelapse': 'P1DT12H17M59.1048303S'}]},
#        'GameBaseVariantId': '257a305e-4dd3-41f1-9824-dfe7e8bd59e1',
#        'TotalKills': 3328,
#        'TotalHeadshots': 1047,
#        'TotalWeaponDamage': 519613.2600509692,
#        'TotalShotsFired': 97033,
#        'TotalShotsLanded': 33152,
#        'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#          'Attachments': []},
#         'TotalShotsFired': 8252,
#         'TotalShotsLanded': 3940,
#         'TotalHeadshots': 340,
#         'TotalKills': 435,
#         'TotalDamageDealt': 71070.99071025848,
#         'TotalPossessionTime': 'PT5H8M24.9162S'},
#        'TotalMeleeKills': 90,
#        'TotalMeleeDamage': 13453.024040699005,
#        'TotalAssassinations': 28,
#        'TotalGroundPoundKills': 20,
#        'TotalGroundPoundDamage': 1559.509256362915,
#        'TotalShoulderBashKills': 5,
#        'TotalShoulderBashDamage': 363.50000381469727,
#        'TotalGrenadeDamage': 21867.154071837664,
#        'TotalPowerWeaponKills': 1608,
#        'TotalPowerWeaponDamage': 266264.97832069173,
#        'TotalPowerWeaponGrabs': 83,
#        'TotalPowerWeaponPossessionTime': 'PT14H19M47.0159S',
#        'TotalDeaths': 2232,
#        'TotalAssists': 1197,
#        'TotalGamesCompleted': 265,
#        'TotalGamesWon': 145,
#        'TotalGamesLost': 120,
#        'TotalGamesTied': 0,
#        'TotalTimePlayed': 'P1DT12H17M59.1048303S',
#        'TotalGrenadeKills': 138,
#        'MedalAwards': [{'MedalId': 2078758684, 'Count': 250},
#         {'MedalId': 824733727, 'Count': 146},
#         {'MedalId': 3261908037, 'Count': 676},
#         {'MedalId': 2838259753, 'Count': 136},
#         {'MedalId': 2430242797, 'Count': 141},
#         {'MedalId': 3400287617, 'Count': 178},
#         {'MedalId': 1080468863, 'Count': 26},
#         {'MedalId': 848240062, 'Count': 137},
#         {'MedalId': 2977773352, 'Count': 11},
#         {'MedalId': 3522125871, 'Count': 17},
#         {'MedalId': 298813630, 'Count': 5},
#         {'MedalId': 3744028405, 'Count': 14},
#         {'MedalId': 3270120991, 'Count': 21},
#         {'MedalId': 2287626681, 'Count': 61},
#         {'MedalId': 2108880282, 'Count': 1},
#         {'MedalId': 3486286344, 'Count': 16},
#         {'MedalId': 2564994165, 'Count': 8},
#         {'MedalId': 3491849182, 'Count': 6},
#         {'MedalId': 3098362934, 'Count': 13},
#         {'MedalId': 2782465081, 'Count': 37},
#         {'MedalId': 2251767925, 'Count': 20},
#         {'MedalId': 466059351, 'Count': 31},
#         {'MedalId': 1986137636, 'Count': 16},
#         {'MedalId': 492192256, 'Count': 20},
#         {'MedalId': 285057226, 'Count': 50},
#         {'MedalId': 2077162827, 'Count': 1},
#         {'MedalId': 3148489433, 'Count': 5},
#         {'MedalId': 2763748638, 'Count': 19},
#         {'MedalId': 1691836029, 'Count': 8},
#         {'MedalId': 194124164, 'Count': 6},
#         {'MedalId': 3001183151, 'Count': 25},
#         {'MedalId': 3653057799, 'Count': 61},
#         {'MedalId': 250435527, 'Count': 23},
#         {'MedalId': 2683910456, 'Count': 14},
#         {'MedalId': 352859864, 'Count': 27},
#         {'MedalId': 3786961025, 'Count': 1},
#         {'MedalId': 2494364276, 'Count': 6},
#         {'MedalId': 370413844, 'Count': 11},
#         {'MedalId': 2766284219, 'Count': 4},
#         {'MedalId': 2966496172, 'Count': 7},
#         {'MedalId': 4252521258, 'Count': 10},
#         {'MedalId': 1792284502, 'Count': 2},
#         {'MedalId': 3925170236, 'Count': 144},
#         {'MedalId': 876932011, 'Count': 60},
#         {'MedalId': 2366628262, 'Count': 28},
#         {'MedalId': 2093481574, 'Count': 1},
#         {'MedalId': 2279899989, 'Count': 16},
#         {'MedalId': 1326375333, 'Count': 18},
#         {'MedalId': 2707871298, 'Count': 3},
#         {'MedalId': 1618319591, 'Count': 2},
#         {'MedalId': 3698887726, 'Count': 4},
#         {'MedalId': 1259067733, 'Count': 2},
#         {'MedalId': 882267095, 'Count': 11},
#         {'MedalId': 2462002800, 'Count': 1},
#         {'MedalId': 685960231, 'Count': 1},
#         {'MedalId': 762229696, 'Count': 5},
#         {'MedalId': 3865042769, 'Count': 3},
#         {'MedalId': 2497544753, 'Count': 15},
#         {'MedalId': 651116095, 'Count': 6},
#         {'MedalId': 4048801324, 'Count': 10},
#         {'MedalId': 515648662, 'Count': 1},
#         {'MedalId': 3824002610, 'Count': 12},
#         {'MedalId': 35545941, 'Count': 4},
#         {'MedalId': 1568252876, 'Count': 4},
#         {'MedalId': 281002471, 'Count': 2},
#         {'MedalId': 2732907792, 'Count': 1},
#         {'MedalId': 786413504, 'Count': 17},
#         {'MedalId': 3392925967, 'Count': 6},
#         {'MedalId': 1219497744, 'Count': 3},
#         {'MedalId': 4204396686, 'Count': 7},
#         {'MedalId': 615190505, 'Count': 4},
#         {'MedalId': 3676723563, 'Count': 10},
#         {'MedalId': 1801925525, 'Count': 3},
#         {'MedalId': 92444561, 'Count': 6},
#         {'MedalId': 1423504140, 'Count': 5},
#         {'MedalId': 2237392606, 'Count': 1},
#         {'MedalId': 3992195104, 'Count': 5},
#         {'MedalId': 3440416044, 'Count': 2},
#         {'MedalId': 125834251, 'Count': 1},
#         {'MedalId': 1711392399, 'Count': 2},
#         {'MedalId': 2016270491, 'Count': 1}],
#        'DestroyedEnemyVehicles': [{'Enemy': {'BaseId': 419783896,
#           'Attachments': [1751251319]},
#          'TotalKills': 5},
#         {'Enemy': {'BaseId': 3010146366, 'Attachments': [2217709794]},
#          'TotalKills': 15},
#         {'Enemy': {'BaseId': 1063919886, 'Attachments': [2217709794]},
#          'TotalKills': 1},
#         {'Enemy': {'BaseId': 1730553442, 'Attachments': []}, 'TotalKills': 4},
#         {'Enemy': {'BaseId': 1206711506, 'Attachments': [512832729]},
#          'TotalKills': 2},
#         {'Enemy': {'BaseId': 1206711506, 'Attachments': [521254352]},
#          'TotalKills': 2},
#         {'Enemy': {'BaseId': 3227919741, 'Attachments': []}, 'TotalKills': 4},
#         {'Enemy': {'BaseId': 4028516791, 'Attachments': [2217709794]},
#          'TotalKills': 6}],
#        'EnemyKills': [],
#        'WeaponStats': [{'WeaponId': {'StockId': 313138863, 'Attachments': []},
#          'TotalShotsFired': 4184,
#          'TotalShotsLanded': 1583,
#          'TotalHeadshots': 0,
#          'TotalKills': 82,
#          'TotalDamageDealt': 12128.49369764328,
#          'TotalPossessionTime': 'PT1H13M28.0671S'},
#         {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#          'TotalShotsFired': 8252,
#          'TotalShotsLanded': 3940,
#          'TotalHeadshots': 340,
#          'TotalKills': 435,
#          'TotalDamageDealt': 71070.99071025848,
#          'TotalPossessionTime': 'PT5H8M24.9162S'},
#         {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#          'TotalShotsFired': 7119,
#          'TotalShotsLanded': 3196,
#          'TotalHeadshots': 166,
#          'TotalKills': 199,
#          'TotalDamageDealt': 26719.5339884758,
#          'TotalPossessionTime': 'PT1H48M14.3004S'},
#         {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#          'TotalShotsFired': 2027,
#          'TotalShotsLanded': 997,
#          'TotalHeadshots': 93,
#          'TotalKills': 130,
#          'TotalDamageDealt': 20122.03765642643,
#          'TotalPossessionTime': 'PT1H17M12.3665S'},
#         {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#          'TotalShotsFired': 816,
#          'TotalShotsLanded': 294,
#          'TotalHeadshots': 0,
#          'TotalKills': 24,
#          'TotalDamageDealt': 3876.300820350647,
#          'TotalPossessionTime': 'PT16M58.4329S'},
#         {'WeaponId': {'StockId': 723523180, 'Attachments': []},
#          'TotalShotsFired': 533,
#          'TotalShotsLanded': 345,
#          'TotalHeadshots': 0,
#          'TotalKills': 139,
#          'TotalDamageDealt': 18766.464545607567,
#          'TotalPossessionTime': 'PT48M42.5998S'},
#         {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#          'TotalShotsFired': 2759,
#          'TotalShotsLanded': 947,
#          'TotalHeadshots': 0,
#          'TotalKills': 45,
#          'TotalDamageDealt': 6688.269163131714,
#          'TotalPossessionTime': 'PT31M12.7668S'},
#         {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#          'TotalShotsFired': 1377,
#          'TotalShotsLanded': 569,
#          'TotalHeadshots': 0,
#          'TotalKills': 33,
#          'TotalDamageDealt': 4001.2458715438843,
#          'TotalPossessionTime': 'PT18M38.4668S'},
#         {'WeaponId': {'StockId': 669296699, 'Attachments': []},
#          'TotalShotsFired': 602,
#          'TotalShotsLanded': 256,
#          'TotalHeadshots': 83,
#          'TotalKills': 121,
#          'TotalDamageDealt': 20396.845386505127,
#          'TotalPossessionTime': 'PT1H20M15.6337S'},
#         {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#          'TotalShotsFired': 1412,
#          'TotalShotsLanded': 818,
#          'TotalHeadshots': 0,
#          'TotalKills': 92,
#          'TotalDamageDealt': 16194.333945542574,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#          'TotalShotsFired': 257,
#          'TotalShotsLanded': 110,
#          'TotalHeadshots': 0,
#          'TotalKills': 34,
#          'TotalDamageDealt': 4076.809680700302,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#          'TotalShotsFired': 1182,
#          'TotalShotsLanded': 128,
#          'TotalHeadshots': 0,
#          'TotalKills': 12,
#          'TotalDamageDealt': 1596.0104455947876,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 150,
#          'TotalDamageDealt': 16059.346710681915,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#          'TotalShotsFired': 1377,
#          'TotalShotsLanded': 734,
#          'TotalHeadshots': 77,
#          'TotalKills': 100,
#          'TotalDamageDealt': 19978.248927235603,
#          'TotalPossessionTime': 'PT1H15M30.917S'},
#         {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#          'TotalShotsFired': 1042,
#          'TotalShotsLanded': 646,
#          'TotalHeadshots': 0,
#          'TotalKills': 92,
#          'TotalDamageDealt': 18968.991514526308,
#          'TotalPossessionTime': 'PT58M4.5164S'},
#         {'WeaponId': {'StockId': 4108759423, 'Attachments': []},
#          'TotalShotsFired': 3454,
#          'TotalShotsLanded': 1778,
#          'TotalHeadshots': 123,
#          'TotalKills': 173,
#          'TotalDamageDealt': 23133.69016933441,
#          'TotalPossessionTime': 'PT1H27M41.9667S'},
#         {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#          'TotalShotsFired': 4339,
#          'TotalShotsLanded': 1062,
#          'TotalHeadshots': 0,
#          'TotalKills': 78,
#          'TotalDamageDealt': 15753.402061302215,
#          'TotalPossessionTime': 'PT51M54.7826S'},
#         {'WeaponId': {'StockId': 47178948, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 8,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#          'TotalShotsFired': 86,
#          'TotalShotsLanded': 51,
#          'TotalHeadshots': 0,
#          'TotalKills': 28,
#          'TotalDamageDealt': 3248.087001800537,
#          'TotalPossessionTime': 'PT16M54.0003S'},
#         {'WeaponId': {'StockId': 2457457776, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT5.0666S'},
#         {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#          'TotalShotsFired': 434,
#          'TotalShotsLanded': 304,
#          'TotalHeadshots': 18,
#          'TotalKills': 191,
#          'TotalDamageDealt': 27991.213163712993,
#          'TotalPossessionTime': 'PT1H24M51.817S'},
#         {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#          'TotalShotsFired': 1107,
#          'TotalShotsLanded': 414,
#          'TotalHeadshots': 0,
#          'TotalKills': 27,
#          'TotalDamageDealt': 3870.8937091827393,
#          'TotalPossessionTime': 'PT20M39.2167S'},
#         {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#          'TotalShotsFired': 1183,
#          'TotalShotsLanded': 404,
#          'TotalHeadshots': 0,
#          'TotalKills': 18,
#          'TotalDamageDealt': 3804.372463107109,
#          'TotalPossessionTime': 'PT17M13.5504S'},
#         {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#          'TotalShotsFired': 869,
#          'TotalShotsLanded': 523,
#          'TotalHeadshots': 0,
#          'TotalKills': 10,
#          'TotalDamageDealt': 9808.714273452759,
#          'TotalPossessionTime': 'PT37M30.7671S'},
#         {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 44,
#          'TotalDamageDealt': 4860.896974563599,
#          'TotalPossessionTime': 'PT37M24.4998S'},
#         {'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#          'TotalShotsFired': 717,
#          'TotalShotsLanded': 323,
#          'TotalHeadshots': 0,
#          'TotalKills': 47,
#          'TotalDamageDealt': 8679.899816036224,
#          'TotalPossessionTime': 'PT28M54.9163S'},
#         {'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#          'TotalShotsFired': 1816,
#          'TotalShotsLanded': 509,
#          'TotalHeadshots': 0,
#          'TotalKills': 42,
#          'TotalDamageDealt': 5179.190636634827,
#          'TotalPossessionTime': 'PT28M42.7669S'},
#         {'WeaponId': {'StockId': 2140505068, 'Attachments': []},
#          'TotalShotsFired': 10841,
#          'TotalShotsLanded': 2828,
#          'TotalHeadshots': 51,
#          'TotalKills': 116,
#          'TotalDamageDealt': 16874.23154258728,
#          'TotalPossessionTime': 'PT47M8.384S'},
#         {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#          'TotalShotsFired': 405,
#          'TotalShotsLanded': 244,
#          'TotalHeadshots': 0,
#          'TotalKills': 15,
#          'TotalDamageDealt': 2207.53800201416,
#          'TotalPossessionTime': 'PT14M10.917S'},
#         {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#          'TotalShotsFired': 2111,
#          'TotalShotsLanded': 957,
#          'TotalHeadshots': 0,
#          'TotalKills': 137,
#          'TotalDamageDealt': 22100.096989154816,
#          'TotalPossessionTime': 'PT48M20.4664S'},
#         {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#          'TotalShotsFired': 328,
#          'TotalShotsLanded': 121,
#          'TotalHeadshots': 41,
#          'TotalKills': 52,
#          'TotalDamageDealt': 9457.362796783447,
#          'TotalPossessionTime': 'PT26M46.6999S'},
#         {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#          'TotalShotsFired': 14792,
#          'TotalShotsLanded': 1104,
#          'TotalHeadshots': 0,
#          'TotalKills': 103,
#          'TotalDamageDealt': 24429.927688121796,
#          'TotalPossessionTime': 'PT59M33.0323S'},
#         {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#          'TotalShotsFired': 5361,
#          'TotalShotsLanded': 2384,
#          'TotalHeadshots': 0,
#          'TotalKills': 129,
#          'TotalDamageDealt': 21681.360666275024,
#          'TotalPossessionTime': 'PT57M26.5162S'},
#         {'WeaponId': {'StockId': 642449794, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 4222743534, 'Attachments': []},
#          'TotalShotsFired': 920,
#          'TotalShotsLanded': 453,
#          'TotalHeadshots': 18,
#          'TotalKills': 26,
#          'TotalDamageDealt': 3735.0907888412476,
#          'TotalPossessionTime': 'PT11M41.4832S'},
#         {'WeaponId': {'StockId': 2492868984, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT18.4663S'},
#         {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#          'TotalShotsFired': 1608,
#          'TotalShotsLanded': 479,
#          'TotalHeadshots': 0,
#          'TotalKills': 22,
#          'TotalDamageDealt': 4154.56231713295,
#          'TotalPossessionTime': 'PT18M34.5503S'},
#         {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#          'TotalShotsFired': 184,
#          'TotalShotsLanded': 85,
#          'TotalHeadshots': 26,
#          'TotalKills': 39,
#          'TotalDamageDealt': 7170.827011108398,
#          'TotalPossessionTime': 'PT20M7.4169S'},
#         {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#          'TotalShotsFired': 649,
#          'TotalShotsLanded': 417,
#          'TotalHeadshots': 0,
#          'TotalKills': 112,
#          'TotalDamageDealt': 15325.624665498734,
#          'TotalPossessionTime': 'PT39M6.5672S'},
#         {'WeaponId': {'StockId': 2758094302, 'Attachments': []},
#          'TotalShotsFired': 371,
#          'TotalShotsLanded': 114,
#          'TotalHeadshots': 11,
#          'TotalKills': 20,
#          'TotalDamageDealt': 2335.1276655197144,
#          'TotalPossessionTime': 'PT17M51.3501S'},
#         {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#          'TotalShotsFired': 7642,
#          'TotalShotsLanded': 2383,
#          'TotalHeadshots': 0,
#          'TotalKills': 16,
#          'TotalDamageDealt': 3933.3141174316406,
#          'TotalPossessionTime': 'PT21M38.1497S'},
#         {'WeaponId': {'StockId': 3010146366, 'Attachments': []},
#          'TotalShotsFired': 1912,
#          'TotalShotsLanded': 539,
#          'TotalHeadshots': 0,
#          'TotalKills': 45,
#          'TotalDamageDealt': 9001.302110625431,
#          'TotalPossessionTime': 'PT17M21.5333S'},
#         {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#          'TotalShotsFired': 393,
#          'TotalShotsLanded': 267,
#          'TotalHeadshots': 0,
#          'TotalKills': 41,
#          'TotalDamageDealt': 8873.712938023731,
#          'TotalPossessionTime': 'PT36M19.0002S'},
#         {'WeaponId': {'StockId': 4233134183, 'Attachments': []},
#          'TotalShotsFired': 176,
#          'TotalShotsLanded': 13,
#          'TotalHeadshots': 0,
#          'TotalKills': 6,
#          'TotalDamageDealt': 1028.6686248779297,
#          'TotalPossessionTime': 'PT1M23.9834S'},
#         {'WeaponId': {'StockId': 3207900961, 'Attachments': []},
#          'TotalShotsFired': 737,
#          'TotalShotsLanded': 212,
#          'TotalHeadshots': 0,
#          'TotalKills': 16,
#          'TotalDamageDealt': 1626.1722602844238,
#          'TotalPossessionTime': 'PT3M6.5832S'},
#         {'WeaponId': {'StockId': 1206711506, 'Attachments': []},
#          'TotalShotsFired': 281,
#          'TotalShotsLanded': 58,
#          'TotalHeadshots': 0,
#          'TotalKills': 3,
#          'TotalDamageDealt': 823.2530517578125,
#          'TotalPossessionTime': 'PT2M50.7999S'},
#         {'WeaponId': {'StockId': 1609865982, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT11S'},
#         {'WeaponId': {'StockId': 4028516791, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 419783896, 'Attachments': []},
#          'TotalShotsFired': 879,
#          'TotalShotsLanded': 350,
#          'TotalHeadshots': 0,
#          'TotalKills': 65,
#          'TotalDamageDealt': 11639.92008972168,
#          'TotalPossessionTime': 'PT20M50.9166S'},
#         {'WeaponId': {'StockId': 1730553442, 'Attachments': []},
#          'TotalShotsFired': 460,
#          'TotalShotsLanded': 192,
#          'TotalHeadshots': 0,
#          'TotalKills': 11,
#          'TotalDamageDealt': 1964.1300659179688,
#          'TotalPossessionTime': 'PT2M7.7667S'},
#         {'WeaponId': {'StockId': 2988661926, 'Attachments': []},
#          'TotalShotsFired': 39,
#          'TotalShotsLanded': 21,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 336.10003662109375,
#          'TotalPossessionTime': 'PT10.6667S'},
#         {'WeaponId': {'StockId': 1063919886, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT5.0667S'},
#         {'WeaponId': {'StockId': 1259783693, 'Attachments': []},
#          'TotalShotsFired': 0,
#          'TotalShotsLanded': 0,
#          'TotalHeadshots': 0,
#          'TotalKills': 0,
#          'TotalDamageDealt': 0.0,
#          'TotalPossessionTime': 'PT9.6167S'}],
#        'Impulses': [{'Id': 2556889090, 'Count': 163},
#         {'Id': 3174430457, 'Count': 132},
#         {'Id': 1408036107, 'Count': 26}],
#        'TotalSpartanKills': 3278,
#        'FastestMatchWin': 'PT6M32.8180298S'},
#       {'FlexibleStats': {'MedalStatCounts': [],
#         'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#           'Count': 382},
#          {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 175},
#          {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 231},
#          {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 2},
#          {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 193},
#          {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 30},
#          {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 20},
#          {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 14}],
#         'MedalTimelapses': [],
#         'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#           'Timelapse': 'PT5H6M41.5354156S'}]},
#        'GameBaseVariantId': '65f033d2-1303-4748-bc26-ef62c38eced4',
#        'TotalKills': 398,
#        'TotalHeadshots': 193,
#        'TotalWeaponDamage': 69489.11292243004,
#        'TotalShotsFired': 15596,
#        'TotalShotsLanded': 6028,
#        'WeaponWithMostKills': {'WeaponId': {'StockId': 424645655,
#          'Attachments': []},
#         'TotalShotsFired': 9051,
#         'TotalShotsLanded': 4073,
#         'TotalHeadshots': 162,
#         'TotalKills': 195,
#         'TotalDamageDealt': 31708.902229309082,
#         'TotalPossessionTime': 'PT2H25M41.1167S'},
#        'TotalMeleeKills': 13,
#        'TotalMeleeDamage': 1422.966661453247,
#        'TotalAssassinations': 2,
#        'TotalGroundPoundKills': 3,
#        'TotalGroundPoundDamage': 402.33331298828125,
#        'TotalShoulderBashKills': 0,
#        'TotalShoulderBashDamage': 190.0,
#        'TotalGrenadeDamage': 5664.935998678207,
#        'TotalPowerWeaponKills': 69,
#        'TotalPowerWeaponDamage': 11054.022086143494,
#        'TotalPowerWeaponGrabs': 14,
#        'TotalPowerWeaponPossessionTime': 'PT30M35.5504S',
#        'TotalDeaths': 231,
#        'TotalAssists': 175,
#        'TotalGamesCompleted': 30,
#        'TotalGamesWon': 15,
#        'TotalGamesLost': 15,
#        'TotalGamesTied': 0,
#        'TotalTimePlayed': 'PT5H6M41.5354156S',
#        'TotalGrenadeKills': 14,
#        'MedalAwards': [{'MedalId': 3261908037, 'Count': 153},
#         {'MedalId': 824733727, 'Count': 12},
#         {'MedalId': 3400287617, 'Count': 15},
#         {'MedalId': 1080468863, 'Count': 27},
#         {'MedalId': 2430242797, 'Count': 18},
#         {'MedalId': 1691836029, 'Count': 3},
#         {'MedalId': 2838259753, 'Count': 15},
#         {'MedalId': 1423504140, 'Count': 6},
#         {'MedalId': 3824002610, 'Count': 4},
#         {'MedalId': 2287626681, 'Count': 11},
#         {'MedalId': 2782465081, 'Count': 4},
#         {'MedalId': 2078758684, 'Count': 27},
#         {'MedalId': 370413844, 'Count': 3},
#         {'MedalId': 1326375333, 'Count': 4},
#         {'MedalId': 3676723563, 'Count': 4},
#         {'MedalId': 3001183151, 'Count': 1},
#         {'MedalId': 3925170236, 'Count': 2},
#         {'MedalId': 848240062, 'Count': 6},
#         {'MedalId': 352859864, 'Count': 5},
#         {'MedalId': 466059351, 'Count': 1},
#         {'MedalId': 4048801324, 'Count': 8},
#         {'MedalId': 92444561, 'Count': 7},
#         {'MedalId': 492192256, 'Count': 3},
#         {'MedalId': 250435527, 'Count': 2},
#         {'MedalId': 1618319591, 'Count': 3},
#         {'MedalId': 2251767925, 'Count': 1},
#         {'MedalId': 3522125871, 'Count': 2},
#         {'MedalId': 285057226, 'Count': 2},
#         {'MedalId': 3491849182, 'Count': 1},
#         {'MedalId': 2497544753, 'Count': 7},
#         {'MedalId': 3148489433, 'Count': 1},
#         {'MedalId': 876932011, 'Count': 1},
#         {'MedalId': 194124164, 'Count': 1},
#         {'MedalId': 3270120991, 'Count': 2},
#         {'MedalId': 3744028405, 'Count': 2},
#         {'MedalId': 3440416044, 'Count': 1},
#         {'MedalId': 2531822079, 'Count': 1},
#         {'MedalId': 3698887726, 'Count': 1},
#         {'MedalId': 3486286344, 'Count': 1},
#         {'MedalId': 3865042769, 'Count': 1},
#         {'MedalId': 1986137636, 'Count': 1},
#         {'MedalId': 1711392399, 'Count': 1},
#         {'MedalId': 35545941, 'Count': 1}],
#        'DestroyedEnemyVehicles': [{'Enemy': {'BaseId': 4028516791,
#           'Attachments': []},
#          'TotalKills': 7},
#         {'Enemy': {'BaseId': 3010146366, 'Attachments': []}, 'TotalKills': 7},
#         {'Enemy': {'BaseId': 1730553442, 'Attachments': []}, 'TotalKills': 1}],
#        'EnemyKills': [],
#        'WeaponStats': [{'WeaponId': {'StockId': 424645655, 'Attachments': []},
#          'TotalShotsFired': 9051,
#          'TotalShotsLanded': 4073,
#          'TotalHeadshots': 162,
#          'TotalKills': 195,
#          'TotalDamageDealt': 31708.902229309082,
#          'TotalPossessionTime': 'PT2H25M41.1167S'},
#         {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#          'TotalShotsFired': 258,
#          'TotalShotsLanded': 92,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 587.0933513641357,
#          'TotalPossessionTime': 'PT14M0.5832S'},
#         {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#          'TotalShotsFired': 18,
#          'TotalShotsLanded': 15,
#          'TotalHeadshots': 0,
#          'TotalKills': 10,
#          'TotalDamageDealt': 1223.0177154541016,
#          'TotalPossessionTime': 'PT3M40.8001S'},
#         {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#          'TotalShotsFired': 1140,
#          'TotalShotsLanded': 47,
#          'TotalHeadshots': 0,
#          'TotalKills': 6,
#          'TotalDamageDealt': 755.2338790893555,
#          'TotalPossessionTime': 'PT3M58.3333S'},
#         {'WeaponId': {'StockId': 1749823285, 'Attachments': []},
#          'TotalShotsFired': 59,
#          'TotalShotsLanded': 9,
#          'TotalHeadshots': 0,
#          'TotalKills': 2,
#          'TotalDamageDealt': 259.14477920532227,
#          'TotalPossessionTime': 'PT54.7667S'},
#         {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#          'TotalShotsFired': 319,
#          'TotalShotsLanded': 228,
#          'TotalHeadshots': 0,
#          'TotalKills': 6,
#          'TotalDamageDealt': 4217.552994728088,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#          'TotalShotsFired': 41,
#          'TotalShotsLanded': 25,
#          'TotalHeadshots': 0,
#          'TotalKills': 5,
#          'TotalDamageDealt': 942.8823673725128,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#          'TotalShotsFired': 276,
#          'TotalShotsLanded': 39,
#          'TotalHeadshots': 0,
#          'TotalKills': 3,
#          'TotalDamageDealt': 504.5006365776062,
#          'TotalPossessionTime': 'PT0S'},
#         {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#          'TotalShotsFired': 56,
#          'TotalShotsLanded': 18,
#          'TotalHeadshots': 0,
#          'TotalKills': 1,
#          'TotalDamageDealt': 201.39999389648438,
#          'TotalPossessionTime': 'PT1M35.3167S'},
#         {'WeaponId': {'StockId': 2907783784, 'Attachments': []},
#          'TotalShotsFired': 36,
#          'TotalShotsLanded': 23,
#          'TotalHeadshots': 0,
#          'TotalKills': 5,
#          'TotalDamageDealt': 532.3145523071289,
#          'TotalPossessionTime': 'PT2M21.7001S'},
#         {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#          'TotalShotsFired': 11,
#          'TotalShotsLanded': 6,
#          'TotalHeadshots': 0,
# ...
#        'TotalPossessionTime': 'PT6H22M8.6509S'},
#       {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#        'TotalShotsFired': 31100,
#        'TotalShotsLanded': 21205,
#        'TotalHeadshots': 0,
#        'TotalKills': 4074,
#        'TotalDamageDealt': 617197.8951030689,
#        'TotalPossessionTime': 'P1DT3H11M57.4328S'},
#       {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#        'TotalShotsFired': 35070,
#        'TotalShotsLanded': 10874,
#        'TotalHeadshots': 0,
#        'TotalKills': 453,
#        'TotalDamageDealt': 67269.3625369072,
#        'TotalPossessionTime': 'PT9H22M16.2821S'},
#       {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#        'TotalShotsFired': 8089,
#        'TotalShotsLanded': 5269,
#        'TotalHeadshots': 0,
#        'TotalKills': 3215,
#        'TotalDamageDealt': 363660.2106643915,
#        'TotalPossessionTime': 'PT20H44M34.2487S'},
#       {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#        'TotalShotsFired': 352203,
#        'TotalShotsLanded': 92812,
#        'TotalHeadshots': 0,
#        'TotalKills': 5089,
#        'TotalDamageDealt': 859697.8645020616,
#        'TotalPossessionTime': 'P1DT9H8M42.7322S'},
#       {'WeaponId': {'StockId': 2457457776, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 4,
#        'TotalDamageDealt': 1223.5938568115234,
#        'TotalPossessionTime': 'PT1M9.5649S'},
#       {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#        'TotalShotsFired': 11812,
#        'TotalShotsLanded': 9220,
#        'TotalHeadshots': 0,
#        'TotalKills': 14006,
#        'TotalDamageDealt': 1599143.2625285797,
#        'TotalPossessionTime': 'P4DT11H43M12.2411S'},
#       {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#        'TotalShotsFired': 33308,
#        'TotalShotsLanded': 14339,
#        'TotalHeadshots': 894,
#        'TotalKills': 1547,
#        'TotalDamageDealt': 290935.3557044249,
#        'TotalPossessionTime': 'PT22H28M32.0298S'},
#       {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#        'TotalShotsFired': 28510,
#        'TotalShotsLanded': 3796,
#        'TotalHeadshots': 0,
#        'TotalKills': 298,
#        'TotalDamageDealt': 48485.678797296714,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 642449794, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 2,
#        'TotalDamageDealt': 205.62858128547668,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 2988661926, 'Attachments': []},
#        'TotalShotsFired': 18086,
#        'TotalShotsLanded': 4671,
#        'TotalHeadshots': 0,
#        'TotalKills': 174,
#        'TotalDamageDealt': 38111.21569442749,
#        'TotalPossessionTime': 'PT1H49M28.017S'},
#       {'WeaponId': {'StockId': 2244200496, 'Attachments': []},
#        'TotalShotsFired': 2952,
#        'TotalShotsLanded': 903,
#        'TotalHeadshots': 38,
#        'TotalKills': 71,
#        'TotalDamageDealt': 11569.752565801144,
#        'TotalPossessionTime': 'PT7H2M43.7157S'},
#       {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#        'TotalShotsFired': 7843,
#        'TotalShotsLanded': 5241,
#        'TotalHeadshots': 237,
#        'TotalKills': 3448,
#        'TotalDamageDealt': 382319.6201735893,
#        'TotalPossessionTime': 'PT22H8M1.4687S'},
#       {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#        'TotalShotsFired': 34864,
#        'TotalShotsLanded': 12235,
#        'TotalHeadshots': 0,
#        'TotalKills': 795,
#        'TotalDamageDealt': 122811.84554809332,
#        'TotalPossessionTime': 'PT10H48M58.7861S'},
#       {'WeaponId': {'StockId': 1730553442, 'Attachments': []},
#        'TotalShotsFired': 2899,
#        'TotalShotsLanded': 1050,
#        'TotalHeadshots': 0,
#        'TotalKills': 162,
#        'TotalDamageDealt': 52754.40249633789,
#        'TotalPossessionTime': 'PT2H23M19.2836S'},
#       {'WeaponId': {'StockId': 2907783784, 'Attachments': []},
#        'TotalShotsFired': 3008,
#        'TotalShotsLanded': 1496,
#        'TotalHeadshots': 0,
#        'TotalKills': 241,
#        'TotalDamageDealt': 45696.1087243557,
#        'TotalPossessionTime': 'PT1H45M22.9497S'},
#       {'WeaponId': {'StockId': 1259783693, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT10H47M42.6177S'},
#       {'WeaponId': {'StockId': 1063919886, 'Attachments': []},
#        'TotalShotsFired': 914,
#        'TotalShotsLanded': 621,
#        'TotalHeadshots': 0,
#        'TotalKills': 344,
#        'TotalDamageDealt': 53710.878648519516,
#        'TotalPossessionTime': 'PT1H3M1.7833S'},
#       {'WeaponId': {'StockId': 3010146366, 'Attachments': []},
#        'TotalShotsFired': 63341,
#        'TotalShotsLanded': 11313,
#        'TotalHeadshots': 0,
#        'TotalKills': 925,
#        'TotalDamageDealt': 180132.2723901719,
#        'TotalPossessionTime': 'PT8H23M7.1002S'},
#       {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#        'TotalShotsFired': 190304,
#        'TotalShotsLanded': 25297,
#        'TotalHeadshots': 0,
#        'TotalKills': 1960,
#        'TotalDamageDealt': 230601.85464134812,
#        'TotalPossessionTime': 'PT14H36M10.1658S'},
#       {'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#        'TotalShotsFired': 62279,
#        'TotalShotsLanded': 21258,
#        'TotalHeadshots': 0,
#        'TotalKills': 1845,
#        'TotalDamageDealt': 212315.3195677381,
#        'TotalPossessionTime': 'PT16H19M48.4359S'},
#       {'WeaponId': {'StockId': 1749823285, 'Attachments': []},
#        'TotalShotsFired': 6402,
#        'TotalShotsLanded': 994,
#        'TotalHeadshots': 0,
#        'TotalKills': 137,
#        'TotalDamageDealt': 31584.646369457245,
#        'TotalPossessionTime': 'PT1H3M37.7838S'},
#       {'WeaponId': {'StockId': 419783896, 'Attachments': []},
#        'TotalShotsFired': 2448,
#        'TotalShotsLanded': 678,
#        'TotalHeadshots': 0,
#        'TotalKills': 157,
#        'TotalDamageDealt': 31589.08839225769,
#        'TotalPossessionTime': 'PT1H12M2.8004S'},
#       {'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#        'TotalShotsFired': 21406,
#        'TotalShotsLanded': 17279,
#        'TotalHeadshots': 0,
#        'TotalKills': 2985,
#        'TotalDamageDealt': 413412.46948795486,
#        'TotalPossessionTime': 'PT19H49M17.2501S'},
#       {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#        'TotalShotsFired': 76160,
#        'TotalShotsLanded': 26630,
#        'TotalHeadshots': 0,
#        'TotalKills': 2691,
#        'TotalDamageDealt': 355235.28150095046,
#        'TotalPossessionTime': 'PT19H54M14.5168S'},
#       {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#        'TotalShotsFired': 25860,
#        'TotalShotsLanded': 9672,
#        'TotalHeadshots': 0,
#        'TotalKills': 511,
#        'TotalDamageDealt': 70193.3614513278,
#        'TotalPossessionTime': 'PT7H39M26.9966S'},
#       {'WeaponId': {'StockId': 2140505068, 'Attachments': []},
#        'TotalShotsFired': 363132,
#        'TotalShotsLanded': 65178,
#        'TotalHeadshots': 1735,
#        'TotalKills': 3577,
#        'TotalDamageDealt': 487608.9306746684,
#        'TotalPossessionTime': 'PT21H22M11.2995S'},
#       {'WeaponId': {'StockId': 4028516791, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 1,
#        'TotalHeadshots': 0,
#        'TotalKills': 535,
#        'TotalDamageDealt': 107992.0085401535,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 47178948, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 123,
#        'TotalDamageDealt': 578.0900630950928,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#        'TotalShotsFired': 26906,
#        'TotalShotsLanded': 19866,
#        'TotalHeadshots': 0,
#        'TotalKills': 6298,
#        'TotalDamageDealt': 781149.3961592866,
#        'TotalPossessionTime': 'P1DT4H7M57.4816S'},
#       {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#        'TotalShotsFired': 38368,
#        'TotalShotsLanded': 25371,
#        'TotalHeadshots': 0,
#        'TotalKills': 548,
#        'TotalDamageDealt': 204273.14184185676,
#        'TotalPossessionTime': 'PT14H5M40.0525S'},
#       {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#        'TotalShotsFired': 17560,
#        'TotalShotsLanded': 6671,
#        'TotalHeadshots': 1917,
#        'TotalKills': 3022,
#        'TotalDamageDealt': 473273.0257728696,
#        'TotalPossessionTime': 'PT21H56M43.1641S'},
#       {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#        'TotalShotsFired': 102419,
#        'TotalShotsLanded': 55347,
#        'TotalHeadshots': 0,
#        'TotalKills': 7068,
#        'TotalDamageDealt': 833805.0257206559,
#        'TotalPossessionTime': 'P1DT3H39M25.8299S'},
#       {'WeaponId': {'StockId': 1701501807, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT10.9S'},
#       {'WeaponId': {'StockId': 4222743534, 'Attachments': []},
#        'TotalShotsFired': 39475,
#        'TotalShotsLanded': 16988,
#        'TotalHeadshots': 721,
#        'TotalKills': 946,
#        'TotalDamageDealt': 136208.7589746397,
#        'TotalPossessionTime': 'PT12H18M8.6517S'},
#       {'WeaponId': {'StockId': 1206711506, 'Attachments': []},
#        'TotalShotsFired': 3334,
#        'TotalShotsLanded': 1471,
#        'TotalHeadshots': 0,
#        'TotalKills': 344,
#        'TotalDamageDealt': 60606.5321931839,
#        'TotalPossessionTime': 'PT2H40M42.017S'},
#       {'WeaponId': {'StockId': 4233134183, 'Attachments': []},
#        'TotalShotsFired': 1676,
#        'TotalShotsLanded': 452,
#        'TotalHeadshots': 0,
#        'TotalKills': 186,
#        'TotalDamageDealt': 29477.06695842743,
#        'TotalPossessionTime': 'PT52M37.4334S'},
#       {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#        'TotalShotsFired': 62883,
#        'TotalShotsLanded': 57431,
#        'TotalHeadshots': 0,
#        'TotalKills': 6807,
#        'TotalDamageDealt': 776361.7763924716,
#        'TotalPossessionTime': 'P1DT12H49M16.7172S'},
#       {'WeaponId': {'StockId': 393532233, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 272,
#        'TotalDamageDealt': 28587.692980552092,
#        'TotalPossessionTime': 'PT4H21M3.2816S'},
#       {'WeaponId': {'StockId': 2492868984, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT16M58.8284S'},
#       {'WeaponId': {'StockId': 2758094302, 'Attachments': []},
#        'TotalShotsFired': 6554,
#        'TotalShotsLanded': 2988,
#        'TotalHeadshots': 357,
#        'TotalKills': 531,
#        'TotalDamageDealt': 78338.17450934649,
#        'TotalPossessionTime': 'PT6H8M21.9001S'},
#       {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#        'TotalShotsFired': 176573,
#        'TotalShotsLanded': 59654,
#        'TotalHeadshots': 0,
#        'TotalKills': 4399,
#        'TotalDamageDealt': 627040.9308496565,
#        'TotalPossessionTime': 'P1DT3H55M25.0484S'},
#       {'WeaponId': {'StockId': 1609865982, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT3H44M35.6838S'},
#       {'WeaponId': {'StockId': 3227919741, 'Attachments': []},
#        'TotalShotsFired': 32684,
#        'TotalShotsLanded': 11126,
#        'TotalHeadshots': 0,
#        'TotalKills': 399,
#        'TotalDamageDealt': 143048.7346277237,
#        'TotalPossessionTime': 'PT3H40M5.0995S'},
#       {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#        'TotalShotsFired': 18734,
#        'TotalShotsLanded': 6979,
#        'TotalHeadshots': 0,
#        'TotalKills': 272,
#        'TotalDamageDealt': 69164.73773390055,
#        'TotalPossessionTime': 'PT8H37M51.6968S'},
#       {'WeaponId': {'StockId': 3207900961, 'Attachments': []},
#        'TotalShotsFired': 12287,
#        'TotalShotsLanded': 4104,
#        'TotalHeadshots': 0,
#        'TotalKills': 155,
#        'TotalDamageDealt': 20479.26117324829,
#        'TotalPossessionTime': 'PT40M45.1166S'},
#       {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#        'TotalShotsFired': 45519,
#        'TotalShotsLanded': 27437,
#        'TotalHeadshots': 1674,
#        'TotalKills': 3405,
#        'TotalDamageDealt': 516338.5729469657,
#        'TotalPossessionTime': 'PT21H25M22.8486S'},
#       {'WeaponId': {'StockId': 1351500565, 'Attachments': []},
#        'TotalShotsFired': 451,
#        'TotalShotsLanded': 95,
#        'TotalHeadshots': 0,
#        'TotalKills': 8,
#        'TotalDamageDealt': 1304.1348732709885,
#        'TotalPossessionTime': 'PT10M1.3335S'},
#       {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#        'TotalShotsFired': 206312,
#        'TotalShotsLanded': 55263,
#        'TotalHeadshots': 0,
#        'TotalKills': 473,
#        'TotalDamageDealt': 91537.35593568906,
#        'TotalPossessionTime': 'PT8H7M30.9524S'},
#       {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#        'TotalShotsFired': 17162,
#        'TotalShotsLanded': 15281,
#        'TotalHeadshots': 0,
#        'TotalKills': 3259,
#        'TotalDamageDealt': 434321.6633715463,
#        'TotalPossessionTime': 'P1DT2H12M38.0147S'},
#       {'WeaponId': {'StockId': 409331533, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 58,
#        'TotalDamageDealt': 6748.767757892609,
#        'TotalPossessionTime': 'PT1H8M2.8998S'},
#       {'WeaponId': {'StockId': 698769165, 'Attachments': []},
#        'TotalShotsFired': 17542,
#        'TotalShotsLanded': 563,
#        'TotalHeadshots': 0,
#        'TotalKills': 13,
#        'TotalDamageDealt': 3858.1043090820312,
#        'TotalPossessionTime': 'PT22M0.1001S'},
#       {'WeaponId': {'StockId': 3218397906, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 139.72967529296875,
#        'TotalPossessionTime': 'PT0S'}],
#      'Impulses': [{'Id': 2556889090, 'Count': 6341},
#       {'Id': 1408036107, 'Count': 1867},
#       {'Id': 3174430457, 'Count': 905},
#       {'Id': 4191318012, 'Count': 10695},
#       {'Id': 1039658009, 'Count': 2890},
#       {'Id': 3435524855, 'Count': 9245},
#       {'Id': 2299858338, 'Count': 3079},
#       {'Id': 1063951891, 'Count': 1717},
#       {'Id': 3060032974, 'Count': 383},
#       {'Id': 415845940, 'Count': 87},
#       {'Id': 938151029, 'Count': 30},
#       {'Id': 3514632335, 'Count': 177},
#       {'Id': 2944278681, 'Count': 1415},
#       {'Id': 540014008, 'Count': 314},
#       {'Id': 2483589021, 'Count': 14981},
#       {'Id': 2512065773, 'Count': 105},
#       {'Id': 3930101026, 'Count': 82},
#       {'Id': 4040349679, 'Count': 1},
#       {'Id': 588422610, 'Count': 12918},
#       {'Id': 2192206750, 'Count': 166},
#       {'Id': 365321763, 'Count': 101},
#       {'Id': 472607776, 'Count': 32},
#       {'Id': 2664358695, 'Count': 1}],
#      'TotalSpartanKills': 130529,
#      'FastestMatchWin': 'PT1M19.080834S'},
#     'PlayerId': {'Gamertag': 'BeardedDirdMirm', 'Xuid': None},
#     'SpartanRank': 150,
#     'Xp': 33042531}}],
#  'Links': {'Self': {'AuthorityId': 'spartanstats',
#    'Path': '/h5/servicerecords/arena',
#    'QueryString': '?players=er0sking%2CANuNNaKI%20Vs%2CS%20H%20I%20N%20I%20N%20MEX%2CDrymander%2CCDAxXB4RD0KXx%2CLiLmeFromDaFutr%2CJubiPrincess%2Cmaneth%20007%2CBeardedDirdMirm&include-xuids=false&view=full',
#    'RetryPolicyId': '',
#    'TopicName': '',
#    'AcknowledgementTypeId': 0,
#    'AuthenticationLifetimeExtensionSupported': False,
#    'ClearanceAware': False}}}

# %%
# Function to build secondary dataframe with more informative player stats
def build_history_dataframe(player_history, variant_id, streamlit=False):
    
    # Option to view 'streamlit' dataframe, which includes pertinent
    # information but excludes all stats for modeling
    if streamlit == True:
        vdf_columns = ['Gamertag','TotalTimePlayed','K/D','Accuracy','WinRate']
        vdf = pd.DataFrame(columns = vdf_columns)
    else:
        stat_list = ['Gamertag', 'TotalKills', 'TotalHeadshots', 'TotalWeaponDamage', 'TotalShotsFired',
                    'TotalShotsLanded', 'TotalMeleeKills', 'TotalMeleeDamage', 'TotalAssassinations',
                    'TotalGroundPoundKills', 'TotalGroundPoundDamage', 'TotalShoulderBashKills',
                    'TotalShoulderBashDamage', 'TotalGrenadeDamage', 'TotalPowerWeaponKills',
                    'TotalPowerWeaponDamage', 'TotalPowerWeaponGrabs', 'TotalPowerWeaponPossessionTime',
                    'TotalDeaths', 'TotalAssists', 'TotalGamesCompleted', 'TotalGamesWon',
                    'TotalGamesLost', 'TotalGamesTied', 'TotalTimePlayed','TotalGrenadeKills']
        vdf = pd.DataFrame(columns = stat_list)
    
    # Set coutner variable
    i = 0
    # Loop the goes through each player in the player history JSON
    for player in player_history['Results']:
        
        # Loop that goes through each Arena Game Base Variant and locates
        # the details specific to the game vase variant of the match
        for variant in player['Result']['ArenaStats']['ArenaGameBaseVariantStats']:
            if variant['GameBaseVariantId'] == variant_id:
                variant_stats = variant
        
        # Create empty dictionary where stats will be added
        variant_dic = {}
        
        # Streamlit option - calculates specifc features
        if streamlit == True:
            variant_dic['Gamertag'] = player_history['Results'][i]['Id']
            variant_dic['TotalTimePlayed']= isodate.parse_duration(variant_stats['TotalTimePlayed']).total_seconds() / 3600
            variant_dic['K/D'] = variant_stats['TotalKills'] / variant_stats['TotalDeaths']
            variant_dic['Accuracy'] = variant_stats['TotalShotsLanded'] / variant_stats['TotalShotsFired']
            variant_dic['WinRate'] = variant_stats['TotalGamesWon'] / variant_stats['TotalGamesLost']
            vdf = vdf.append(variant_dic, True)
            i += 1
        
        # Modeling option - includes all features but does not yet calculate
        else:
            variant_dic['Gamertag'] = player_history['Results'][i]['Id']
            
            # Loop that appends all stats to variant dic
            for stat in stat_list[1:]:    
                variant_dic[stat] = variant_stats[stat]
            
            # Parsing ISO duration times
            variant_dic['TotalTimePlayed']= isodate.parse_duration(variant_stats['TotalTimePlayed']).total_seconds() / 3600
            vdf = vdf.append(variant_dic, True)
            i += 1
    
    # Return the streamlit or modeling dataframe
    return vdf
    
build_history_dataframe(player_history, '1571fdac-e0b4-4ebc-a73a-6e13001b71d3', streamlit=False)
# Out:
#           Gamertag TotalKills TotalHeadshots  TotalWeaponDamage  \
# 0         er0sking        543            234       62957.174945
# 1      ANuNNaKI Vs        324             52       43548.503118
# 2  S H I N I N MEX         95             21       10633.469292
# 3        Drymander       2551            137      316416.816237
# 4    CDAxXB4RD0KXx        350             48       43411.333340
# 5  LiLmeFromDaFutr        645            121       84079.585467
# 6     JubiPrincess         57              4        6880.550871
# 7       maneth 007        982             86      124854.242591
# 8  BeardedDirdMirm       2440            282      315338.029387
#
#   TotalShotsFired TotalShotsLanded TotalMeleeKills  TotalMeleeDamage  \
# 0           10842             4737              37       4765.384587
# 1            8089             2809              13       1537.806410
# 2            2103              898              20       2147.748150
# 3           60129            20832             126      15502.626122
# 4            6901             2439              19       2812.913459
# 5           16675             7122              47       9281.277675
# 6             865              334               0        368.500008
# 7           26179             8609              61       8004.927242
# 8           50893            18587             159      19027.618741
#
#   TotalAssassinations TotalGroundPoundKills  TotalGroundPoundDamage  \
# 0                   4                     3               95.000000
# 1                   2                     0                0.000000
# 2                   6                     0                0.000000
# 3                  25                     2              766.000008
# 4                   4                     3              431.459885
# 5                   7                     3               58.533337
# 6                   1                     0                0.000000
# 7                  15                     4              490.000000
# 8                  24                    21             2346.714638
#
#   TotalShoulderBashKills  TotalShoulderBashDamage  TotalGrenadeDamage  \
# 0                      1                95.000000          514.327088
# 1                      0                95.000000         2580.592167
# 2                      1               380.609253         1872.249517
# 3                      6              1952.204443        12575.908441
# 4                      2              1204.362621         1893.862724
# 5                      0                95.000000         5904.373441
# 6                      0               190.000000          203.277176
# 7                     10              1612.036028         6903.990424
# 8                     25              3336.278517        34299.446539
#
#   TotalPowerWeaponKills  TotalPowerWeaponDamage TotalPowerWeaponGrabs  \
# 0                    39             5461.777581                    21
# 1                   229            30520.437774                     0
# 2                    18             1812.343102                     1
# 3                  2136           271196.989875                     2
# 4                   264            35738.711423                     0
# 5                   297            39471.911242                     3
# 6                    38             4330.150912                     0
# 7                   723            92774.118724                     2
# 8                  1685           219718.764253                    10
#
#   TotalPowerWeaponPossessionTime TotalDeaths TotalAssists TotalGamesCompleted  \
# 0                  PT13M33.9836S         406          209                  48
# 1                 PT1H41M9.4011S         272           78                  27
# 2                      PT7M55.3S          96           19                  10
# 3               PT16H36M29.8987S        2852          487                 250
# 4                PT2H15M28.0174S         323           80                  37
# 5                PT1H46M57.8161S         559          228                  67
# 6                  PT22M58.9164S         103           12                  17
# 7                PT5H20M47.6851S        1082          288                 110
# 8               PT12H15M39.9151S        2263          612                 248
#
#   TotalGamesWon TotalGamesLost TotalGamesTied  TotalTimePlayed  \
# 0            20             28              0         5.154200
# 1            11             16              0         3.228458
# 2             4              6              0         1.130857
# 3           148            102              0        28.649340
# 4            14             23              0         3.781016
# 5            43             24              0         7.109608
# 6             8              9              0         1.672351
# 7            55             55              0        11.891076
# 8           128            120              0        27.166478
#
#   TotalGrenadeKills
# 0                44
# 1                10
# 2                 6
# 3                49
# 4                 6
# 5                46
# 6                 1
# 7                32
# 8               138

# %%
# Function that combines all functions above to go through each step to
# Get the match dataframe
def recent_match_stats(gamertag, back_count=0):
    
    # Pull the match result as JSON from API
    match_results = pull_recent_match(back_count, explore=False, gamertag=gamertag)
    
    # Build the base dataframe
    base_df = build_base_dataframe(match_results, gamertag=gamertag)
    
    # Sleep for 1.01 seconds to avoid issues with API
    time.sleep(1.01)
    
    # Create playerlist for player history API call
    player_list = get_player_list(base_df)
    
    # Call API to get player history JSON
    player_history = get_player_history(base_df)
    
    # Build base player stats dataframe based on player history API call
    history_df = build_history_dataframe(player_history, match_results['GameBaseVariantId'])
    
    # Merge the base dataframe and stats dataframe
    full_stats_df = pd.merge(base_df, history_df, how='inner', on = 'Gamertag')
    
    return full_stats_df

# Show full dataframe for match
df = recent_match_stats('Drymander', back_count=0)
df
# Out:
#                      Date                               MatchId  \
# 0 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
# 1 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
# 2 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
# 3 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
# 4 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
# 5 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
# 6 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
# 7 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
#
#                       GameBaseVariantId                            PlaylistId  \
# 0  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 1  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 2  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 3  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 4  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 5  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 6  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 7  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
#
#                            MapVariantId  DNF  TeamId PlayerTeam   Winner  \
# 0  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     0.0      Enemy  Victory
# 1  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     0.0      Enemy  Victory
# 2  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     0.0      Enemy  Victory
# 3  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     0.0      Enemy  Victory
# 4  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     1.0     Player   Defeat
# 5  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     1.0     Player   Defeat
# 6  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     1.0     Player   Defeat
# 7  6b306cc8-1d60-41ae-9e95-464fdbe1288b  0.0     1.0     Player   Defeat
#
#   TeamColor        Gamertag SpartanRank PrevTotalXP TotalKills TotalHeadshots  \
# 0       Red    Dimension vv         138     6187181      18667           9548
# 1       Red       Nefarious         144     7508121      22619           9779
# 2       Red  SourStarfish28         143     6823910      19021           1565
# 3       Red      Nottheeddu         150    27262125      15350           4305
# 4      Blue       Drymander         148    15539108      28622           2148
# 5      Blue  cryptolockerSD         151    47129356      53976           6853
# 6      Blue        Bophodes         146     9757943      37954           4160
# 7      Blue  SixKnifeWalker         151    37537896     180085          39306
#
#    TotalWeaponDamage TotalShotsFired TotalShotsLanded TotalMeleeKills  \
# 0       1.841544e+06          266971           107489             988
# 1       2.341174e+06          301329           132159            1768
# 2       2.442232e+06          346960           132726             522
# 3       2.086481e+06          396248           136780            1021
# 4       3.804711e+06          752121           241046            1473
# 5       7.029784e+06         1246999           440258            4119
# 6       5.284578e+06          933293           343770            1414
# 7       2.096487e+07         3882031          1385612           19851
#
#    TotalMeleeDamage TotalAssassinations TotalGroundPoundKills  \
# 0      1.665585e+05                 569                   106
# 1      1.827042e+05                 498                   183
# 2      5.683225e+04                  99                    12
# 3      1.581637e+05                 314                    60
# 4      1.607738e+05                 208                    35
# 5      4.852049e+05                 830                   184
# 6      1.557253e+05                 247                   116
# 7      2.467716e+06                4572                   120
#
#    TotalGroundPoundDamage TotalShoulderBashKills  TotalShoulderBashDamage  \
# 0            12037.056124                    217             28651.529271
# 1            16618.659790                    347             26330.779343
# 2             2313.328398                     71             10473.208076
# 3            10741.944481                     84             16998.106466
# 4             5230.651564                    100             19095.688572
# 5            36020.682724                     98             22102.556794
# 6            17884.960927                    104             24934.632016
# 7            13565.930386                   1238            201230.095609
#
#    TotalGrenadeDamage TotalPowerWeaponKills  TotalPowerWeaponDamage  \
# 0        8.813844e+04                  6384            7.974387e+05
# 1        1.470351e+05                  8724            1.057324e+06
# 2        3.920214e+04                 16021            2.080327e+06
# 3        1.828776e+05                  7468            1.005274e+06
# 4        1.279060e+05                 23221            3.094004e+06
# 5        6.867552e+05                 33719            4.388698e+06
# 6        2.671945e+05                 26908            3.625981e+06
# 7        1.943314e+06                 64233            7.911166e+06
#
#   TotalPowerWeaponGrabs TotalPowerWeaponPossessionTime TotalDeaths  \
# 0                   457              P1DT23H28M8.0898S       18458
# 1                   520              P2DT8H12M46.2633S       20930
# 2                    16                P5DT4H52M7.412S       18264
# 3                   124              P2DT12H2M20.8034S       14490
# 4                   140              P7DT14H34M15.173S       27853
# 5                   691             P10DT18H4M48.0387S       49088
# 6                    86             P8DT15H14M29.4774S       35635
# 7                 10667             P19DT2H15M59.4167S      170820
#
#   TotalAssists TotalGamesCompleted TotalGamesWon TotalGamesLost  \
# 0         4120                1561           726            835
# 1         4852                1726           803            923
# 2         3729                1483           730            752
# 3         4623                1367           655            711
# 4         5890                2510          1252           1258
# 5        15393                4885          2577           2307
# 6        10059                3054          1459           1594
# 7        58661               15051          7465           7576
#
#   TotalGamesTied  TotalTimePlayed TotalGrenadeKills
# 0              0       178.628452               517
# 1              0       195.564511               758
# 2              1       193.553819               212
# 3              1       164.625542               737
# 4              0       297.931417               452
# 5              1       560.944904              2748
# 6              1       395.276087              1147
# 7             10      2016.365563             16832

# %%
# Function to convert the full match dataframe into a single Pandas row for modeling
def one_row(df, for_model=False):
    
    # If statement that rules out matches that will present issues for the model
    # We want to make sure that exactly 8 players finished teh match and that
    # No player exited the game before it was over
    if ((for_model==True) and ((len(df.index) != 8) or (1 in df['DNF'].values))):
        # Returns an empty dataframe that will be appended to the modeling dataset,
        # effectively denoting that the match will not be usable for the model
        df = pd.DataFrame()
    
    # If the match meets the modeling criteria:
    else:
        # Sort by PlayerTeam (captures player team stats first)
        # Sort by TotalTimePlayed
        df = df.sort_values(by=['PlayerTeam', 'TotalTimePlayed'], ascending=(False, False))
        
        # Isolate portion of the dataframe for creating information we need
        df = df.reset_index()
        df_row = df.iloc[0:1,1:6]
        
        # Determine whether player won, lost, or tied the match
        df_player = df.loc[df['PlayerTeam'] == 'Player']
        if df_player['Winner'].str.contains('Victory').any():
            df_row['WinLoseTie'] = 'Victory'
        elif df_player['Winner'].str.contains('Defeat').any():
            df_row['WinLoseTie'] = 'Defeat'
        elif df_player['Winner'].str.contains('Tie').any():
            df_row['WinLoseTie'] = 'Tie'
        else: 
            df_row['WinLoseTie'] = 'Error Determining Victor'
        
        # 'Flatten' the match dataframe so that each player stat can
        # be represented in one line of data
        column_list = df.columns.to_list()
        columns_converted = []
        df = df.drop(df.iloc[:, 0:11], axis = 1)
        df = df.stack().to_frame().T
        df.columns = ['{}_{}'.format(*c) for c in df.columns]
        
        # Dictionary to convert strings denoting P1-4 (Player 1-4), E1 (Enemey 1-4)
        column_convert_dic = {"0_":"P1-", "1_":"P2-","2_":"P3-","3_":"P4-",
                              "4_":"E1-","5_":"E2-","6_":"E3-","7_":"E4-",}

        # Use dictionary to set column names
        for k, v in column_convert_dic.items():
            df.columns = df.columns.str.replace(k, v)
        df.columns = df.columns.str.replace('-', '_')
        df = df_row.join(df, how='outer')
    
    # Return match dataframe as one row
    return df

# Test function
one_row(df, for_model=False)
# Out:
#                      Date                               MatchId  \
# 0 2021-07-22 21:00:59.258  2eecaf00-ba9f-432e-b144-bc1c90b29430
#
#                       GameBaseVariantId                            PlaylistId  \
# 0  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
#
#                            MapVariantId WinLoseTie     P1_Gamertag  \
# 0  6b306cc8-1d60-41ae-9e95-464fdbe1288b     Defeat  SixKnifeWalker
#
#   P1_SpartanRank P1_PrevTotalXP P1_TotalKills P1_TotalHeadshots  \
# 0            151       37537896        180085             39306
#
#   P1_TotalWeaponDamage P1_TotalShotsFired P1_TotalShotsLanded  \
# 0          2.09649e+07            3882031             1385612
#
#   P1_TotalMeleeKills P1_TotalMeleeDamage P1_TotalAssassinations  \
# 0              19851         2.46772e+06                   4572
#
#   P1_TotalGroundPoundKills P1_TotalGroundPoundDamage  \
# 0                      120                   13565.9
#
#   P1_TotalShoulderBashKills P1_TotalShoulderBashDamage P1_TotalGrenadeDamage  \
# 0                      1238                     201230           1.94331e+06
#
#   P1_TotalPowerWeaponKills P1_TotalPowerWeaponDamage P1_TotalPowerWeaponGrabs  \
# 0                    64233               7.91117e+06                    10667
#
#   P1_TotalPowerWeaponPossessionTime P1_TotalDeaths P1_TotalAssists  \
# 0                P19DT2H15M59.4167S         170820           58661
#
#   P1_TotalGamesCompleted P1_TotalGamesWon P1_TotalGamesLost P1_TotalGamesTied  \
# 0                  15051             7465              7576                10
#
#   P1_TotalTimePlayed P1_TotalGrenadeKills     P2_Gamertag P2_SpartanRank  \
# 0            2016.37                16832  cryptolockerSD            151
#
#   P2_PrevTotalXP P2_TotalKills P2_TotalHeadshots P2_TotalWeaponDamage  \
# 0       47129356         53976              6853          7.02978e+06
#
#   P2_TotalShotsFired P2_TotalShotsLanded P2_TotalMeleeKills  \
# 0            1246999              440258               4119
#
#   P2_TotalMeleeDamage P2_TotalAssassinations P2_TotalGroundPoundKills  \
# 0              485205                    830                      184
#
#   P2_TotalGroundPoundDamage P2_TotalShoulderBashKills  \
# 0                   36020.7                        98
#
#   P2_TotalShoulderBashDamage P2_TotalGrenadeDamage P2_TotalPowerWeaponKills  \
# 0                    22102.6                686755                    33719
#
#   P2_TotalPowerWeaponDamage P2_TotalPowerWeaponGrabs  \
# 0                4.3887e+06                      691
#
#   P2_TotalPowerWeaponPossessionTime P2_TotalDeaths P2_TotalAssists  \
# 0                P10DT18H4M48.0387S          49088           15393
#
#   P2_TotalGamesCompleted P2_TotalGamesWon P2_TotalGamesLost P2_TotalGamesTied  \
# 0                   4885             2577              2307                 1
#
#   P2_TotalTimePlayed P2_TotalGrenadeKills P3_Gamertag P3_SpartanRank  \
# 0            560.945                 2748    Bophodes            146
#
#   P3_PrevTotalXP P3_TotalKills P3_TotalHeadshots P3_TotalWeaponDamage  \
# 0        9757943         37954              4160          5.28458e+06
#
#   P3_TotalShotsFired P3_TotalShotsLanded P3_TotalMeleeKills  \
# 0             933293              343770               1414
#
#   P3_TotalMeleeDamage P3_TotalAssassinations P3_TotalGroundPoundKills  \
# 0              155725                    247                      116
#
#   P3_TotalGroundPoundDamage P3_TotalShoulderBashKills  \
# 0                     17885                       104
#
#   P3_TotalShoulderBashDamage P3_TotalGrenadeDamage P3_TotalPowerWeaponKills  \
# 0                    24934.6                267195                    26908
#
#   P3_TotalPowerWeaponDamage P3_TotalPowerWeaponGrabs  \
# 0               3.62598e+06                       86
#
#   P3_TotalPowerWeaponPossessionTime P3_TotalDeaths P3_TotalAssists  \
# 0                P8DT15H14M29.4774S          35635           10059
#
#   P3_TotalGamesCompleted P3_TotalGamesWon P3_TotalGamesLost P3_TotalGamesTied  \
# 0                   3054             1459              1594                 1
#
#   P3_TotalTimePlayed P3_TotalGrenadeKills P4_Gamertag P4_SpartanRank  \
# 0            395.276                 1147   Drymander            148
#
#   P4_PrevTotalXP P4_TotalKills P4_TotalHeadshots P4_TotalWeaponDamage  \
# 0       15539108         28622              2148          3.80471e+06
#
#   P4_TotalShotsFired P4_TotalShotsLanded P4_TotalMeleeKills  \
# 0             752121              241046               1473
#
#   P4_TotalMeleeDamage P4_TotalAssassinations P4_TotalGroundPoundKills  \
# 0              160774                    208                       35
#
#   P4_TotalGroundPoundDamage P4_TotalShoulderBashKills  \
# 0                   5230.65                       100
#
#   P4_TotalShoulderBashDamage P4_TotalGrenadeDamage P4_TotalPowerWeaponKills  \
# 0                    19095.7                127906                    23221
#
#   P4_TotalPowerWeaponDamage P4_TotalPowerWeaponGrabs  \
# 0                 3.094e+06                      140
#
#   P4_TotalPowerWeaponPossessionTime P4_TotalDeaths P4_TotalAssists  \
# 0                 P7DT14H34M15.173S          27853            5890
#
#   P4_TotalGamesCompleted P4_TotalGamesWon P4_TotalGamesLost P4_TotalGamesTied  \
# 0                   2510             1252              1258                 0
#
#   P4_TotalTimePlayed P4_TotalGrenadeKills E1_Gamertag E1_SpartanRank  \
# 0            297.931                  452   Nefarious            144
#
#   E1_PrevTotalXP E1_TotalKills E1_TotalHeadshots E1_TotalWeaponDamage  \
# 0        7508121         22619              9779          2.34117e+06
#
#   E1_TotalShotsFired E1_TotalShotsLanded E1_TotalMeleeKills  \
# 0             301329              132159               1768
#
#   E1_TotalMeleeDamage E1_TotalAssassinations E1_TotalGroundPoundKills  \
# 0              182704                    498                      183
#
#   E1_TotalGroundPoundDamage E1_TotalShoulderBashKills  \
# 0                   16618.7                       347
#
#   E1_TotalShoulderBashDamage E1_TotalGrenadeDamage E1_TotalPowerWeaponKills  \
# 0                    26330.8                147035                     8724
#
#   E1_TotalPowerWeaponDamage E1_TotalPowerWeaponGrabs  \
# 0               1.05732e+06                      520
#
#   E1_TotalPowerWeaponPossessionTime E1_TotalDeaths E1_TotalAssists  \
# 0                 P2DT8H12M46.2633S          20930            4852
#
#   E1_TotalGamesCompleted E1_TotalGamesWon E1_TotalGamesLost E1_TotalGamesTied  \
# 0                   1726              803               923                 0
#
#   E1_TotalTimePlayed E1_TotalGrenadeKills     E2_Gamertag E2_SpartanRank  \
# 0            195.565                  758  SourStarfish28            143
#
#   E2_PrevTotalXP E2_TotalKills E2_TotalHeadshots E2_TotalWeaponDamage  \
# 0        6823910         19021              1565          2.44223e+06
#
#   E2_TotalShotsFired E2_TotalShotsLanded E2_TotalMeleeKills  \
# 0             346960              132726                522
#
#   E2_TotalMeleeDamage E2_TotalAssassinations E2_TotalGroundPoundKills  \
# 0             56832.3                     99                       12
#
#   E2_TotalGroundPoundDamage E2_TotalShoulderBashKills  \
# 0                   2313.33                        71
#
#   E2_TotalShoulderBashDamage E2_TotalGrenadeDamage E2_TotalPowerWeaponKills  \
# 0                    10473.2               39202.1                    16021
#
#   E2_TotalPowerWeaponDamage E2_TotalPowerWeaponGrabs  \
# 0               2.08033e+06                       16
#
#   E2_TotalPowerWeaponPossessionTime E2_TotalDeaths E2_TotalAssists  \
# 0                   P5DT4H52M7.412S          18264            3729
#
#   E2_TotalGamesCompleted E2_TotalGamesWon E2_TotalGamesLost E2_TotalGamesTied  \
# 0                   1483              730               752                 1
#
#   E2_TotalTimePlayed E2_TotalGrenadeKills   E3_Gamertag E3_SpartanRank  \
# 0            193.554                  212  Dimension vv            138
#
#   E3_PrevTotalXP E3_TotalKills E3_TotalHeadshots E3_TotalWeaponDamage  \
# 0        6187181         18667              9548          1.84154e+06
#
#   E3_TotalShotsFired E3_TotalShotsLanded E3_TotalMeleeKills  \
# 0             266971              107489                988
#
#   E3_TotalMeleeDamage E3_TotalAssassinations E3_TotalGroundPoundKills  \
# 0              166559                    569                      106
#
#   E3_TotalGroundPoundDamage E3_TotalShoulderBashKills  \
# 0                   12037.1                       217
#
#   E3_TotalShoulderBashDamage E3_TotalGrenadeDamage E3_TotalPowerWeaponKills  \
# 0                    28651.5               88138.4                     6384
#
#   E3_TotalPowerWeaponDamage E3_TotalPowerWeaponGrabs  \
# 0                    797439                      457
#
#   E3_TotalPowerWeaponPossessionTime E3_TotalDeaths E3_TotalAssists  \
# 0                 P1DT23H28M8.0898S          18458            4120
#
#   E3_TotalGamesCompleted E3_TotalGamesWon E3_TotalGamesLost E3_TotalGamesTied  \
# 0                   1561              726               835                 0
#
#   E3_TotalTimePlayed E3_TotalGrenadeKills E4_Gamertag E4_SpartanRank  \
# 0            178.628                  517  Nottheeddu            150
#
#   E4_PrevTotalXP E4_TotalKills E4_TotalHeadshots E4_TotalWeaponDamage  \
# 0       27262125         15350              4305          2.08648e+06
#
#   E4_TotalShotsFired E4_TotalShotsLanded E4_TotalMeleeKills  \
# 0             396248              136780               1021
#
#   E4_TotalMeleeDamage E4_TotalAssassinations E4_TotalGroundPoundKills  \
# 0              158164                    314                       60
#
#   E4_TotalGroundPoundDamage E4_TotalShoulderBashKills  \
# 0                   10741.9                        84
#
#   E4_TotalShoulderBashDamage E4_TotalGrenadeDamage E4_TotalPowerWeaponKills  \
# 0                    16998.1                182878                     7468
#
#   E4_TotalPowerWeaponDamage E4_TotalPowerWeaponGrabs  \
# 0               1.00527e+06                      124
#
#   E4_TotalPowerWeaponPossessionTime E4_TotalDeaths E4_TotalAssists  \
# 0                 P2DT12H2M20.8034S          14490            4623
#
#   E4_TotalGamesCompleted E4_TotalGamesWon E4_TotalGamesLost E4_TotalGamesTied  \
# 0                   1367              655               711                 1
#
#   E4_TotalTimePlayed E4_TotalGrenadeKills
# 0            164.626                  737

# %%
# Load unique gamertags pickle file from EDA notebook

with open('unique_gamertags.pkl', 'rb') as unique_gamertags_pickle:
    unique_gamertags = pickle.load(unique_gamertags_pickle)

# See how many unique gamertags that the player has played with
len(unique_gamertags)
# Out:
# 24248

# %%
# Function that slightly models the pull_recent_match function
# Designed to pull 25 matches from each gamertag for modeling
def model_pull_matches(how_recent, api_key=api_key, 
                       gamertag='Drymander', count=25):
    
    # Use gamertag_for_api function to remove any spaces
    gamertag = gamertag_for_api(gamertag)
    # Set API key
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': api_key,
    }
    
    # Pulls from arena mode, how_recent is how far to go back in the match history
    # 'count' refers to the number of matches to pull
    params = urllib.parse.urlencode({
        # Request parameters
        'modes': 'arena',
        'start': 0,
        'count': count,
        'include-times': True,
    })
    
    # Try / except for error handling
    try:
        
        # Connect to API and pull most recent 25 matches for specified gamer
        # and format into JSON
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/players/{gamertag}/matches?%s" % params, "{body}", headers)
        time.sleep(1.01)
        response = conn.getresponse()
        data = response.read()
        history_pull = json.loads(data)
        print(history_pull['ResultCount'])
        
        # Counter variable for printing status
        i = 0
        
        # Empty list to append 25 matches
        latest_count_matches = []
        
        # Loop to go through each of the 25 matches to pull match details for each
        for match in history_pull['Results']:
            
            # Identify match ID and match date
            match_id = match['Id']['MatchId']
            match_date = match['MatchCompletedDate']['ISO8601Date']
            
            # API call for each match ID in teh 25 matches
            conn.request("GET", f"/stats/h5/arena/matches/{match_id}?%s" % params, "{body}", headers)
            time.sleep(1.1)
            
            # Format into JSON and append match ID and date
            response = conn.getresponse()
            data = response.read()
            match_results = json.loads(data)
            match_results['MatchId'] = match_id
            match_results['Date'] = match_date
            
            # Append each match JSON to full list
            latest_count_matches.append(match_results)
            conn.close()
            i += 1
            
            # Print total number of matches appended to list
            print(f'{i} matches appended')
    
    # Error handling
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    # Return full set of 25 matches
    return latest_count_matches

# Testing the function
latest_count_matches = model_pull_matches(0, gamertag='Drymander', count=5)
# Out:
# 5
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended

# %%
# Setting run to false
# If set to true, model will start adding new rows to model datafarme stored in .csv
run = False

# Isolating portion of unique_gamertags to build model dataframe in manageable chunks
gamertag_list = unique_gamertags[651:850]

# Function add rows to the modeling dataframe
def model_recent_match_stats(gamertag_list, back_count=0, count=25):
    
    # Create new dataframe
    df = pd.DataFrame()
    
    # Set gamertag_count to zero, will be used in updating status via print
    gamertag_count = 0
    
    # Loop through gamertags in unique_gamertags list
    for gamertag in tqdm(gamertag_list):
        
        # Try / except to deal with API error handling
        try:
            # Use latest_count_match function to pull 25 matches from player 
            latest_count_matches = model_pull_matches(0, gamertag=gamertag, count=count)
            time.sleep(1.1)
            
            # Setting error counter and additional counter variable
            error_count = 0
            i = 0
            
            # Loop through each of the players 25 matches
            for match in latest_count_matches:
                
                # Error handling
                try:
                    
                    # Build the base dataframe
                    base_df = build_base_dataframe(match, gamertag=gamertag)
                    
                    # Create playerlist for player history API call
                    player_list = get_player_list(base_df)
                    
                    # Call API to get player history JSON
                    player_history = get_player_history(base_df)
                    
                    # Build base player stats dataframe based on player history API call
                    history_df = build_history_dataframe(player_history, match_results['GameBaseVariantId'])
                    
                    # Merge the base dataframe and stats dataframe
                    full_stats_df = pd.merge(base_df, history_df, how='inner', on = 'Gamertag')
                    
                    # Flatten full match dataframe into one row, 
                    row = one_row(full_stats_df, for_model=True)
                    
                    # Append row to model dataframe .csv with specific date format  
                    row.to_csv('MODEL_PULL.csv', mode ='a', date_format='%Y-%m-%d %H:%M:%S', header=False)
                    
                    # Append to model dataframe if working outside of .csv
                    df = df.append(row)
                    
                    # Print how many rows have been added to the dataframe
                    i += 1
                    print(f'{i} rows added to model dataframe')

                    time.sleep(1.1)
                except:
                    
                    # Print error count if row cannot be added because it doesn't meet criteria
                    # Typically this occurs when a player has changed their gamertag
                    error_count += 1
                    print(f'{error_count} rows returned error when getting player history')
                    time.sleep(1.1)
                    error_count += 1
                    continue
            
            # Print number of gamertags that the function has gone through
            gamertag_count += 1
            print(f'{gamertag_count} completed')
        
        except:
            
            # Show error message if gamer skipped due to name change or other issue with API
            print('gamertag skipped due to error')
    
    # Return modeling dataframe
    return df

if run == True:
    model_df = model_recent_match_stats(gamertag_list, back_count=0, count=25)
else:
    pass

# %% [markdown]
# # Load Model Dataframe from CSV

# %%
# Load csv created by model_recent_match_stats
df = pd.read_csv('MODEL_PULL.csv')

# Convert the dates to datetime objects
df['Date'] = df['Date'].apply(pd.to_datetime)

# Drop 'Unnamed: 0' from dataframe
df = df.drop(['Unnamed: 0'], axis=1)

# Remove null, infinity, and negative infinity
# This can cause errors when creating features
df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

df.head(3)
# Out:
#                  Date                               MatchId  \
# 0 2021-07-17 21:39:00  1bc32b01-2dda-418a-8853-ba3d3b09f912
# 1 2021-07-19 00:29:00  06c5149f-72af-4678-9615-7d2db89db290
# 2 2021-07-19 00:25:00  7801d2b0-f941-4851-9b04-8208a5439497
#
#                       GameBaseVariantId                            PlaylistId  \
# 0  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 1  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 2  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
#
#                            MapVariantId WinLoseTie    P1_Gamertag  \
# 0  d5f2d94f-b51f-4a0c-8c35-af99426bf14d     Defeat  TED Cloverlan
# 1  7a4ca104-7242-4efe-a53e-fb5295d7b092    Victory      Drymander
# 2  d0a6c435-a5df-465f-b728-0547dea06c3c    Victory    TWINKYNECKS
#
#    P1_SpartanRank  P1_PrevTotalXP  P1_TotalKills  P1_TotalHeadshots  \
# 0             102         3348130           3378                551
# 1             148        15348257          39273               3202
# 2             151        37161347          58661              11418
#
#    P1_TotalWeaponDamage  P1_TotalShotsFired  P1_TotalShotsLanded  \
# 0          4.362411e+05               96140                31174
# 1          5.020049e+06             1025141               367059
# 2          7.990578e+06             1326652               460037
#
#    P1_TotalMeleeKills  P1_TotalMeleeDamage  P1_TotalAssassinations  \
# 0                 150          14200.28244                      13
# 1                1289         147219.06830                     216
# 2                1669         222380.10050                     325
#
#    P1_TotalGroundPoundKills  P1_TotalGroundPoundDamage  \
# 0                         1                 435.899994
# 1                        26                5870.122829
# 2                       118               21481.336320
#
#    P1_TotalShoulderBashKills  P1_TotalShoulderBashDamage  \
# 0                         12                 1809.374457
# 1                        123                26233.730550
# 2                        374                65457.288060
#
#    P1_TotalGrenadeDamage  P1_TotalPowerWeaponKills  P1_TotalPowerWeaponDamage  \
# 0            17833.89112                      2746               3.535647e+05
# 1           192043.79460                     34812               4.462575e+06
# 2           867137.32960                     44999               5.979214e+06
#
#    P1_TotalPowerWeaponGrabs P1_TotalPowerWeaponPossessionTime  P1_TotalDeaths  \
# 0                         0                   PT14H20M2.4819S            3593
# 1                        16                 P6DT13H36M8.2793S           44504
# 2                       270                P8DT23H28M16.8446S           61053
#
#    P1_TotalAssists  P1_TotalGamesCompleted  P1_TotalGamesWon  \
# 0             1499                     256               124
# 1            14978                    3051              1594
# 2            25331                    3568              1565
#
#    P1_TotalGamesLost  P1_TotalGamesTied  P1_TotalTimePlayed  \
# 0                105                 27           26.475012
# 1               1198                259          288.020209
# 2               1567                436          417.975375
#
#    P1_TotalGrenadeKills      P2_Gamertag  P2_SpartanRank  P2_PrevTotalXP  \
# 0                    69  TackleZoMbIeZ90              72         1755469
# 1                   687   its ghobi baby             149        23870326
# 2                  3314        Drymander             148        15345204
#
#    P2_TotalKills  P2_TotalHeadshots  P2_TotalWeaponDamage  P2_TotalShotsFired  \
# 0           3388                378          4.506744e+05              123305
# 1          39309               6720          5.369387e+06             1111772
# 2          39273               3202          5.020049e+06             1025141
#
#    P2_TotalShotsLanded  P2_TotalMeleeKills  P2_TotalMeleeDamage  \
# 0                33670                 115          13798.77195
# 1               391306                 876         105948.32160
# 2               367059                1289         147219.06830
#
#    P2_TotalAssassinations  P2_TotalGroundPoundKills  \
# 0                      22                         9
# 1                     130                         0
# 2                     216                        26
#
#    P2_TotalGroundPoundDamage  P2_TotalShoulderBashKills  \
# 0                2178.285184                         20
# 1                   0.000000                          9
# 2                5870.122829                        123
#
#    P2_TotalShoulderBashDamage  P2_TotalGrenadeDamage  \
# 0                 3866.135540            33681.92404
# 1                 1718.871307           480275.91350
# 2                26233.730550           192043.79460
#
#    P2_TotalPowerWeaponKills  P2_TotalPowerWeaponDamage  \
# 0                      2706               3.561506e+05
# 1                     31754               4.124953e+06
# 2                     34812               4.462575e+06
#
#    P2_TotalPowerWeaponGrabs P2_TotalPowerWeaponPossessionTime  P2_TotalDeaths  \
# 0                         3                  PT14H28M24.8987S            2804
# 1                         3                  P5DT4H38M6.6719S           35407
# 2                        16                 P6DT13H36M8.2793S           44504
#
#    P2_TotalAssists  P2_TotalGamesCompleted  P2_TotalGamesWon  \
# 0             1630                     231               100
# 1            19300                    2382              1330
# 2            14978                    3051              1594
#
#    P2_TotalGamesLost  P2_TotalGamesTied  P2_TotalTimePlayed  \
# 0                 94                 37           25.016905
# 1                772                280          241.513053
# 2               1198                259          288.020209
#
#    P2_TotalGrenadeKills      P3_Gamertag  P3_SpartanRank  P3_PrevTotalXP  \
# 0                   132  MrPicardBottoms             145         8584030
# 1                  1649     Noob JSkeree              96         2970740
# 2                   687  PumpedAlpaca184             146         9774869
#
#    P3_TotalKills  P3_TotalHeadshots  P3_TotalWeaponDamage  P3_TotalShotsFired  \
# 0           1882                309          2.504024e+05               54355
# 1           7914                801          9.670463e+05              143169
# 2          21952               3777          2.937519e+06              521487
#
#    P3_TotalShotsLanded  P3_TotalMeleeKills  P3_TotalMeleeDamage  \
# 0                17223                 130          13866.32449
# 1                41817                 211          26461.92472
# 2               203513                 907          96793.46693
#
#    P3_TotalAssassinations  P3_TotalGroundPoundKills  \
# 0                      21                         5
# 1                      31                        35
# 2                     107                        18
#
#    P3_TotalGroundPoundDamage  P3_TotalShoulderBashKills  \
# 0                1778.400188                         19
# 1                8937.051069                         25
# 2                3082.305937                         71
#
#    P3_TotalShoulderBashDamage  P3_TotalGrenadeDamage  \
# 0                 3887.518391            17023.67813
# 1                 4594.986589           162607.74880
# 2                16138.151560           219603.14600
#
#    P3_TotalPowerWeaponKills  P3_TotalPowerWeaponDamage  \
# 0                      1306               1.785042e+05
# 1                      5453               6.966502e+05
# 2                     16367               2.128939e+06
#
#    P3_TotalPowerWeaponGrabs P3_TotalPowerWeaponPossessionTime  P3_TotalDeaths  \
# 0                        17                    PT6H20M26.117S            2034
# 1                        13                  P1DT21H2M9.2834S            7935
# 2                        52                  P3DT2H27M21.023S           25535
#
#    P3_TotalAssists  P3_TotalGamesCompleted  P3_TotalGamesWon  \
# 0              828                     146                60
# 1             2866                     570               216
# 2            10584                    1359               591
#
#    P3_TotalGamesLost  P3_TotalGamesTied  P3_TotalTimePlayed  \
# 0                 70                 16           15.919856
# 1                245                109           73.169910
# 2                586                182          160.492698
#
#    P3_TotalGrenadeKills      P4_Gamertag  P4_SpartanRank  P4_PrevTotalXP  \
# 0                    62  GermanGames6869             144         7375370
# 1                   773      Daniel TSM5              98         3105846
# 2                   787      Psycho Smak              48          759776
#
#    P4_TotalKills  P4_TotalHeadshots  P4_TotalWeaponDamage  P4_TotalShotsFired  \
# 0           1315                253           163307.5974               22859
# 1           2646                399           324629.8990               65294
# 2           6436               1229           853174.8455              161503
#
#    P4_TotalShotsLanded  P4_TotalMeleeKills  P4_TotalMeleeDamage  \
# 0                 9212                  34          6087.614542
# 1                24390                 120         13928.636150
# 2                56437                  93         11200.409080
#
#    P4_TotalAssassinations  P4_TotalGroundPoundKills  \
# 0                       6                         3
# 1                      32                        15
# 2                      19                         0
#
#    P4_TotalGroundPoundDamage  P4_TotalShoulderBashKills  \
# 0                 776.223419                         13
# 1                1363.579624                         18
# 2                   0.000000                          1
#
#    P4_TotalShoulderBashDamage  P4_TotalGrenadeDamage  \
# 0                 3712.180248            10792.43986
# 1                 3102.606691            11552.87847
# 2                  164.162956            64568.21276
#
#    P4_TotalPowerWeaponKills  P4_TotalPowerWeaponDamage  \
# 0                      1002                123037.4187
# 1                      2093                263532.4852
# 2                      5300                678333.8271
#
#    P4_TotalPowerWeaponGrabs P4_TotalPowerWeaponPossessionTime  P4_TotalDeaths  \
# 0                        23                    PT5H22M45.868S            1410
# 1                         0                     PT10H27.2496S            2493
# 2                         0                 P1DT2H47M17.9369S            5543
#
#    P4_TotalAssists  P4_TotalGamesCompleted  P4_TotalGamesWon  \
# 0              392                     102                49
# 1              928                     187                79
# 2             3132                     433               190
#
#    P4_TotalGamesLost  P4_TotalGamesTied  P4_TotalTimePlayed  \
# 0                 40                 13           11.637733
# 1                 87                 21           18.867221
# 2                184                 59           46.458067
#
#    P4_TotalGrenadeKills      E1_Gamertag  E1_SpartanRank  E1_PrevTotalXP  \
# 0                    41   TheJudgePaul91             152        52946125
# 1                    46          xxRowan             149        18608380
# 2                   226  PeakTree4879815             147        11150915
#
#    E1_TotalKills  E1_TotalHeadshots  E1_TotalWeaponDamage  E1_TotalShotsFired  \
# 0          16222               3950           2140170.267              439309
# 1          19844               7015           2720339.122              446426
# 2          31941               5861           4173908.467              719658
#
#    E1_TotalShotsLanded  E1_TotalMeleeKills  E1_TotalMeleeDamage  \
# 0               141949                 704          95917.87382
# 1               187932                1067         124757.00720
# 2               248379                 869         113148.63170
#
#    E1_TotalAssassinations  E1_TotalGroundPoundKills  \
# 0                     148                         6
# 1                     219                        16
# 2                     186                        37
#
#    E1_TotalGroundPoundDamage  E1_TotalShoulderBashKills  \
# 0                 990.599998                         82
# 1                1435.099349                          2
# 2                9390.987291                         79
#
#    E1_TotalShoulderBashDamage  E1_TotalGrenadeDamage  \
# 0                  8975.22238            132581.0872
# 1                   332.50000            184216.2895
# 2                 21581.61390            284210.2578
#
#    E1_TotalPowerWeaponKills  E1_TotalPowerWeaponDamage  \
# 0                     11464                1513326.279
# 1                      8652                1156967.202
# 2                     25437                3284115.189
#
#    E1_TotalPowerWeaponGrabs E1_TotalPowerWeaponPossessionTime  E1_TotalDeaths  \
# 0                        40                 P2DT4H33M47.4005S           14354
# 1                       575                P1DT22H45M43.2322S           17082
# 2                       116                P5DT20H32M55.0879S           25248
#
#    E1_TotalAssists  E1_TotalGamesCompleted  E1_TotalGamesWon  \
# 0             6974                    1114               465
# 1             9207                    1497               596
# 2            12021                    2121               855
#
#    E1_TotalGamesLost  E1_TotalGamesTied  E1_TotalTimePlayed  \
# 0                522                127          121.181253
# 1                822                 79          182.559031
# 2                986                280          248.465858
#
#    E1_TotalGrenadeKills   E2_Gamertag  E2_SpartanRank  E2_PrevTotalXP  \
# 0                   622  Vincent 5593             149        18388319
# 1                   915   TotableZeus             152        50393335
# 2                  1258   TotableZeus             152        50390893
#
#    E2_TotalKills  E2_TotalHeadshots  E2_TotalWeaponDamage  E2_TotalShotsFired  \
# 0          12790               1262           1684482.176              371779
# 1          13209               2226           1771995.966              310586
# 2          13209               2226           1771995.966              310586
#
#    E2_TotalShotsLanded  E2_TotalMeleeKills  E2_TotalMeleeDamage  \
# 0               118414                 297          31542.31179
# 1               108407                 426          55482.92789
# 2               108407                 426          55482.92789
#
#    E2_TotalAssassinations  E2_TotalGroundPoundKills  \
# 0                      41                         5
# 1                     107                        10
# 2                     107                        10
#
#    E2_TotalGroundPoundDamage  E2_TotalShoulderBashKills  \
# 0                1799.382126                         60
# 1                3549.135921                         15
# 2                3549.135921                         15
#
#    E2_TotalShoulderBashDamage  E2_TotalGrenadeDamage  \
# 0                11246.566490            48645.77231
# 1                 4227.417664           107495.89430
# 2                 4227.417664           107495.89430
#
#    E2_TotalPowerWeaponKills  E2_TotalPowerWeaponDamage  \
# 0                     10966                1422631.281
# 1                      9786                1283124.698
# 2                      9786                1283124.698
#
#    E2_TotalPowerWeaponGrabs E2_TotalPowerWeaponPossessionTime  E2_TotalDeaths  \
# 0                        18                 P2DT14H27M3.2457S           11968
# 1                       184                P2DT12H27M12.2619S           13956
# 2                       184                P2DT12H27M12.2619S           13956
#
#    E2_TotalAssists  E2_TotalGamesCompleted  E2_TotalGamesWon  \
# 0             5457                    1044               362
# 1             5694                    1139               402
# 2             5694                    1139               402
#
#    E2_TotalGamesLost  E2_TotalGamesTied  E2_TotalTimePlayed  \
# 0                535                147          107.843492
# 1                622                115          124.481313
# 2                622                115          124.481313
#
#    E2_TotalGrenadeKills    E3_Gamertag  E3_SpartanRank  E3_PrevTotalXP  \
# 0                   171      Noble J76             147        11450262
# 1                   497  DanyTorres123             145         8731606
# 2                   497    charlezZ228             149        19076207
#
#    E3_TotalKills  E3_TotalHeadshots  E3_TotalWeaponDamage  E3_TotalShotsFired  \
# 0           6174                693          7.163374e+05              119575
# 1           6268                969          7.732204e+05              150020
# 2          13090               1966          1.614739e+06              249751
#
#    E3_TotalShotsLanded  E3_TotalMeleeKills  E3_TotalMeleeDamage  \
# 0                41628                 284          36559.27300
# 1                53167                 240          27062.24454
# 2                92898                 590          74317.29507
#
#    E3_TotalAssassinations  E3_TotalGroundPoundKills  \
# 0                      81                        34
# 1                      48                         3
# 2                     139                        29
#
#    E3_TotalGroundPoundDamage  E3_TotalShoulderBashKills  \
# 0                7355.041995                         42
# 1                 599.247807                          1
# 2                5427.876639                        122
#
#    E3_TotalShoulderBashDamage  E3_TotalGrenadeDamage  \
# 0                 9618.008672            49044.63998
# 1                  875.000000            15518.16956
# 2                19644.680740           118579.39140
#
#    E3_TotalPowerWeaponKills  E3_TotalPowerWeaponDamage  \
# 0                      4471               5.760876e+05
# 1                      5180               6.531948e+05
# 2                      9568               1.210915e+06
#
#    E3_TotalPowerWeaponGrabs E3_TotalPowerWeaponPossessionTime  E3_TotalDeaths  \
# 0                        10                   P1DT32M26.5998S            5624
# 1                         0                   P1DT50M25.8505S            5201
# 2                       154                P2DT11H17M19.4204S           15814
#
#    E3_TotalAssists  E3_TotalGamesCompleted  E3_TotalGamesWon  \
# 0             2011                     409               187
# 1             2228                     424               153
# 2             4507                    1129               457
#
#    E3_TotalGamesLost  E3_TotalGamesTied  E3_TotalTimePlayed  \
# 0                166                 56           44.727687
# 1                199                 72           44.032128
# 2                541                131          124.022817
#
#    E3_TotalGrenadeKills      E4_Gamertag  E4_SpartanRank  E4_PrevTotalXP  \
# 0                   222          MrAce2C              89         2573644
# 1                    87  waCkyWateRm3LoN              70         1723305
# 2                   494        Xoecy4263              43          622488
#
#    E4_TotalKills  E4_TotalHeadshots  E4_TotalWeaponDamage  E4_TotalShotsFired  \
# 0           1162                195           153926.5150               37952
# 1           1100                426           132589.5271               22536
# 2           1751                352           243191.0494               57678
#
#    E4_TotalShotsLanded  E4_TotalMeleeKills  E4_TotalMeleeDamage  \
# 0                11932                  57          8731.553861
# 1                 8725                 156         23400.353120
# 2                18932                  56          5328.879808
#
#    E4_TotalAssassinations  E4_TotalGroundPoundKills  \
# 0                      14                         1
# 1                      40                         2
# 2                      10                         0
#
#    E4_TotalGroundPoundDamage  E4_TotalShoulderBashKills  \
# 0                 115.000000                         21
# 1                   7.752099                         11
# 2                   0.000000                          1
#
#    E4_TotalShoulderBashDamage  E4_TotalGrenadeDamage  \
# 0                 2859.333313            7499.043766
# 1                 1290.497803            2365.737600
# 2                  282.250000           11689.892470
#
#    E4_TotalPowerWeaponKills  E4_TotalPowerWeaponDamage  \
# 0                       628                79717.32960
# 1                       304                41107.47136
# 2                      1336               178937.82920
#
#    E4_TotalPowerWeaponGrabs E4_TotalPowerWeaponPossessionTime  E4_TotalDeaths  \
# 0                        18                   PT2H59M39.6153S            1089
# 1                        31                   PT1H50M55.1666S            1227
# 2                         0                   PT6H28M57.5337S            1603
#
#    E4_TotalAssists  E4_TotalGamesCompleted  E4_TotalGamesWon  \
# 0              445                     107                52
# 1              559                     105                35
# 2              853                     117                49
#
#    E4_TotalGamesLost  E4_TotalGamesTied  E4_TotalTimePlayed  \
# 0                 48                  7           11.855415
# 1                 65                  5           12.014393
# 2                 48                 20           12.392531
#
#    E4_TotalGrenadeKills
# 0                    43
# 1                    11
# 2                    40

# %%
# Define roster to interact with dataframe
roster = ['P1', 'P2', 'P3', 'P4', 'E1', 'E2', 'E3', 'E4']

# Loop through players in roster
for player in roster:
    
    # Empty list of parsed times
    parsed_times = []
    
    # Parse times for each player 
    for row in df[f'{player}_TotalPowerWeaponPossessionTime']:
        row = isodate.parse_duration(row).total_seconds() / 3600
        parsed_times.append(row)
    
    # Set column to parsed times list
    df[f'{player}_TotalPowerWeaponPossessionTime'] = parsed_times

df['P1_TotalPowerWeaponPossessionTime']
# Out:
# 0         14.334023
# 1        157.602300
# 2        215.471346
# 3        346.243585
# 4        157.602300
#             ...
# 17149     78.836189
# 17150    236.848029
# 17151    195.612312
# 17152    159.773125
# 17153    159.671667
# Name: P1_TotalPowerWeaponPossessionTime, Length: 17137, dtype: float64

# %%
# This function will convert codes provided by the API into a readable format
def decode_column(df, column, api_dict):
    
    # Empty list of decoded values
    decoded_list = []
    
    # Loop through each row
    for row in df[column]:
        i = 0
        
        # Loop through API dictionary
        for item in api_dict:
            
            # If code found, append it to list
            if item['id'] == row:
                name = item['name']
                decoded_list.append(name)
            
            # Otherwise keep searching until found
            else:
                i += 1
    
    # Return decoded list
    return decoded_list

# %%
# This function will convert maps to readable format
def decode_maps(df, column, api_dict):
    decoded_list = []
    
    # Loop through each row
    for row in df[column]:
        i = 0
        
        # Creating map_count variable
        map_count = len(api_dict)
        
        # For each item in API dictionary
        for item in api_dict:
            
            # If map cannot be found, name 'Custom Map'
            if (i+1) == map_count:
                name = 'Custom Map'
                decoded_list.append(name)
            
            # If found, assign value to code
            elif item['id'] == row:
                name = item['name']
                decoded_list.append(name)
            
            # Otherwise keep looping
            else:
                i += 1
    
    # Return decoded list
    return decoded_list

# %%
# Loading GameBaseVariantId metadata dictionary pulled from API
with open('GameBaseVariantId.pkl', 'rb') as GameBaseVariantId_pickle:
    GameBaseVariantId_dic = pickle.load(GameBaseVariantId_pickle)

# Loading PlaylistId metadata dictionary pulled from API
with open('PlaylistId_dic.pkl', 'rb') as PlaylistId_dic_pickle:
    PlaylistId_dic = pickle.load(PlaylistId_dic_pickle)

# Loading map_list metadata dictionary pulled from API
with open('map_list.pkl', 'rb') as map_list_pickle:
    map_list = pickle.load(map_list_pickle)

# Decode columsn with using our decode functions
df['GameBaseVariantId'] = decode_column(df, 'GameBaseVariantId', GameBaseVariantId_dic)    
df['PlaylistId'] = decode_column(df, 'PlaylistId', PlaylistId_dic)
df['MapVariantId'] = decode_maps(df, 'MapVariantId', map_list)

df[['GameBaseVariantId', 'PlaylistId', 'MapVariantId']].head(3)
# Out:
#   GameBaseVariantId          PlaylistId              MapVariantId
# 0            Slayer  Super Fiesta Party                   Transit
# 1  Capture the Flag  Super Fiesta Party                  Coliseum
# 2  Capture the Flag  Super Fiesta Party  Raid on the Control Room

# %%
# Remove ties from df
df = df[df['WinLoseTie'] != 'Tie']

# Set victories to 1 and defeats to 0
df.loc[(df['WinLoseTie'] == 'Victory'),'WinLoseTie'] = 1
df.loc[(df['WinLoseTie'] == 'Defeat'),'WinLoseTie'] = 0

# Convert to integers to be safe
df['WinLoseTie'] = df['WinLoseTie'].astype('int')

# Set date range, only want matches later than 7/1/21
df = df[(df['Date'] > '2021-07-01')]

df.head(3)
# Out:
#                  Date                               MatchId GameBaseVariantId  \
# 0 2021-07-17 21:39:00  1bc32b01-2dda-418a-8853-ba3d3b09f912            Slayer
# 1 2021-07-19 00:29:00  06c5149f-72af-4678-9615-7d2db89db290  Capture the Flag
# 2 2021-07-19 00:25:00  7801d2b0-f941-4851-9b04-8208a5439497  Capture the Flag
#
#            PlaylistId              MapVariantId  WinLoseTie    P1_Gamertag  \
# 0  Super Fiesta Party                   Transit           0  TED Cloverlan
# 1  Super Fiesta Party                  Coliseum           1      Drymander
# 2  Super Fiesta Party  Raid on the Control Room           1    TWINKYNECKS
#
#    P1_SpartanRank  P1_PrevTotalXP  P1_TotalKills  P1_TotalHeadshots  \
# 0             102         3348130           3378                551
# 1             148        15348257          39273               3202
# 2             151        37161347          58661              11418
#
#    P1_TotalWeaponDamage  P1_TotalShotsFired  P1_TotalShotsLanded  \
# 0          4.362411e+05               96140                31174
# 1          5.020049e+06             1025141               367059
# 2          7.990578e+06             1326652               460037
#
#    P1_TotalMeleeKills  P1_TotalMeleeDamage  P1_TotalAssassinations  \
# 0                 150          14200.28244                      13
# 1                1289         147219.06830                     216
# 2                1669         222380.10050                     325
#
#    P1_TotalGroundPoundKills  P1_TotalGroundPoundDamage  \
# 0                         1                 435.899994
# 1                        26                5870.122829
# 2                       118               21481.336320
#
#    P1_TotalShoulderBashKills  P1_TotalShoulderBashDamage  \
# 0                         12                 1809.374457
# 1                        123                26233.730550
# 2                        374                65457.288060
#
#    P1_TotalGrenadeDamage  P1_TotalPowerWeaponKills  P1_TotalPowerWeaponDamage  \
# 0            17833.89112                      2746               3.535647e+05
# 1           192043.79460                     34812               4.462575e+06
# 2           867137.32960                     44999               5.979214e+06
#
#    P1_TotalPowerWeaponGrabs  P1_TotalPowerWeaponPossessionTime  \
# 0                         0                          14.334023
# 1                        16                         157.602300
# 2                       270                         215.471346
#
#    P1_TotalDeaths  P1_TotalAssists  P1_TotalGamesCompleted  P1_TotalGamesWon  \
# 0            3593             1499                     256               124
# 1           44504            14978                    3051              1594
# 2           61053            25331                    3568              1565
#
#    P1_TotalGamesLost  P1_TotalGamesTied  P1_TotalTimePlayed  \
# 0                105                 27           26.475012
# 1               1198                259          288.020209
# 2               1567                436          417.975375
#
#    P1_TotalGrenadeKills      P2_Gamertag  P2_SpartanRank  P2_PrevTotalXP  \
# 0                    69  TackleZoMbIeZ90              72         1755469
# 1                   687   its ghobi baby             149        23870326
# 2                  3314        Drymander             148        15345204
#
#    P2_TotalKills  P2_TotalHeadshots  P2_TotalWeaponDamage  P2_TotalShotsFired  \
# 0           3388                378          4.506744e+05              123305
# 1          39309               6720          5.369387e+06             1111772
# 2          39273               3202          5.020049e+06             1025141
#
#    P2_TotalShotsLanded  P2_TotalMeleeKills  P2_TotalMeleeDamage  \
# 0                33670                 115          13798.77195
# 1               391306                 876         105948.32160
# 2               367059                1289         147219.06830
#
#    P2_TotalAssassinations  P2_TotalGroundPoundKills  \
# 0                      22                         9
# 1                     130                         0
# 2                     216                        26
#
#    P2_TotalGroundPoundDamage  P2_TotalShoulderBashKills  \
# 0                2178.285184                         20
# 1                   0.000000                          9
# 2                5870.122829                        123
#
#    P2_TotalShoulderBashDamage  P2_TotalGrenadeDamage  \
# 0                 3866.135540            33681.92404
# 1                 1718.871307           480275.91350
# 2                26233.730550           192043.79460
#
#    P2_TotalPowerWeaponKills  P2_TotalPowerWeaponDamage  \
# 0                      2706               3.561506e+05
# 1                     31754               4.124953e+06
# 2                     34812               4.462575e+06
#
#    P2_TotalPowerWeaponGrabs  P2_TotalPowerWeaponPossessionTime  \
# 0                         3                          14.473583
# 1                         3                         124.635187
# 2                        16                         157.602300
#
#    P2_TotalDeaths  P2_TotalAssists  P2_TotalGamesCompleted  P2_TotalGamesWon  \
# 0            2804             1630                     231               100
# 1           35407            19300                    2382              1330
# 2           44504            14978                    3051              1594
#
#    P2_TotalGamesLost  P2_TotalGamesTied  P2_TotalTimePlayed  \
# 0                 94                 37           25.016905
# 1                772                280          241.513053
# 2               1198                259          288.020209
#
#    P2_TotalGrenadeKills      P3_Gamertag  P3_SpartanRank  P3_PrevTotalXP  \
# 0                   132  MrPicardBottoms             145         8584030
# 1                  1649     Noob JSkeree              96         2970740
# 2                   687  PumpedAlpaca184             146         9774869
#
#    P3_TotalKills  P3_TotalHeadshots  P3_TotalWeaponDamage  P3_TotalShotsFired  \
# 0           1882                309          2.504024e+05               54355
# 1           7914                801          9.670463e+05              143169
# 2          21952               3777          2.937519e+06              521487
#
#    P3_TotalShotsLanded  P3_TotalMeleeKills  P3_TotalMeleeDamage  \
# 0                17223                 130          13866.32449
# 1                41817                 211          26461.92472
# 2               203513                 907          96793.46693
#
#    P3_TotalAssassinations  P3_TotalGroundPoundKills  \
# 0                      21                         5
# 1                      31                        35
# 2                     107                        18
#
#    P3_TotalGroundPoundDamage  P3_TotalShoulderBashKills  \
# 0                1778.400188                         19
# 1                8937.051069                         25
# 2                3082.305937                         71
#
#    P3_TotalShoulderBashDamage  P3_TotalGrenadeDamage  \
# 0                 3887.518391            17023.67813
# 1                 4594.986589           162607.74880
# 2                16138.151560           219603.14600
#
#    P3_TotalPowerWeaponKills  P3_TotalPowerWeaponDamage  \
# 0                      1306               1.785042e+05
# 1                      5453               6.966502e+05
# 2                     16367               2.128939e+06
#
#    P3_TotalPowerWeaponGrabs  P3_TotalPowerWeaponPossessionTime  \
# 0                        17                           6.340588
# 1                        13                          45.035912
# 2                        52                          74.455840
#
#    P3_TotalDeaths  P3_TotalAssists  P3_TotalGamesCompleted  P3_TotalGamesWon  \
# 0            2034              828                     146                60
# 1            7935             2866                     570               216
# 2           25535            10584                    1359               591
#
#    P3_TotalGamesLost  P3_TotalGamesTied  P3_TotalTimePlayed  \
# 0                 70                 16           15.919856
# 1                245                109           73.169910
# 2                586                182          160.492698
#
#    P3_TotalGrenadeKills      P4_Gamertag  P4_SpartanRank  P4_PrevTotalXP  \
# 0                    62  GermanGames6869             144         7375370
# 1                   773      Daniel TSM5              98         3105846
# 2                   787      Psycho Smak              48          759776
#
#    P4_TotalKills  P4_TotalHeadshots  P4_TotalWeaponDamage  P4_TotalShotsFired  \
# 0           1315                253           163307.5974               22859
# 1           2646                399           324629.8990               65294
# 2           6436               1229           853174.8455              161503
#
#    P4_TotalShotsLanded  P4_TotalMeleeKills  P4_TotalMeleeDamage  \
# 0                 9212                  34          6087.614542
# 1                24390                 120         13928.636150
# 2                56437                  93         11200.409080
#
#    P4_TotalAssassinations  P4_TotalGroundPoundKills  \
# 0                       6                         3
# 1                      32                        15
# 2                      19                         0
#
#    P4_TotalGroundPoundDamage  P4_TotalShoulderBashKills  \
# 0                 776.223419                         13
# 1                1363.579624                         18
# 2                   0.000000                          1
#
#    P4_TotalShoulderBashDamage  P4_TotalGrenadeDamage  \
# 0                 3712.180248            10792.43986
# 1                 3102.606691            11552.87847
# 2                  164.162956            64568.21276
#
#    P4_TotalPowerWeaponKills  P4_TotalPowerWeaponDamage  \
# 0                      1002                123037.4187
# 1                      2093                263532.4852
# 2                      5300                678333.8271
#
#    P4_TotalPowerWeaponGrabs  P4_TotalPowerWeaponPossessionTime  \
# 0                        23                           5.379408
# 1                         0                          10.007569
# 2                         0                          26.788316
#
#    P4_TotalDeaths  P4_TotalAssists  P4_TotalGamesCompleted  P4_TotalGamesWon  \
# 0            1410              392                     102                49
# 1            2493              928                     187                79
# 2            5543             3132                     433               190
#
#    P4_TotalGamesLost  P4_TotalGamesTied  P4_TotalTimePlayed  \
# 0                 40                 13           11.637733
# 1                 87                 21           18.867221
# 2                184                 59           46.458067
#
#    P4_TotalGrenadeKills      E1_Gamertag  E1_SpartanRank  E1_PrevTotalXP  \
# 0                    41   TheJudgePaul91             152        52946125
# 1                    46          xxRowan             149        18608380
# 2                   226  PeakTree4879815             147        11150915
#
#    E1_TotalKills  E1_TotalHeadshots  E1_TotalWeaponDamage  E1_TotalShotsFired  \
# 0          16222               3950           2140170.267              439309
# 1          19844               7015           2720339.122              446426
# 2          31941               5861           4173908.467              719658
#
#    E1_TotalShotsLanded  E1_TotalMeleeKills  E1_TotalMeleeDamage  \
# 0               141949                 704          95917.87382
# 1               187932                1067         124757.00720
# 2               248379                 869         113148.63170
#
#    E1_TotalAssassinations  E1_TotalGroundPoundKills  \
# 0                     148                         6
# 1                     219                        16
# 2                     186                        37
#
#    E1_TotalGroundPoundDamage  E1_TotalShoulderBashKills  \
# 0                 990.599998                         82
# 1                1435.099349                          2
# 2                9390.987291                         79
#
#    E1_TotalShoulderBashDamage  E1_TotalGrenadeDamage  \
# 0                  8975.22238            132581.0872
# 1                   332.50000            184216.2895
# 2                 21581.61390            284210.2578
#
#    E1_TotalPowerWeaponKills  E1_TotalPowerWeaponDamage  \
# 0                     11464                1513326.279
# 1                      8652                1156967.202
# 2                     25437                3284115.189
#
#    E1_TotalPowerWeaponGrabs  E1_TotalPowerWeaponPossessionTime  \
# 0                        40                          52.563167
# 1                       575                          46.762009
# 2                       116                         140.548636
#
#    E1_TotalDeaths  E1_TotalAssists  E1_TotalGamesCompleted  E1_TotalGamesWon  \
# 0           14354             6974                    1114               465
# 1           17082             9207                    1497               596
# 2           25248            12021                    2121               855
#
#    E1_TotalGamesLost  E1_TotalGamesTied  E1_TotalTimePlayed  \
# 0                522                127          121.181253
# 1                822                 79          182.559031
# 2                986                280          248.465858
#
#    E1_TotalGrenadeKills   E2_Gamertag  E2_SpartanRank  E2_PrevTotalXP  \
# 0                   622  Vincent 5593             149        18388319
# 1                   915   TotableZeus             152        50393335
# 2                  1258   TotableZeus             152        50390893
#
#    E2_TotalKills  E2_TotalHeadshots  E2_TotalWeaponDamage  E2_TotalShotsFired  \
# 0          12790               1262           1684482.176              371779
# 1          13209               2226           1771995.966              310586
# 2          13209               2226           1771995.966              310586
#
#    E2_TotalShotsLanded  E2_TotalMeleeKills  E2_TotalMeleeDamage  \
# 0               118414                 297          31542.31179
# 1               108407                 426          55482.92789
# 2               108407                 426          55482.92789
#
#    E2_TotalAssassinations  E2_TotalGroundPoundKills  \
# 0                      41                         5
# 1                     107                        10
# 2                     107                        10
#
#    E2_TotalGroundPoundDamage  E2_TotalShoulderBashKills  \
# 0                1799.382126                         60
# 1                3549.135921                         15
# 2                3549.135921                         15
#
#    E2_TotalShoulderBashDamage  E2_TotalGrenadeDamage  \
# 0                11246.566490            48645.77231
# 1                 4227.417664           107495.89430
# 2                 4227.417664           107495.89430
#
#    E2_TotalPowerWeaponKills  E2_TotalPowerWeaponDamage  \
# 0                     10966                1422631.281
# 1                      9786                1283124.698
# 2                      9786                1283124.698
#
#    E2_TotalPowerWeaponGrabs  E2_TotalPowerWeaponPossessionTime  \
# 0                        18                          62.450902
# 1                       184                          60.453406
# 2                       184                          60.453406
#
#    E2_TotalDeaths  E2_TotalAssists  E2_TotalGamesCompleted  E2_TotalGamesWon  \
# 0           11968             5457                    1044               362
# 1           13956             5694                    1139               402
# 2           13956             5694                    1139               402
#
#    E2_TotalGamesLost  E2_TotalGamesTied  E2_TotalTimePlayed  \
# 0                535                147          107.843492
# 1                622                115          124.481313
# 2                622                115          124.481313
#
#    E2_TotalGrenadeKills    E3_Gamertag  E3_SpartanRank  E3_PrevTotalXP  \
# 0                   171      Noble J76             147        11450262
# 1                   497  DanyTorres123             145         8731606
# 2                   497    charlezZ228             149        19076207
#
#    E3_TotalKills  E3_TotalHeadshots  E3_TotalWeaponDamage  E3_TotalShotsFired  \
# 0           6174                693          7.163374e+05              119575
# 1           6268                969          7.732204e+05              150020
# 2          13090               1966          1.614739e+06              249751
#
#    E3_TotalShotsLanded  E3_TotalMeleeKills  E3_TotalMeleeDamage  \
# 0                41628                 284          36559.27300
# 1                53167                 240          27062.24454
# 2                92898                 590          74317.29507
#
#    E3_TotalAssassinations  E3_TotalGroundPoundKills  \
# 0                      81                        34
# 1                      48                         3
# 2                     139                        29
#
#    E3_TotalGroundPoundDamage  E3_TotalShoulderBashKills  \
# 0                7355.041995                         42
# 1                 599.247807                          1
# 2                5427.876639                        122
#
#    E3_TotalShoulderBashDamage  E3_TotalGrenadeDamage  \
# 0                 9618.008672            49044.63998
# 1                  875.000000            15518.16956
# 2                19644.680740           118579.39140
#
#    E3_TotalPowerWeaponKills  E3_TotalPowerWeaponDamage  \
# 0                      4471               5.760876e+05
# 1                      5180               6.531948e+05
# 2                      9568               1.210915e+06
#
#    E3_TotalPowerWeaponGrabs  E3_TotalPowerWeaponPossessionTime  \
# 0                        10                          24.540722
# 1                         0                          24.840514
# 2                       154                          59.288728
#
#    E3_TotalDeaths  E3_TotalAssists  E3_TotalGamesCompleted  E3_TotalGamesWon  \
# 0            5624             2011                     409               187
# 1            5201             2228                     424               153
# 2           15814             4507                    1129               457
#
#    E3_TotalGamesLost  E3_TotalGamesTied  E3_TotalTimePlayed  \
# 0                166                 56           44.727687
# 1                199                 72           44.032128
# 2                541                131          124.022817
#
#    E3_TotalGrenadeKills      E4_Gamertag  E4_SpartanRank  E4_PrevTotalXP  \
# 0                   222          MrAce2C              89         2573644
# 1                    87  waCkyWateRm3LoN              70         1723305
# 2                   494        Xoecy4263              43          622488
#
#    E4_TotalKills  E4_TotalHeadshots  E4_TotalWeaponDamage  E4_TotalShotsFired  \
# 0           1162                195           153926.5150               37952
# 1           1100                426           132589.5271               22536
# 2           1751                352           243191.0494               57678
#
#    E4_TotalShotsLanded  E4_TotalMeleeKills  E4_TotalMeleeDamage  \
# 0                11932                  57          8731.553861
# 1                 8725                 156         23400.353120
# 2                18932                  56          5328.879808
#
#    E4_TotalAssassinations  E4_TotalGroundPoundKills  \
# 0                      14                         1
# 1                      40                         2
# 2                      10                         0
#
#    E4_TotalGroundPoundDamage  E4_TotalShoulderBashKills  \
# 0                 115.000000                         21
# 1                   7.752099                         11
# 2                   0.000000                          1
#
#    E4_TotalShoulderBashDamage  E4_TotalGrenadeDamage  \
# 0                 2859.333313            7499.043766
# 1                 1290.497803            2365.737600
# 2                  282.250000           11689.892470
#
#    E4_TotalPowerWeaponKills  E4_TotalPowerWeaponDamage  \
# 0                       628                79717.32960
# 1                       304                41107.47136
# 2                      1336               178937.82920
#
#    E4_TotalPowerWeaponGrabs  E4_TotalPowerWeaponPossessionTime  \
# 0                        18                           2.994338
# 1                        31                           1.848657
# 2                         0                           6.482648
#
#    E4_TotalDeaths  E4_TotalAssists  E4_TotalGamesCompleted  E4_TotalGamesWon  \
# 0            1089              445                     107                52
# 1            1227              559                     105                35
# 2            1603              853                     117                49
#
#    E4_TotalGamesLost  E4_TotalGamesTied  E4_TotalTimePlayed  \
# 0                 48                  7           11.855415
# 1                 65                  5           12.014393
# 2                 48                 20           12.392531
#
#    E4_TotalGrenadeKills
# 0                    43
# 1                    11
# 2                    40

# %% [markdown]
# # Choose GameBaseVariantId to model

# %%
# Function to choose gametype
def choose_gametype(df, GameBaseVariantId, PlaylistId):
    
    # If none selected, return df
    # This will be useful for the next function
    if GameBaseVariantId == None and PlaylistId == None:
        gametype_df = df
    
    # Option to set GameBaseVariantId to None
    elif GameBaseVariantId == None:
        gametype_df = df[df['PlaylistId'] == PlaylistId]
    
    # Option to set PlaylistId to None
    elif PlaylistId == None:
        gametype_df = df[df['GameBaseVariantId'] == GameBaseVariantId]
    
    # Set dataframe to specified GameBaseVariantId and PlaylistId
    else:
        gametype_df = df[(df['GameBaseVariantId'] == GameBaseVariantId) & (df['PlaylistId'] == PlaylistId)]
    
    # Return dataframe
    return gametype_df

# Set to Super Fiesta Party
df = choose_gametype(df, None, 'Super Fiesta Party')

# Check function with value counts
df['PlaylistId'].value_counts()
# Out:
# Super Fiesta Party    9257
# Name: PlaylistId, dtype: int64

# %% [markdown]
# ## Drop columns

# %%
# Drop unnecessary columns
df = df.drop(['Date',
        'MatchId',
        'GameBaseVariantId',
        'PlaylistId',
        'MapVariantId',
        'P1_Gamertag',
        'P2_Gamertag',
        'P3_Gamertag',
        'P4_Gamertag',
        'E1_Gamertag',
        'E2_Gamertag',
        'E3_Gamertag',
        'E4_Gamertag',
        ]
        ,axis=1)

# Rename WinLoseTie to PlayerWin for clarity
df.rename(columns={'WinLoseTie':'PlayerWin'}, inplace=True)

df.head(5)
# Out:
#    PlayerWin  P1_SpartanRank  P1_PrevTotalXP  P1_TotalKills  \
# 0          0             102         3348130           3378
# 1          1             148        15348257          39273
# 2          1             151        37161347          58661
# 3          1             151        47050485         100339
# 4          1             148        15342496          39273
#
#    P1_TotalHeadshots  P1_TotalWeaponDamage  P1_TotalShotsFired  \
# 0                551          4.362411e+05               96140
# 1               3202          5.020049e+06             1025141
# 2              11418          7.990578e+06             1326652
# 3              22173          1.279709e+07             2176535
# 4               3202          5.020049e+06             1025141
#
#    P1_TotalShotsLanded  P1_TotalMeleeKills  P1_TotalMeleeDamage  \
# 0                31174                 150          14200.28244
# 1               367059                1289         147219.06830
# 2               460037                1669         222380.10050
# 3               766384                1959         228599.80510
# 4               367059                1289         147219.06830
#
#    P1_TotalAssassinations  P1_TotalGroundPoundKills  \
# 0                      13                         1
# 1                     216                        26
# 2                     325                       118
# 3                     375                        39
# 4                     216                        26
#
#    P1_TotalGroundPoundDamage  P1_TotalShoulderBashKills  \
# 0                 435.899994                         12
# 1                5870.122829                        123
# 2               21481.336320                        374
# 3                6033.137176                         89
# 4                5870.122829                        123
#
#    P1_TotalShoulderBashDamage  P1_TotalGrenadeDamage  \
# 0                 1809.374457            17833.89112
# 1                26233.730550           192043.79460
# 2                65457.288060           867137.32960
# 3                12423.010870           905357.84200
# 4                26233.730550           192043.79460
#
#    P1_TotalPowerWeaponKills  P1_TotalPowerWeaponDamage  \
# 0                      2746               3.535647e+05
# 1                     34812               4.462575e+06
# 2                     44999               5.979214e+06
# 3                     87067               1.075508e+07
# 4                     34812               4.462575e+06
#
#    P1_TotalPowerWeaponGrabs  P1_TotalPowerWeaponPossessionTime  \
# 0                         0                          14.334023
# 1                        16                         157.602300
# 2                       270                         215.471346
# 3                        69                         346.243585
# 4                        16                         157.602300
#
#    P1_TotalDeaths  P1_TotalAssists  P1_TotalGamesCompleted  P1_TotalGamesWon  \
# 0            3593             1499                     256               124
# 1           44504            14978                    3051              1594
# 2           61053            25331                    3568              1565
# 3           63783            33268                    4867              2023
# 4           44504            14978                    3051              1594
#
#    P1_TotalGamesLost  P1_TotalGamesTied  P1_TotalTimePlayed  \
# 0                105                 27           26.475012
# 1               1198                259          288.020209
# 2               1567                436          417.975375
# 3               2032                812          558.988557
# 4               1198                259          288.020209
#
#    P1_TotalGrenadeKills  P2_SpartanRank  P2_PrevTotalXP  P2_TotalKills  \
# 0                    69              72         1755469           3388
# 1                   687             149        23870326          39309
# 2                  3314             148        15345204          39273
# 3                  2878             150        25138214          73644
# 4                   687             145         8986431          11675
#
#    P2_TotalHeadshots  P2_TotalWeaponDamage  P2_TotalShotsFired  \
# 0                378          4.506744e+05              123305
# 1               6720          5.369387e+06             1111772
# 2               3202          5.020049e+06             1025141
# 3              11265          9.922924e+06             2081512
# 4               2525          1.584917e+06              310439
#
#    P2_TotalShotsLanded  P2_TotalMeleeKills  P2_TotalMeleeDamage  \
# 0                33670                 115          13798.77195
# 1               391306                 876         105948.32160
# 2               367059                1289         147219.06830
# 3               669436                1568         192638.97540
# 4               108355                 319          44222.39503
#
#    P2_TotalAssassinations  P2_TotalGroundPoundKills  \
# 0                      22                         9
# 1                     130                         0
# 2                     216                        26
# 3                     212                        44
# 4                      84                         3
#
#    P2_TotalGroundPoundDamage  P2_TotalShoulderBashKills  \
# 0                2178.285184                         20
# 1                   0.000000                          9
# 2                5870.122829                        123
# 3                7041.194090                        114
# 4                 437.500000                         40
#
#    P2_TotalShoulderBashDamage  P2_TotalGrenadeDamage  \
# 0                 3866.135540            33681.92404
# 1                 1718.871307           480275.91350
# 2                26233.730550           192043.79460
# 3                29377.620450           447423.20260
# 4                 6723.297248            78299.87460
#
#    P2_TotalPowerWeaponKills  P2_TotalPowerWeaponDamage  \
# 0                      2706               3.561506e+05
# 1                     31754               4.124953e+06
# 2                     34812               4.462575e+06
# 3                     62187               8.212049e+06
# 4                      9265               1.240237e+06
#
#    P2_TotalPowerWeaponGrabs  P2_TotalPowerWeaponPossessionTime  \
# 0                         3                          14.473583
# 1                         3                         124.635187
# 2                        16                         157.602300
# 3                         6                         268.604838
# 4                         3                          37.255634
#
#    P2_TotalDeaths  P2_TotalAssists  P2_TotalGamesCompleted  P2_TotalGamesWon  \
# 0            2804             1630                     231               100
# 1           35407            19300                    2382              1330
# 2           44504            14978                    3051              1594
# 3           77764            31658                    4829              2264
# 4           10656             5070                     650               293
#
#    P2_TotalGamesLost  P2_TotalGamesTied  P2_TotalTimePlayed  \
# 0                 94                 37           25.016905
# 1                772                280          241.513053
# 2               1198                259          288.020209
# 3               1939                626          509.550529
# 4                266                 91           73.749186
#
#    P2_TotalGrenadeKills  P3_SpartanRank  P3_PrevTotalXP  P3_TotalKills  \
# 0                   132             145         8584030           1882
# 1                  1649              96         2970740           7914
# 2                   687             146         9774869          21952
# 3                  1681             150        28963826          67990
# 4                   318             151        42591953           8780
#
#    P3_TotalHeadshots  P3_TotalWeaponDamage  P3_TotalShotsFired  \
# 0                309          2.504024e+05               54355
# 1                801          9.670463e+05              143169
# 2               3777          2.937519e+06              521487
# 3              13972          9.059519e+06             1602064
# 4               1338          1.131636e+06              185417
#
#    P3_TotalShotsLanded  P3_TotalMeleeKills  P3_TotalMeleeDamage  \
# 0                17223                 130          13866.32449
# 1                41817                 211          26461.92472
# 2               203513                 907          96793.46693
# 3               594433                1131         142355.90000
# 4                73199                 202          25683.02879
#
#    P3_TotalAssassinations  P3_TotalGroundPoundKills  \
# 0                      21                         5
# 1                      31                        35
# 2                     107                        18
# 3                     155                         7
# 4                      44                        13
#
#    P3_TotalGroundPoundDamage  P3_TotalShoulderBashKills  \
# 0                1778.400188                         19
# 1                8937.051069                         25
# 2                3082.305937                         71
# 3                1549.980980                         18
# 4                3413.963149                         53
#
#    P3_TotalShoulderBashDamage  P3_TotalGrenadeDamage  \
# 0                 3887.518391            17023.67813
# 1                 4594.986589           162607.74880
# 2                16138.151560           219603.14600
# 3                 3564.747462           515516.28270
# 4                 8892.856932            70735.08642
#
#    P3_TotalPowerWeaponKills  P3_TotalPowerWeaponDamage  \
# 0                      1306               1.785042e+05
# 1                      5453               6.966502e+05
# 2                     16367               2.128939e+06
# 3                     52836               6.812084e+06
# 4                      6652               8.405961e+05
#
#    P3_TotalPowerWeaponGrabs  P3_TotalPowerWeaponPossessionTime  \
# 0                        17                           6.340588
# 1                        13                          45.035912
# 2                        52                          74.455840
# 3                        55                         180.095888
# 4                        16                          27.263305
#
#    P3_TotalDeaths  P3_TotalAssists  P3_TotalGamesCompleted  P3_TotalGamesWon  \
# 0            2034              828                     146                60
# 1            7935             2866                     570               216
# 2           25535            10584                    1359               591
# 3           54037            26641                    3465              1825
# 4            7740             3488                     551               321
#
#    P3_TotalGamesLost  P3_TotalGamesTied  P3_TotalTimePlayed  \
# 0                 70                 16           15.919856
# 1                245                109           73.169910
# 2                586                182          160.492698
# 3               1257                383          379.261607
# 4                187                 43           58.029374
#
#    P3_TotalGrenadeKills  P4_SpartanRank  P4_PrevTotalXP  P4_TotalKills  \
# 0                    62             144         7375370           1315
# 1                   773              98         3105846           2646
# 2                   787              48          759776           6436
# 3                  2034             148        15343353          39273
# 4                   305             149        20307647           5539
#
#    P4_TotalHeadshots  P4_TotalWeaponDamage  P4_TotalShotsFired  \
# 0                253          1.633076e+05               22859
# 1                399          3.246299e+05               65294
# 2               1229          8.531748e+05              161503
# 3               3202          5.020049e+06             1025141
# 4                980          7.203931e+05              111881
#
#    P4_TotalShotsLanded  P4_TotalMeleeKills  P4_TotalMeleeDamage  \
# 0                 9212                  34          6087.614542
# 1                24390                 120         13928.636150
# 2                56437                  93         11200.409080
# 3               367059                1289        147219.068300
# 4                39568                 140         22794.301900
#
#    P4_TotalAssassinations  P4_TotalGroundPoundKills  \
# 0                       6                         3
# 1                      32                        15
# 2                      19                         0
# 3                     216                        26
# 4                      36                         6
#
#    P4_TotalGroundPoundDamage  P4_TotalShoulderBashKills  \
# 0                 776.223419                         13
# 1                1363.579624                         18
# 2                   0.000000                          1
# 3                5870.122829                        123
# 4                 962.931915                         23
#
#    P4_TotalShoulderBashDamage  P4_TotalGrenadeDamage  \
# 0                 3712.180248            10792.43986
# 1                 3102.606691            11552.87847
# 2                  164.162956            64568.21276
# 3                26233.730550           192043.79460
# 4                 4721.356329            59299.09927
#
#    P4_TotalPowerWeaponKills  P4_TotalPowerWeaponDamage  \
# 0                      1002               1.230374e+05
# 1                      2093               2.635325e+05
# 2                      5300               6.783338e+05
# 3                     34812               4.462575e+06
# 4                      4304               5.400171e+05
#
#    P4_TotalPowerWeaponGrabs  P4_TotalPowerWeaponPossessionTime  \
# 0                        23                           5.379408
# 1                         0                          10.007569
# 2                         0                          26.788316
# 3                        16                         157.602300
# 4                        22                          18.032953
#
#    P4_TotalDeaths  P4_TotalAssists  P4_TotalGamesCompleted  P4_TotalGamesWon  \
# 0            1410              392                     102                49
# 1            2493              928                     187                79
# 2            5543             3132                     433               190
# 3           44504            14978                    3051              1594
# 4            7012             2200                     373               249
#
#    P4_TotalGamesLost  P4_TotalGamesTied  P4_TotalTimePlayed  \
# 0                 40                 13           11.637733
# 1                 87                 21           18.867221
# 2                184                 59           46.458067
# 3               1198                259          288.020209
# 4                 97                 27           41.323951
#
#    P4_TotalGrenadeKills  E1_SpartanRank  E1_PrevTotalXP  E1_TotalKills  \
# 0                    41             152        52946125          16222
# 1                    46             149        18608380          19844
# 2                   226             147        11150915          31941
# 3                   687             147        11149681          31941
# 4                   235             150        25137635          73644
#
#    E1_TotalHeadshots  E1_TotalWeaponDamage  E1_TotalShotsFired  \
# 0               3950           2140170.267              439309
# 1               7015           2720339.122              446426
# 2               5861           4173908.467              719658
# 3               5861           4173908.467              719658
# 4              11265           9922923.785             2081512
#
#    E1_TotalShotsLanded  E1_TotalMeleeKills  E1_TotalMeleeDamage  \
# 0               141949                 704          95917.87382
# 1               187932                1067         124757.00720
# 2               248379                 869         113148.63170
# 3               248379                 869         113148.63170
# 4               669436                1568         192638.97540
#
#    E1_TotalAssassinations  E1_TotalGroundPoundKills  \
# 0                     148                         6
# 1                     219                        16
# 2                     186                        37
# 3                     186                        37
# 4                     212                        44
#
#    E1_TotalGroundPoundDamage  E1_TotalShoulderBashKills  \
# 0                 990.599998                         82
# 1                1435.099349                          2
# 2                9390.987291                         79
# 3                9390.987291                         79
# 4                7041.194090                        114
#
#    E1_TotalShoulderBashDamage  E1_TotalGrenadeDamage  \
# 0                  8975.22238            132581.0872
# 1                   332.50000            184216.2895
# 2                 21581.61390            284210.2578
# 3                 21581.61390            284210.2578
# 4                 29377.62045            447423.2026
#
#    E1_TotalPowerWeaponKills  E1_TotalPowerWeaponDamage  \
# 0                     11464                1513326.279
# 1                      8652                1156967.202
# 2                     25437                3284115.189
# 3                     25437                3284115.189
# 4                     62187                8212048.515
#
#    E1_TotalPowerWeaponGrabs  E1_TotalPowerWeaponPossessionTime  \
# 0                        40                          52.563167
# 1                       575                          46.762009
# 2                       116                         140.548636
# 3                       116                         140.548636
# 4                         6                         268.604838
#
#    E1_TotalDeaths  E1_TotalAssists  E1_TotalGamesCompleted  E1_TotalGamesWon  \
# 0           14354             6974                    1114               465
# 1           17082             9207                    1497               596
# 2           25248            12021                    2121               855
# 3           25248            12021                    2121               855
# 4           77764            31658                    4829              2264
#
#    E1_TotalGamesLost  E1_TotalGamesTied  E1_TotalTimePlayed  \
# 0                522                127          121.181253
# 1                822                 79          182.559031
# 2                986                280          248.465858
# 3                986                280          248.465858
# 4               1939                626          509.550529
#
#    E1_TotalGrenadeKills  E2_SpartanRank  E2_PrevTotalXP  E2_TotalKills  \
# 0                   622             149        18388319          12790
# 1                   915             152        50393335          13209
# 2                  1258             152        50390893          13209
# 3                  1258             149        19074972          13090
# 4                  1681             150        28963191          67990
#
#    E2_TotalHeadshots  E2_TotalWeaponDamage  E2_TotalShotsFired  \
# 0               1262           1684482.176              371779
# 1               2226           1771995.966              310586
# 2               2226           1771995.966              310586
# 3               1966           1614739.074              249751
# 4              13972           9059519.099             1602064
#
#    E2_TotalShotsLanded  E2_TotalMeleeKills  E2_TotalMeleeDamage  \
# 0               118414                 297          31542.31179
# 1               108407                 426          55482.92789
# 2               108407                 426          55482.92789
# 3                92898                 590          74317.29507
# 4               594433                1131         142355.90000
#
#    E2_TotalAssassinations  E2_TotalGroundPoundKills  \
# 0                      41                         5
# 1                     107                        10
# 2                     107                        10
# 3                     139                        29
# 4                     155                         7
#
#    E2_TotalGroundPoundDamage  E2_TotalShoulderBashKills  \
# 0                1799.382126                         60
# 1                3549.135921                         15
# 2                3549.135921                         15
# 3                5427.876639                        122
# 4                1549.980980                         18
#
#    E2_TotalShoulderBashDamage  E2_TotalGrenadeDamage  \
# 0                11246.566490            48645.77231
# 1                 4227.417664           107495.89430
# 2                 4227.417664           107495.89430
# 3                19644.680740           118579.39140
# 4                 3564.747462           515516.28270
#
#    E2_TotalPowerWeaponKills  E2_TotalPowerWeaponDamage  \
# 0                     10966                1422631.281
# 1                      9786                1283124.698
# 2                      9786                1283124.698
# 3                      9568                1210914.765
# 4                     52836                6812083.523
#
#    E2_TotalPowerWeaponGrabs  E2_TotalPowerWeaponPossessionTime  \
# 0                        18                          62.450902
# 1                       184                          60.453406
# 2                       184                          60.453406
# 3                       154                          59.288728
# 4                        55                         180.095888
#
#    E2_TotalDeaths  E2_TotalAssists  E2_TotalGamesCompleted  E2_TotalGamesWon  \
# 0           11968             5457                    1044               362
# 1           13956             5694                    1139               402
# 2           13956             5694                    1139               402
# 3           15814             4507                    1129               457
# 4           54037            26641                    3465              1825
#
#    E2_TotalGamesLost  E2_TotalGamesTied  E2_TotalTimePlayed  \
# 0                535                147          107.843492
# 1                622                115          124.481313
# 2                622                115          124.481313
# 3                541                131          124.022817
# 4               1257                383          379.261607
#
#    E2_TotalGrenadeKills  E3_SpartanRank  E3_PrevTotalXP  E3_TotalKills  \
# 0                   171             147        11450262           6174
# 1                   497             145         8731606           6268
# 2                   497             149        19076207          13090
# 3                   494             151        42593149           8780
# 4                  2034             147        11149103          31941
#
#    E3_TotalHeadshots  E3_TotalWeaponDamage  E3_TotalShotsFired  \
# 0                693          7.163374e+05              119575
# 1                969          7.732204e+05              150020
# 2               1966          1.614739e+06              249751
# 3               1338          1.131636e+06              185417
# 4               5861          4.173908e+06              719658
#
#    E3_TotalShotsLanded  E3_TotalMeleeKills  E3_TotalMeleeDamage  \
# 0                41628                 284          36559.27300
# 1                53167                 240          27062.24454
# 2                92898                 590          74317.29507
# 3                73199                 202          25683.02879
# 4               248379                 869         113148.63170
#
#    E3_TotalAssassinations  E3_TotalGroundPoundKills  \
# 0                      81                        34
# 1                      48                         3
# 2                     139                        29
# 3                      44                        13
# 4                     186                        37
#
#    E3_TotalGroundPoundDamage  E3_TotalShoulderBashKills  \
# 0                7355.041995                         42
# 1                 599.247807                          1
# 2                5427.876639                        122
# 3                3413.963149                         53
# 4                9390.987291                         79
#
#    E3_TotalShoulderBashDamage  E3_TotalGrenadeDamage  \
# 0                 9618.008672            49044.63998
# 1                  875.000000            15518.16956
# 2                19644.680740           118579.39140
# 3                 8892.856932            70735.08642
# 4                21581.613900           284210.25780
#
#    E3_TotalPowerWeaponKills  E3_TotalPowerWeaponDamage  \
# 0                      4471               5.760876e+05
# 1                      5180               6.531948e+05
# 2                      9568               1.210915e+06
# 3                      6652               8.405961e+05
# 4                     25437               3.284115e+06
#
#    E3_TotalPowerWeaponGrabs  E3_TotalPowerWeaponPossessionTime  \
# 0                        10                          24.540722
# 1                         0                          24.840514
# 2                       154                          59.288728
# 3                        16                          27.263305
# 4                       116                         140.548636
#
#    E3_TotalDeaths  E3_TotalAssists  E3_TotalGamesCompleted  E3_TotalGamesWon  \
# 0            5624             2011                     409               187
# 1            5201             2228                     424               153
# 2           15814             4507                    1129               457
# 3            7740             3488                     551               321
# 4           25248            12021                    2121               855
#
#    E3_TotalGamesLost  E3_TotalGamesTied  E3_TotalTimePlayed  \
# 0                166                 56           44.727687
# 1                199                 72           44.032128
# 2                541                131          124.022817
# 3                187                 43           58.029374
# 4                986                280          248.465858
#
#    E3_TotalGrenadeKills  E4_SpartanRank  E4_PrevTotalXP  E4_TotalKills  \
# 0                   222              89         2573644           1162
# 1                    87              70         1723305           1100
# 2                   494              43          622488           1751
# 3                   305             149        20308617           5539
# 4                  1258             148        14980333          13121
#
#    E4_TotalHeadshots  E4_TotalWeaponDamage  E4_TotalShotsFired  \
# 0                195          1.539265e+05               37952
# 1                426          1.325895e+05               22536
# 2                352          2.431910e+05               57678
# 3                980          7.203931e+05              111881
# 4               3541          1.664497e+06              295970
#
#    E4_TotalShotsLanded  E4_TotalMeleeKills  E4_TotalMeleeDamage  \
# 0                11932                  57          8731.553861
# 1                 8725                 156         23400.353120
# 2                18932                  56          5328.879808
# 3                39568                 140         22794.301900
# 4               102071                 218         26183.200930
#
#    E4_TotalAssassinations  E4_TotalGroundPoundKills  \
# 0                      14                         1
# 1                      40                         2
# 2                      10                         0
# 3                      36                         6
# 4                      49                        12
#
#    E4_TotalGroundPoundDamage  E4_TotalShoulderBashKills  \
# 0                 115.000000                         21
# 1                   7.752099                         11
# 2                   0.000000                          1
# 3                 962.931915                         23
# 4                1488.331004                          5
#
#    E4_TotalShoulderBashDamage  E4_TotalGrenadeDamage  \
# 0                 2859.333313            7499.043766
# 1                 1290.497803            2365.737600
# 2                  282.250000           11689.892470
# 3                 4721.356329           59299.099270
# 4                 1365.466648           52188.653820
#
#    E4_TotalPowerWeaponKills  E4_TotalPowerWeaponDamage  \
# 0                       628               7.971733e+04
# 1                       304               4.110747e+04
# 2                      1336               1.789378e+05
# 3                      4304               5.400171e+05
# 4                     10618               1.342302e+06
#
#    E4_TotalPowerWeaponGrabs  E4_TotalPowerWeaponPossessionTime  \
# 0                        18                           2.994338
# 1                        31                           1.848657
# 2                         0                           6.482648
# 3                        22                          18.032953
# 4                        35                          49.419732
#
#    E4_TotalDeaths  E4_TotalAssists  E4_TotalGamesCompleted  E4_TotalGamesWon  \
# 0            1089              445                     107                52
# 1            1227              559                     105                35
# 2            1603              853                     117                49
# 3            7012             2200                     373               249
# 4            6777             4525                     748               292
#
#    E4_TotalGamesLost  E4_TotalGamesTied  E4_TotalTimePlayed  \
# 0                 48                  7           11.855415
# 1                 65                  5           12.014393
# 2                 48                 20           12.392531
# 3                 97                 27           41.323951
# 4                343                113           84.279160
#
#    E4_TotalGrenadeKills
# 0                    43
# 1                    11
# 2                    40
# 3                   235
# 4                   248

# %% [markdown]
# ## Feature Creation

# %%
# Set roster for sifting through players of dataframe
roster = ['P1', 'P2', 'P3', 'P4', 'E1', 'E2', 'E3', 'E4']

# Loop through players in roster
for player in roster:
    
    # Set win rate
    df[f'{player}_WinRate'] = df[f'{player}_TotalGamesWon'] / df[f'{player}_TotalGamesLost']
    
    # Set K/D (or Kill / Death ratio)
    df[f'{player}_K/D'] = df[f'{player}_TotalKills'] / df[f'{player}_TotalDeaths']
    
    # Set accuracy
    df[f'{player}_Accuracy'] = df[f'{player}_TotalShotsLanded'] / df[f'{player}_TotalShotsFired']
    
    per_game_stat_list = ['TotalKills', 'TotalHeadshots', 'TotalWeaponDamage', 
                      'TotalShotsFired', 'TotalShotsLanded', 'TotalMeleeKills', 
                      'TotalMeleeDamage', 'TotalAssassinations', 'TotalGroundPoundKills', 
                      'TotalGroundPoundDamage', 'TotalShoulderBashKills', 
                      'TotalShoulderBashDamage', 'TotalGrenadeDamage', 'TotalPowerWeaponKills', 
                      'TotalPowerWeaponDamage', 'TotalPowerWeaponGrabs', 
                      'TotalPowerWeaponPossessionTime', 'TotalDeaths', 'TotalAssists', 
                      'TotalGrenadeKills']
            
    for stat in per_game_stat_list:
        per_game_stat_string = stat.replace('Total', '')
        per_game_stat_string = f'{per_game_stat_string}PerGame'
        df[f'{player}_{per_game_stat_string}'] = df[f'{player}_{stat}'] / df[f'{player}_TotalGamesCompleted']
#         variant_dic[per_game_stat_string] = variant_dic[stat] / variant_dic['TotalGamesCompleted']


# Drop infinity values, which can arise if it is the first time a player
# is playing specified playlist
df = df.dropna()
df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

df
# Out:
#        PlayerWin  P1_SpartanRank  P1_PrevTotalXP  P1_TotalKills  \
# 0              0             102         3348130           3378
# 1              1             148        15348257          39273
# 2              1             151        37161347          58661
# 3              1             151        47050485         100339
# 4              1             148        15342496          39273
# ...          ...             ...             ...            ...
# 17149          1             150        33302326          18575
# 17150          0             148        15055260          61629
# 17151          1             149        22175571          48496
# 17152          1             150        28039999          39665
# 17153          0             151        37327188          35392
#
#        P1_TotalHeadshots  P1_TotalWeaponDamage  P1_TotalShotsFired  \
# 0                    551          4.362411e+05               96140
# 1                   3202          5.020049e+06             1025141
# 2                  11418          7.990578e+06             1326652
# 3                  22173          1.279709e+07             2176535
# 4                   3202          5.020049e+06             1025141
# ...                  ...                   ...                 ...
# 17149               2655          2.512373e+06              471061
# 17150               2372          8.551291e+06             1411114
# 17151               6036          6.323878e+06             1316104
# 17152               3931          5.160209e+06              959904
# 17153               1694          4.916751e+06             1151702
#
#        P1_TotalShotsLanded  P1_TotalMeleeKills  P1_TotalMeleeDamage  \
# 0                    31174                 150         14200.282440
# 1                   367059                1289        147219.068300
# 2                   460037                1669        222380.100500
# 3                   766384                1959        228599.805100
# 4                   367059                1289        147219.068300
# ...                    ...                 ...                  ...
# 17149               174539                 477         48077.295310
# 17150               543555                2134        263653.063311
# 17151               429774                1627        181559.937668
# 17152               334606                1094        129554.672029
# 17153               329302                1570        194267.528834
#
#        P1_TotalAssassinations  P1_TotalGroundPoundKills  \
# 0                          13                         1
# 1                         216                        26
# 2                         325                       118
# 3                         375                        39
# 4                         216                        26
# ...                       ...                       ...
# 17149                      59                         0
# 17150                     537                         1
# 17151                     301                        15
# 17152                     180                         3
# 17153                     303                         0
#
#        P1_TotalGroundPoundDamage  P1_TotalShoulderBashKills  \
# 0                     435.899994                         12
# 1                    5870.122829                        123
# 2                   21481.336320                        374
# 3                    6033.137176                         89
# 4                    5870.122829                        123
# ...                          ...                        ...
# 17149                 285.000000                          4
# 17150                 190.000000                        138
# 17151                2895.922417                         75
# 17152                 609.718712                         74
# 17153                   0.000000                         18
#
#        P1_TotalShoulderBashDamage  P1_TotalGrenadeDamage  \
# 0                     1809.374457           1.783389e+04
# 1                    26233.730550           1.920438e+05
# 2                    65457.288060           8.671373e+05
# 3                    12423.010870           9.053578e+05
# 4                    26233.730550           1.920438e+05
# ...                           ...                    ...
# 17149                  624.204346           1.879024e+05
# 17150                21252.532578           1.447501e+06
# 17151                14633.611238           2.668581e+05
# 17152                16510.107470           2.580257e+05
# 17153                 4380.611336           4.161335e+05
#
#        P1_TotalPowerWeaponKills  P1_TotalPowerWeaponDamage  \
# 0                          2746               3.535647e+05
# 1                         34812               4.462575e+06
# 2                         44999               5.979214e+06
# 3                         87067               1.075508e+07
# 4                         34812               4.462575e+06
# ...                         ...                        ...
# 17149                     15472               2.024696e+06
# 17150                     50787               6.521562e+06
# 17151                     40392               5.194313e+06
# 17152                     34339               4.420410e+06
# 17153                     28854               3.941001e+06
#
#        P1_TotalPowerWeaponGrabs  P1_TotalPowerWeaponPossessionTime  \
# 0                             0                          14.334023
# 1                            16                         157.602300
# 2                           270                         215.471346
# 3                            69                         346.243585
# 4                            16                         157.602300
# ...                         ...                                ...
# 17149                         9                          78.836189
# 17150                         0                         236.848029
# 17151                         8                         195.612312
# 17152                        81                         159.773125
# 17153                        76                         159.671667
#
#        P1_TotalDeaths  P1_TotalAssists  P1_TotalGamesCompleted  \
# 0                3593             1499                     256
# 1               44504            14978                    3051
# 2               61053            25331                    3568
# 3               63783            33268                    4867
# 4               44504            14978                    3051
# ...               ...              ...                     ...
# 17149           15557             8148                    1286
# 17150           75944            29624                    4674
# 17151           51193            20923                    3365
# 17152           44640            16472                    2756
# 17153           48072            17199                    3023
#
#        P1_TotalGamesWon  P1_TotalGamesLost  P1_TotalGamesTied  \
# 0                   124                105                 27
# 1                  1594               1198                259
# 2                  1565               1567                436
# 3                  2023               2032                812
# 4                  1594               1198                259
# ...                 ...                ...                ...
# 17149               458                632                196
# 17150              2559               1579                536
# 17151              1561               1353                451
# 17152              1436                974                346
# 17153              1451               1205                367
#
#        P1_TotalTimePlayed  P1_TotalGrenadeKills  P2_SpartanRank  \
# 0               26.475012                    69              72
# 1              288.020209                   687             149
# 2              417.975375                  3314             148
# 3              558.988557                  2878             150
# 4              288.020209                   687             145
# ...                   ...                   ...             ...
# 17149          135.547986                   679             145
# 17150          461.974762                  4410             150
# 17151          369.859851                  1049             150
# 17152          294.697989                   879             149
# 17153          312.827415                  1724             150
#
#        P2_PrevTotalXP  P2_TotalKills  P2_TotalHeadshots  P2_TotalWeaponDamage  \
# 0             1755469           3388                378          4.506744e+05
# 1            23870326          39309               6720          5.369387e+06
# 2            15345204          39273               3202          5.020049e+06
# 3            25138214          73644              11265          9.922924e+06
# 4             8986431          11675               2525          1.584917e+06
# ...               ...            ...                ...                   ...
# 17149         8402934           3580                429          5.183810e+05
# 17150        33297717          18575               2655          2.512373e+06
# 17151        25949089          47496               9070          6.745410e+06
# 17152        21078544          26297               4043          3.667258e+06
# 17153        33288811          18575               2655          2.512373e+06
#
#        P2_TotalShotsFired  P2_TotalShotsLanded  P2_TotalMeleeKills  \
# 0                  123305                33670                 115
# 1                 1111772               391306                 876
# 2                 1025141               367059                1289
# 3                 2081512               669436                1568
# 4                  310439               108355                 319
# ...                   ...                  ...                 ...
# 17149              129723                40977                  78
# 17150              471061               174539                 477
# 17151             1658366               482630                1250
# 17152              899738               279150                 748
# 17153              471061               174539                 477
#
#        P2_TotalMeleeDamage  P2_TotalAssassinations  P2_TotalGroundPoundKills  \
# 0             13798.771950                      22                         9
# 1            105948.321600                     130                         0
# 2            147219.068300                     216                        26
# 3            192638.975400                     212                        44
# 4             44222.395030                      84                         3
# ...                    ...                     ...                       ...
# 17149          8276.362618                      11                         1
# 17150         48077.295310                      59                         0
# 17151        150164.480082                     193                         8
# 17152         85156.954115                     147                        37
# 17153         48077.295310                      59                         0
#
#        P2_TotalGroundPoundDamage  P2_TotalShoulderBashKills  \
# 0                    2178.285184                         20
# 1                       0.000000                          9
# 2                    5870.122829                        123
# 3                    7041.194090                        114
# 4                     437.500000                         40
# ...                          ...                        ...
# 17149                  35.000000                          0
# 17150                 285.000000                          4
# 17151                2260.195777                         24
# 17152                5761.967788                         17
# 17153                 285.000000                          4
#
#        P2_TotalShoulderBashDamage  P2_TotalGrenadeDamage  \
# 0                     3866.135540           33681.924040
# 1                     1718.871307          480275.913500
# 2                    26233.730550          192043.794600
# 3                    29377.620450          447423.202600
# 4                     6723.297248           78299.874600
# ...                           ...                    ...
# 17149                  190.000000           50753.426637
# 17150                  624.204346          187902.423894
# 17151                 4154.589319          640415.840727
# 17152                 5598.245636          295746.541320
# 17153                  624.204346          187902.423894
#
#        P2_TotalPowerWeaponKills  P2_TotalPowerWeaponDamage  \
# 0                          2706               3.561506e+05
# 1                         31754               4.124953e+06
# 2                         34812               4.462575e+06
# 3                         62187               8.212049e+06
# 4                          9265               1.240237e+06
# ...                         ...                        ...
# 17149                      2510               3.398281e+05
# 17150                     15472               2.024696e+06
# 17151                     37823               5.123769e+06
# 17152                     21030               2.800032e+06
# 17153                     15472               2.024696e+06
#
#        P2_TotalPowerWeaponGrabs  P2_TotalPowerWeaponPossessionTime  \
# 0                             3                          14.473583
# 1                             3                         124.635187
# 2                            16                         157.602300
# 3                             6                         268.604838
# 4                             3                          37.255634
# ...                         ...                                ...
# 17149                         0                          15.836440
# 17150                         9                          78.836189
# 17151                         0                         186.968467
# 17152                        22                          92.367106
# 17153                         9                          78.836189
#
#        P2_TotalDeaths  P2_TotalAssists  P2_TotalGamesCompleted  \
# 0                2804             1630                     231
# 1               35407            19300                    2382
# 2               44504            14978                    3051
# 3               77764            31658                    4829
# 4               10656             5070                     650
# ...               ...              ...                     ...
# 17149            4548             2309                     308
# 17150           15557             8148                    1286
# 17151           46775            25078                    3391
# 17152           23707            12791                    1646
# 17153           15557             8148                    1286
#
#        P2_TotalGamesWon  P2_TotalGamesLost  P2_TotalGamesTied  \
# 0                   100                 94                 37
# 1                  1330                772                280
# 2                  1594               1198                259
# 3                  2264               1939                626
# 4                   293                266                 91
# ...                 ...                ...                ...
# 17149               132                126                 50
# 17150               458                632                196
# 17151              1429               1475                487
# 17152               708                715                223
# 17153               458                632                196
#
#        P2_TotalTimePlayed  P2_TotalGrenadeKills  P3_SpartanRank  \
# 0               25.016905                   132             145
# 1              241.513053                  1649              96
# 2              288.020209                   687             146
# 3              509.550529                  1681             150
# 4               73.749186                   318             151
# ...                   ...                   ...             ...
# 17149           33.496369                   204             142
# 17150          135.547986                   679             145
# 17151          350.628509                  2112             150
# 17152          177.043284                   927             150
# 17153          135.547986                   679             144
#
#        P3_PrevTotalXP  P3_TotalKills  P3_TotalHeadshots  P3_TotalWeaponDamage  \
# 0             8584030           1882                309          2.504024e+05
# 1             2970740           7914                801          9.670463e+05
# 2             9774869          21952               3777          2.937519e+06
# 3            28963826          67990              13972          9.059519e+06
# 4            42591953           8780               1338          1.131636e+06
# ...               ...            ...                ...                   ...
# 17149         6776919           2212                106          2.955593e+05
# 17150         8398559           3580                429          5.183810e+05
# 17151        33293835          18575               2655          2.512373e+06
# 17152        33291501          18575               2655          2.512373e+06
# 17153         7205338           6786                943          8.529598e+05
#
#        P3_TotalShotsFired  P3_TotalShotsLanded  P3_TotalMeleeKills  \
# 0                   54355                17223                 130
# 1                  143169                41817                 211
# 2                  521487               203513                 907
# 3                 1602064               594433                1131
# 4                  185417                73199                 202
# ...                   ...                  ...                 ...
# 17149               60616                12016                  34
# 17150              129723                40977                  78
# 17151              471061               174539                 477
# 17152              471061               174539                 477
# 17153              101961                42006                 185
#
#        P3_TotalMeleeDamage  P3_TotalAssassinations  P3_TotalGroundPoundKills  \
# 0             13866.324490                      21                         5
# 1             26461.924720                      31                        35
# 2             96793.466930                     107                        18
# 3            142355.900000                     155                         7
# 4             25683.028790                      44                        13
# ...                    ...                     ...                       ...
# 17149          3482.815693                       2                        11
# 17150          8276.362618                      11                         1
# 17151         48077.295310                      59                         0
# 17152         48077.295310                      59                         0
# 17153         24729.738401                      43                         0
#
#        P3_TotalGroundPoundDamage  P3_TotalShoulderBashKills  \
# 0                    1778.400188                         19
# 1                    8937.051069                         25
# 2                    3082.305937                         71
# 3                    1549.980980                         18
# 4                    3413.963149                         53
# ...                          ...                        ...
# 17149                2296.688987                          2
# 17150                  35.000000                          0
# 17151                 285.000000                          4
# 17152                 285.000000                          4
# 17153                 285.000000                         48
#
#        P3_TotalShoulderBashDamage  P3_TotalGrenadeDamage  \
# 0                     3887.518391           17023.678130
# 1                     4594.986589          162607.748800
# 2                    16138.151560          219603.146000
# 3                     3564.747462          515516.282700
# 4                     8892.856932           70735.086420
# ...                           ...                    ...
# 17149                  891.852951           58016.705520
# 17150                  190.000000           50753.426637
# 17151                  624.204346          187902.423894
# 17152                  624.204346          187902.423894
# 17153                 8934.415877           20998.387933
#
#        P3_TotalPowerWeaponKills  P3_TotalPowerWeaponDamage  \
# 0                          1306               1.785042e+05
# 1                          5453               6.966502e+05
# 2                         16367               2.128939e+06
# 3                         52836               6.812084e+06
# 4                          6652               8.405961e+05
# ...                         ...                        ...
# 17149                      1427               1.973169e+05
# 17150                      2510               3.398281e+05
# 17151                     15472               2.024696e+06
# 17152                     15472               2.024696e+06
# 17153                      5929               7.473317e+05
#
#        P3_TotalPowerWeaponGrabs  P3_TotalPowerWeaponPossessionTime  \
# 0                            17                           6.340588
# 1                            13                          45.035912
# 2                            52                          74.455840
# 3                            55                         180.095888
# 4                            16                          27.263305
# ...                         ...                                ...
# 17149                         5                          12.984087
# 17150                         0                          15.836440
# 17151                         9                          78.836189
# 17152                         9                          78.836189
# 17153                         0                          32.477833
#
#        P3_TotalDeaths  P3_TotalAssists  P3_TotalGamesCompleted  \
# 0                2034              828                     146
# 1                7935             2866                     570
# 2               25535            10584                    1359
# 3               54037            26641                    3465
# 4                7740             3488                     551
# ...               ...              ...                     ...
# 17149            2590             1056                     159
# 17150            4548             2309                     308
# 17151           15557             8148                    1286
# 17152           15557             8148                    1286
# 17153            7005             2264                     682
#
#        P3_TotalGamesWon  P3_TotalGamesLost  P3_TotalGamesTied  \
# 0                    60                 70                 16
# 1                   216                245                109
# 2                   591                586                182
# 3                  1825               1257                383
# 4                   321                187                 43
# ...                 ...                ...                ...
# 17149                64                 60                 35
# 17150               132                126                 50
# 17151               458                632                196
# 17152               458                632                196
# 17153               295                319                 68
#
#        P3_TotalTimePlayed  P3_TotalGrenadeKills  P4_SpartanRank  \
# 0               15.919856                    62             144
# 1               73.169910                   773              98
# 2              160.492698                   787              48
# 3              379.261607                  2034             148
# 4               58.029374                   305             149
# ...                   ...                   ...             ...
# 17149           22.365889                   259              19
# 17150           33.496369                   204              45
# 17151          135.547986                   679             146
# 17152          135.547986                   679              84
# 17153           57.710799                    96              52
#
#        P4_PrevTotalXP  P4_TotalKills  P4_TotalHeadshots  P4_TotalWeaponDamage  \
# 0             7375370           1315                253          1.633076e+05
# 1             3105846           2646                399          3.246299e+05
# 2              759776           6436               1229          8.531748e+05
# 3            15343353          39273               3202          5.020049e+06
# 4            20307647           5539                980          7.203931e+05
# ...               ...            ...                ...                   ...
# 17149          156898           1051                183          1.448845e+05
# 17150          668726            830                117          1.064151e+05
# 17151        10656889           5389                859          7.190559e+05
# 17152         2410217           6209               1523          8.146049e+05
# 17153          936221            607                 51          7.486255e+04
#
#        P4_TotalShotsFired  P4_TotalShotsLanded  P4_TotalMeleeKills  \
# 0                   22859                 9212                  34
# 1                   65294                24390                 120
# 2                  161503                56437                  93
# 3                 1025141               367059                1289
# 4                  111881                39568                 140
# ...                   ...                  ...                 ...
# 17149               37131                12129                  12
# 17150               20408                 6492                  41
# 17151              136505                49001                 101
# 17152              140907                52594                 139
# 17153               18855                 5372                  63
#
#        P4_TotalMeleeDamage  P4_TotalAssassinations  P4_TotalGroundPoundKills  \
# 0              6087.614542                       6                         3
# 1             13928.636150                      32                        15
# 2             11200.409080                      19                         0
# 3            147219.068300                     216                        26
# 4             22794.301900                      36                         6
# ...                    ...                     ...                       ...
# 17149          1154.068493                       0                         0
# 17150          6658.344380                      18                         0
# 17151         13147.393102                      24                         0
# 17152         13952.475305                      13                         1
# 17153          6376.120871                      10                         0
#
#        P4_TotalGroundPoundDamage  P4_TotalShoulderBashKills  \
# 0                     776.223419                         13
# 1                    1363.579624                         18
# 2                       0.000000                          1
# 3                    5870.122829                        123
# 4                     962.931915                         23
# ...                          ...                        ...
# 17149                   0.000000                          0
# 17150                   0.000000                          0
# 17151                 285.000000                         17
# 17152                 159.285248                          5
# 17153                   0.000000                          5
#
#        P4_TotalShoulderBashDamage  P4_TotalGrenadeDamage  \
# 0                     3712.180248           10792.439860
# 1                     3102.606691           11552.878470
# 2                      164.162956           64568.212760
# 3                    26233.730550          192043.794600
# 4                     4721.356329           59299.099270
# ...                           ...                    ...
# 17149                    0.000000            5741.055486
# 17150                  285.000000            7001.950355
# 17151                 3125.997933           32973.702104
# 17152                  814.267700           22657.234288
# 17153                  539.459305            2456.071609
#
#        P4_TotalPowerWeaponKills  P4_TotalPowerWeaponDamage  \
# 0                          1002               1.230374e+05
# 1                          2093               2.635325e+05
# 2                          5300               6.783338e+05
# 3                         34812               4.462575e+06
# 4                          4304               5.400171e+05
# ...                         ...                        ...
# 17149                       866               1.141231e+05
# 17150                       695               9.001226e+04
# 17151                      4538               5.860970e+05
# 17152                      5276               6.862109e+05
# 17153                       438               5.657558e+04
#
#        P4_TotalPowerWeaponGrabs  P4_TotalPowerWeaponPossessionTime  \
# 0                            23                           5.379408
# 1                             0                          10.007569
# 2                             0                          26.788316
# 3                            16                         157.602300
# 4                            22                          18.032953
# ...                         ...                                ...
# 17149                         0                           4.350533
# 17150                         0                           3.669130
# 17151                        20                          22.843518
# 17152                         0                          17.421093
# 17153                         9                           2.252690
#
#        P4_TotalDeaths  P4_TotalAssists  P4_TotalGamesCompleted  \
# 0                1410              392                     102
# 1                2493              928                     187
# 2                5543             3132                     433
# 3               44504            14978                    3051
# 4                7012             2200                     373
# ...               ...              ...                     ...
# 17149             755              474                      79
# 17150            1072              354                      76
# 17151            4919             2165                     394
# 17152            4784             2130                     307
# 17153             748              256                      55
#
#        P4_TotalGamesWon  P4_TotalGamesLost  P4_TotalGamesTied  \
# 0                    49                 40                 13
# 1                    79                 87                 21
# 2                   190                184                 59
# 3                  1594               1198                259
# 4                   249                 97                 27
# ...                 ...                ...                ...
# 17149                21                 44                 14
# 17150                37                 31                  8
# 17151               147                192                 55
# 17152               172                 96                 39
# 17153                24                 26                  5
#
#        P4_TotalTimePlayed  P4_TotalGrenadeKills  E1_SpartanRank  \
# 0               11.637733                    41             152
# 1               18.867221                    46             149
# 2               46.458067                   226             147
# 3              288.020209                   687             147
# 4               41.323951                   235             150
# ...                   ...                   ...             ...
# 17149            7.740090                    28             145
# 17150            7.046150                    18             144
# 17151           41.237516                   125             147
# 17152           31.649927                    79             147
# 17153            5.294193                    14              81
#
#        E1_PrevTotalXP  E1_TotalKills  E1_TotalHeadshots  E1_TotalWeaponDamage  \
# 0            52946125          16222               3950          2.140170e+06
# 1            18608380          19844               7015          2.720339e+06
# 2            11150915          31941               5861          4.173908e+06
# 3            11149681          31941               5861          4.173908e+06
# 4            25137635          73644              11265          9.922924e+06
# ...               ...            ...                ...                   ...
# 17149         7774816           2383                406          3.006300e+05
# 17150         7440843          14922                811          1.961913e+06
# 17151        11688537          22524               4159          2.929495e+06
# 17152        13819162          63590              15083          8.628021e+06
# 17153         2183096           2796                537          3.454589e+05
#
#        E1_TotalShotsFired  E1_TotalShotsLanded  E1_TotalMeleeKills  \
# 0                  439309               141949                 704
# 1                  446426               187932                1067
# 2                  719658               248379                 869
# 3                  719658               248379                 869
# 4                 2081512               669436                1568
# ...                   ...                  ...                 ...
# 17149               59815                19228                  96
# 17150              469537               147821                 463
# 17151              506356               192718                 961
# 17152             1625954               572023                 662
# 17153               57546                20267                 107
#
#        E1_TotalMeleeDamage  E1_TotalAssassinations  E1_TotalGroundPoundKills  \
# 0             95917.873820                     148                         6
# 1            124757.007200                     219                        16
# 2            113148.631700                     186                        37
# 3            113148.631700                     186                        37
# 4            192638.975400                     212                        44
# ...                    ...                     ...                       ...
# 17149         14147.510803                      26                         4
# 17150         58974.862094                     113                         0
# 17151        110548.349425                     121                         2
# 17152         89968.078171                     136                         0
# 17153         13514.770675                      26                         1
#
#        E1_TotalGroundPoundDamage  E1_TotalShoulderBashKills  \
# 0                     990.599998                         82
# 1                    1435.099349                          2
# 2                    9390.987291                         79
# 3                    9390.987291                         79
# 4                    7041.194090                        114
# ...                          ...                        ...
# 17149                 636.781109                         51
# 17150                 143.857143                         24
# 17151                 214.895515                         35
# 17152                   0.000000                         64
# 17153                 244.823997                          6
#
#        E1_TotalShoulderBashDamage  E1_TotalGrenadeDamage  \
# 0                     8975.222380          132581.087200
# 1                      332.500000          184216.289500
# 2                    21581.613900          284210.257800
# 3                    21581.613900          284210.257800
# 4                    29377.620450          447423.202600
# ...                           ...                    ...
# 17149                10056.732410           15445.614266
# 17150                 3843.027175           82925.219961
# 17151                 7642.344279          122085.033355
# 17152                 9269.909812          370101.542099
# 17153                  928.260933            8085.129743
#
#        E1_TotalPowerWeaponKills  E1_TotalPowerWeaponDamage  \
# 0                         11464               1.513326e+06
# 1                          8652               1.156967e+06
# 2                         25437               3.284115e+06
# 3                         25437               3.284115e+06
# 4                         62187               8.212049e+06
# ...                         ...                        ...
# 17149                      1918               2.501823e+05
# 17150                     13068               1.694024e+06
# 17151                     18245               2.358535e+06
# 17152                     49935               6.597491e+06
# 17153                      2409               3.031702e+05
#
#        E1_TotalPowerWeaponGrabs  E1_TotalPowerWeaponPossessionTime  \
# 0                            40                          52.563167
# 1                           575                          46.762009
# 2                           116                         140.548636
# 3                           116                         140.548636
# 4                             6                         268.604838
# ...                         ...                                ...
# 17149                         1                          10.837880
# 17150                         0                          74.058487
# 17151                         3                          76.505689
# 17152                        86                         203.657650
# 17153                         4                          11.455647
#
#        E1_TotalDeaths  E1_TotalAssists  E1_TotalGamesCompleted  \
# 0               14354             6974                    1114
# 1               17082             9207                    1497
# 2               25248            12021                    2121
# 3               25248            12021                    2121
# 4               77764            31658                    4829
# ...               ...              ...                     ...
# 17149            2469              974                     188
# 17150           16454             7016                    1259
# 17151           23124             9175                    1483
# 17152           54018            27838                    3832
# 17153            2629              996                     189
#
#        E1_TotalGamesWon  E1_TotalGamesLost  E1_TotalGamesTied  \
# 0                   465                522                127
# 1                   596                822                 79
# 2                   855                986                280
# 3                   855                986                280
# 4                  2264               1939                626
# ...                 ...                ...                ...
# 17149                77                 89                 22
# 17150               511                592                156
# 17151               671                627                185
# 17152              1861               1530                441
# 17153                69                101                 19
#
#        E1_TotalTimePlayed  E1_TotalGrenadeKills  E2_SpartanRank  \
# 0              121.181253                   622             149
# 1              182.559031                   915             152
# 2              248.465858                  1258             152
# 3              248.465858                  1258             149
# 4              509.550529                  1681             150
# ...                   ...                   ...             ...
# 17149           19.387991                    43              27
# 17150          127.565580                   313             125
# 17151          150.129249                   433             144
# 17152          415.814285                  1596             148
# 17153           19.747233                    35              54
#
#        E2_PrevTotalXP  E2_TotalKills  E2_TotalHeadshots  E2_TotalWeaponDamage  \
# 0            18388319          12790               1262          1.684482e+06
# 1            50393335          13209               2226          1.771996e+06
# 2            50390893          13209               2226          1.771996e+06
# 3            19074972          13090               1966          1.614739e+06
# 4            28963191          67990              13972          9.059519e+06
# ...               ...            ...                ...                   ...
# 17149          278906            936                330          1.178031e+05
# 17150         5022569          14575               1767          1.921847e+06
# 17151         7439606          14922                811          1.961913e+06
# 17152        17471950          16690               2140          2.178511e+06
# 17153         1088124           2615                332          3.375160e+05
#
#        E2_TotalShotsFired  E2_TotalShotsLanded  E2_TotalMeleeKills  \
# 0                  371779               118414                 297
# 1                  310586               108407                 426
# 2                  310586               108407                 426
# 3                  249751                92898                 590
# 4                 1602064               594433                1131
# ...                   ...                  ...                 ...
# 17149               25412                 7031                  32
# 17150              382975               131883                 602
# 17151              469537               147821                 463
# 17152              382843               144723                 554
# 17153               70476                23219                 135
#
#        E2_TotalMeleeDamage  E2_TotalAssassinations  E2_TotalGroundPoundKills  \
# 0             31542.311790                      41                         5
# 1             55482.927890                     107                        10
# 2             55482.927890                     107                        10
# 3             74317.295070                     139                        29
# 4            142355.900000                     155                         7
# ...                    ...                     ...                       ...
# 17149          6475.991490                      32                         1
# 17150         72621.635562                     107                        12
# 17151         58974.862094                     113                         0
# 17152         72071.612779                      85                         9
# 17153         16960.050350                      21                         0
#
#        E2_TotalGroundPoundDamage  E2_TotalShoulderBashKills  \
# 0                    1799.382126                         60
# 1                    3549.135921                         15
# 2                    3549.135921                         15
# 3                    5427.876639                        122
# 4                    1549.980980                         18
# ...                          ...                        ...
# 17149                 400.000000                          2
# 17150                1288.308033                         18
# 17151                 143.857143                         24
# 17152                1594.183304                         66
# 17153                  70.000000                          7
#
#        E2_TotalShoulderBashDamage  E2_TotalGrenadeDamage  \
# 0                    11246.566490           48645.772310
# 1                     4227.417664          107495.894300
# 2                     4227.417664          107495.894300
# 3                    19644.680740          118579.391400
# 4                     3564.747462          515516.282700
# ...                           ...                    ...
# 17149                  467.000000            4798.436010
# 17150                 2951.744655           98951.244538
# 17151                 3843.027175           82925.219961
# 17152                15046.164890           64368.799300
# 17153                 1255.465202           21501.693383
#
#        E2_TotalPowerWeaponKills  E2_TotalPowerWeaponDamage  \
# 0                         10966               1.422631e+06
# 1                          9786               1.283125e+06
# 2                          9786               1.283125e+06
# 3                          9568               1.210915e+06
# 4                         52836               6.812084e+06
# ...                         ...                        ...
# 17149                       662               8.690794e+04
# 17150                     12238               1.598581e+06
# 17151                     13068               1.694024e+06
# 17152                     14049               1.830968e+06
# 17153                      2078               2.719041e+05
#
#        E2_TotalPowerWeaponGrabs  E2_TotalPowerWeaponPossessionTime  \
# 0                            18                          62.450902
# 1                           184                          60.453406
# 2                           184                          60.453406
# 3                           154                          59.288728
# 4                            55                         180.095888
# ...                         ...                                ...
# 17149                         1                           3.614741
# 17150                         0                          57.017607
# 17151                         0                          74.058487
# 17152                        15                          60.336330
# 17153                         0                           9.606491
#
#        E2_TotalDeaths  E2_TotalAssists  E2_TotalGamesCompleted  \
# 0               11968             5457                    1044
# 1               13956             5694                    1139
# 2               13956             5694                    1139
# 3               15814             4507                    1129
# 4               54037            26641                    3465
# ...               ...              ...                     ...
# 17149             624              433                      71
# 17150           16944             6304                    1075
# ...
# 4                                 0.051976         15.595094
# ...                                    ...               ...
# 17149                             0.050912          8.788732
# 17150                             0.053040         15.761860
# 17151                             0.058823         13.069102
# 17152                             0.049741         17.399011
# 17153                             0.051372         13.780749
#
#        E2_AssistsPerGame  E2_GrenadeKillsPerGame  E3_WinRate    E3_K/D  \
# 0               5.227011                0.163793    1.126506  1.097795
# 1               4.999122                0.436348    0.768844  1.205153
# 2               4.999122                0.436348    0.844732  0.827748
# 3               3.992028                0.437555    1.716578  1.134367
# 4               7.688600                0.587013    0.867140  1.265090
# ...                  ...                     ...         ...       ...
# 17149           6.098592                0.239437    0.518519  0.790801
# 17150           5.864186                0.313488    0.994624  0.949108
# 17151           5.572677                0.248610    0.864173  0.860186
# 17152           5.730420                0.222589    0.701818  1.014831
# 17153           5.754011                0.422460    0.428571  1.182609
#
#        E3_Accuracy  E3_KillsPerGame  E3_HeadshotsPerGame  \
# 0         0.348133        15.095355             1.694377
# 1         0.354399        14.783019             2.285377
# 2         0.371962        11.594331             1.741364
# 3         0.394780        15.934664             2.428312
# 4         0.345135        15.059406             2.763319
# ...            ...              ...                  ...
# 17149     0.306637        11.104167             1.833333
# 17150     0.327187        10.878788             1.154040
# 17151     0.344365        13.558140             1.643721
# 17152     0.338656        12.138402             2.775828
# 17153     0.324048        13.877551             2.448980
#
#        E3_WeaponDamagePerGame  E3_ShotsFiredPerGame  E3_ShotsLandedPerGame  \
# 0                 1751.436078            292.359413             101.779951
# 1                 1823.632920            353.820755             125.393868
# 2                 1430.238329            221.214349              82.283437
# 3                 2053.786483            336.509982             132.847550
# 4                 1967.896496            339.301273             117.104668
# ...                       ...                   ...                    ...
# 17149             1460.561215            208.104167              63.812500
# 17150             1454.546862            285.522727              93.419192
# 17151             1787.764957            356.255814             122.681860
# 17152             1563.540232            272.231969              92.192982
# 17153             1885.714822            350.918367             113.714286
#
#        E3_MeleeKillsPerGame  E3_MeleeDamagePerGame  E3_AssassinationsPerGame  \
# 0                  0.694377              89.386976                  0.198044
# 1                  0.566038              63.826048                  0.113208
# 2                  0.522586              65.825771                  0.123118
# 3                  0.366606              46.611667                  0.079855
# 4                  0.409712              53.346832                  0.087694
# ...                     ...                    ...                       ...
# 17149              0.333333              49.584221                  0.104167
# 17150              0.401515              51.112891                  0.050505
# 17151              0.560000              67.555010                  0.099535
# 17152              0.543860              76.502755                  0.185185
# 17153              0.142857              18.495671                  0.020408
#
#        E3_GroundPoundKillsPerGame  E3_GroundPoundDamagePerGame  \
# 0                        0.083130                    17.982988
# 1                        0.007075                     1.413320
# 2                        0.025686                     4.807685
# 3                        0.023593                     6.195940
# 4                        0.017445                     4.427622
# ...                           ...                          ...
# 17149                    0.000000                     1.979167
# 17150                    0.000000                     0.000000
# 17151                    0.011163                     1.198426
# 17152                    0.037037                     7.011708
# 17153                    0.040816                     6.873542
#
#        E3_ShoulderBashKillsPerGame  E3_ShoulderBashDamagePerGame  \
# 0                         0.102689                     23.515914
# 1                         0.002358                      2.063679
# 2                         0.108060                     17.400072
# 3                         0.096189                     16.139486
# 4                         0.037247                     10.175207
# ...                            ...                           ...
# 17149                     0.000000                      3.958333
# 17150                     0.040404                      7.523978
# 17151                     0.016744                      2.745809
# 17152                     0.017544                      3.437903
# 17153                     0.000000                      0.000000
#
#        E3_GrenadeDamagePerGame  E3_PowerWeaponKillsPerGame  \
# 0                   119.913545                   10.931540
# 1                    36.599457                   12.216981
# 2                   105.030462                    8.474756
# 3                   128.375837                   12.072595
# 4                   133.998236                   11.992928
# ...                        ...                         ...
# 17149               129.769872                    8.312500
# 17150                84.657310                    8.944444
# 17151                92.047669                   11.384186
# 17152                98.607330                    8.130604
# 17153               135.808750                   11.591837
#
#        E3_PowerWeaponDamagePerGame  E3_PowerWeaponGrabsPerGame  \
# 0                      1408.527027                    0.024450
# 1                      1540.553778                    0.000000
# 2                      1072.555151                    0.136404
# 3                      1525.582677                    0.029038
# 4                      1548.380570                    0.054691
# ...                            ...                         ...
# 17149                  1098.189692                    0.083333
# 17150                  1160.204922                    0.000000
# 17151                  1487.051855                    0.000000
# 17152                  1064.340863                    0.337232
# 17153                  1478.879567                    0.040816
#
#        E3_PowerWeaponPossessionTimePerGame  E3_DeathsPerGame  \
# 0                                 0.060002         13.750611
# 1                                 0.058586         12.266509
# 2                                 0.052514         14.007086
# 3                                 0.049480         14.047187
# 4                                 0.066265         11.903819
# ...                                    ...               ...
# 17149                             0.081696         14.041667
# 17150                             0.047240         11.462121
# 17151                             0.053040         15.761860
# 17152                             0.053484         11.961014
# 17153                             0.068233         11.734694
#
#        E3_AssistsPerGame  E3_GrenadeKillsPerGame  E4_WinRate    E4_K/D  \
# 0               4.916870                0.542787    1.083333  1.067034
# 1               5.254717                0.205189    0.538462  0.896496
# 2               3.992028                0.437555    1.020833  1.092327
# 3               6.330309                0.553539    2.567010  0.789932
# 4               5.667610                0.593116    0.851312  1.936107
# ...                  ...                     ...         ...       ...
# 17149           4.437500                0.770833    0.400000  1.022599
# 17150           4.727273                0.303030    0.541667  1.444902
# 17151           5.864186                0.313488    0.541667  1.444902
# 17152           4.578947                0.456140    0.833333  0.957711
# 17153           4.346939                0.673469    0.545455  0.808411
#
#        E4_Accuracy  E4_KillsPerGame  E4_HeadshotsPerGame  \
# 0         0.314397        10.859813             1.822430
# 1         0.387158        10.476190             4.057143
# 2         0.328236        14.965812             3.008547
# 3         0.353661        14.849866             2.627346
# 4         0.344869        17.541444             4.733957
# ...            ...              ...                  ...
# 17149     0.250733        12.066667             2.333333
# 17150     0.355227        17.109756             5.829268
# 17151     0.355227        17.109756             5.829268
# 17152     0.337246        11.159420             1.753623
# 17153     0.354272        10.176471             1.411765
#
#        E4_WeaponDamagePerGame  E4_ShotsFiredPerGame  E4_ShotsLandedPerGame  \
# 0                 1438.565561            354.691589             111.514019
# 1                 1262.757401            214.628571              83.095238
# 2                 2078.555978            492.974359             161.811966
# 3                 1931.348814            299.949062             106.080429
# 4                 2225.263902            395.681818             136.458556
# ...                       ...                   ...                    ...
# 17149             1858.809019            545.600000             136.800000
# 17150             2201.957454            341.073171             121.158537
# 17151             2201.957454            341.073171             121.158537
# 17152             1439.763343            286.420290              96.594203
# 17153             1443.605013            221.000000              78.294118
#
#        E4_MeleeKillsPerGame  E4_MeleeDamagePerGame  E4_AssassinationsPerGame  \
# 0                  0.532710              81.603307                  0.130841
# 1                  1.485714             222.860506                  0.380952
# 2                  0.478632              45.545981                  0.085470
# 3                  0.375335              61.110729                  0.096515
# 4                  0.291444              35.004279                  0.065508
# ...                     ...                    ...                       ...
# 17149              0.200000              23.604266                  0.000000
# 17150              0.329268              37.496218                  0.060976
# 17151              0.329268              37.496218                  0.060976
# 17152              0.536232              75.491951                  0.246377
# 17153              0.235294              24.653690                  0.000000
#
#        E4_GroundPoundKillsPerGame  E4_GroundPoundDamagePerGame  \
# 0                        0.009346                     1.074766
# 1                        0.019048                     0.073830
# 2                        0.000000                     0.000000
# 3                        0.016086                     2.581587
# 4                        0.016043                     1.989747
# ...                           ...                          ...
# 17149                    0.000000                     0.000000
# 17150                    0.000000                     0.000000
# 17151                    0.000000                     0.000000
# 17152                    0.043478                     6.376812
# 17153                    0.000000                     0.000000
#
#        E4_ShoulderBashKillsPerGame  E4_ShoulderBashDamagePerGame  \
# 0                         0.196262                     26.722741
# 1                         0.104762                     12.290455
# 2                         0.008547                      2.412393
# 3                         0.061662                     12.657792
# 4                         0.006684                      1.825490
# ...                            ...                           ...
# 17149                     0.000000                      0.000000
# 17150                     0.012195                      4.878049
# 17151                     0.012195                      4.878049
# 17152                     0.014493                      1.666667
# 17153                     0.000000                      0.000000
#
#        E4_GrenadeDamagePerGame  E4_PowerWeaponKillsPerGame  \
# 0                    70.084521                    5.869159
# 1                    22.530834                    2.895238
# 2                    99.913611                   11.418803
# 3                   158.978818                   11.538874
# 4                    69.770928                   14.195187
# ...                        ...                         ...
# 17149                51.056815                    9.800000
# 17150                76.791433                   14.170732
# 17151                76.791433                   14.170732
# 17152               110.960693                    7.086957
# 17153               132.942945                    8.117647
#
#        E4_PowerWeaponDamagePerGame  E4_PowerWeaponGrabsPerGame  \
# 0                       745.021772                    0.168224
# 1                       391.499727                    0.295238
# 2                      1529.383156                    0.000000
# 3                      1447.766989                    0.058981
# 4                      1794.521844                    0.046791
# ...                            ...                         ...
# 17149                  1455.149755                    0.000000
# 17150                  1790.903009                    0.048780
# 17151                  1790.903009                    0.048780
# 17152                   912.142563                    0.115942
# 17153                  1074.660991                    0.000000
#
#        E4_PowerWeaponPossessionTimePerGame  E4_DeathsPerGame  \
# 0                                 0.027984         10.177570
# 1                                 0.017606         11.685714
# 2                                 0.055407         13.700855
# 3                                 0.048346         18.798928
# 4                                 0.066069          9.060160
# ...                                    ...               ...
# 17149                             0.054486         11.800000
# 17150                             0.058538         11.841463
# 17151                             0.058538         11.841463
# 17152                             0.044756         11.652174
# 17153                             0.038053         12.588235
#
#        E4_AssistsPerGame  E4_GrenadeKillsPerGame
# 0               4.158879                0.401869
# 1               5.323810                0.104762
# 2               7.290598                0.341880
# 3               5.898123                0.630027
# 4               6.049465                0.331551
# ...                  ...                     ...
# 17149           6.733333                0.266667
# 17150           5.329268                0.414634
# 17151           5.329268                0.414634
# 17152           4.362319                0.449275
# 17153           5.000000                0.235294
#
# [9197 rows x 401 columns]

# %% [markdown]
# # Make Model Dataframe Function

# %%
# Set columns for full model dataframe
feature_list = ['WinRate', 'TotalKills', 'TotalHeadshots', 'TotalWeaponDamage', 
                'TotalShotsFired', 'K/D', 'TotalPowerWeaponPossessionTime', 'Accuracy',
                'TotalShotsLanded', 'TotalMeleeKills', 'TotalMeleeDamage', 'TotalAssassinations',
                'TotalGroundPoundKills', 'TotalGroundPoundDamage', 'TotalShoulderBashKills',
                'TotalShoulderBashDamage', 'TotalGrenadeDamage', 'TotalPowerWeaponKills',
                'TotalPowerWeaponDamage', 'TotalPowerWeaponGrabs',
                'TotalDeaths', 'TotalAssists', 'TotalGamesCompleted', 'TotalGamesWon',
                'TotalGamesLost', 'TotalGamesTied', 'TotalTimePlayed','TotalGrenadeKills',
                'PrevTotalXP', 'SpartanRank',
#                 'KillsPerGame', 'HeadshotsPerGame', 'WeaponDamagePerGame', 
#                 'ShotsFiredPerGame', 'ShotsLandedPerGame', 'MeleeKillsPerGame', 
#                 'MeleeDamagePerGame', 'AssassinationsPerGame', 'GroundPoundKillsPerGame', 
#                 'GroundPoundDamagePerGame', 'ShoulderBashKillsPerGame', 
#                 'ShoulderBashDamagePerGame', 'GrenadeDamagePerGame', 'PowerWeaponKillsPerGame', 
#                 'PowerWeaponDamagePerGame', 'PowerWeaponGrabsPerGame', 
#                 'PowerWeaponPossessionTimePerGame', 'DeathsPerGame', 'AssistsPerGame', 
#                 'GrenadeKillsPerGame',
]
# feature_list = ['WinRate', 'K/D', 'TotalGamesCompleted', 'TotalTimePlayed', 'Accuracy',
#                 'PrevTotalXP', 'SpartanRank']

# Function that sorts player stats
def sort_players(df, feature_list, GameBaseVariantId, PlaylistId):
    
    # Choose gametype function
    df = choose_gametype(df, GameBaseVariantId, PlaylistId) 
    
    # Empty dataframe with PlayerWin as first column
    model_df = pd.DataFrame()
    model_df['PlayerWin'] = df['PlayerWin']
    
    # Loop that sorts player stats per team
    for feature in feature_list:
        feature_columns = [
            f'P1_{feature}', f'P2_{feature}',
            f'P3_{feature}', f'P4_{feature}', f'E1_{feature}',
            f'E2_{feature}', f'E3_{feature}', f'E4_{feature}',
            ]
        
        # Copy input dataframe columns
        feature_df = df[feature_columns].copy()

        # Sort Players in dataframe by highest value
        i = 0
        for row in tqdm(feature_df.iterrows()):
            # Sort player / enemy from highest to lowest in row
            feature_df.iloc[i, 0:4] = feature_df.iloc[i, 0:4].sort_values(ascending=False).values
            feature_df.iloc[i, 4:8] = feature_df.iloc[i, 4:8].sort_values(ascending=False).values
            i += 1
        
        # Join sorted features with PlayerWin column
        model_df = model_df.join(feature_df, on=model_df.index)
    
    # Drop null values
    model_df = model_df.dropna()
    
    # Return sorted dataframe
    return model_df
            
df = sort_players(df, feature_list, None, None)

df
# Out:
# 9197it [00:09, 983.20it/s]
# 9197it [00:10, 918.57it/s]
# 9197it [00:10, 919.49it/s]
# 9197it [00:09, 983.63it/s]
# 9197it [00:09, 920.04it/s]
# 9197it [00:09, 984.68it/s]
# 9197it [00:09, 984.47it/s]
# 9197it [00:09, 975.90it/s]
# 9197it [00:09, 925.51it/s]
# 9197it [00:10, 918.48it/s]
# 9197it [00:09, 964.64it/s]
# 9197it [00:10, 909.40it/s]
# 9197it [00:09, 920.60it/s]
# 9197it [00:09, 984.78it/s]
# 9197it [00:10, 903.61it/s]
# 9197it [00:09, 973.06it/s]
# 9197it [00:09, 969.52it/s]
# 9197it [00:10, 909.40it/s]
# 9197it [00:09, 960.72it/s]
# 9197it [00:10, 907.51it/s]
# 9197it [00:09, 920.96it/s]
# 9197it [00:09, 921.96it/s]
# 9197it [00:09, 924.39it/s]
# 9197it [00:09, 923.65it/s]
# 9197it [00:09, 922.03it/s]
# 9197it [00:10, 919.10it/s]
# 9197it [00:09, 987.00it/s]
# 9197it [00:09, 922.91it/s]
# 9197it [00:09, 922.76it/s]
# 9197it [00:09, 923.83it/s]
# 9197it [00:09, 982.78it/s]
# 9197it [00:09, 987.64it/s]
# 9197it [00:09, 986.44it/s]
# 9197it [00:09, 987.53it/s]
# 9197it [00:09, 982.78it/s]
# 9197it [00:09, 978.86it/s]
# 9197it [00:09, 981.64it/s]
# 9197it [00:09, 982.68it/s]
# 9197it [00:09, 987.11it/s]
# 9197it [00:09, 991.63it/s]
# 9197it [00:09, 986.72it/s]
# 9197it [00:09, 984.36it/s]
# 9197it [00:09, 988.06it/s]
# 9197it [00:09, 985.84it/s]
# 9197it [00:09, 988.00it/s]
# 9197it [00:09, 987.42it/s]
# 9197it [00:09, 986.90it/s]
# 9197it [00:09, 983.41it/s]
# 9197it [00:09, 984.65it/s]
# 9197it [00:09, 987.59it/s]
#        PlayerWin  P1_WinRate  P2_WinRate  P3_WinRate  P4_WinRate  E1_WinRate  \
# 0              0    1.225000    1.180952    1.063830    0.857143    1.126506
# 1              1    1.722798    1.330551    0.908046    0.881633    0.768844
# 2              1    1.330551    1.032609    1.008532    0.998724    1.020833
# 3              1    1.451870    1.330551    1.167612    0.995571    2.567010
# 4              1    2.567010    1.716578    1.330551    1.101504    1.451870
# ...          ...         ...         ...         ...         ...         ...
# 17149          1    1.066667    1.047619    0.724684    0.477273    0.865169
# 17150          0    1.620646    1.193548    1.047619    0.724684    0.994624
# 17151          1    1.153732    0.968814    0.765625    0.724684    1.070175
# 17152          1    1.791667    1.474333    0.990210    0.724684    1.216340
# 17153          0    1.204149    0.924765    0.923077    0.724684    1.088608
#
#        E2_WinRate  E3_WinRate  E4_WinRate  P1_TotalKills  P2_TotalKills  \
# 0        1.083333    0.890805    0.676636           3388           3378
# 1        0.725061    0.646302    0.538462          39309          39273
# 2        0.867140    0.844732    0.646302          58661          39273
# 3        1.716578    0.867140    0.844732         100339          73644
# 4        1.167612    0.867140    0.851312          39273          11675
# ...           ...         ...         ...            ...            ...
# 17149    0.518519    0.500000    0.400000          18575           3580
# 17150    0.864173    0.863176    0.541667          61629          18575
# 17151    0.864173    0.863176    0.541667          48496          47496
# 17152    1.133065    0.833333    0.701818          39665          26297
# 17153    0.683168    0.545455    0.428571          35392          18575
#
#        P3_TotalKills  P4_TotalKills  E1_TotalKills  E2_TotalKills  \
# 0               1882           1315          16222          12790
# 1               7914           2646          19844          13209
# 2              21952           6436          31941          13209
# 3              67990          39273          31941          13090
# 4               8780           5539          73644          67990
# ...              ...            ...            ...            ...
# 17149           2212           1051           2383            936
# 17150           3580            830          14922          14575
# 17151          18575           5389          22524          14922
# 17152          18575           6209          63590          16690
# 17153           6786            607           2796           2615
#
#        E3_TotalKills  E4_TotalKills  P1_TotalHeadshots  P2_TotalHeadshots  \
# 0               6174           1162                551                378
# 1               6268           1100               6720               3202
# 2              13090           1751              11418               3777
# 3               8780           5539              22173              13972
# 4              31941          13121               3202               2525
# ...              ...            ...                ...                ...
# 17149            533            181               2655                429
# 17150           4308           1403               2655               2372
# 17151          14575           1403               9070               6036
# 17152           6227            770               4043               3931
# 17153            680            173               2655               1694
#
#        P3_TotalHeadshots  P4_TotalHeadshots  E1_TotalHeadshots  \
# 0                    309                253               3950
# 1                    801                399               7015
# 2                   3202               1229               5861
# 3                  11265               3202               5861
# 4                   1338                980              13972
# ...                  ...                ...                ...
# 17149                183                106                406
# 17150                429                117               1767
# 17151               2655                859               4159
# 17152               2655               1523              15083
# 17153                943                 51                537
#
#        E2_TotalHeadshots  E3_TotalHeadshots  E4_TotalHeadshots  \
# 0                   1262                693                195
# 1                   2226                969                426
# 2                   2226               1966                352
# 3                   1966               1338                980
# 4                  11265               5861               3541
# ...                  ...                ...                ...
# 17149                330                 88                 35
# 17150                811                478                457
# 17151               1767                811                478
# 17152               2140               1424                121
# 17153                332                120                 24
#
#        P1_TotalWeaponDamage  P2_TotalWeaponDamage  P3_TotalWeaponDamage  \
# 0              4.506744e+05          4.362411e+05          2.504024e+05
# 1              5.369387e+06          5.020049e+06          9.670463e+05
# 2              7.990578e+06          5.020049e+06          2.937519e+06
# 3              1.279709e+07          9.922924e+06          9.059519e+06
# 4              5.020049e+06          1.584917e+06          1.131636e+06
# ...                     ...                   ...                   ...
# 17149          2.512373e+06          5.183810e+05          2.955593e+05
# 17150          8.551291e+06          2.512373e+06          5.183810e+05
# 17151          6.745410e+06          6.323878e+06          2.512373e+06
# 17152          5.160209e+06          3.667258e+06          2.512373e+06
# 17153          4.916751e+06          2.512373e+06          8.529598e+05
#
#        P4_TotalWeaponDamage  E1_TotalWeaponDamage  E2_TotalWeaponDamage  \
# 0              1.633076e+05          2.140170e+06          1.684482e+06
# 1              3.246299e+05          2.720339e+06          1.771996e+06
# 2              8.531748e+05          4.173908e+06          1.771996e+06
# 3              5.020049e+06          4.173908e+06          1.614739e+06
# 4              7.203931e+05          9.922924e+06          9.059519e+06
# ...                     ...                   ...                   ...
# 17149          1.448845e+05          3.006300e+05          1.178031e+05
# 17150          1.064151e+05          1.961913e+06          1.921847e+06
# 17151          7.190559e+05          2.929495e+06          1.961913e+06
# 17152          8.146049e+05          8.628021e+06          2.178511e+06
# 17153          7.486255e+04          3.454589e+05          3.375160e+05
#
#        E3_TotalWeaponDamage  E4_TotalWeaponDamage  P1_TotalShotsFired  \
# 0              7.163374e+05          1.539265e+05              123305
# 1              7.732204e+05          1.325895e+05             1111772
# 2              1.614739e+06          2.431910e+05             1326652
# 3              1.131636e+06          7.203931e+05             2176535
# 4              4.173908e+06          1.664497e+06             1025141
# ...                     ...                   ...                 ...
# 17149          7.010694e+04          2.788214e+04              471061
# 17150          5.760006e+05          1.805605e+05             1411114
# 17151          1.921847e+06          1.805605e+05             1658366
# 17152          8.020961e+05          9.934367e+04              959904
# 17153          9.240003e+04          2.454129e+04             1151702
#
#        P2_TotalShotsFired  P3_TotalShotsFired  P4_TotalShotsFired  \
# 0                   96140               54355               22859
# 1                 1025141              143169               65294
# 2                 1025141              521487              161503
# 3                 2081512             1602064             1025141
# 4                  310439              185417              111881
# ...                   ...                 ...                 ...
# 17149              129723               60616               37131
# 17150              471061              129723               20408
# 17151             1316104              471061              136505
# 17152              899738              471061              140907
# 17153              471061              101961               18855
#
#        E1_TotalShotsFired  E2_TotalShotsFired  E3_TotalShotsFired  \
# 0                  439309              371779              119575
# 1                  446426              310586              150020
# 2                  719658              310586              249751
# 3                  719658              249751              185417
# 4                 2081512             1602064              719658
# ...                   ...                 ...                 ...
# 17149               59815               25412                9989
# 17150              469537              382975              113067
# 17151              506356              469537              382975
# 17152             1625954              382843              139655
# 17153               70476               57546               17195
#
#        E4_TotalShotsFired    P1_K/D    P2_K/D    P3_K/D    P4_K/D    E1_K/D  \
# 0                   37952  1.208274  0.940161  0.932624  0.925270  1.130138
# 1                   22536  1.110204  1.061372  0.997353  0.882460  1.205153
# 2                   57678  1.161104  0.960821  0.882460  0.859683  1.265090
# 3                  111881  1.573131  1.258212  0.947019  0.882460  1.265090
# 4                  295970  1.134367  1.095627  0.882460  0.789932  1.936107
# ...                   ...       ...       ...       ...       ...       ...
# 17149                8184  1.392053  1.193996  0.854054  0.787159  1.500000
# 17150               27968  1.193996  0.811506  0.787159  0.774254  1.444902
# 17151               27968  1.193996  1.095548  1.015414  0.947317  1.444902
# 17152               19763  1.297868  1.193996  1.109250  0.888553  1.177200
# 17153                3757  1.193996  0.968737  0.811497  0.736229  1.182609
#
#          E2_K/D    E3_K/D    E4_K/D  P1_TotalPowerWeaponPossessionTime  \
# 0      1.097795  1.068683  1.067034                          14.473583
# 1      1.161691  0.946475  0.896496                         157.602300
# 2      1.092327  0.946475  0.827748                         215.471346
# 3      1.134367  0.827748  0.789932                         346.243585
# 4      1.265090  1.258212  0.947019                         157.602300
# ...         ...       ...       ...                                ...
# 17149  1.022599  0.965168  0.790801                          78.836189
# 17150  0.949108  0.906892  0.860186                         236.848029
# 17151  0.974053  0.906892  0.860186                         195.612312
# 17152  1.014831  0.957711  0.790808                         159.773125
# 17153  1.063522  1.014746  0.808411                         159.671667
#
#        P2_TotalPowerWeaponPossessionTime  P3_TotalPowerWeaponPossessionTime  \
# 0                              14.334023                           6.340588
# 1                             124.635187                          45.035912
# 2                             157.602300                          74.455840
# 3                             268.604838                         180.095888
# 4                              37.255634                          27.263305
# ...                                  ...                                ...
# 17149                          15.836440                          12.984087
# 17150                          78.836189                          15.836440
# 17151                         186.968467                          78.836189
# 17152                          92.367106                          78.836189
# 17153                          78.836189                          32.477833
#
#        P4_TotalPowerWeaponPossessionTime  E1_TotalPowerWeaponPossessionTime  \
# 0                               5.379408                          62.450902
# 1                              10.007569                          60.453406
# 2                              26.788316                         140.548636
# 3                             157.602300                         140.548636
# 4                              18.032953                         268.604838
# ...                                  ...                                ...
# 17149                           4.350533                          10.837880
# 17150                           3.669130                          74.058487
# 17151                          22.843518                          76.505689
# 17152                          17.421093                         203.657650
# 17153                           2.252690                          11.455647
#
#        E2_TotalPowerWeaponPossessionTime  E3_TotalPowerWeaponPossessionTime  \
# 0                              52.563167                          24.540722
# 1                              46.762009                          24.840514
# 2                              60.453406                          59.288728
# 3                              59.288728                          27.263305
# 4                             180.095888                         140.548636
# ...                                  ...                                ...
# 17149                           3.921426                           3.614741
# 17150                          57.017607                          18.706935
# 17151                          74.058487                          57.017607
# 17152                          60.336330                          27.437500
# 17153                           9.606491                           3.343393
#
#        E4_TotalPowerWeaponPossessionTime  P1_Accuracy  P2_Accuracy  \
# 0                               2.994338     0.402992     0.324256
# 1                               1.848657     0.373541     0.358057
# 2                               6.482648     0.390255     0.358057
# 3                              18.032953     0.371042     0.358057
# 4                              49.419732     0.394780     0.358057
# ...                                  ...          ...          ...
# 17149                           0.817292     0.370523     0.326654
# 17150                           4.800134     0.385196     0.370523
# 17151                           4.800134     0.370523     0.358969
# 17152                           3.088185     0.373253     0.370523
# 17153                           0.646898     0.411981     0.370523
#
#        P3_Accuracy  P4_Accuracy  E1_Accuracy  E2_Accuracy  E3_Accuracy  \
# 0         0.316861     0.273063     0.348133     0.323119     0.318506
# 1         0.351966     0.292081     0.420970     0.387158     0.354399
# 2         0.349449     0.346765     0.371962     0.349040     0.345135
# 3         0.352112     0.321610     0.394780     0.371962     0.353661
# 4         0.353661     0.349038     0.371042     0.345135     0.344869
# ...            ...          ...          ...          ...          ...
# 17149     0.315881     0.198231     0.321458     0.306637     0.276680
# 17150     0.318111     0.315881     0.355227     0.344365     0.327187
# 17151     0.326550     0.291027     0.380598     0.355227     0.344365
# 17152     0.348583     0.310257     0.378022     0.351808     0.338656
# 17153     0.285926     0.284911     0.354272     0.352188     0.329460
#
#        E4_Accuracy  P1_TotalShotsLanded  P2_TotalShotsLanded  \
# 0         0.314397                33670                31174
# 1         0.349040               391306               367059
# 2         0.328236               460037               367059
# 3         0.345135               766384               669436
# 4         0.321610               367059               108355
# ...            ...                  ...                  ...
# 17149     0.250733               174539                40977
# 17150     0.314823               543555               174539
# 17151     0.314823               482630               429774
# 17152     0.337246               334606               279150
# 17153     0.324048               329302               174539
#
#        P3_TotalShotsLanded  P4_TotalShotsLanded  E1_TotalShotsLanded  \
# 0                    17223                 9212               141949
# 1                    41817                24390               187932
# 2                   203513                56437               248379
# 3                   594433               367059               248379
# 4                    73199                39568               669436
# ...                    ...                  ...                  ...
# 17149                12129                12016                19228
# 17150                40977                 6492               147821
# 17151               174539                49001               192718
# 17152               174539                52594               572023
# 17153                42006                 5372                23219
#
#        E2_TotalShotsLanded  E3_TotalShotsLanded  E4_TotalShotsLanded  \
# 0                   118414                41628                11932
# 1                   108407                53167                 8725
# 2                   108407                92898                18932
# 3                    92898                73199                39568
# 4                   594433               248379               102071
# ...                    ...                  ...                  ...
# 17149                 7031                 3063                 2052
# 17150               131883                36994                 9935
# 17151               147821               131883                 9935
# 17152               144723                47295                 6665
# 17153                20267                 5572                 1331
#
#        P1_TotalMeleeKills  P2_TotalMeleeKills  P3_TotalMeleeKills  \
# 0                     150                 130                 115
# 1                    1289                 876                 211
# 2                    1669                1289                 907
# 3                    1959                1568                1289
# 4                    1289                 319                 202
# ...                   ...                 ...                 ...
# 17149                 477                  78                  34
# 17150                2134                 477                  78
# 17151                1627                1250                 477
# 17152                1094                 748                 477
# 17153                1570                 477                 185
#
#        P4_TotalMeleeKills  E1_TotalMeleeKills  E2_TotalMeleeKills  \
# 0                      34                 704                 297
# 1                     120                1067                 426
# 2                      93                 869                 590
# 3                    1131                 869                 590
# 4                     140                1568                1131
# ...                   ...                 ...                 ...
# 17149                  12                  96                  32
# 17150                  41                 602                 463
# 17151                 101                 961                 602
# 17152                 139                 662                 554
# 17153                  63                 135                 107
#
#        E3_TotalMeleeKills  E4_TotalMeleeKills  P1_TotalMeleeDamage  \
# 0                     284                  57         14200.282440
# 1                     240                 156        147219.068300
# 2                     426                  56        222380.100500
# 3                     202                 140        228599.805100
# 4                     869                 218        147219.068300
# ...                   ...                 ...                  ...
# 17149                  16                   3         48077.295310
# 17150                 159                  27        263653.063311
# 17151                 463                  27        181559.937668
# 17152                 279                  37        129554.672029
# 17153                   7                   4        194267.528834
#
#        P2_TotalMeleeDamage  P3_TotalMeleeDamage  P4_TotalMeleeDamage  \
# 0             13866.324490         13798.771950          6087.614542
# 1            105948.321600         26461.924720         13928.636150
# 2            147219.068300         96793.466930         11200.409080
# 3            192638.975400        147219.068300        142355.900000
# 4             44222.395030         25683.028790         22794.301900
# ...                    ...                  ...                  ...
# 17149          8276.362618          3482.815693          1154.068493
# 17150         48077.295310          8276.362618          6658.344380
# 17151        150164.480082         48077.295310         13147.393102
# 17152         85156.954115         48077.295310         13952.475305
# 17153         48077.295310         24729.738401          6376.120871
#
#        E1_TotalMeleeDamage  E2_TotalMeleeDamage  E3_TotalMeleeDamage  \
# 0             95917.873820         36559.273000         31542.311790
# 1            124757.007200         55482.927890         27062.244540
# 2            113148.631700         74317.295070         55482.927890
# 3            113148.631700         74317.295070         25683.028790
# 4            192638.975400        142355.900000        113148.631700
# ...                    ...                  ...                  ...
# 17149         14147.510803          6475.991490          2380.042631
# 17150         72621.635562         58974.862094         20240.704950
# 17151        110548.349425         72621.635562         58974.862094
# 17152         89968.078171         72071.612779         39245.913157
# 17153         16960.050350         13514.770675           906.287860
#
#        E4_TotalMeleeDamage  P1_TotalAssassinations  P2_TotalAssassinations  \
# 0              8731.553861                      22                      21
# 1             23400.353120                     216                     130
# 2              5328.879808                     325                     216
# 3             22794.301900                     375                     216
# 4             26183.200930                     216                      84
# ...                    ...                     ...                     ...
# 17149           354.063993                      59                      11
# 17150          3074.689894                     537                      59
# 17151          3074.689894                     301                     193
# 17152          5208.944646                     180                     147
# 17153           419.112724                     303                      59
#
#        P3_TotalAssassinations  P4_TotalAssassinations  E1_TotalAssassinations  \
# 0                          13                       6                     148
# 1                          32                      31                     219
# 2                         107                      19                     186
# 3                         212                     155                     186
# 4                          44                      36                     212
# ...                       ...                     ...                     ...
# 17149                       2                       0                      32
# 17150                      18                      11                     113
# 17151                      59                      24                     121
# 17152                      59                      13                     136
# 17153                      43                      10                      26
#
#        E2_TotalAssassinations  E3_TotalAssassinations  E4_TotalAssassinations  \
# 0                          81                      41                      14
# 1                         107                      48                      40
# 2                         139                     107                      10
# 3                         139                      44                      36
# 4                         186                     155                      49
# ...                       ...                     ...                     ...
# 17149                      26                       5                       0
# 17150                     107                      20                       5
# 17151                     113                     107                       5
# 17152                      95                      85                      17
# 17153                      21                       1                       0
#
#        P1_TotalGroundPoundKills  P2_TotalGroundPoundKills  \
# 0                             9                         5
# 1                            35                        26
# 2                           118                        26
# 3                            44                        39
# 4                            26                        13
# ...                         ...                       ...
# 17149                        11                         1
# 17150                         1                         1
# 17151                        15                         8
# 17152                        37                         3
# 17153                         0                         0
#
#        P3_TotalGroundPoundKills  P4_TotalGroundPoundKills  \
# 0                             3                         1
# 1                            15                         0
# 2                            18                         0
# 3                            26                         7
# 4                             6                         3
# ...                         ...                       ...
# 17149                         0                         0
# 17150                         0                         0
# 17151                         0                         0
# 17152                         1                         0
# 17153                         0                         0
#
#        E1_TotalGroundPoundKills  E2_TotalGroundPoundKills  \
# 0                            34                         6
# 1                            16                        10
# 2                            37                        29
# 3                            37                        29
# 4                            44                        37
# ...                         ...                       ...
# 17149                         4                         1
# 17150                        12                         0
# 17151                        12                         2
# 17152                        19                         9
# 17153                         2                         1
#
#        E3_TotalGroundPoundKills  E4_TotalGroundPoundKills  \
# 0                             5                         1
# 1                             3                         2
# 2                            10                         0
# 3                            13                         6
# 4                            12                         7
# ...                         ...                       ...
# 17149                         0                         0
# 17150                         0                         0
# 17151                         0                         0
# 17152                         3                         0
# 17153                         0                         0
#
#        P1_TotalGroundPoundDamage  P2_TotalGroundPoundDamage  \
# 0                    2178.285184                1778.400188
# 1                    8937.051069                5870.122829
# 2                   21481.336320                5870.122829
# 3                    7041.194090                6033.137176
# 4                    5870.122829                3413.963149
# ...                          ...                        ...
# 17149                2296.688987                 285.000000
# 17150                 285.000000                 190.000000
# 17151                2895.922417                2260.195777
# 17152                5761.967788                 609.718712
# 17153                 285.000000                 285.000000
#
#        P3_TotalGroundPoundDamage  P4_TotalGroundPoundDamage  \
# 0                     776.223419                 435.899994
# 1                    1363.579624                   0.000000
# 2                    3082.305937                   0.000000
# 3                    5870.122829                1549.980980
# 4                     962.931915                 437.500000
# ...                          ...                        ...
# 17149                  35.000000                   0.000000
# 17150                  35.000000                   0.000000
# 17151                 285.000000                 285.000000
# 17152                 285.000000                 159.285248
# 17153                   0.000000                   0.000000
#
#        E1_TotalGroundPoundDamage  E2_TotalGroundPoundDamage  \
# 0                    7355.041995                1799.382126
# 1                    3549.135921                1435.099349
# 2                    9390.987291                5427.876639
# 3                    9390.987291                5427.876639
# 4                    9390.987291                7041.194090
# ...                          ...                        ...
# 17149                 636.781109                 400.000000
# 17150                1288.308033                 143.857143
# 17151                1288.308033                 214.895515
# 17152                3597.006096                1594.183304
# 17153                 336.803579                 244.823997
#
#        E3_TotalGroundPoundDamage  E4_TotalGroundPoundDamage  \
# 0                     990.599998                 115.000000
# 1                     599.247807                   7.752099
# 2                    3549.135921                   0.000000
# 3                    3413.963149                 962.931915
# 4                    1549.980980                1488.331004
# ...                          ...                        ...
# 17149                  95.000000                   0.000000
# 17150                   0.000000                   0.000000
# 17151                 143.857143                   0.000000
# 17152                 440.000000                   0.000000
# 17153                  70.000000                   0.000000
#
#        P1_TotalShoulderBashKills  P2_TotalShoulderBashKills  \
# 0                             20                         19
# 1                            123                         25
# 2                            374                        123
# 3                            123                        114
# 4                            123                         53
# ...                          ...                        ...
# 17149                          4                          2
# 17150                        138                          4
# 17151                         75                         24
# 17152                         74                         17
# 17153                         48                         18
#
#        P3_TotalShoulderBashKills  P4_TotalShoulderBashKills  \
# 0                             13                         12
# 1                             18                          9
# 2                             71                          1
# 3                             89                         18
# 4                             40                         23
# ...                          ...                        ...
# 17149                          0                          0
# 17150                          0                          0
# 17151                         17                          4
# 17152                          5                          4
# 17153                          5                          4
#
#        E1_TotalShoulderBashKills  E2_TotalShoulderBashKills  \
# 0                             82                         60
# 1                             15                         11
# 2                            122                         79
# 3                            122                         79
# 4                            114                         79
# ...                          ...                        ...
# 17149                         51                          2
# 17150                         24                         18
# 17151                         35                         24
# 17152                         66                         64
# 17153                          7                          6
#
#        E3_TotalShoulderBashKills  E4_TotalShoulderBashKills  \
# 0                             42                         21
# 1                              2                          1
# 2                             15                          1
# 3                             53                         23
# 4                             18                          5
# ...                          ...                        ...
# 17149                          0                          0
# 17150                         16                          1
# 17151                         18                          1
# 17152                          9                          1
# 17153                          0                          0
#
#        P1_TotalShoulderBashDamage  P2_TotalShoulderBashDamage  \
# 0                     3887.518391                 3866.135540
# 1                    26233.730550                 4594.986589
# 2                    65457.288060                26233.730550
# 3                    29377.620450                26233.730550
# 4                    26233.730550                 8892.856932
# ...                           ...                         ...
# 17149                  891.852951                  624.204346
# 17150                21252.532578                  624.204346
# 17151                14633.611238                 4154.589319
# 17152                16510.107470                 5598.245636
# 17153                 8934.415877                 4380.611336
#
#        P3_TotalShoulderBashDamage  P4_TotalShoulderBashDamage  \
# 0                     3712.180248                 1809.374457
# 1                     3102.606691                 1718.871307
# 2                    16138.151560                  164.162956
# 3                    12423.010870                 3564.747462
# 4                     6723.297248                 4721.356329
# ...                           ...                         ...
# 17149                  190.000000                    0.000000
# 17150                  285.000000                  190.000000
# 17151                 3125.997933                  624.204346
# 17152                  814.267700                  624.204346
# 17153                  624.204346                  539.459305
#
#        E1_TotalShoulderBashDamage  E2_TotalShoulderBashDamage  \
# 0                    11246.566490                 9618.008672
# 1                     4227.417664                 1290.497803
# 2                    21581.613900                19644.680740
# 3                    21581.613900                19644.680740
# 4                    29377.620450                21581.613900
# ...                           ...                         ...
# 17149                10056.732410                  467.000000
# 17150                 3843.027175                 2979.495301
# 17151                 7642.344279                 3843.027175
# 17152                15046.164890                 9269.909812
# 17153                 1255.465202                  928.260933
#
#        E3_TotalShoulderBashDamage  E4_TotalShoulderBashDamage  \
# 0                     8975.222380                 2859.333313
# 1                      875.000000                  332.500000
# 2                     4227.417664                  282.250000
# 3                     8892.856932                 4721.356329
# 4                     3564.747462                 1365.466648
# ...                           ...                         ...
# 17149                  190.000000                    0.000000
# 17150                 2951.744655                  400.000000
# 17151                 2951.744655                  400.000000
# 17152                 1763.644077                  115.000000
# 17153                    0.000000                    0.000000
#
#        P1_TotalGrenadeDamage  P2_TotalGrenadeDamage  P3_TotalGrenadeDamage  \
# 0               3.368192e+04           17833.891120           17023.678130
# 1               4.802759e+05          192043.794600          162607.748800
# 2               8.671373e+05          219603.146000          192043.794600
# 3               9.053578e+05          515516.282700          447423.202600
# 4               1.920438e+05           78299.874600           70735.086420
# ...                      ...                    ...                    ...
# 17149           1.879024e+05           58016.705520           50753.426637
# 17150           1.447501e+06          187902.423894           50753.426637
# 17151           6.404158e+05          266858.066247          187902.423894
# 17152           2.957465e+05          258025.714207          187902.423894
# 17153           4.161335e+05          187902.423894           20998.387933
#
#        P4_TotalGrenadeDamage  E1_TotalGrenadeDamage  E2_TotalGrenadeDamage  \
# 0               10792.439860          132581.087200           49044.639980
# 1               11552.878470          184216.289500          107495.894300
# 2               64568.212760          284210.257800          118579.391400
# 3              192043.794600          284210.257800          118579.391400
# 4               59299.099270          515516.282700          447423.202600
# ...                      ...                    ...                    ...
# 17149            5741.055486           15445.614266            6228.953874
# 17150            7001.950355           98951.244538           82925.219961
# 17151           32973.702104          122085.033355           98951.244538
# 17152           22657.234288          370101.542099           64368.799300
# 17153            2456.071609           21501.693383            8085.129743
#
#        E3_TotalGrenadeDamage  E4_TotalGrenadeDamage  P1_TotalPowerWeaponKills  \
# 0               48645.772310            7499.043766                      2746
# 1               15518.169560            2365.737600                     34812
# 2              107495.894300           11689.892470                     44999
# 3               70735.086420           59299.099270                     87067
# 4              284210.257800           52188.653820                     34812
# ...                      ...                    ...                       ...
# 17149            4798.436010             765.852230                     15472
# 17150           33524.294650            6296.897543                     50787
# 17151           82925.219961            6296.897543                     40392
# 17152           50585.560052            7656.287787                     34339
# 17153            6654.628752            2260.030067                     28854
#
#        P2_TotalPowerWeaponKills  P3_TotalPowerWeaponKills  \
# 0                          2706                      1306
# 1                         31754                      5453
# 2                         34812                     16367
# 3                         62187                     52836
# 4                          9265                      6652
# ...                         ...                       ...
# 17149                      2510                      1427
# 17150                     15472                      2510
# 17151                     37823                     15472
# 17152                     21030                     15472
# 17153                     15472                      5929
#
#        P4_TotalPowerWeaponKills  E1_TotalPowerWeaponKills  \
# 0                          1002                     11464
# 1                          2093                      9786
# 2                          5300                     25437
# 3                         34812                     25437
# 4                          4304                     62187
# ...                         ...                       ...
# 17149                       866                      1918
# 17150                       695                     13068
# 17151                      4538                     18245
# 17152                      5276                     49935
# 17153                       438                      2409
#
#        E2_TotalPowerWeaponKills  E3_TotalPowerWeaponKills  \
# 0                         10966                      4471
# 1                          8652                      5180
# 2                          9786                      9568
# 3                          9568                      6652
# 4                         52836                     25437
# ...                         ...                       ...
# 17149                       662                       399
# 17150                     12238                      3542
# 17151                     13068                     12238
# 17152                     14049                      4171
# 17153                      2078                       568
#
#        E4_TotalPowerWeaponKills  P1_TotalPowerWeaponDamage  \
# 0                           628               3.561506e+05
# 1                           304               4.462575e+06
# 2                          1336               5.979214e+06
# 3                          4304               1.075508e+07
# 4                         10618               4.462575e+06
# ...                         ...                        ...
# 17149                       147               2.024696e+06
# 17150                      1162               6.521562e+06
# 17151                      1162               5.194313e+06
# 17152                       489               4.420410e+06
# 17153                       138               3.941001e+06
#
#        P2_TotalPowerWeaponDamage  P3_TotalPowerWeaponDamage  \
# 0                   3.535647e+05               1.785042e+05
# 1                   4.124953e+06               6.966502e+05
# 2                   4.462575e+06               2.128939e+06
# 3                   8.212049e+06               6.812084e+06
# 4                   1.240237e+06               8.405961e+05
# ...                          ...                        ...
# 17149               3.398281e+05               1.973169e+05
# 17150               2.024696e+06               3.398281e+05
# 17151               5.123769e+06               2.024696e+06
# 17152               2.800032e+06               2.024696e+06
# 17153               2.024696e+06               7.473317e+05
#
#        P4_TotalPowerWeaponDamage  E1_TotalPowerWeaponDamage  \
# 0                   1.230374e+05               1.513326e+06
# 1                   2.635325e+05               1.283125e+06
# 2                   6.783338e+05               3.284115e+06
# 3                   4.462575e+06               3.284115e+06
# 4                   5.400171e+05               8.212049e+06
# ...                          ...                        ...
# 17149               1.141231e+05               2.501823e+05
# 17150               9.001226e+04               1.694024e+06
# 17151               5.860970e+05               2.358535e+06
# 17152               6.862109e+05               6.597491e+06
# 17153               5.657558e+04               3.031702e+05
#
#        E2_TotalPowerWeaponDamage  E3_TotalPowerWeaponDamage  \
# 0                   1.422631e+06               5.760876e+05
# 1                   1.156967e+06               6.531948e+05
# 2                   1.283125e+06               1.210915e+06
# 3                   1.210915e+06               8.405961e+05
# 4                   6.812084e+06               3.284115e+06
# ...                          ...                        ...
# 17149               8.690794e+04               5.271311e+04
# 17150               1.598581e+06               4.594411e+05
# 17151               1.694024e+06               1.598581e+06
# 17152               1.830968e+06               5.460069e+05
# 17153               2.719041e+05               7.246510e+04
#
#        E4_TotalPowerWeaponDamage  P1_TotalPowerWeaponGrabs  \
# 0                   7.971733e+04                        23
# 1                   4.110747e+04                        16
# 2                   1.789378e+05                       270
# 3                   5.400171e+05                        69
# 4                   1.342302e+06                        22
# ...                          ...                       ...
# 17149               2.182725e+04                         9
# 17150               1.468540e+05                         9
# 17151               1.468540e+05                        20
# 17152               6.293784e+04                        81
# 17153               1.826924e+04                        76
#
#        P2_TotalPowerWeaponGrabs  P3_TotalPowerWeaponGrabs  \
# 0                            17                         3
# ...
# 3                      1462.659624                  1548.380570
# 4                      1447.766989                  1965.969271
# ...                            ...                          ...
# 17149                  1103.337921                  1455.149755
# 17150                  1103.337921                  1790.903009
# 17151                  1487.555915                  1790.903009
# 17152                  1574.413781                  1721.683390
# 17153                  1028.646917                  1604.075054
#
#        E2_PowerWeaponDamagePerGame  E3_PowerWeaponDamagePerGame  \
# 0                      1362.673641                  1358.461651
# 1                      1126.536170                   772.857182
# 2                      1529.383156                  1126.536170
# 3                      1525.582677                  1447.766989
# 4                      1794.521844                  1700.569169
# ...                            ...                          ...
# 17149                  1330.756676                  1224.055432
# 17150                  1487.051855                  1345.531681
# 17151                  1590.380742                  1487.051855
# 17152                  1509.453953                  1064.340863
# 17153                  1478.879567                  1454.032709
#
#        E4_PowerWeaponDamagePerGame  P1_PowerWeaponGrabsPerGame  \
# 0                       745.021772                    0.225490
# 1                       391.499727                    0.022807
# 2                      1072.555151                    0.075673
# 3                      1072.555151                    0.015873
# 4                      1548.380570                    0.058981
# ...                            ...                         ...
# 17149                  1098.189692                    0.031447
# 17150                  1160.204922                    0.006998
# 17151                  1345.531681                    0.050761
# 17152                   912.142563                    0.029390
# 17153                  1074.660991                    0.163636
#
#        P2_PowerWeaponGrabsPerGame  P3_PowerWeaponGrabsPerGame  \
# 0                        0.116438                    0.012987
# 1                        0.005244                    0.001259
# 2                        0.038263                    0.005244
# 3                        0.014177                    0.005244
# 4                        0.029038                    0.005244
# ...                           ...                         ...
# 17149                    0.006998                    0.000000
# 17150                    0.000000                    0.000000
# 17151                    0.006998                    0.002377
# 17152                    0.013366                    0.006998
# 17153                    0.025141                    0.006998
#
#        P4_PowerWeaponGrabsPerGame  E1_PowerWeaponGrabsPerGame  \
# 0                        0.000000                    0.168224
# 1                        0.000000                    0.384102
# 2                        0.000000                    0.161545
# 3                        0.001242                    0.136404
# 4                        0.004615                    0.054691
# ...                           ...                         ...
# 17149                    0.000000                    0.083333
# 17150                    0.000000                    0.048780
# 17151                    0.000000                    0.048780
# 17152                    0.000000                    0.337232
# 17153                    0.000000                    0.040816
#
#        E2_PowerWeaponGrabsPerGame  E3_PowerWeaponGrabsPerGame  \
# 0                        0.035907                    0.024450
# 1                        0.295238                    0.161545
# 2                        0.136404                    0.054691
# 3                        0.058981                    0.054691
# 4                        0.046791                    0.015873
# ...                           ...                         ...
# 17149                    0.014085                    0.005319
# 17150                    0.000000                    0.000000
# 17151                    0.002023                    0.000000
# 17152                    0.115942                    0.022443
# 17153                    0.021164                    0.000000
#
#        E4_PowerWeaponGrabsPerGame  P1_PowerWeaponPossessionTimePerGame  \
# 0                        0.017241                             0.062656
# 1                        0.000000                             0.079010
# 2                        0.000000                             0.061867
# 3                        0.029038                             0.071141
# 4                        0.001242                             0.057316
# ...                           ...                                  ...
# 17149                    0.000000                             0.081661
# 17150                    0.000000                             0.061303
# 17151                    0.000000                             0.061303
# 17152                    0.012366                             0.061303
# 17153                    0.000000                             0.061303
#
#        P2_PowerWeaponPossessionTimePerGame  \
# 0                                 0.055992
# 1                                 0.053516
# 2                                 0.060390
# 3                                 0.055623
# 4                                 0.051656
# ...                                    ...
# 17149                             0.061303
# 17150                             0.051417
# 17151                             0.058131
# 17152                             0.057973
# 17153                             0.052819
#
#        P3_PowerWeaponPossessionTimePerGame  \
# 0                                 0.052739
# 1                                 0.052324
# 2                                 0.054787
# 3                                 0.051976
# 4                                 0.049480
# ...                                    ...
# 17149                             0.055070
# 17150                             0.050674
# 17151                             0.057978
# 17152                             0.056746
# 17153                             0.047621
#
#        P4_PowerWeaponPossessionTimePerGame  \
# 0                                 0.043429
# 1                                 0.051656
# 2                                 0.051656
# 3                                 0.051656
# 4                                 0.048346
# ...                                    ...
# 17149                             0.051417
# 17150                             0.048278
# 17151                             0.055137
# 17152                             0.056116
# 17153                             0.040958
#
#        E1_PowerWeaponPossessionTimePerGame  \
# 0                                 0.060002
# 1                                 0.058586
# 2                                 0.066265
# 3                                 0.066265
# 4                                 0.066265
# ...                                    ...
# 17149                             0.081696
# 17150                             0.058823
# 17151                             0.058823
# 17152                             0.053484
# 17153                             0.068233
#
#        E2_PowerWeaponPossessionTimePerGame  \
# 0                                 0.059819
# 1                                 0.053076
# 2                                 0.055407
# 3                                 0.052514
# 4                                 0.066069
# ...                                    ...
# 17149                             0.057648
# 17150                             0.058538
# 17151                             0.058538
# 17152                             0.053147
# 17153                             0.060612
#
#        E3_PowerWeaponPossessionTimePerGame  \
# 0                                 0.047184
# 1                                 0.031237
# 2                                 0.053076
# 3                                 0.049480
# 4                                 0.055623
# ...                                    ...
# 17149                             0.054486
# 17150                             0.053040
# 17151                             0.053040
# 17152                             0.049741
# 17153                             0.051372
#
#        E4_PowerWeaponPossessionTimePerGame  P1_DeathsPerGame  \
# 0                                 0.027984         14.035156
# 1                                 0.017606         14.864400
# 2                                 0.052514         18.789551
# 3                                 0.048346         16.103541
# 4                                 0.051976         18.798928
# ...                                    ...               ...
# 17149                             0.050912         16.289308
# 17150                             0.047240         16.248181
# 17151                             0.051588         15.213373
# 17152                             0.044756         16.197388
# 17153                             0.038053         15.902084
#
#        P2_DeathsPerGame  P3_DeathsPerGame  P4_DeathsPerGame  E1_DeathsPerGame  \
# 0             13.931507         13.823529         12.138528         13.750611
# 1             14.586693         13.921053         13.331551         12.266509
# 2             17.111267         14.586693         12.801386         14.007086
# 3             15.595094         14.586693         13.105198         18.798928
# 4             16.393846         14.586693         14.047187         16.103541
# ...                 ...               ...               ...               ...
# 17149         14.766234         12.097201          9.556962         14.041667
# 17150         14.766234         14.105263         12.097201         15.761860
# 17151         13.793866         12.484772         12.097201         15.761860
# 17152         15.583062         14.402795         12.097201         17.399011
# 17153         13.600000         12.097201         10.271261         13.910053
#
#        E2_DeathsPerGame  E3_DeathsPerGame  E4_DeathsPerGame  \
# 0             12.885099         11.463602         10.177570
# 1             12.252853         11.685714         11.410822
# 2             13.700855         12.252853         11.903819
# 3             14.047187         14.007086         11.903819
# 4             15.595094         11.903819          9.060160
# ...                 ...               ...               ...
# 17149         13.132979         11.800000          8.788732
# 17150         13.069102         11.841463         11.462121
# 17151         15.592717         13.069102         11.841463
# 17152         14.096555         11.961014         11.652174
# 17153         13.780749         12.588235         11.734694
#
#        P1_AssistsPerGame  P2_AssistsPerGame  P3_AssistsPerGame  \
# 0               7.056277           5.855469           5.671233
# 1               8.102435           5.028070           4.962567
# 2               7.788079           7.233256           7.099496
# 3               7.688600           6.835422           6.555809
# 4               7.800000           6.330309           5.898123
# ...                  ...                ...                ...
# 17149           7.496753           6.641509           6.335925
# 17150           7.496753           6.338040           6.335925
# 17151           7.395459           6.335925           6.217831
# 17152           7.770960           6.938111           6.335925
# 17153           6.335925           5.689381           4.654545
#
#        P4_AssistsPerGame  E1_AssistsPerGame  E2_AssistsPerGame  \
# 0               3.843137           6.260323           5.227011
# 1               4.909210           6.150301           5.323810
# 2               4.909210           7.290598           5.667610
# 3               4.909210           6.330309           5.898123
# 4               4.909210           7.688600           6.555809
# ...                  ...                ...                ...
# 17149           6.000000           6.733333           6.098592
# 17150           4.657895           5.864186           5.572677
# 17151           5.494924           6.186784           5.864186
# 17152           5.976778           7.264614           5.730420
# 17153           3.319648           5.754011           5.269841
#
#        E3_AssistsPerGame  E4_AssistsPerGame  P1_GrenadeKillsPerGame  \
# 0               4.916870           4.158879                0.571429
# 1               5.254717           4.999122                1.356140
# 2               4.999122           3.992028                0.928812
# 3               5.667610           3.992028                0.591329
# 4               6.049465           5.667610                0.630027
# ...                  ...                ...                     ...
# 17149           5.180851           4.437500                1.628931
# 17150           5.329268           4.727273                0.943517
# 17151           5.572677           5.329268                0.622825
# 17152           4.578947           4.362319                0.563183
# 17153           5.000000           4.346939                0.570294
#
#        P2_GrenadeKillsPerGame  P3_GrenadeKillsPerGame  P4_GrenadeKillsPerGame  \
# 0                    0.424658                0.401961                0.269531
# 1                    0.692275                0.245989                0.225172
# 2                    0.579102                0.521940                0.225172
# 3                    0.587013                0.348105                0.225172
# 4                    0.553539                0.489231                0.225172
# ...                       ...                     ...                     ...
# 17149                0.662338                0.527994                0.354430
# 17150                0.662338                0.527994                0.236842
# 17151                0.527994                0.317259                0.311738
# 17152                0.527994                0.318940                0.257329
# 17153                0.527994                0.254545                0.140762
#
#        E1_GrenadeKillsPerGame  E2_GrenadeKillsPerGame  E3_GrenadeKillsPerGame  \
# 0                    0.558348                0.542787                0.401869
# 1                    0.611222                0.436348                0.205189
# 2                    0.593116                0.437555                0.436348
# 3                    0.630027                0.593116                0.553539
# 4                    0.593116                0.587013                0.348105
# ...                       ...                     ...                     ...
# 17149                0.770833                0.266667                0.239437
# 17150                0.414634                0.313488                0.303030
# 17151                0.414634                0.313488                0.291976
# 17152                0.456140                0.449275                0.416493
# 17153                0.673469                0.422460                0.235294
#
#        E4_GrenadeKillsPerGame
# 0                    0.163793
# 1                    0.104762
# 2                    0.341880
# 3                    0.437555
# 4                    0.331551
# ...                       ...
# 17149                0.228723
# 17150                0.248610
# 17151                0.248610
# 17152                0.222589
# 17153                0.185185
#
# [9197 rows x 401 columns]

# %%
# df.to_csv('Model_DF_All_Features_Sorted.csv')

# %%
# Function to convert model dataframe from individual players stats to averaged team stats
def condense_features(df, feature_list):
    
    # Empty dataframe
    df_total=pd.DataFrame()
    
    # Copy PlayerWin column
    df_total['PlayerWin'] = df['PlayerWin']
    
    # Loop through features for each player
    for feature in feature_list:
        
        # Add sum features for respective teams
        df_total[f'Player_{feature}'] = df[f'P1_{feature}'] + df[f'P2_{feature}'] + df[f'P3_{feature}'] + df[f'P4_{feature}']
        df_total[f'Enemy_{feature}'] = df[f'E1_{feature}'] + df[f'E2_{feature}'] + df[f'E3_{feature}'] + df[f'E4_{feature}']
        
        # Divide by 4 to get average
        df_total[f'Player_{feature}'] = df_total[f'Player_{feature}'] / 4
        df_total[f'Enemy_{feature}'] = df_total[f'Enemy_{feature}'] / 4

    return df_total
    
df = condense_features(df, feature_list)
df.head(5)
# Out:
#    PlayerWin  Player_WinRate  Enemy_WinRate  Player_K/D  Enemy_K/D  \
# 0          0        1.081731       0.944320    1.001582   1.090913
# 1          1        1.210757       0.669667    1.012847   1.052453
# 2          1        1.092604       0.844752    0.966017   1.032910
# 3          1        1.236401       1.498865    1.165205   1.004284
# 4          1        1.678911       1.084483    0.975596   1.351607
#
#    Player_TotalGamesCompleted  Enemy_TotalGamesCompleted  \
# 0                      183.75                     668.50
# 1                     1547.50                     791.25
# 2                     2102.75                    1126.50
# 3                     4053.00                    1043.50
# 4                     1156.25                    2790.75
#
#    Player_TotalTimePlayed  Enemy_TotalTimePlayed  Player_Accuracy  \
# 0               19.762377              71.401962         0.329293
# 1              155.392598              90.771716         0.343911
# 2              228.236587             127.340630         0.361132
# 3              433.955225             117.960500         0.350705
# 4              115.280680             305.389289         0.363884
#
#    Enemy_Accuracy  Player_PrevTotalXP  Enemy_PrevTotalXP  Player_SpartanRank  \
# 0        0.326039          5265749.75        21339587.50              115.75
# 1        0.377892         11323792.25        19864156.50              122.75
# 2        0.348593         15760299.00        20310125.75              123.25
# 3        0.366385         29123969.50        23281604.75              149.75
# 4        0.345664         21807131.75        20057565.50              148.25
#
#    Enemy_SpartanRank
# 0             134.25
# 1             129.00
# 2             122.75
# 3             149.00
# 4             148.75

# %% [markdown]
# # Model with All Features

# %%
# Make model_df from a copy of our dataframe up to this point
model_df = df.copy()

# Assign features and target
features = model_df.drop(['PlayerWin'], axis=1)
target = model_df['PlayerWin']

# Assigning X and y for train test split
X = features
y = target

# Ensure target is integer format
y = y.astype('int')

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=8)

# Print shape
print(X_train.shape)
print(X_test.shape)
# Out:
# (6437, 400)
# (2760, 400)

# %%
# Create logistic regression model
model_log = LogisticRegression(random_state=8)

# Train on X_train and y_train
model_log.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=8)

# %%
# Function to return cross validation scores
def cross_val_check(model_string_name, model, X_train, y_train, X_test, y_test):
    scores = cross_val_score(model, X_train, y_train, cv=5) # model, train, target, cross validation
    print(f'{model_string_name} Cross Validation Scores:')
    print(scores)
    print(f'\nCross validation mean: \t{scores.mean():.2%}')
    
cross_val_check('Logistic Regression', model_log, X_train, y_train, X_test, y_test)
# Out:
# Logistic Regression Cross Validation Scores:
# [0.6234472  0.63819876 0.6037296  0.64257964 0.62703963]
#
# Cross validation mean: 	62.70%

# %%
def evaluate_model(model, X_train, X_test, y_train, 
                   y_test, cmap='Greens', normalize=None,
                   classes=None,figsize=(10,4), graphs=False):
    
    """
    model :: classifier user desires to evaluate
    X_train :: X training data
    X_test :: X test data
    y_train :: y_train data
    y_test :: y_train data
    cmap :: color palette of confusion matrix
    normalize :: set to True if normalized confusion matrix is desired
    figsize :: desired plot size

    """
    
    # Print model accuracy
    print(f'Training Accuracy: {model.score(X_train,y_train):.2%}')
    print(f'Test Accuracy: {model.score(X_test,y_test):.2%}')
    print('')
    
    # Option to show graphs
    if graphs == True:
        
        # Print classification report
        y_test_predict = model.predict(X_test)
        print(metrics.classification_report(y_test, y_test_predict,
                                            target_names=classes))

        # Plot confusion matrix
        fig,ax = plt.subplots(ncols=2,figsize=figsize)
        metrics.plot_confusion_matrix(model, X_test,y_test,cmap=cmap, 
                                      normalize=normalize,display_labels=classes,
                                      ax=ax[0])

        #Plot ROC curves
        with sns.axes_style("darkgrid"):
            curve = metrics.plot_roc_curve(model,X_train,y_train,ax=ax[1])
            curve2 = metrics.plot_roc_curve(model,X_test,y_test,ax=ax[1])
            curve.ax_.grid()
            curve.ax_.plot([0,1],[0,1],ls=':')
            fig.tight_layout()
            plt.show()

evaluate_model(model_log, X_train, X_test, y_train, 
                   y_test, graphs=True)
# Out:
# Training Accuracy: 62.93%
# Test Accuracy: 62.10%
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.44      0.51      1217
#            1       0.63      0.76      0.69      1543
#
#     accuracy                           0.62      2760
#    macro avg       0.61      0.60      0.60      2760
# weighted avg       0.62      0.62      0.61      2760

# %%
# Function to create models
def make_model(df, regressor=LogisticRegression, scale=False, graphs=False, dummy=False, cmap='Greens',
              slim=False, scaler=StandardScaler()):

    # Assigning X and y for train test split
    X = df.drop(['PlayerWin'], axis=1)
    y = df['PlayerWin']
    
    # Ensure target is integer format
    y=y.astype('int')

    # Train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                        random_state=8)
    
    # Option to scale data with scaler type as parameter
    if scale==True:
        scaler = scaler
        X_train = pd.DataFrame(scaler.fit_transform(X_train))
        X_test = pd.DataFrame(scaler.transform(X_test))
    
    # Option to return dummy model
    if dummy == True:
        model_log = DummyClassifier(strategy='stratified')
        print('Using Dummy Model')
    else:
        model_log = regressor
    
    # Fit to X_train and y_train
    model_log.fit(X_train, y_train)
   
    # Print total number of samples
    total_samples = X_train.shape[0] + X_test.shape[0]
    print(f'Total number of samples: {total_samples}')
    print('------------------------------------------')
    
    # Option to suppress cross validation scores
    if slim == False:
        cross_val_check('Logistic Regression', model_log, X_train, y_train, X_test, y_test)
    
    evaluate_model(model_log, X_train, X_test, y_train, y_test, graphs=graphs, cmap=cmap)

make_model(model_df, scale=False, graphs=True, regressor=LogisticRegression())
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.6234472  0.63819876 0.6037296  0.64257964 0.62703963]
#
# Cross validation mean: 	62.70%
# Training Accuracy: 62.93%
# Test Accuracy: 62.10%
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.44      0.51      1217
#            1       0.63      0.76      0.69      1543
#
#     accuracy                           0.62      2760
#    macro avg       0.61      0.60      0.60      2760
# weighted avg       0.62      0.62      0.61      2760

# %%
# Logistic regression with power transformer scaler
make_model(model_df, scale=True, graphs=True, regressor=LogisticRegression(), scaler=PowerTransformer())

# make_model(model_df, scale=True, graphs=True, regressor=LogisticRegression(), scaler=StandardScaler())
# make_model(model_df, scale=True, graphs=True, regressor=LogisticRegression(), scaler=RobustScaler())
# All features sorted power transformer 66.44 cross val, 67.96 test accuracy
# All features merged (not divided by 4) PT - 67.12 CV, 68.55 TA
# All features merged AVERAGE - PT - 67.03 CV, 68.55 TA
# Select featuers sorted 64.97 cv 67.30 TA
# Select features averaged 66.07 cv, 67.89 TA
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.65916149 0.66770186 0.64335664 0.64568765 0.65656566]
#
# Cross validation mean: 	65.45%
# Training Accuracy: 71.03%
# Test Accuracy: 68.12%
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.59      0.62      1217
#            1       0.70      0.75      0.72      1543
#
#     accuracy                           0.68      2760
#    macro avg       0.68      0.67      0.67      2760
# weighted avg       0.68      0.68      0.68      2760

# %% [markdown]
# ## Remove Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor    

def calculate_vif_(X, thresh=5.0):
    variables = list(range(X.shape[1]))
    dropped = True
    while dropped:
        dropped = False
        vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X.iloc[:, variables].columns[maxloc] +
                  '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped = True

    print('Remaining variables:')
    print(X.columns[variables])
    return X.iloc[:, variables]

# %%
# Dummy model for comparison
make_model(model_df, scale=False, graphs=True, dummy=True, 
           cmap='Reds', regressor=LogisticRegression())
# Out:
# Using Dummy Model
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.5007764  0.50388199 0.5019425  0.48873349 0.5019425 ]
#
# Cross validation mean: 	49.95%
# Training Accuracy: 49.34%
# Test Accuracy: 51.23%
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.44      0.43      1217
#            1       0.55      0.53      0.54      1543
#
#     accuracy                           0.49      2760
#    macro avg       0.49      0.49      0.49      2760
# weighted avg       0.49      0.49      0.49      2760

# %% [markdown]
# ## Linear Regression Feature Importances

# %%
# Make model_df from a copy of our dataframe up to this point
model_df = df.copy()

# Assign features and target
features = model_df.drop(['PlayerWin'], axis=1)
target = model_df['PlayerWin']

# Assigning X and y for train test split
X = features
y = target

from statsmodels.stats.outliers_influence import variance_inflation_factor    

def calculate_vif_(X, thresh=5.0):
    variables = list(range(X.shape[1]))
    dropped = True
    while dropped:
        dropped = False
        vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X.iloc[:, variables].columns[maxloc] +
                  '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped = True

    print('Remaining variables:')
    print(X.columns[variables])
    return X.iloc[:, variables]

X = calculate_vif_(X, thresh=5.0)

# Ensure target is integer format
y = y.astype('int')

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=8)

# Define and scale X train and test
scaler = PowerTransformer()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_test = pd.DataFrame(scaler.transform(X_test))

# Create and fit logistic regressoin
model_log = LogisticRegression()
model_log.fit(X_train, y_train)

# Print shape
print(X_train.shape)
print(X_test.shape)
# Out:
# dropping 'P1_TotalGamesCompleted' at index: 176
# dropping 'E1_TotalGamesCompleted' at index: 179
# dropping 'P1_TotalPowerWeaponKills' at index: 136
# dropping 'E1_TotalPowerWeaponKills' at index: 139
# dropping 'P2_TotalPowerWeaponKills' at index: 136
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-309-76e30891f01d> in <module>
#      31     return X.iloc[:, variables]
#      32
# ---> 33 X = calculate_vif_(X, thresh=5.0)
#      34
#      35 # Ensure target is integer format
#
# <ipython-input-309-76e30891f01d> in calculate_vif_(X, thresh)
#      17     while dropped:
#      18         dropped = False
# ---> 19         vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
#      20                for ix in range(X.iloc[:, variables].shape[1])]
#      21
#
# <ipython-input-309-76e30891f01d> in <listcomp>(.0)
#      17     while dropped:
#      18         dropped = False
# ---> 19         vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
#      20                for ix in range(X.iloc[:, variables].shape[1])]
#      21
#
# ~\anaconda3\envs\learn-env\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     190     mask = np.arange(k_vars) != exog_idx
#     191     x_noti = exog[:, mask]
# --> 192     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     193     vif = 1. / (1. - r_squared_i)
#     194     return vif
#
# ~\anaconda3\envs\learn-env\lib\site-packages\statsmodels\regression\linear_model.py in fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     303                     hasattr(self, 'rank')):
#     304
# --> 305                 self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     306                 self.normalized_cov_params = np.dot(
#     307                     self.pinv_wexog, np.transpose(self.pinv_wexog))
#
# ~\anaconda3\envs\learn-env\lib\site-packages\statsmodels\tools\tools.py in pinv_extended(x, rcond)
#     405     x = np.asarray(x)
#     406     x = x.conjugate()
# --> 407     u, s, vt = np.linalg.svd(x, False)
#     408     s_orig = np.copy(s)
#     409     m = u.shape[0]
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1624
#    1625         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1626         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1627         u = u.astype(result_t, copy=False)
#    1628         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
# Function to show model accuracy
def model_accuracy(model, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test):
    
    print(f'Training Accuracy: {model.score(X_train,y_train):.2%}')
    print(f'Test Accuracy: {model.score(X_test,y_test):.2%}')

# Uncomment line below to create images for presentation
# sns.set_context('talk')

# Function to plot logistic regression coefficients
def plot_coefficients(model, features, X_train, X_test, y_train=y_train, y_test=y_test, count=20):    
    
    # Create a list of coefficients
    coeffs = pd.Series(model.coef_.flatten(), index=features.columns).sort_values(ascending=False)
#     coeffs = coeffs[:20]
    top_coeffs = coeffs[:count]
    bottom_coeffs = coeffs[-count:]
    coeffs = top_coeffs.append(bottom_coeffs)
    
    # Display accuracy of newly trained model
    model_accuracy(model, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)

    # Create coefficients plot
    with sns.axes_style("darkgrid"):
        plt.figure(figsize=(12, 10))
        ax = sns.barplot(x=coeffs, y=coeffs.index, palette='coolwarm')
        ax.set(xlabel='Log Coefficients', ylabel='Features')
    
    # Save image
    plt.tight_layout()

    
plot_coefficients(model_log, features, X_train, X_test)
# Out:
# Training Accuracy: 71.03%
# Test Accuracy: 68.12%

# %% [markdown]
# # Random Forest

# %%
# Make model_df from a copy of our dataframe up to this point
model_df = df.copy()

# Assign features and target
features = model_df.drop(['PlayerWin'], axis=1)
target = model_df['PlayerWin']

# Assigning X and y for train test split
X = features
y = target

# Ensure target is integer format
y = y.astype('int')

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=8)

# Print shape
print(X_train.shape)
print(X_test.shape)
# Out:
# (6437, 400)
# (2760, 400)

# %%
# Random forest not scaled
make_model(model_df, scale=False, graphs=True, regressor=RandomForestClassifier())
# all features sorted 65.88 CV, 67.11 test accuracy
# all features averaged 66.24 cv, 67.96 TA
# select features sort 67.30 TA
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.67701863 0.66381988 0.65268065 0.66045066 0.66744367]
#
# Cross validation mean: 	66.43%
# Training Accuracy: 100.00%
# Test Accuracy: 67.50%
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.56      0.60      1217
#            1       0.69      0.77      0.73      1543
#
#     accuracy                           0.68      2760
#    macro avg       0.67      0.66      0.66      2760
# weighted avg       0.67      0.68      0.67      2760

# %%
# Random forest with power transformer scale
make_model(model_df, scale=True, graphs=True, 
           regressor=RandomForestClassifier(), scaler=PowerTransformer())

# all featuers standard scaler 65.34 CV, 68.09 test accuracy
# all featuers added PT 64.89 CV, 68.29 test accuracy
# all features averaged PT 65.68 cv, 67.17 TA
# Select features sorted PT 65.85 CV 68.55 TA
# Select features merged PT 66.50 CV 68.42 TA
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.68478261 0.6568323  0.65889666 0.68686869 0.67599068]
#
# Cross validation mean: 	67.27%
# Training Accuracy: 100.00%
# Test Accuracy: 69.09%
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.57      0.62      1217
#            1       0.70      0.79      0.74      1543
#
#     accuracy                           0.69      2760
#    macro avg       0.69      0.68      0.68      2760
# weighted avg       0.69      0.69      0.69      2760

# %% [markdown]
# # Support Vector Machines

# %%
# SVM without scaling
make_model(model_df, scale=False, graphs=True, regressor=svm.SVC())
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.62189441 0.63276398 0.5975136  0.61383061 0.60994561]
#
# Cross validation mean: 	61.52%
# Training Accuracy: 62.06%
# Test Accuracy: 61.70%
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.32      0.42      1217
#            1       0.61      0.85      0.71      1543
#
#     accuracy                           0.62      2760
#    macro avg       0.62      0.59      0.57      2760
# weighted avg       0.62      0.62      0.59      2760

# %%
# SVM with standard scaler
# make_model(model_df, scale=True, graphs=True, regressor=svm.SVC(), scaler=StandardScaler())

# make_model(model_df, scale=True, graphs=True, regressor=svm.SVC(), scaler=RobustScaler())
make_model(model_df, scale=True, graphs=True, regressor=svm.SVC(), scaler=PowerTransformer())
# all features sorted PT 66.16 cv 67.76 ta
# all features merged PT averaged by 4 66.53 CV 68.68 TA
# sorted features 68.09 TA
# sorted merged standard scaler 67.04 TA
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.67779503 0.67003106 0.66433566 0.68376068 0.67443667]
#
# Cross validation mean: 	67.41%
# Training Accuracy: 82.12%
# Test Accuracy: 68.08%
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.56      0.61      1217
#            1       0.69      0.78      0.73      1543
#
#     accuracy                           0.68      2760
#    macro avg       0.68      0.67      0.67      2760
# weighted avg       0.68      0.68      0.68      2760

# %% [markdown]
# # XGBoost

# %%
make_model(model_df, scale=False, graphs=True, regressor=XGBClassifier())
# no 68
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.66304348 0.65450311 0.65034965 0.67443667 0.67521368]
#
# Cross validation mean: 	66.35%
# Training Accuracy: 99.97%
# Test Accuracy: 67.39%
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.58      0.61      1217
#            1       0.69      0.75      0.72      1543
#
#     accuracy                           0.67      2760
#    macro avg       0.67      0.66      0.66      2760
# weighted avg       0.67      0.67      0.67      2760

# %%
make_model(model_df, scale=True, graphs=True, regressor=XGBClassifier(), scaler=StandardScaler())
# make_model(model_df, scale=True, graphs=True, regressor=XGBClassifier(), scaler=RobustScaler())
# make_model(model_df, scale=True, graphs=True, regressor=XGBClassifier(), scaler=PowerTransformer())
# no 68
# Out:
# Total number of samples: 9197
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.66304348 0.65450311 0.65034965 0.67443667 0.67909868]
#
# Cross validation mean: 	66.43%
# Training Accuracy: 99.97%
# Test Accuracy: 67.39%
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.58      0.61      1217
#            1       0.69      0.75      0.72      1543
#
#     accuracy                           0.67      2760
#    macro avg       0.67      0.66      0.66      2760
# weighted avg       0.67      0.67      0.67      2760

# %% [markdown]
# # K Nearest Neighbors

# %%
make_model(model_df, scale=False, graphs=True, regressor=KNeighborsClassifier())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-264-f7756e759b73> in <module>
# ----> 1 make_model(model_df, scale=False, graphs=True, regressor=KNeighborsClassifier())
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
make_model(model_df, scale=True, graphs=True, 
           regressor=KNeighborsClassifier(), scaler=PowerTransformer())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-263-1bf705deced8> in <module>
#       1 make_model(model_df, scale=True, graphs=True,
# ----> 2            regressor=KNeighborsClassifier(), scaler=PowerTransformer())
#
# NameError: name 'KNeighborsClassifier' is not defined

# %% [markdown]
# # Neural Networks

# %% [markdown]
# ## MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier

make_model(model_df, scale=True, scaler=PowerTransformer(), graphs=True, 
           regressor=MLPClassifier(solver='lbfgs', alpha=1e-5, 
                                   hidden_layer_sizes=(5, 2), random_state=1))
# Out:
# Total number of samples: 5066
# ------------------------------------------
# Logistic Regression Cross Validation Scores:
# [0.66619718 0.68124118 0.67983075 0.64880113 0.65021157]
#
# Cross validation mean: 	66.53%
# Training Accuracy: 68.02%
# Test Accuracy: 67.24%
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.56      0.61       685
#            1       0.68      0.77      0.72       835
#
#     accuracy                           0.67      1520
#    macro avg       0.67      0.66      0.66      1520
# weighted avg       0.67      0.67      0.67      1520

# %% [markdown]
# ## CNN Model

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
X

# %%
model_df = df.copy()

# Assigning X and y for train test split

features = model_df.drop(['PlayerWin'], axis=1)
target = model_df['PlayerWin']


X = features
Y = target

Y=Y.astype('int')

# %%
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

# %%
# baseline model
def create_baseline():
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=12, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
# evaluate model with standardized dataset
estimator = KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=5, verbose=True)
kfold = StratifiedKFold(n_splits=10, shuffle=True)
results = cross_val_score(estimator, X, encoded_Y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

# %% [markdown]
# # Unused code

# %%
# Set roster for sifting through players of dataframe
roster = ['P1', 'P2', 'P3', 'P4', 'E1', 'E2', 'E3', 'E4']

# Loop through players in roster
for player in roster:
    
    # Set win rate
    df[f'{player}_WinRate'] = df[f'{player}_TotalGamesWon'] / df[f'{player}_TotalGamesLost']
    
    # Set K/D (or Kill / Death ratio)
    df[f'{player}_K/D'] = df[f'{player}_TotalKills'] / df[f'{player}_TotalDeaths']
    
    # Set accuracy
    df[f'{player}_Accuracy'] = df[f'{player}_TotalShotsLanded'] / df[f'{player}_TotalShotsFired']

# Drop infinity values, which can arise if it is the first time a player
# is playing specified playlist
df = df.dropna()
df = df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

df[['P1_WinRate', 'P1_K/D', 'P1_Accuracy']]
