# %%
import jupyterthemes as jt

# !jt -t chesterish

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

import json
def get_keys(path):
    with open(path) as f:
        return json.load(f)
# keys = get_keys("/Users/Johnny/.secret/yelp_api.json")
# api_key = keys['api_key']
# pip install tmdbsimple #Ctrl+? this line to install tmdbsimple
import tmdbsimple as tmdb
# tmdb.API_KEY = api_key

scrape = False

import ast
import time
import http.client, urllib.request, urllib.parse, urllib.error, base64

api_key = 'ceeaacb7cf024c7485e00ef8457e42dc'


user = 'Drymander'

import pickle
from tqdm import tqdm

# pip install isodate

import isodate

# %%
#Standard python libraries
import pandas as pd
import seaborn as sns
# sns.set_context('talk')
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings(action='ignore') 

# Preprocessing tools
from sklearn.model_selection import train_test_split,cross_val_predict,cross_validate
from sklearn.preprocessing import MinMaxScaler,StandardScaler,OneHotEncoder
scaler = StandardScaler()
from sklearn import metrics

# Models & Utilities
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score

# Warnings
import warnings
warnings.filterwarnings(action='ignore') 

# NLP Libraries
import nltk
import collections
# nltk.download('punkt')
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
from nltk import regexp_tokenize
import re
from nltk.corpus import stopwords
from nltk.collocations import *
from nltk import FreqDist
from nltk import word_tokenize
from nltk import ngrams
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('stopwords')
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\johnn\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Pull Most Recent Match Details
#
# This is a combination of two API calls - the first is to pull the latest match for a given player based on their gamertag.  This provides the Match ID, and the second API call pulls the data using the Match ID.

# %%
def pull_recent_match(how_recent, api_key=api_key, explore=False, gamertag='Drymander'):

    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': api_key,
    }

    params = urllib.parse.urlencode({
        # Request parameters
        'modes': 'arena',
        'start': how_recent,
        'count': 1,
        'include-times': True,
    })

    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/players/{gamertag}/matches?%s" % params, "{body}", headers)
        response = conn.getresponse()
        latest_match = json.loads(response.read())

        match_id = latest_match['Results'][0]['Id']['MatchId']

        time.sleep(1.1)

        conn.request("GET", f"/stats/h5/arena/matches/{match_id}?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        
        if explore == True:
            print(data)
        else:
            match_results = json.loads(data)
        conn.close()
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    return match_results

####################################

# match_results = pull_recent_match(5, explore=True)
match_results = pull_recent_match(7, explore=True)
# Out:
# b'{"PlayerStats":[{"XpInfo":{"PrevSpartanRank":149,"SpartanRank":149,"PrevTotalXP":22705290,"TotalXP":22711064,"SpartanRankMatchXPScalar":2.249,"PlayerTimePerformanceXPAward":516,"PerformanceXP":99,"PlayerRankXPAward":200,"BoostAmount":1752,"MatchSpeedWinAmount":0,"ObjectivesCompletedAmount":0},"PreviousCsr":null,"CurrentCsr":null,"MeasurementMatchesLeft":10,"RewardSets":[],"KilledOpponentDetails":[{"GamerTag":"XxMegaManxX8196","TotalKills":3},{"GamerTag":"LIL CALIFOOYA","TotalKills":8},{"GamerTag":"TyrannicJonas","TotalKills":7},{"GamerTag":"Kal LP2","TotalKills":2}],"KilledByOpponentDetails":[{"GamerTag":"TyrannicJonas","TotalKills":2},{"GamerTag":"Kal LP2","TotalKills":2},{"GamerTag":"LIL CALIFOOYA","TotalKills":2},{"GamerTag":"XxMegaManxX8196","TotalKills":1}],"FlexibleStats":{"MedalStatCounts":[],"ImpulseStatCounts":[{"Id":"ba327946-418c-495d-90c0-89f084bf7447","Count":20},{"Id":"7dcd7306-f905-401a-97f2-345d4b25170a","Count":4},{"Id":"ea38d25f-d887-4bdf-b17b-8e8e649b9a87","Count":7},{"Id":"a1d97ad4-c1d9-4807-b619-ca3710cc5a8d","Count":0},{"Id":"3465eba1-608c-47d7-9cb6-ef4c7a55a2dd","Count":3},{"Id":"780104cb-5b86-4ed9-8fb1-40b919de0766","Count":0},{"Id":"a5a0d0d5-5c9f-4888-b42a-2c87f8e58336","Count":2},{"Id":"71ce2293-23bb-492f-a8c0-46e095b55eb7","Count":0},{"Id":"ba1b0043-3a1e-4894-a04f-f8d889103ec5","Count":20}],"MedalTimelapses":[],"ImpulseTimelapses":[{"Id":"f1c317ee-1ac4-4089-85e8-a9c536c6cf18","Timelapse":"PT6M8.8931896S"}]},"CreditsEarned":{"Result":2,"TotalCreditsEarned":871,"SpartanRankModifier":1.0,"PlayerRankAmount":375,"TimePlayedAmount":495.11263347313013,"BoostAmount":0,"MatchSpeedWinAmount":0,"ObjectivesCompletedAmount":0},"MetaCommendationDeltas":[],"ProgressiveCommendationDeltas":[{"Id":"20dc7d74-be8f-4a60-ae4f-15230855cced","PreviousProgress":102347,"Progress":102367},{"Id":"e4195550-426b-471e-ab67-570207d86847","PreviousProgress":545,"Progress":547},{"Id":"e1203a73-2067-4479-9a47-2abccb0069ae","PreviousProgress":11756,"Progress":11759},{"Id":"7d91c1a2-0555-476c-9b04-fd6321f053cf","PreviousProgress":1251,"Progress":1252},{"Id":"07653860-9949-4a12-b341-90c8b9653165","PreviousProgress":62017,"Progress":62019},{"Id":"664b927f-3684-48c5-8653-dfa6938ceac6","PreviousProgress":3719,"Progress":3720},{"Id":"24e0ba42-59df-4c45-9fe6-d4fb739aeadc","PreviousProgress":5905,"Progress":5906},{"Id":"2d5080e0-62ee-42d9-a2dd-364d101832ea","PreviousProgress":6308,"Progress":6309},{"Id":"1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458","PreviousProgress":6769,"Progress":6770},{"Id":"c43149a6-7b14-4cfd-8d4e-4b5f0b1c91bd","PreviousProgress":125,"Progress":126},{"Id":"4fe355fc-eff3-4ec6-878f-5b83fc76bd2f","PreviousProgress":592,"Progress":596},{"Id":"2eb4257c-9058-46e7-a40f-b9307f3553d9","PreviousProgress":1113,"Progress":1118},{"Id":"750783af-3332-4c7d-b5b5-26aa8800655a","PreviousProgress":6418,"Progress":6419},{"Id":"6f770f69-62a9-4c8b-a5a8-bcc5d4950492","PreviousProgress":392,"Progress":394},{"Id":"79b6e993-ff9b-4a53-9789-cccaf86a4e22","PreviousProgress":4336,"Progress":4337},{"Id":"8594ca5e-6f59-4e21-b601-406111fa2b58","PreviousProgress":1181,"Progress":1183},{"Id":"49b744bf-ec46-47aa-bb16-0042cbf49614","PreviousProgress":2280,"Progress":2281},{"Id":"d3b6b1ce-c5f0-4cbf-b443-ca76c2917b77","PreviousProgress":3004,"Progress":3005},{"Id":"be522e1e-eada-4ec7-aba9-7ee0c0d6732a","PreviousProgress":10,"Progress":11},{"Id":"a61833aa-b90a-4fa8-83d3-b6a0e94d2866","PreviousProgress":4054,"Progress":4055}],"BoostInfo":{"DefinitionId":"76def815-634a-42cd-b9ca-4c539205b863","CardConsumed":true},"Player":{"Gamertag":"Dirus Lupus","Xuid":null},"TeamId":1,"Rank":1,"DNF":false,"AvgLifeTimeOfPlayer":"PT39.3493586S","PreMatchRatings":null,"PostMatchRatings":null,"PlayerScore":20,"GameEndStatus":3,"TotalKills":20,"TotalHeadshots":3,"TotalWeaponDamage":2398.6609115600586,"TotalShotsFired":309,"TotalShotsLanded":107,"WeaponWithMostKills":{"WeaponId":{"StockId":1390323522,"Attachments":[]},"TotalShotsFired":7,"TotalShotsLanded":6,"TotalHeadshots":0,"TotalKill ...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-72-90aaa7411862> in <module>
#      41
#      42 # match_results = pull_recent_match(5, explore=True)
# ---> 43 match_results = pull_recent_match(7, explore=True)
#
# <ipython-input-72-90aaa7411862> in pull_recent_match(how_recent, api_key, explore, gamertag)
#      36         print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
#      37
# ---> 38     return match_results
#      39
#      40 ####################################
#
# UnboundLocalError: local variable 'match_results' referenced before assignment

# %% [markdown]
# # Pull Any Match

# %%
explore = True
matchId = '0bbc809c-87d8-423f-88a4-ffb9fc782fd6'

def pull_match(matchId, api_key=api_key, explore=False):

    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': api_key,
    }

    params = urllib.parse.urlencode({
    })

    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/arena/matches/{matchId}?%s" % params, "{body}", headers)
        response = conn.getresponse()
        if explore == True:
            data = response.read()
            print(data)
        else:
            data = response.read()
            data = json.loads(data)
        conn.close()
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    return data

        
pull_match('0bbc809c-87d8-423f-88a4-ffb9fc782fd6', explore=False)
# Out:
# {'PlayerStats': [{'XpInfo': {'PrevSpartanRank': 20,
#     'SpartanRank': 20,
#     'PrevTotalXP': 160878,
#     'TotalXP': 162780,
#     'SpartanRankMatchXPScalar': 1.71,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 50,
#     'BoostAmount': 500,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 3,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Drymander', 'TotalKills': 2},
#     {'GamerTag': 'UndeadJubei', 'TotalKills': 4},
#     {'GamerTag': 'zxxCRISTI4Nxxz', 'TotalKills': 2},
#     {'GamerTag': 'DarkZazke', 'TotalKills': 2}],
#    'KilledByOpponentDetails': [{'GamerTag': 'DarkZazke', 'TotalKills': 3},
#     {'GamerTag': 'zxxCRISTI4Nxxz', 'TotalKills': 6},
#     {'GamerTag': 'UndeadJubei', 'TotalKills': 3}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 10},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 2},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 12},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 6},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 1},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5457571S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 767,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 250,
#     'TimePlayedAmount': 516.1545925655166,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 1024,
#      'Progress': 1034},
#     {'Id': 'f33f1aec-59ad-47eb-be13-fd0e654a53aa',
#      'PreviousProgress': 240,
#      'Progress': 244},
#     {'Id': '07653860-9949-4a12-b341-90c8b9653165',
#      'PreviousProgress': 495,
#      'Progress': 501},
#     {'Id': '61217e0a-832e-487b-9f3b-51b36a6803c7',
#      'PreviousProgress': 193,
#      'Progress': 196},
#     {'Id': '61eac0e9-0a4c-4f90-aca2-c322a88a4763',
#      'PreviousProgress': 2,
#      'Progress': 3},
#     {'Id': 'c9bcb904-607f-42ea-acae-4cbdcdf65143',
#      'PreviousProgress': 12,
#      'Progress': 14}],
#    'BoostInfo': {'DefinitionId': '1f7bd827-6090-4185-a2bf-7d0e1ac77a09',
#     'CardConsumed': True},
#    'Player': {'Gamertag': 'AmeXSB', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 5,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT25.9766953S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 1,
#    'TotalKills': 10,
#    'TotalHeadshots': 6,
#    'TotalWeaponDamage': 1558.7465090751648,
#    'TotalShotsFired': 287,
#    'TotalShotsLanded': 129,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#      'Attachments': []},
#     'TotalShotsFired': 67,
#     'TotalShotsLanded': 38,
#     'TotalHeadshots': 4,
#     'TotalKills': 4,
#     'TotalDamageDealt': 683.1838722229004,
#     'TotalPossessionTime': 'PT1M30.4001S'},
#    'TotalMeleeKills': 0,
#    'TotalMeleeDamage': 115.0,
#    'TotalAssassinations': 1,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 52.19779968261719,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 134.2207145690918,
#    'TotalPowerWeaponKills': 0,
#    'TotalPowerWeaponDamage': 0.0,
#    'TotalPowerWeaponGrabs': 1,
#    'TotalPowerWeaponPossessionTime': 'PT19.8333S',
#    'TotalDeaths': 12,
#    'TotalAssists': 2,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5457571S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 3261908037, 'Count': 6},
#     {'MedalId': 3001183151, 'Count': 1},
#     {'MedalId': 2782465081, 'Count': 1},
#     {'MedalId': 3400287617, 'Count': 1},
#     {'MedalId': 2966496172, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 67,
#      'TotalShotsLanded': 38,
#      'TotalHeadshots': 4,
#      'TotalKills': 4,
#      'TotalDamageDealt': 683.1838722229004,
#      'TotalPossessionTime': 'PT1M30.4001S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 167,
#      'TotalShotsLanded': 68,
#      'TotalHeadshots': 0,
#      'TotalKills': 3,
#      'TotalDamageDealt': 498.8419222831726,
#      'TotalPossessionTime': 'PT3M2.3832S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.65S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 167.1977996826172,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 17,
#      'TotalShotsLanded': 11,
#      'TotalHeadshots': 2,
#      'TotalKills': 2,
#      'TotalDamageDealt': 235.0,
#      'TotalPossessionTime': 'PT35.6166S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 18,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT19.8333S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 7,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 7.5,
#      'TotalPossessionTime': 'PT6.8S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 10,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 101.27021789550781,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 32.950496673583984,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 10,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 18,
#     'SpartanRank': 18,
#     'PrevTotalXP': 118474,
#     'TotalXP': 120681,
#     'SpartanRankMatchXPScalar': 1.65,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 25,
#     'BoostAmount': 750,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 1,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'UndeadJubei', 'TotalKills': 1},
#     {'GamerTag': 'Drymander', 'TotalKills': 1},
#     {'GamerTag': 'DarkZazke', 'TotalKills': 3}],
#    'KilledByOpponentDetails': [{'GamerTag': 'zxxCRISTI4Nxxz', 'TotalKills': 4},
#     {'GamerTag': 'DarkZazke', 'TotalKills': 6},
#     {'GamerTag': 'UndeadJubei', 'TotalKills': 4},
#     {'GamerTag': 'Drymander', 'TotalKills': 1}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 5},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 5},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 16},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 0},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 1},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5367574S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 742,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 225,
#     'TimePlayedAmount': 516.1536925955032,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 546,
#      'Progress': 551},
#     {'Id': '61eac0e9-0a4c-4f90-aca2-c322a88a4763',
#      'PreviousProgress': 10,
#      'Progress': 11},
#     {'Id': '61217e0a-832e-487b-9f3b-51b36a6803c7',
#      'PreviousProgress': 37,
#      'Progress': 41}],
#    'BoostInfo': {'DefinitionId': '49386ddf-723b-4392-9cfd-7ac6a4b3dee6',
#     'CardConsumed': True},
#    'Player': {'Gamertag': 'Felex 9', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 8,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT17.9560091S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 1,
#    'TotalKills': 5,
#    'TotalHeadshots': 0,
#    'TotalWeaponDamage': 736.8662781715393,
#    'TotalShotsFired': 264,
#    'TotalShotsLanded': 97,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 313138863,
#      'Attachments': []},
#     'TotalShotsFired': 215,
#     'TotalShotsLanded': 78,
#     'TotalHeadshots': 0,
#     'TotalKills': 4,
#     'TotalDamageDealt': 621.6561341285706,
#     'TotalPossessionTime': 'PT3M46.9998S'},
#    'TotalMeleeKills': 0,
#    'TotalMeleeDamage': 114.60000991821289,
#    'TotalAssassinations': 1,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 17.525615692138672,
#    'TotalPowerWeaponKills': 0,
#    'TotalPowerWeaponDamage': 46.33837890625,
#    'TotalPowerWeaponGrabs': 1,
#    'TotalPowerWeaponPossessionTime': 'PT44.6666S',
#    'TotalDeaths': 16,
#    'TotalAssists': 5,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5367574S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 2966496172, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 114.60000991821289,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 215,
#      'TotalShotsLanded': 78,
#      'TotalHeadshots': 0,
#      'TotalKills': 4,
#      'TotalDamageDealt': 621.6561341285706,
#      'TotalPossessionTime': 'PT3M46.9998S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 3,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT6.5333S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 22.5,
#      'TotalPossessionTime': 'PT8.6S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT6.2167S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 18,
#      'TotalShotsLanded': 8,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 46.33837890625,
#      'TotalPossessionTime': 'PT44.6666S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 17,
#      'TotalShotsLanded': 7,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 28.846149444580078,
#      'TotalPossessionTime': 'PT11.6833S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 5,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 17.525615692138672,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 5,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 23,
#     'SpartanRank': 23,
#     'PrevTotalXP': 193033,
#     'TotalXP': 194078,
#     'SpartanRankMatchXPScalar': 1.78,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 25,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': {'Tier': 4,
#     'DesignationId': 3,
#     'Csr': 0,
#     'PercentToNextTier': 72,
#     'Rank': None},
#    'CurrentCsr': {'Tier': 4,
#     'DesignationId': 3,
#     'Csr': 0,
#     'PercentToNextTier': 46,
#     'Rank': None},
#    'MeasurementMatchesLeft': 0,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'DarkZazke', 'TotalKills': 5},
#     {'GamerTag': 'UndeadJubei', 'TotalKills': 2},
#     {'GamerTag': 'Drymander', 'TotalKills': 1}],
#    'KilledByOpponentDetails': [{'GamerTag': 'DarkZazke', 'TotalKills': 3},
#     {'GamerTag': 'UndeadJubei', 'TotalKills': 3},
#     {'GamerTag': 'zxxCRISTI4Nxxz', 'TotalKills': 5}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 8},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 5},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 11},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 2},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 1},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5367574S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 742,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 225,
#     'TimePlayedAmount': 516.1536925955032,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 1412,
#      'Progress': 1420},
#     {'Id': '61217e0a-832e-487b-9f3b-51b36a6803c7',
#      'PreviousProgress': 334,
#      'Progress': 335},
#     {'Id': 'c9bcb904-607f-42ea-acae-4cbdcdf65143',
#      'PreviousProgress': 66,
#      'Progress': 67},
#     {'Id': '79b6e993-ff9b-4a53-9789-cccaf86a4e22',
#      'PreviousProgress': 80,
#      'Progress': 82},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 131,
#      'Progress': 132},
#     {'Id': 'af609abb-c6e2-4e97-826f-5aca4fccf70c',
#      'PreviousProgress': 35,
#      'Progress': 36},
#     {'Id': 'f33f1aec-59ad-47eb-be13-fd0e654a53aa',
#      'PreviousProgress': 266,
#      'Progress': 269},
#     {'Id': '07653860-9949-4a12-b341-90c8b9653165',
#      'PreviousProgress': 430,
#      'Progress': 432},
#     {'Id': 'ad36d0cd-7e44-49a2-8a2c-c103a38f17d8',
#      'PreviousProgress': 50,
#      'Progress': 51}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'CptnColdCrush', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 7,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT32.1569479S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 1,
#    'TotalKills': 8,
#    'TotalHeadshots': 2,
#    'TotalWeaponDamage': 1205.0183095932007,
#    'TotalShotsFired': 219,
#    'TotalShotsLanded': 77,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#      'Attachments': []},
#     'TotalShotsFired': 95,
#     'TotalShotsLanded': 34,
#     'TotalHeadshots': 2,
#     'TotalKills': 3,
#     'TotalDamageDealt': 572.7974500656128,
#     'TotalPossessionTime': 'PT3M38.7833S'},
#    'TotalMeleeKills': 1,
#    'TotalMeleeDamage': 258.46603202819824,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 52.19779968261719,
#    'TotalGrenadeDamage': 419.8891792297363,
#    'TotalPowerWeaponKills': 0,
#    'TotalPowerWeaponDamage': 0.0,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT0S',
#    'TotalDeaths': 11,
#    'TotalAssists': 5,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5367574S',
#    'TotalGrenadeKills': 2,
#    'MedalAwards': [{'MedalId': 250435527, 'Count': 1},
#     {'MedalId': 3400287617, 'Count': 1},
#     {'MedalId': 3653057799, 'Count': 1},
#     {'MedalId': 3261908037, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 29,
#      'TotalShotsLanded': 13,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 97.33168029785156,
#      'TotalPossessionTime': 'PT1M41.6S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 95,
#      'TotalShotsLanded': 34,
#      'TotalHeadshots': 2,
#      'TotalKills': 3,
#      'TotalDamageDealt': 572.7974500656128,
#      'TotalPossessionTime': 'PT3M38.7833S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 115.0,
#      'TotalPossessionTime': 'PT32.3333S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 23,
#      'TotalShotsLanded': 12,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 293.80731201171875,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 310.66383171081543,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 3,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#      'TotalShotsFired': 60,
#      'TotalShotsLanded': 10,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 126.08186721801758,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [{'Id': 3174430457, 'Count': 1}],
#    'TotalSpartanKills': 8,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 8,
#     'SpartanRank': 8,
#     'PrevTotalXP': 22911,
#     'TotalXP': 23645,
#     'SpartanRankMatchXPScalar': 1.25,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 0,
#     'PlayerRankXPAward': 25,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 8,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'UndeadJubei', 'TotalKills': 3},
#     {'GamerTag': 'zxxCRISTI4Nxxz', 'TotalKills': 2},
#     {'GamerTag': 'Drymander', 'TotalKills': 4}],
#    'KilledByOpponentDetails': [{'GamerTag': 'zxxCRISTI4Nxxz', 'TotalKills': 6},
#     {'GamerTag': 'UndeadJubei', 'TotalKills': 4},
#     {'GamerTag': 'DarkZazke', 'TotalKills': 2}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 9},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 1},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 12},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 0},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 1},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5367574S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 742,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 225,
#     'TimePlayedAmount': 516.1536925955032,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 228,
#      'Progress': 237},
#     {'Id': '3c357b49-4860-48b7-9d92-dfdfd9931b49',
#      'PreviousProgress': 15,
#      'Progress': 17},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 26,
#      'Progress': 29},
#     {'Id': 'af609abb-c6e2-4e97-826f-5aca4fccf70c',
#      'PreviousProgress': 4,
#      'Progress': 5},
#     {'Id': '61217e0a-832e-487b-9f3b-51b36a6803c7',
#      'PreviousProgress': 61,
#      'Progress': 65}],
#    'BoostInfo': {'DefinitionId': '2ead1dc8-c82a-488b-a0b8-50cee41044be',
#     'CardConsumed': True},
#    'Player': {'Gamertag': 'SoT ChuckNorris', 'Xuid': None},
#    'TeamId': 1,
#    'Rank': 6,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT25.9645144S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 1,
#    'TotalKills': 9,
#    'TotalHeadshots': 0,
#    'TotalWeaponDamage': 1018.3848361968994,
#    'TotalShotsFired': 297,
#    'TotalShotsLanded': 102,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 313138863,
#      'Attachments': []},
#     'TotalShotsFired': 159,
#     'TotalShotsLanded': 56,
#     'TotalHeadshots': 0,
#     'TotalKills': 4,
#     'TotalDamageDealt': 424.0177536010742,
#     'TotalPossessionTime': 'PT3M12.75S'},
#    'TotalMeleeKills': 2,
#    'TotalMeleeDamage': 305.6045112609863,
#    'TotalAssassinations': 1,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 337.19781494140625,
#    'TotalGrenadeDamage': 140.93502807617188,
#    'TotalPowerWeaponKills': 0,
#    'TotalPowerWeaponDamage': 148.63202381134033,
#    'TotalPowerWeaponGrabs': 1,
#    'TotalPowerWeaponPossessionTime': 'PT27.85S',
#    'TotalDeaths': 12,
#    'TotalAssists': 1,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5367574S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 3270120991, 'Count': 1},
#     {'MedalId': 250435527, 'Count': 1},
#     {'MedalId': 2782465081, 'Count': 1},
#     {'MedalId': 2287626681, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2.7S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 159,
#      'TotalShotsLanded': 56,
#      'TotalHeadshots': 0,
#      'TotalKills': 4,
#      'TotalDamageDealt': 424.0177536010742,
#      'TotalPossessionTime': 'PT3M12.75S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 18,
#      'TotalShotsLanded': 6,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 148.63202381134033,
#      'TotalPossessionTime': 'PT18.6333S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 106,
#      'TotalShotsLanded': 34,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 259.800030708313,
#      'TotalPossessionTime': 'PT1M38.3S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 3,
#      'TotalDamageDealt': 642.8023262023926,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#      'TotalShotsFired': 3,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT9.2167S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 6,
#      'TotalShotsLanded': 2,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 45.0,
#      'TotalPossessionTime': 'PT15.1833S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 5,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 140.93502807617188,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 9,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 3,
#     'SpartanRank': 3,
#     'PrevTotalXP': 5625,
#     'TotalXP': 6336,
#     'SpartanRankMatchXPScalar': 1.0,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 99,
#     'PlayerRankXPAward': 50,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 9,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'Felex 9', 'TotalKills': 1}],
#    'KilledByOpponentDetails': [{'GamerTag': 'AmeXSB', 'TotalKills': 2},
#     {'GamerTag': 'SoT ChuckNorris', 'TotalKills': 4},
#     {'GamerTag': 'Felex 9', 'TotalKills': 1},
#     {'GamerTag': 'CptnColdCrush', 'TotalKills': 1}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 1},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 4},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 8},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 0},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5367574S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 767,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 250,
#     'TimePlayedAmount': 516.1536925955032,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 24,
#      'Progress': 25},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 5,
#      'Progress': 6},
#     {'Id': 'd3b6b1ce-c5f0-4cbf-b443-ca76c2917b77',
#      'PreviousProgress': 1,
#      'Progress': 2}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'Drymander', 'Xuid': None},
#    'TeamId': 0,
#    'Rank': 4,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT41.0639125S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 3,
#    'TotalKills': 1,
#    'TotalHeadshots': 0,
#    'TotalWeaponDamage': 448.2759037017822,
#    'TotalShotsFired': 222,
#    'TotalShotsLanded': 54,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 3168248199,
#      'Attachments': []},
#     'TotalShotsFired': 0,
#     'TotalShotsLanded': 0,
#     'TotalHeadshots': 0,
#     'TotalKills': 1,
#     'TotalDamageDealt': 106.66666793823242,
#     'TotalPossessionTime': 'PT0S'},
#    'TotalMeleeKills': 0,
#    'TotalMeleeDamage': 106.66666793823242,
#    'TotalAssassinations': 1,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 0.0,
#    'TotalPowerWeaponKills': 0,
#    'TotalPowerWeaponDamage': 0.0,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT0S',
#    'TotalDeaths': 8,
#    'TotalAssists': 4,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5367574S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 3270120991, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 138,
#      'TotalShotsLanded': 38,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 304.6425676345825,
#      'TotalPossessionTime': 'PT3M31.9166S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT10.7834S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT21.5S'},
#     {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#      'TotalShotsFired': 76,
#      'TotalShotsLanded': 12,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 135.83333587646484,
#      'TotalPossessionTime': 'PT1M30.6S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 106.66666793823242,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 7.800000190734863,
#      'TotalPossessionTime': 'PT34S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 4,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 1,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 4,
#     'SpartanRank': 4,
#     'PrevTotalXP': 7327,
#     'TotalXP': 8427,
#     'SpartanRankMatchXPScalar': 1.05,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 99,
#     'PlayerRankXPAward': 100,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': None,
#    'CurrentCsr': None,
#    'MeasurementMatchesLeft': 6,
#    'RewardSets': [{'RewardSet': 'f05ab061-e5ca-43cf-b72f-734786558e74',
#      'RewardSourceType': 2,
#      'SpartanRankSource': None,
#      'CommendationLevelId': '502ccc42-9c44-4f83-a981-d290a9a6cc1b',
#      'CommendationSource': '20dc7d74-be8f-4a60-ae4f-15230855cced'}],
#    'KilledOpponentDetails': [{'GamerTag': 'CptnColdCrush', 'TotalKills': 3},
#     {'GamerTag': 'Felex 9', 'TotalKills': 4},
#     {'GamerTag': 'AmeXSB', 'TotalKills': 3},
#     {'GamerTag': 'SoT ChuckNorris', 'TotalKills': 4}],
#    'KilledByOpponentDetails': [{'GamerTag': 'Felex 9', 'TotalKills': 1},
#     {'GamerTag': 'SoT ChuckNorris', 'TotalKills': 3},
#     {'GamerTag': 'AmeXSB', 'TotalKills': 4},
#     {'GamerTag': 'CptnColdCrush', 'TotalKills': 2}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 14},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 3},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 10},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 0},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 1},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5367574S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 817,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 300,
#     'TimePlayedAmount': 516.1536925955032,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 99,
#      'Progress': 113},
#     {'Id': '61217e0a-832e-487b-9f3b-51b36a6803c7',
#      'PreviousProgress': 61,
#      'Progress': 70},
#     {'Id': '2bda6fbf-4a87-4e10-9684-c971c8b43226',
#      'PreviousProgress': 0,
#      'Progress': 1},
#     {'Id': '79b6e993-ff9b-4a53-9789-cccaf86a4e22',
#      'PreviousProgress': 7,
#      'Progress': 9},
#     {'Id': '750783af-3332-4c7d-b5b5-26aa8800655a',
#      'PreviousProgress': 0,
#      'Progress': 1},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 21,
#      'Progress': 23},
#     {'Id': 'e1203a73-2067-4479-9a47-2abccb0069ae',
#      'PreviousProgress': 3,
#      'Progress': 4},
#     {'Id': '7d05bc12-7328-44fe-913e-1a64fe6a2a64',
#      'PreviousProgress': 0,
#      'Progress': 1},
#     {'Id': 'd3b6b1ce-c5f0-4cbf-b443-ca76c2917b77',
#      'PreviousProgress': 0,
#      'Progress': 1}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'UndeadJubei', 'Xuid': None},
#    'TeamId': 0,
#    'Rank': 3,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT32.1474065S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 3,
#    'TotalKills': 14,
#    'TotalHeadshots': 0,
#    'TotalWeaponDamage': 1301.9587135314941,
#    'TotalShotsFired': 441,
#    'TotalShotsLanded': 154,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 313138863,
#      'Attachments': []},
#     'TotalShotsFired': 407,
#     'TotalShotsLanded': 132,
#     'TotalHeadshots': 0,
#     'TotalKills': 9,
#     'TotalDamageDealt': 1066.1100177764893,
#     'TotalPossessionTime': 'PT5M15.7334S'},
#    'TotalMeleeKills': 2,
#    'TotalMeleeDamage': 336.8000087738037,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 0,
#    'TotalShoulderBashDamage': 0.0,
#    'TotalGrenadeDamage': 131.80160522460938,
#    'TotalPowerWeaponKills': 1,
#    'TotalPowerWeaponDamage': 14.047090530395508,
#    'TotalPowerWeaponGrabs': 1,
#    'TotalPowerWeaponPossessionTime': 'PT19.1833S',
#    'TotalDeaths': 10,
#    'TotalAssists': 3,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5367574S',
#    'TotalGrenadeKills': 2,
#    'MedalAwards': [{'MedalId': 3698887726, 'Count': 1},
#     {'MedalId': 2430242797, 'Count': 1},
#     {'MedalId': 2287626681, 'Count': 2},
#     {'MedalId': 2078758684, 'Count': 1},
#     {'MedalId': 2782465081, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 407,
#      'TotalShotsLanded': 132,
#      'TotalHeadshots': 0,
#      'TotalKills': 9,
#      'TotalDamageDealt': 1066.1100177764893,
#      'TotalPossessionTime': 'PT5M15.7334S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 336.8000087738037,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 13,
#      'TotalShotsLanded': 11,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 131.80160522460938,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT6S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 6,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 90.0,
#      'TotalPossessionTime': 'PT11.0667S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 15,
#      'TotalShotsLanded': 7,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 14.047090530395508,
#      'TotalPossessionTime': 'PT19.1833S'}],
#    'Impulses': [],
#    'TotalSpartanKills': 14,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 37,
#     'SpartanRank': 37,
#     'PrevTotalXP': 475435,
#     'TotalXP': 477119,
#     'SpartanRankMatchXPScalar': 1.95,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 99,
#     'PlayerRankXPAward': 100,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': {'Tier': 2,
#     'DesignationId': 3,
#     'Csr': 0,
#     'PercentToNextTier': 98,
#     'Rank': None},
#    'CurrentCsr': {'Tier': 3,
#     'DesignationId': 3,
#     'Csr': 0,
#     'PercentToNextTier': 32,
#     'Rank': None},
#    'MeasurementMatchesLeft': 0,
#    'RewardSets': [{'RewardSet': '3ec0ab09-1b22-4476-aebc-9f3e368f9ffb',
#      'RewardSourceType': 2,
#      'SpartanRankSource': None,
#      'CommendationLevelId': 'bbff6821-e62c-4642-9938-30c7d153ad0c',
#      'CommendationSource': '7d05bc12-7328-44fe-913e-1a64fe6a2a64'}],
#    'KilledOpponentDetails': [{'GamerTag': 'AmeXSB', 'TotalKills': 3},
#     {'GamerTag': 'CptnColdCrush', 'TotalKills': 3},
#     {'GamerTag': 'Felex 9', 'TotalKills': 6},
#     {'GamerTag': 'SoT ChuckNorris', 'TotalKills': 2}],
#    'KilledByOpponentDetails': [{'GamerTag': 'CptnColdCrush', 'TotalKills': 5},
#     {'GamerTag': 'AmeXSB', 'TotalKills': 2},
#     {'GamerTag': 'Felex 9', 'TotalKills': 3}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 14},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 6},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 10},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 2},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 0},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 1},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5367574S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 817,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 300,
#     'TimePlayedAmount': 516.1536925955032,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 2285,
#      'Progress': 2299},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 330,
#      'Progress': 334},
#     {'Id': '2bda6fbf-4a87-4e10-9684-c971c8b43226',
#      'PreviousProgress': 6,
#      'Progress': 7},
#     {'Id': '3c357b49-4860-48b7-9d92-dfdfd9931b49',
#      'PreviousProgress': 313,
#      'Progress': 314},
#     {'Id': 'f33f1aec-59ad-47eb-be13-fd0e654a53aa',
#      'PreviousProgress': 280,
#      'Progress': 283},
#     {'Id': '07653860-9949-4a12-b341-90c8b9653165',
#      'PreviousProgress': 604,
#      'Progress': 606},
#     {'Id': '7d05bc12-7328-44fe-913e-1a64fe6a2a64',
#      'PreviousProgress': 14,
#      'Progress': 15},
#     {'Id': '79b6e993-ff9b-4a53-9789-cccaf86a4e22',
#      'PreviousProgress': 111,
#      'Progress': 112},
#     {'Id': '2d5080e0-62ee-42d9-a2dd-364d101832ea',
#      'PreviousProgress': 69,
#      'Progress': 70},
#     {'Id': 'ab7c2b82-1c4b-4ba8-accf-0dfc5cf2ff77',
#      'PreviousProgress': 35,
#      'Progress': 37},
#     {'Id': '61217e0a-832e-487b-9f3b-51b36a6803c7',
#      'PreviousProgress': 215,
#      'Progress': 217},
#     {'Id': 'e1203a73-2067-4479-9a47-2abccb0069ae',
#      'PreviousProgress': 131,
#      'Progress': 132},
#     {'Id': '24e0ba42-59df-4c45-9fe6-d4fb739aeadc',
#      'PreviousProgress': 96,
#      'Progress': 97},
#     {'Id': '750783af-3332-4c7d-b5b5-26aa8800655a',
#      'PreviousProgress': 27,
#      'Progress': 28},
#     {'Id': 'd3b6b1ce-c5f0-4cbf-b443-ca76c2917b77',
#      'PreviousProgress': 35,
#      'Progress': 36}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'DarkZazke', 'Xuid': None},
#    'TeamId': 0,
#    'Rank': 2,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT32.1641006S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 3,
#    'TotalKills': 14,
#    'TotalHeadshots': 2,
#    'TotalWeaponDamage': 1695.1412329673767,
#    'TotalShotsFired': 407,
#    'TotalShotsLanded': 136,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 3168248199,
#      'Attachments': []},
#     'TotalShotsFired': 0,
#     'TotalShotsLanded': 0,
#     'TotalHeadshots': 0,
#     'TotalKills': 6,
#     'TotalDamageDealt': 468.2000045776367,
#     'TotalPossessionTime': 'PT0S'},
#    'TotalMeleeKills': 2,
#    'TotalMeleeDamage': 238.20000457763672,
#    'TotalAssassinations': 2,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 2,
#    'TotalShoulderBashDamage': 230.0,
#    'TotalGrenadeDamage': 398.3272933959961,
#    'TotalPowerWeaponKills': 1,
#    'TotalPowerWeaponDamage': 80.0,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT12.4167S',
#    'TotalDeaths': 10,
#    'TotalAssists': 6,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5367574S',
#    'TotalGrenadeKills': 1,
#    'MedalAwards': [{'MedalId': 3270120991, 'Count': 2},
#     {'MedalId': 3698887726, 'Count': 1},
#     {'MedalId': 2287626681, 'Count': 2},
#     {'MedalId': 3261908037, 'Count': 2},
#     {'MedalId': 3400287617, 'Count': 3},
#     {'MedalId': 2782465081, 'Count': 1},
#     {'MedalId': 285057226, 'Count': 1},
#     {'MedalId': 298813630, 'Count': 2},
#     {'MedalId': 2078758684, 'Count': 1},
#     {'MedalId': 2838259753, 'Count': 1},
#     {'MedalId': 2430242797, 'Count': 1}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 123,
#      'TotalShotsLanded': 41,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 331.7996473312378,
#      'TotalPossessionTime': 'PT1M47.1667S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 6,
#      'TotalDamageDealt': 468.2000045776367,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 60,
#      'TotalShotsLanded': 27,
#      'TotalHeadshots': 2,
#      'TotalKills': 3,
#      'TotalDamageDealt': 500.4142427444458,
#      'TotalPossessionTime': 'PT1M40.0834S'},
#     {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#      'TotalShotsFired': 6,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT14.4334S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 1,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT9.5334S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 127,
#      'TotalShotsLanded': 49,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 384.600049495697,
#      'TotalPossessionTime': 'PT1M35.4666S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 3,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT12.6166S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 12,
#      'TotalShotsLanded': 1,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 80.0,
#      'TotalPossessionTime': 'PT12.4167S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 13,
#      'TotalShotsLanded': 10,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 197.228515625,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#      'TotalShotsFired': 60,
#      'TotalShotsLanded': 8,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 201.0987777709961,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [{'Id': 2556889090, 'Count': 1}],
#    'TotalSpartanKills': 14,
#    'FastestMatchWin': None},
#   {'XpInfo': {'PrevSpartanRank': 34,
#     'SpartanRank': 34,
#     'PrevTotalXP': 394116,
#     'TotalXP': 395770,
#     'SpartanRankMatchXPScalar': 1.92,
#     'PlayerTimePerformanceXPAward': 562,
#     'PerformanceXP': 99,
#     'PlayerRankXPAward': 200,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'PreviousCsr': {'Tier': 3,
#     'DesignationId': 3,
#     'Csr': 0,
#     'PercentToNextTier': 76,
#     'Rank': None},
#    'CurrentCsr': {'Tier': 4,
#     'DesignationId': 3,
#     'Csr': 0,
#     'PercentToNextTier': 12,
#     'Rank': None},
#    'MeasurementMatchesLeft': 0,
#    'RewardSets': [],
#    'KilledOpponentDetails': [{'GamerTag': 'SoT ChuckNorris', 'TotalKills': 6},
#     {'GamerTag': 'AmeXSB', 'TotalKills': 6},
#     {'GamerTag': 'Felex 9', 'TotalKills': 4},
#     {'GamerTag': 'CptnColdCrush', 'TotalKills': 5}],
#    'KilledByOpponentDetails': [{'GamerTag': 'SoT ChuckNorris',
#      'TotalKills': 2},
#     {'GamerTag': 'AmeXSB', 'TotalKills': 2}],
#    'FlexibleStats': {'MedalStatCounts': [],
#     'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#       'Count': 21},
#      {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 6},
#      {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 4},
#      {'Id': 'a1d97ad4-c1d9-4807-b619-ca3710cc5a8d', 'Count': 0},
#      {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 9},
#      {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 2},
#      {'Id': 'a5a0d0d5-5c9f-4888-b42a-2c87f8e58336', 'Count': 0},
#      {'Id': '71ce2293-23bb-492f-a8c0-46e095b55eb7', 'Count': 0},
#      {'Id': 'ba1b0043-3a1e-4894-a04f-f8d889103ec5', 'Count': 0}],
#     'MedalTimelapses': [],
#     'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#       'Timelapse': 'PT7M31.5367574S'}]},
#    'CreditsEarned': {'Result': 2,
#     'TotalCreditsEarned': 892,
#     'SpartanRankModifier': 1.0,
#     'PlayerRankAmount': 375,
#     'TimePlayedAmount': 516.1536925955032,
#     'BoostAmount': 0,
#     'MatchSpeedWinAmount': 0,
#     'ObjectivesCompletedAmount': 0},
#    'MetaCommendationDeltas': [],
#    'ProgressiveCommendationDeltas': [{'Id': '20dc7d74-be8f-4a60-ae4f-15230855cced',
#      'PreviousProgress': 2850,
#      'Progress': 2871},
#     {'Id': 'f33f1aec-59ad-47eb-be13-fd0e654a53aa',
#      'PreviousProgress': 1066,
#      'Progress': 1074},
#     {'Id': '07653860-9949-4a12-b341-90c8b9653165',
#      'PreviousProgress': 1498,
#      'Progress': 1507},
#     {'Id': '8594ca5e-6f59-4e21-b601-406111fa2b58',
#      'PreviousProgress': 112,
#      'Progress': 118},
#     {'Id': 'e1203a73-2067-4479-9a47-2abccb0069ae',
#      'PreviousProgress': 222,
#      'Progress': 226},
#     {'Id': 'c9bcb904-607f-42ea-acae-4cbdcdf65143',
#      'PreviousProgress': 65,
#      'Progress': 69},
#     {'Id': '750783af-3332-4c7d-b5b5-26aa8800655a',
#      'PreviousProgress': 78,
#      'Progress': 80},
#     {'Id': '1f8a93a3-6e1f-4f48-afe2-5ce1c44f2458',
#      'PreviousProgress': 149,
#      'Progress': 150},
#     {'Id': '3c357b49-4860-48b7-9d92-dfdfd9931b49',
#      'PreviousProgress': 34,
#      'Progress': 35},
#     {'Id': 'ab7c2b82-1c4b-4ba8-accf-0dfc5cf2ff77',
#      'PreviousProgress': 17,
#      'Progress': 18},
#     {'Id': 'ad36d0cd-7e44-49a2-8a2c-c103a38f17d8',
#      'PreviousProgress': 155,
#      'Progress': 157},
#     {'Id': 'd3b6b1ce-c5f0-4cbf-b443-ca76c2917b77',
#      'PreviousProgress': 86,
#      'Progress': 87},
#     {'Id': '49b744bf-ec46-47aa-bb16-0042cbf49614',
#      'PreviousProgress': 20,
#      'Progress': 21}],
#    'BoostInfo': None,
#    'Player': {'Gamertag': 'zxxCRISTI4Nxxz', 'Xuid': None},
#    'TeamId': 0,
#    'Rank': 1,
#    'DNF': False,
#    'AvgLifeTimeOfPlayer': 'PT1M20.3884412S',
#    'PreMatchRatings': None,
#    'PostMatchRatings': None,
#    'PlayerScore': None,
#    'GameEndStatus': 3,
#    'TotalKills': 21,
#    'TotalHeadshots': 9,
#    'TotalWeaponDamage': 2413.6108016967773,
#    'TotalShotsFired': 242,
#    'TotalShotsLanded': 123,
#    'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#      'Attachments': []},
#     'TotalShotsFired': 94,
#     'TotalShotsLanded': 54,
#     'TotalHeadshots': 7,
#     'TotalKills': 8,
#     'TotalDamageDealt': 997.0117797851562,
#     'TotalPossessionTime': 'PT2M45.6834S'},
#    'TotalMeleeKills': 1,
#    'TotalMeleeDamage': 117.50000381469727,
#    'TotalAssassinations': 0,
#    'TotalGroundPoundKills': 0,
#    'TotalGroundPoundDamage': 0.0,
#    'TotalShoulderBashKills': 1,
#    'TotalShoulderBashDamage': 126.5283203125,
#    'TotalGrenadeDamage': 191.83021545410156,
#    'TotalPowerWeaponKills': 6,
#    'TotalPowerWeaponDamage': 446.19998931884766,
#    'TotalPowerWeaponGrabs': 0,
#    'TotalPowerWeaponPossessionTime': 'PT1M22.7667S',
#    'TotalDeaths': 4,
#    'TotalAssists': 6,
#    'TotalGamesCompleted': 0,
#    'TotalGamesWon': 0,
#    'TotalGamesLost': 0,
#    'TotalGamesTied': 0,
#    'TotalTimePlayed': 'PT7M31.5367574S',
#    'TotalGrenadeKills': 0,
#    'MedalAwards': [{'MedalId': 3261908037, 'Count': 7},
#     {'MedalId': 2494364276, 'Count': 2},
#     {'MedalId': 3400287617, 'Count': 1},
#     {'MedalId': 2078758684, 'Count': 4},
#     {'MedalId': 2430242797, 'Count': 2},
#     {'MedalId': 466059351, 'Count': 1},
#     {'MedalId': 2287626681, 'Count': 1},
#     {'MedalId': 298813630, 'Count': 1},
#     {'MedalId': 370413844, 'Count': 2}],
#    'DestroyedEnemyVehicles': [],
#    'EnemyKills': [],
#    'WeaponStats': [{'WeaponId': {'StockId': 2457457776, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT3.4S'},
#     {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#      'TotalShotsFired': 94,
#      'TotalShotsLanded': 54,
#      'TotalHeadshots': 7,
#      'TotalKills': 8,
#      'TotalDamageDealt': 997.0117797851562,
#      'TotalPossessionTime': 'PT2M45.6834S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT7.2334S'},
#     {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 8,
#      'TotalHeadshots': 0,
#      'TotalKills': 6,
#      'TotalDamageDealt': 446.19998931884766,
#      'TotalPossessionTime': 'PT1M22.7667S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 244.02832412719727,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1.9333S'},
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 44,
#      'TotalShotsLanded': 32,
#      'TotalHeadshots': 2,
#      'TotalKills': 4,
#      'TotalDamageDealt': 649.1000061035156,
#      'TotalPossessionTime': 'PT2M1.6S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 58,
#      'TotalShotsLanded': 17,
#      'TotalHeadshots': 0,
#      'TotalKills': 1,
#      'TotalDamageDealt': 129.46881103515625,
#      'TotalPossessionTime': 'PT18.25S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 11,
#      'TotalShotsLanded': 9,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 137.66844177246094,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 2,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#      'TotalShotsFired': 24,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 54.161773681640625,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [{'Id': 3174430457, 'Count': 2}],
#    'TotalSpartanKills': 21,
#    'FastestMatchWin': None}],
#  'TeamStats': [{'TeamId': 1,
#    'Score': 31,
#    'Rank': 2,
#    'RoundStats': [{'RoundNumber': 1, 'Rank': 2, 'Score': 31}]},
#   {'TeamId': 0,
#    'Score': 50,
#    'Rank': 1,
#    'RoundStats': [{'RoundNumber': 1, 'Rank': 1, 'Score': 50}]}],
#  'IsMatchOver': True,
#  'TotalDuration': 'PT7M31.5477572S',
#  'MapVariantId': '332c933c-ba2f-4130-b102-19349659e0f3',
#  'GameVariantId': '4e60ded8-be09-4adf-ba25-57c1278b4b64',
#  'PlaylistId': 'c98949ae-60a8-43dc-85d7-0feb0b92e719',
#  'MapId': 'cdb934b0-f206-11e4-8810-24be05e24f7e',
#  'GameBaseVariantId': '257a305e-4dd3-41f1-9824-dfe7e8bd59e1',
#  'IsTeamGame': True,
#  'SeasonId': '2041d318-dd22-47c2-a487-2818ecf14e41',
#  'GameVariantResourceId': {'ResourceType': 2,
#   'ResourceId': '4e60ded8-be09-4adf-ba25-57c1278b4b64',
#   'OwnerType': 3,
#   'Owner': ''},
#  'MapVariantResourceId': {'ResourceType': 3,
#   'ResourceId': '332c933c-ba2f-4130-b102-19349659e0f3',
#   'OwnerType': 3,
#   'Owner': ''}}

# %% [markdown]
# # Build Match Dataframe

# %%
match_results = pull_recent_match(0,explore=False)

# %% [markdown]
# ### Notes
#
# Red team is team ID 0
#
# Blue team is team ID 1

# %%
match_results = pull_recent_match(0)
def build_base_dataframe(match_results):
    
    # Build empty base match dataframe
    df = pd.DataFrame()
    columns = [
        'TeamId',
        'Gamertag',
        'SpartanRank',
        'PrevTotalXP',
    ]
    df = pd.DataFrame(columns = columns)
    
    # Populate base match dataframe with player stats for each player
    i = 0
    for player in match_results['PlayerStats']:

        player_dic = {}
        # Team ID
        player_dic['TeamId'] = match_results['PlayerStats'][i]['TeamId']
        # Team Color
        player_dic['TeamColor'] = match_results['PlayerStats'][i]['TeamId']
        # Gamer Tag
        player_dic['Gamertag'] = match_results['PlayerStats'][i]['Player']['Gamertag']
        # Spartan Rank
        player_dic['SpartanRank'] = match_results['PlayerStats'][i]['XpInfo']['SpartanRank']
        # Previous Total XP
        player_dic['PrevTotalXP'] = match_results['PlayerStats'][i]['XpInfo']['PrevTotalXP']
        df = df.append(player_dic, ignore_index=True)
        i += 1
    
    playerteam = df.loc[df['Gamertag'] == user, 'TeamId'].values[0]
    if playerteam == 0:
        enemyteam = 1
    else:
        enemyteam = 0

    if match_results['TeamStats'][0]['TeamId'] == playerteam:
        playerteam_stats = match_results['TeamStats'][0]
        enemyteam_stats = match_results['TeamStats'][1]
    else: 
        playerteam_stats = match_results['TeamStats'][1]
        enemyteam_stats = match_results['TeamStats'][0]
    
    # Determine winner
    # Tie
    if playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 1:
        df['Winner'] = 'Tie'
    # Player wins
    elif playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 2:
        df['Winner'] = df['TeamId'].map({playerteam:'Victory', enemyteam:'Defeat'})
    # Enemy wins
    elif playerteam_stats['Rank'] == 2 and enemyteam_stats['Rank'] == 1:
        df['Winner'] = df['TeamId'].map({enemyteam:'Victory', playerteam:'Defeat'})
    # Error handling
    else:
        winner = 'Error determining winner'
    df['TeamColor'] = df['TeamId'].map({0:'Red', 1:'Blue'})
    # Set columns
    df = df[['TeamId', 'Winner', 'TeamColor', 'Gamertag', 'SpartanRank', 'PrevTotalXP']]
    # Sort match by winning team
    df = df.sort_values(by=['Winner'], ascending=False)
    
    return df

# df = build_base_dataframe(pull_recent_match(0))
# # df.loc[df['TeamId'] == 0]
# df
build_base_dataframe(pull_recent_match(1))
# Out:
#   TeamId   Winner TeamColor         Gamertag SpartanRank PrevTotalXP
# 4      0  Victory       Red     SoGGy c3r3al         150    24788339
# 5      0  Victory       Red    XxOwninFacexX         148    14099393
# 6      0  Victory       Red   CornyPacman100         150    29925750
# 7      0  Victory       Red     LAMB SAUCE06         149    21379843
# 0      1   Defeat      Blue  MetroidMarcos01         148    14435561
# 1      1   Defeat      Blue  Aldair Vega 117         151    38837521
# 2      1   Defeat      Blue         Kirby144         141     6508846
# 3      1   Defeat      Blue        Drymander         148    15171673

# %%
playerteam = 0

df['TeamColor'] = df['TeamId'].map({0:'Red', 1:'Blue'})
df['Winner'] = df['TeamId'].map({playerteam:'Victory', 1:'Defeat'})
df
# Out:
#   TeamId TeamColor         Gamertag SpartanRank PrevTotalXP   Winner
# 4      0       Red     SoGGy c3r3al         150    24788339  Victory
# 5      0       Red    XxOwninFacexX         148    14099393  Victory
# 6      0       Red   CornyPacman100         150    29925750  Victory
# 7      0       Red     LAMB SAUCE06         149    21379843  Victory
# 0      1      Blue  MetroidMarcos01         148    14435561   Defeat
# 1      1      Blue  Aldair Vega 117         151    38837521   Defeat
# 2      1      Blue         Kirby144         141     6508846   Defeat
# 3      1      Blue        Drymander         148    15171673   Defeat

# %%
# Red victory
build_base_dataframe(pull_recent_match(0))
# Out:
#   TeamId   Winner TeamColor         Gamertag SpartanRank PrevTotalXP
# 0      0  Victory       Red        Drymander         148    15173027
# 1      0  Victory       Red         pukboy85         149    22528820
# 3      0  Victory       Red    sick killer65         149    18610192
# 4      0  Victory       Red  MasterPlayer701          69     1677339
# 2      1   Defeat      Blue           rawdah         148    14341308
# 5      1   Defeat      Blue          EctaX1X           3        5591
# 6      1   Defeat      Blue       foreunner8         143     7036819
# 7      1   Defeat      Blue       HierbaLoka          65     1423999

# %%
# Blue loss
build_base_dataframe(pull_recent_match(1))
# Out:
#   TeamId   Winner TeamColor         Gamertag SpartanRank PrevTotalXP
# 4      0  Victory       Red     SoGGy c3r3al         150    24788339
# 5      0  Victory       Red    XxOwninFacexX         148    14099393
# 6      0  Victory       Red   CornyPacman100         150    29925750
# 7      0  Victory       Red     LAMB SAUCE06         149    21379843
# 0      1   Defeat      Blue  MetroidMarcos01         148    14435561
# 1      1   Defeat      Blue  Aldair Vega 117         151    38837521
# 2      1   Defeat      Blue         Kirby144         141     6508846
# 3      1   Defeat      Blue        Drymander         148    15171673

# %%
# Blue tie
build_base_dataframe(pull_recent_match(2))
# Out:
#   TeamId Winner TeamColor        Gamertag SpartanRank PrevTotalXP
# 4      0    Tie       Red     hoots4binky          92     2708399
# 5      0    Tie       Red  SwiftBunny7995         147    13592319
# 6      0    Tie       Red   XxOwninFacexX         148    14097817
# 7      0    Tie       Red  MasterLalo1326         140     6345025
# 0      1    Tie      Blue     FlashKID124          91     2679164
# 1      1    Tie      Blue       Drymander         148    15170040
# 2      1    Tie      Blue        Kirby144         141     6507106
# 3      1    Tie      Blue       Orihime17         143     6985668

# %%
# Red victory
build_base_dataframe(pull_recent_match(3))
# Out:
#   TeamId   Winner TeamColor         Gamertag SpartanRank PrevTotalXP
# 0      0  Victory       Red        Drymander         148    15163713
# 1      0  Victory       Red  WigglyWizard937          47      729769
# 2      0  Victory       Red     spiderman503          72     1776323
# 3      0  Victory       Red   SwiftBunny7995         147    13590676
# 4      1   Defeat      Blue     ReneOjeda727         152    51558863
# 5      1   Defeat      Blue     xElNinoDiosx         152    55509813
# 6      1   Defeat      Blue         Fr0b0y21         147    13415772
# 7      1   Defeat      Blue    dead duck0397         151    40860333
# 8      1   Defeat      Blue      hoots4binky          92     2707494

# %%
# Red DNF
build_base_dataframe(pull_recent_match(6))
# Out:
#   TeamId   Winner TeamColor        Gamertag SpartanRank PrevTotalXP
# 2      1  Victory      Blue    xElNinoDiosx         152    55493257
# 5      1  Victory      Blue     ZAM19972017         149    20018651
# 6      1  Victory      Blue    ReneOjeda727         152    51542194
# 7      1  Victory      Blue   dead duck0397         151    40832980
# 0      0   Defeat       Red    ALuvElectric          97     3038857
# 1      0   Defeat       Red       Drymander         148    15159025
# 3      0   Defeat       Red  SwiftBunny7995         147    13587925
# 4      0   Defeat       Red      NestorB344         145     8946994
# 8      0   Defeat       Red   OzymandiasGoD         149    23887625

# %%
# Blue victory
build_base_dataframe(pull_recent_match(7))
# Out:
#   TeamId   Winner TeamColor         Gamertag SpartanRank PrevTotalXP
# 4      0   Defeat       Red  XxMegaManxX8196         149    22508753
# 5      0   Defeat       Red    TyrannicJonas         147    12510383
# 6      0   Defeat       Red          Kal LP2         152    59105130
# 7      0   Defeat       Red    LIL CALIFOOYA          36      441397
# 0      1  Victory      Blue      Dirus Lupus         149    22705290
# 1      1  Victory      Blue   supersaiyan245         152    52942362
# 2      1  Victory      Blue        Drymander         148    15159025
# 3      1  Victory      Blue      J05EY WALES         152    84606732

# %% [markdown]
# # Pull Game Base Variant Stats for All Players in Match
#
# Using the match details, we will compile everyone's gamertags into a list and pull more specific information for each player.  We can get statistics on every game mode (or "Game Base Variant" as it is referred to in the API).

# %%
df_match = build_base_dataframe(pull_recent_match(7))
def get_player_list(df):
    player_list = str(list(df_match['Gamertag']))[1:-1]

    player_list
    player_list = player_list.replace(', ',',')
    player_list = player_list.replace("'",'')
    player_list = player_list.replace(' ','+')

    return player_list

get_player_list(df_match)
# Out:
# 'Dirus+Lupus,supersaiyan245,Drymander,J05EY+WALES,XxMegaManxX8196,TyrannicJonas,Kal+LP2,LIL+CALIFOOYA'

# %%
def get_player_history(df):
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': str(api_key),
    }
    params = urllib.parse.urlencode({
    })
    player_list = get_player_list(df)
    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/servicerecords/arena?players={player_list}&%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        player_history = json.loads(data)
    #     print(data)
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))

    return player_history

player_history = get_player_history(df_match)

# %% [markdown]
# ## Compile Individual Stats into Dataframe

# %%
player_history['Results'][1]
# Out:
# {'Id': 'supersaiyan245',
#  'ResultCode': 0,
#  'Result': {'ArenaStats': {'ArenaPlaylistStats': [{'PlaylistId': '2323b76a-db98-4e03-aa37-e171cfbdd1a4',
#      'MeasurementMatchesLeft': 0,
#      'HighestCsr': {'Tier': 5,
#       'DesignationId': 5,
#       'Csr': 0,
#       'PercentToNextTier': 38,
#       'Rank': None},
#      'Csr': {'Tier': 4,
#       'DesignationId': 5,
#       'Csr': 0,
#       'PercentToNextTier': 86,
#       'Rank': None},
#      'CsrPercentile': 6,
#      'TotalKills': 271,
#      'TotalHeadshots': 226,
#      'TotalWeaponDamage': 11498.065107345581,
#      'TotalShotsFired': 1522,
#      'TotalShotsLanded': 580,
#      'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#        'Attachments': []},
#       'TotalShotsFired': 397,
#       'TotalShotsLanded': 180,
#       'TotalHeadshots': 83,
#       'TotalKills': 89,
#       'TotalDamageDealt': 4292.194890022278,
#       'TotalPossessionTime': 'PT31M10.4335S'},
#      'TotalMeleeKills': 28,
#      'TotalMeleeDamage': 1100.9648204725236,
#      'TotalAssassinations': 1,
#      'TotalGroundPoundKills': 0,
#      'TotalGroundPoundDamage': 0.0,
#      'TotalShoulderBashKills': 3,
#      'TotalShoulderBashDamage': 135.0,
#      'TotalGrenadeDamage': 0.0,
#      'TotalPowerWeaponKills': 17,
#      'TotalPowerWeaponDamage': 701.7073020935059,
#      'TotalPowerWeaponGrabs': 0,
#      'TotalPowerWeaponPossessionTime': 'PT7M31.4667S',
#      'TotalDeaths': 201,
#      'TotalAssists': 31,
#      'TotalGamesCompleted': 22,
#      'TotalGamesWon': 15,
#      'TotalGamesLost': 7,
#      'TotalGamesTied': 0,
#      'TotalTimePlayed': 'PT1H45M26.5139025S',
#      'TotalGrenadeKills': 0,
#      'MedalAwards': [{'MedalId': 3261908037, 'Count': 226},
#       {'MedalId': 824733727, 'Count': 23},
#       {'MedalId': 3698887726, 'Count': 2},
#       {'MedalId': 2782465081, 'Count': 23},
#       {'MedalId': 2287626681, 'Count': 21},
#       {'MedalId': 250435527, 'Count': 6},
#       {'MedalId': 2078758684, 'Count': 33},
#       {'MedalId': 2430242797, 'Count': 9},
#       {'MedalId': 3270120991, 'Count': 1},
#       {'MedalId': 298813630, 'Count': 3},
#       {'MedalId': 3001183151, 'Count': 3},
#       {'MedalId': 1423504140, 'Count': 1},
#       {'MedalId': 466059351, 'Count': 3},
#       {'MedalId': 2763748638, 'Count': 2},
#       {'MedalId': 3522125871, 'Count': 1},
#       {'MedalId': 2707871298, 'Count': 1},
#       {'MedalId': 3925170236, 'Count': 3},
#       {'MedalId': 876932011, 'Count': 1},
#       {'MedalId': 2077162827, 'Count': 1}],
#      'DestroyedEnemyVehicles': [],
#      'EnemyKills': [],
#      'WeaponStats': [{'WeaponId': {'StockId': 4222743534, 'Attachments': []},
#        'TotalShotsFired': 440,
#        'TotalShotsLanded': 158,
#        'TotalHeadshots': 55,
#        'TotalKills': 56,
#        'TotalDamageDealt': 2740.0,
#        'TotalPossessionTime': 'PT14M43.1832S'},
#       {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 32,
#        'TotalDamageDealt': 1235.9648204725236,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#        'TotalShotsFired': 397,
#        'TotalShotsLanded': 180,
#        'TotalHeadshots': 83,
#        'TotalKills': 89,
#        'TotalDamageDealt': 4292.194890022278,
#        'TotalPossessionTime': 'PT31M10.4335S'},
#       {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#        'TotalShotsFired': 80,
#        'TotalShotsLanded': 32,
#        'TotalHeadshots': 14,
#        'TotalKills': 16,
#        'TotalDamageDealt': 795.8333349227905,
#        'TotalPossessionTime': 'PT8M2.4334S'},
#       {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#        'TotalShotsFired': 534,
#        'TotalShotsLanded': 176,
#        'TotalHeadshots': 61,
#        'TotalKills': 61,
#        'TotalDamageDealt': 2968.329580307007,
#        'TotalPossessionTime': 'PT26M19.2503S'},
#       {'WeaponId': {'StockId': 2758094302, 'Attachments': []},
#        'TotalShotsFired': 71,
#        'TotalShotsLanded': 34,
#        'TotalHeadshots': 13,
#        'TotalKills': 17,
#        'TotalDamageDealt': 701.7073020935059,
#        'TotalPossessionTime': 'PT7M31.4667S'}],
#      'Impulses': [],
#      'TotalSpartanKills': 271,
#      'FastestMatchWin': 'PT2M58.3684473S'},
#     {'PlaylistId': '892189e9-d712-4bdb-afa7-1ccab43fbed4',
#      'MeasurementMatchesLeft': 0,
#      'HighestCsr': {'Tier': 1,
#       'DesignationId': 6,
#       'Csr': 1579,
#       'PercentToNextTier': 0,
#       'Rank': None},
#      'Csr': {'Tier': 1,
#       'DesignationId': 6,
#       'Csr': 1565,
#       'PercentToNextTier': 0,
#       'Rank': None},
#      'CsrPercentile': 3,
#      'TotalKills': 829,
#      'TotalHeadshots': 264,
#      'TotalWeaponDamage': 108470.93360114098,
#      'TotalShotsFired': 15519,
#      'TotalShotsLanded': 6959,
#      'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#        'Attachments': []},
#       'TotalShotsFired': 6221,
#       'TotalShotsLanded': 2868,
#       'TotalHeadshots': 216,
#       'TotalKills': 304,
#       'TotalDamageDealt': 51301.99886274338,
#       'TotalPossessionTime': 'PT4H37M52.6158S'},
#      'TotalMeleeKills': 108,
#      'TotalMeleeDamage': 11623.172472255304,
#      'TotalAssassinations': 26,
#      'TotalGroundPoundKills': 5,
#      'TotalGroundPoundDamage': 867.5,
#      'TotalShoulderBashKills': 1,
#      'TotalShoulderBashDamage': 805.0,
#      'TotalGrenadeDamage': 7552.15372800827,
#      'TotalPowerWeaponKills': 156,
#      'TotalPowerWeaponDamage': 19407.1707572937,
#      'TotalPowerWeaponGrabs': 30,
#      'TotalPowerWeaponPossessionTime': 'PT56M52.133S',
#      'TotalDeaths': 542,
#      'TotalAssists': 445,
#      'TotalGamesCompleted': 64,
#      'TotalGamesWon': 48,
#      'TotalGamesLost': 16,
#      'TotalGamesTied': 0,
#      'TotalTimePlayed': 'PT9H7M19.9975074S',
#      'TotalGrenadeKills': 24,
#      'MedalAwards': [{'MedalId': 3261908037, 'Count': 228},
#       {'MedalId': 2838259753, 'Count': 95},
#       {'MedalId': 2287626681, 'Count': 72},
#       {'MedalId': 824733727, 'Count': 62},
#       {'MedalId': 3400287617, 'Count': 60},
#       {'MedalId': 2782465081, 'Count': 13},
#       {'MedalId': 2078758684, 'Count': 56},
#       {'MedalId': 250435527, 'Count': 36},
#       {'MedalId': 1326375333, 'Count': 4},
#       {'MedalId': 194124164, 'Count': 2},
#       {'MedalId': 3744028405, 'Count': 8},
#       {'MedalId': 3698887726, 'Count': 10},
#       {'MedalId': 848240062, 'Count': 11},
#       {'MedalId': 3001183151, 'Count': 8},
#       {'MedalId': 2430242797, 'Count': 37},
#       {'MedalId': 3270120991, 'Count': 25},
#       {'MedalId': 3653057799, 'Count': 14},
#       {'MedalId': 2108880282, 'Count': 1},
#       {'MedalId': 1691836029, 'Count': 4},
#       {'MedalId': 285057226, 'Count': 2},
#       {'MedalId': 492192256, 'Count': 5},
#       {'MedalId': 466059351, 'Count': 11},
#       {'MedalId': 1080468863, 'Count': 2},
#       {'MedalId': 298813630, 'Count': 1},
#       {'MedalId': 3522125871, 'Count': 8},
#       {'MedalId': 876932011, 'Count': 2},
#       {'MedalId': 2766284219, 'Count': 2},
#       {'MedalId': 2462002800, 'Count': 1},
#       {'MedalId': 370413844, 'Count': 1},
#       {'MedalId': 3972445431, 'Count': 1},
#       {'MedalId': 2707871298, 'Count': 2},
#       {'MedalId': 3592822316, 'Count': 1},
#       {'MedalId': 2366628262, 'Count': 3},
#       {'MedalId': 3318955876, 'Count': 1},
#       {'MedalId': 2683910456, 'Count': 6},
#       {'MedalId': 352859864, 'Count': 6},
#       {'MedalId': 3148489433, 'Count': 3},
#       {'MedalId': 2251767925, 'Count': 4},
#       {'MedalId': 2494364276, 'Count': 1},
#       {'MedalId': 2763748638, 'Count': 1}],
#      'DestroyedEnemyVehicles': [],
#      'EnemyKills': [],
#      'WeaponStats': [{'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#        'TotalShotsFired': 6221,
#        'TotalShotsLanded': 2868,
#        'TotalHeadshots': 216,
#        'TotalKills': 304,
#        'TotalDamageDealt': 51301.99886274338,
#        'TotalPossessionTime': 'PT4H37M52.6158S'},
#       {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#        'TotalShotsFired': 3658,
#        'TotalShotsLanded': 1524,
#        'TotalHeadshots': 0,
#        'TotalKills': 92,
#        'TotalDamageDealt': 10180.431809186935,
#        'TotalPossessionTime': 'PT44M0.3995S'},
#       {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 140,
#        'TotalDamageDealt': 13295.672472255304,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#        'TotalShotsFired': 1706,
#        'TotalShotsLanded': 741,
#        'TotalHeadshots': 0,
#        'TotalKills': 52,
#        'TotalDamageDealt': 8079.498983383179,
#        'TotalPossessionTime': 'PT20M39.5171S'},
#       {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#        'TotalShotsFired': 11,
#        'TotalShotsLanded': 8,
#        'TotalHeadshots': 0,
#        'TotalKills': 5,
#        'TotalDamageDealt': 671.6666622161865,
#        'TotalPossessionTime': 'PT3M47.0833S'},
#       {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#        'TotalShotsFired': 543,
#        'TotalShotsLanded': 304,
#        'TotalHeadshots': 0,
#        'TotalKills': 19,
#        'TotalDamageDealt': 6501.454906463623,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#        'TotalShotsFired': 57,
#        'TotalShotsLanded': 38,
#        'TotalHeadshots': 2,
#        'TotalKills': 4,
#        'TotalDamageDealt': 868.8333358764648,
#        'TotalPossessionTime': 'PT3M42.8833S'},
#       {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#        'TotalShotsFired': 568,
#        'TotalShotsLanded': 257,
#        'TotalHeadshots': 19,
#        'TotalKills': 31,
#        'TotalDamageDealt': 5256.551406860352,
#        'TotalPossessionTime': 'PT27M6.1337S'},
#       {'WeaponId': {'StockId': 2492868984, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT59.9655S'},
#       {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#        'TotalShotsFired': 40,
#        'TotalShotsLanded': 27,
#        'TotalHeadshots': 0,
#        'TotalKills': 4,
#        'TotalDamageDealt': 688.2926406860352,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#        'TotalShotsFired': 568,
#        'TotalShotsLanded': 231,
#        'TotalHeadshots': 0,
#        'TotalKills': 29,
#        'TotalDamageDealt': 3228.0701999664307,
#        'TotalPossessionTime': 'PT7M56.8666S'},
#       {'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#        'TotalShotsFired': 44,
#        'TotalShotsLanded': 15,
#        'TotalHeadshots': 0,
#        'TotalKills': 2,
#        'TotalDamageDealt': 230.0,
#        'TotalPossessionTime': 'PT26.1334S'},
#       {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#        'TotalShotsFired': 203,
#        'TotalShotsLanded': 24,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 362.40618085861206,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 669296699, 'Attachments': []},
#        'TotalShotsFired': 79,
#        'TotalShotsLanded': 28,
#        'TotalHeadshots': 10,
#        'TotalKills': 15,
#        'TotalDamageDealt': 2207.5,
#        'TotalPossessionTime': 'PT13M12.4833S'},
#       {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#        'TotalShotsFired': 60,
#        'TotalShotsLanded': 52,
#        'TotalHeadshots': 0,
#        'TotalKills': 36,
#        'TotalDamageDealt': 3802.8492860794067,
#        'TotalPossessionTime': 'PT6M22.9832S'},
#       {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#        'TotalShotsFired': 34,
#        'TotalShotsLanded': 11,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 62.499996185302734,
#        'TotalPossessionTime': 'PT24.6499S'},
#       {'WeaponId': {'StockId': 4222743534, 'Attachments': []},
#        'TotalShotsFired': 683,
#        'TotalShotsLanded': 335,
#        'TotalHeadshots': 11,
#        'TotalKills': 15,
#        'TotalDamageDealt': 2559.0683822631836,
#        'TotalPossessionTime': 'PT11M10.0333S'},
#       {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 14,
#        'TotalDamageDealt': 1212.5135345458984,
#        'TotalPossessionTime': 'PT2M39.9666S'},
#       {'WeaponId': {'StockId': 47178948, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#        'TotalShotsFired': 42,
#        'TotalShotsLanded': 27,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 1734.8851070404053,
#        'TotalPossessionTime': 'PT4M37.0333S'},
#       {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#        'TotalShotsFired': 4,
#        'TotalShotsLanded': 4,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 100.0,
#        'TotalPossessionTime': 'PT5.4167S'},
#       {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#        'TotalShotsFired': 467,
#        'TotalShotsLanded': 222,
#        'TotalHeadshots': 0,
#        'TotalKills': 4,
#        'TotalDamageDealt': 2752.0617656707764,
#        'TotalPossessionTime': 'PT5M42.35S'},
#       {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#        'TotalShotsFired': 26,
#        'TotalShotsLanded': 26,
#        'TotalHeadshots': 0,
#        'TotalKills': 20,
#        'TotalDamageDealt': 2037.1658010482788,
#        'TotalPossessionTime': 'PT5M32.6499S'},
#       {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 7,
#        'TotalHeadshots': 0,
#        'TotalKills': 7,
#        'TotalDamageDealt': 602.823486328125,
#        'TotalPossessionTime': 'PT1M53.9999S'},
#       {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#        'TotalShotsFired': 10,
#        'TotalShotsLanded': 2,
#        'TotalHeadshots': 1,
#        'TotalKills': 1,
#        'TotalDamageDealt': 195.0,
#        'TotalPossessionTime': 'PT1M15.2S'},
#       {'WeaponId': {'StockId': 723523180, 'Attachments': []},
#        'TotalShotsFired': 26,
#        'TotalShotsLanded': 26,
#        'TotalHeadshots': 0,
#        'TotalKills': 20,
#        'TotalDamageDealt': 1989.8484191894531,
#        'TotalPossessionTime': 'PT5M16.8834S'},
#       {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#        'TotalShotsFired': 6,
#        'TotalShotsLanded': 6,
#        'TotalHeadshots': 0,
#        'TotalKills': 2,
#        'TotalDamageDealt': 270.1716003417969,
#        'TotalPossessionTime': 'PT2M13.85S'},
#       {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#        'TotalShotsFired': 168,
#        'TotalShotsLanded': 70,
#        'TotalHeadshots': 0,
#        'TotalKills': 3,
#        'TotalDamageDealt': 750.4160919189453,
#        'TotalPossessionTime': 'PT1M12.7166S'},
#       {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#        'TotalShotsFired': 176,
#        'TotalShotsLanded': 88,
#        'TotalHeadshots': 5,
#        'TotalKills': 6,
#        'TotalDamageDealt': 717.4251403808594,
#        'TotalPossessionTime': 'PT3M4.3833S'},
#       {'WeaponId': {'StockId': 642449794, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#        'TotalShotsFired': 4,
#        'TotalShotsLanded': 1,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 80.0,
#        'TotalPossessionTime': 'PT15.55S'},
#       {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#        'TotalShotsFired': 115,
#        'TotalShotsLanded': 17,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 27.500001907348633,
#        'TotalPossessionTime': 'PT10.7167S'}],
#      'Impulses': [{'Id': 2556889090, 'Count': 101},
#       {'Id': 3174430457, 'Count': 17}],
#      'TotalSpartanKills': 829,
#      'FastestMatchWin': 'PT4M43.030205S'},
#     {'PlaylistId': 'aba6fbcb-9a2a-445a-b1d6-373fb2eb6a82',
#      'MeasurementMatchesLeft': 0,
#      'HighestCsr': {'Tier': 1,
#       'DesignationId': 6,
#       'Csr': 1522,
#       'PercentToNextTier': 0,
#       'Rank': None},
#      'Csr': {'Tier': 6,
#       'DesignationId': 5,
#       'Csr': 0,
#       'PercentToNextTier': 4,
#       'Rank': None},
#      'CsrPercentile': 6,
#      'TotalKills': 401,
#      'TotalHeadshots': 134,
#      'TotalWeaponDamage': 52718.959287166595,
#      'TotalShotsFired': 6325,
#      'TotalShotsLanded': 3097,
#      'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#        'Attachments': []},
#       'TotalShotsFired': 3406,
#       'TotalShotsLanded': 1713,
#       'TotalHeadshots': 104,
#       'TotalKills': 145,
#       'TotalDamageDealt': 26103.70299434662,
#       'TotalPossessionTime': 'PT2H30M29.7173S'},
#      'TotalMeleeKills': 52,
#      'TotalMeleeDamage': 3800.347092088312,
#      'TotalAssassinations': 5,
#      'TotalGroundPoundKills': 0,
#      'TotalGroundPoundDamage': 95.0,
#      'TotalShoulderBashKills': 12,
#      'TotalShoulderBashDamage': 1061.8759441375732,
#      'TotalGrenadeDamage': 4081.638895511627,
#      'TotalPowerWeaponKills': 116,
#      'TotalPowerWeaponDamage': 13761.484517097473,
#      'TotalPowerWeaponGrabs': 8,
#      'TotalPowerWeaponPossessionTime': 'PT53M22.0333S',
#      'TotalDeaths': 230,
#      'TotalAssists': 212,
#      'TotalGamesCompleted': 68,
#      'TotalGamesWon': 48,
#      'TotalGamesLost': 20,
#      'TotalGamesTied': 0,
#      'TotalTimePlayed': 'PT6H23M47.9943281S',
#      'TotalGrenadeKills': 14,
#      'MedalAwards': [{'MedalId': 3653057799, 'Count': 19},
#       {'MedalId': 3400287617, 'Count': 12},
#       {'MedalId': 68187090, 'Count': 1},
#       {'MedalId': 2287626681, 'Count': 43},
#       {'MedalId': 3925170236, 'Count': 8},
#       {'MedalId': 2430242797, 'Count': 16},
#       {'MedalId': 1212900805, 'Count': 11},
#       {'MedalId': 3698887726, 'Count': 6},
#       {'MedalId': 298813630, 'Count': 12},
#       {'MedalId': 3261908037, 'Count': 106},
#       {'MedalId': 2782465081, 'Count': 6},
#       {'MedalId': 2078758684, 'Count': 26},
#       {'MedalId': 1573153198, 'Count': 15},
#       {'MedalId': 824733727, 'Count': 23},
#       {'MedalId': 3894006667, 'Count': 5},
#       {'MedalId': 2838259753, 'Count': 23},
#       {'MedalId': 2763748638, 'Count': 4},
#       {'MedalId': 979431049, 'Count': 3},
#       {'MedalId': 3886151616, 'Count': 4},
#       {'MedalId': 3491849182, 'Count': 2},
#       {'MedalId': 2155964350, 'Count': 22},
#       {'MedalId': 2359847435, 'Count': 10},
#       {'MedalId': 3744028405, 'Count': 2},
#       {'MedalId': 3001183151, 'Count': 9},
#       {'MedalId': 1080468863, 'Count': 2},
#       {'MedalId': 2028249938, 'Count': 5},
#       {'MedalId': 250435527, 'Count': 9},
#       {'MedalId': 685960231, 'Count': 1},
#       {'MedalId': 352859864, 'Count': 2},
#       {'MedalId': 2299864088, 'Count': 2},
#       {'MedalId': 3270120991, 'Count': 5},
#       {'MedalId': 848240062, 'Count': 4},
#       {'MedalId': 3148489433, 'Count': 3},
#       {'MedalId': 3972445431, 'Count': 1},
#       {'MedalId': 3522125871, 'Count': 1},
#       {'MedalId': 1618319591, 'Count': 1},
#       {'MedalId': 194124164, 'Count': 1},
#       {'MedalId': 1423504140, 'Count': 1},
#       {'MedalId': 1326375333, 'Count': 3},
#       {'MedalId': 1494478183, 'Count': 1},
#       {'MedalId': 285057226, 'Count': 1},
#       {'MedalId': 1986137636, 'Count': 1}],
#      'DestroyedEnemyVehicles': [],
#      'EnemyKills': [],
#      'WeaponStats': [{'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#        'TotalShotsFired': 3406,
#        'TotalShotsLanded': 1713,
#        'TotalHeadshots': 104,
#        'TotalKills': 145,
#        'TotalDamageDealt': 26103.70299434662,
#        'TotalPossessionTime': 'PT2H30M29.7173S'},
#       {'WeaponId': {'StockId': 2244200496, 'Attachments': []},
#        'TotalShotsFired': 38,
#        'TotalShotsLanded': 17,
#        'TotalHeadshots': 1,
#        'TotalKills': 2,
#        'TotalDamageDealt': 247.49999904632568,
#        'TotalPossessionTime': 'PT3M54.0167S'},
#       {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#        'TotalShotsFired': 200,
#        'TotalShotsLanded': 157,
#        'TotalHeadshots': 0,
#        'TotalKills': 97,
#        'TotalDamageDealt': 11783.04758644104,
#        'TotalPossessionTime': 'PT47M38.1666S'},
#       {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#        'TotalShotsFired': 292,
#        'TotalShotsLanded': 211,
#        'TotalHeadshots': 0,
#        'TotalKills': 13,
#        'TotalDamageDealt': 3829.0493025779724,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 69,
#        'TotalDamageDealt': 4957.223036225885,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#        'TotalShotsFired': 365,
#        'TotalShotsLanded': 167,
#        'TotalHeadshots': 5,
#        'TotalKills': 10,
#        'TotalDamageDealt': 3355.361978530884,
#        'TotalPossessionTime': 'PT13M35.4339S'},
#       {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#        'TotalShotsFired': 309,
#        'TotalShotsLanded': 48,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 252.58959293365479,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#        'TotalShotsFired': 128,
#        'TotalShotsLanded': 97,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 301.7049980163574,
#        'TotalPossessionTime': 'PT17M31.8167S'},
#       {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#        'TotalShotsFired': 4,
#        'TotalShotsLanded': 3,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#        'TotalShotsFired': 635,
#        'TotalShotsLanded': 273,
#        'TotalHeadshots': 0,
#        'TotalKills': 21,
#        'TotalDamageDealt': 1995.135980606079,
#        'TotalPossessionTime': 'PT8M21.5501S'},
#       {'WeaponId': {'StockId': 2492868984, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT6.4332S'},
#       {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#        'TotalShotsFired': 29,
#        'TotalShotsLanded': 9,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 93.58186435699463,
#        'TotalPossessionTime': 'PT1M41.4167S'},
#       {'WeaponId': {'StockId': 642449794, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 4222743534, 'Attachments': []},
#        'TotalShotsFired': 699,
#        'TotalShotsLanded': 295,
#        'TotalHeadshots': 18,
#        'TotalKills': 21,
#        'TotalDamageDealt': 2590.4299240112305,
#        'TotalPossessionTime': 'PT7M37.9999S'},
#       {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#        'TotalShotsFired': 22,
#        'TotalShotsLanded': 10,
#        'TotalHeadshots': 1,
#        'TotalKills': 2,
#        'TotalDamageDealt': 282.0,
#        'TotalPossessionTime': 'PT27.65S'},
#       {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT16.9334S'},
#       {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#        'TotalShotsFired': 3,
#        'TotalShotsLanded': 2,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT14.3667S'},
#       {'WeaponId': {'StockId': 669296699, 'Attachments': []},
#        'TotalShotsFired': 7,
#        'TotalShotsLanded': 7,
#        'TotalHeadshots': 5,
#        'TotalKills': 5,
#        'TotalDamageDealt': 602.5,
#        'TotalPossessionTime': 'PT49.3999S'},
#       {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#        'TotalShotsFired': 11,
#        'TotalShotsLanded': 11,
#        'TotalHeadshots': 0,
#        'TotalKills': 7,
#        'TotalDamageDealt': 665.933012008667,
#        'TotalPossessionTime': 'PT1M5.05S'},
#       {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT8.9833S'},
#       {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT1.1167S'},
#       {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#        'TotalShotsFired': 177,
#        'TotalShotsLanded': 77,
#        'TotalHeadshots': 0,
#        'TotalKills': 6,
#        'TotalDamageDealt': 616.4220542907715,
#        'TotalPossessionTime': 'PT1M36.7S'}],
#      'Impulses': [{'Id': 3174430457, 'Count': 21},
#       {'Id': 4191318012, 'Count': 63},
#       {'Id': 3435524855, 'Count': 40},
#       {'Id': 3930101026, 'Count': 78},
#       {'Id': 540014008, 'Count': 245},
#       {'Id': 3060032974, 'Count': 260},
#       {'Id': 2512065773, 'Count': 43},
#       {'Id': 1039658009, 'Count': 26},
#       {'Id': 2944278681, 'Count': 9},
#       {'Id': 415845940, 'Count': 44},
#       {'Id': 2556889090, 'Count': 25},
#       {'Id': 2299858338, 'Count': 5},
#       {'Id': 4040349679, 'Count': 2},
#       {'Id': 3514632335, 'Count': 2},
#       {'Id': 938151029, 'Count': 6}],
#      'TotalSpartanKills': 401,
#      'FastestMatchWin': 'PT2M28.2423562S'},
#     {'PlaylistId': 'c98949ae-60a8-43dc-85d7-0feb0b92e719',
#      'MeasurementMatchesLeft': 8,
#      'HighestCsr': None,
#      'Csr': None,
#      'CsrPercentile': None,
#      'TotalKills': 13,
#      'TotalHeadshots': 5,
#      'TotalWeaponDamage': 1473.7513122558594,
#      'TotalShotsFired': 149,
#      'TotalShotsLanded': 67,
#      'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#        'Attachments': []},
#       'TotalShotsFired': 127,
#       'TotalShotsLanded': 57,
#       'TotalHeadshots': 5,
#       'TotalKills': 5,
#       'TotalDamageDealt': 1011.7531127929688,
#       'TotalPossessionTime': 'PT5M32.3002S'},
#      'TotalMeleeKills': 3,
#      'TotalMeleeDamage': 152.5,
#      'TotalAssassinations': 0,
#      'TotalGroundPoundKills': 0,
#      'TotalGroundPoundDamage': 0.0,
#      'TotalShoulderBashKills': 0,
#      'TotalShoulderBashDamage': 0.0,
#      'TotalGrenadeDamage': 69.85189819335938,
#      'TotalPowerWeaponKills': 3,
#      'TotalPowerWeaponDamage': 392.14630126953125,
#      'TotalPowerWeaponGrabs': 0,
#      'TotalPowerWeaponPossessionTime': 'PT52.7667S',
#      'TotalDeaths': 14,
#      'TotalAssists': 4,
#      'TotalGamesCompleted': 2,
#      'TotalGamesWon': 1,
#      'TotalGamesLost': 1,
#      'TotalGamesTied': 0,
#      'TotalTimePlayed': 'PT8M51.8336833S',
#      'TotalGrenadeKills': 2,
#      'MedalAwards': [{'MedalId': 3261908037, 'Count': 4},
#       {'MedalId': 3565443938, 'Count': 3},
#       {'MedalId': 2105198095, 'Count': 3},
#       {'MedalId': 1351381581, 'Count': 2},
#       {'MedalId': 2916014239, 'Count': 4},
#       {'MedalId': 3653057799, 'Count': 1},
#       {'MedalId': 2287626681, 'Count': 3}],
#      'DestroyedEnemyVehicles': [],
#      'EnemyKills': [],
#      'WeaponStats': [{'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#        'TotalShotsFired': 127,
#        'TotalShotsLanded': 57,
#        'TotalHeadshots': 5,
#        'TotalKills': 5,
#        'TotalDamageDealt': 1011.7531127929688,
#        'TotalPossessionTime': 'PT5M32.3002S'},
#       {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#        'TotalShotsFired': 3,
#        'TotalShotsLanded': 3,
#        'TotalHeadshots': 0,
#        'TotalKills': 2,
#        'TotalDamageDealt': 240.5,
#        'TotalPossessionTime': 'PT33.5333S'},
#       {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#        'TotalShotsFired': 9,
#        'TotalShotsLanded': 4,
#        'TotalHeadshots': 0,
#        'TotalKills': 2,
#        'TotalDamageDealt': 69.85189819335938,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT0.65S'},
#       {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 3,
#        'TotalDamageDealt': 152.5,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#        'TotalShotsFired': 1,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#        'TotalShotsFired': 8,
#        'TotalShotsLanded': 2,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 36.64630126953125,
#        'TotalPossessionTime': 'PT5.7834S'},
#       {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#        'TotalShotsFired': 1,
#        'TotalShotsLanded': 1,
#        'TotalHeadshots': 0,
#        'TotalKills': 1,
#        'TotalDamageDealt': 115.0,
#        'TotalPossessionTime': 'PT13.45S'}],
#      'Impulses': [{'Id': 3174430457, 'Count': 1}],
#      'TotalSpartanKills': 13,
#      'FastestMatchWin': 'PT5M19.0639897S'}],
#    'HighestCsrAttained': {'Tier': 1,
#     'DesignationId': 7,
#     'Csr': 1789,
#     'PercentToNextTier': 0,
#     'Rank': 112},
#    'ArenaGameBaseVariantStats': [{'FlexibleStats': {'MedalStatCounts': [{'Id': '2b151d0f-cde6-4471-9f1d-d0f8e8644471',
#         'Count': 1777},
#        {'Id': 'f0d50d01-6197-4d0d-a3a5-a86110997e40', 'Count': 933},
#        {'Id': 'dcd5ff64-4b49-4020-96d0-88ba3fb28a56', 'Count': 953},
#        {'Id': '74365be9-d515-4229-9561-bfaac5bab089', 'Count': 757}],
#       'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#         'Count': 3995},
#        {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 1702},
#        {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 3443},
#        {'Id': '780104cb-5b86-4ed9-8fb1-40b919de0766', 'Count': 108}],
#       'MedalTimelapses': [],
#       'ImpulseTimelapses': [{'Id': 'f1c317ee-1ac4-4089-85e8-a9c536c6cf18',
#         'Timelapse': 'P1DT17H46M8.5953303S'}]},
#      'GameBaseVariantId': '1571fdac-e0b4-4ebc-a73a-6e13001b71d3',
#      'TotalKills': 4020,
#      'TotalHeadshots': 1196,
#      'TotalWeaponDamage': 500852.06635510735,
#      'TotalShotsFired': 79011,
#      'TotalShotsLanded': 35357,
#      'WeaponWithMostKills': {'WeaponId': {'StockId': 4096745987,
#        'Attachments': []},
#       'TotalShotsFired': 22402,
#       'TotalShotsLanded': 10861,
#       'TotalHeadshots': 884,
#       'TotalKills': 1187,
#       'TotalDamageDealt': 195387.1124713421,
#       'TotalPossessionTime': 'PT13H48M14.9322S'},
#      'TotalMeleeKills': 506,
#      'TotalMeleeDamage': 62468.28360199928,
#      'TotalAssassinations': 114,
#      'TotalGroundPoundKills': 31,
#      'TotalGroundPoundDamage': 6455.208978176117,
#      'TotalShoulderBashKills': 18,
#      'TotalShoulderBashDamage': 3707.666271209717,
#      'TotalGrenadeDamage': 23534.57643392682,
#      'TotalPowerWeaponKills': 1212,
#      'TotalPowerWeaponDamage': 150385.8421651125,
#      'TotalPowerWeaponGrabs': 39,
#      'TotalPowerWeaponPossessionTime': 'PT6H35M40.0169S',
#      'TotalDeaths': 3443,
#      'TotalAssists': 1702,
#      'TotalGamesCompleted': 374,
#      'TotalGamesWon': 184,
#      'TotalGamesLost': 190,
#      'TotalGamesTied': 0,
#      'TotalTimePlayed': 'P1DT17H46M8.5953303S',
#      'TotalGrenadeKills': 113,
#      'MedalAwards': [{'MedalId': 3565443938, 'Count': 1777},
#       {'MedalId': 2838259753, 'Count': 264},
#       {'MedalId': 2782465081, 'Count': 73},
#       {'MedalId': 1351381581, 'Count': 953},
#       {'MedalId': 2916014239, 'Count': 933},
#       {'MedalId': 2287626681, 'Count': 376},
#       {'MedalId': 2078758684, 'Count': 335},
#       {'MedalId': 2105198095, 'Count': 757},
#       {'MedalId': 1637841390, 'Count': 250},
#       {'MedalId': 250435527, 'Count': 126},
#       {'MedalId': 3270120991, 'Count': 89},
#       {'MedalId': 824733727, 'Count': 179},
#       {'MedalId': 3400287617, 'Count': 250},
#       {'MedalId': 3261908037, 'Count': 1010},
#       {'MedalId': 2430242797, 'Count': 125},
#       {'MedalId': 370413844, 'Count': 6},
#       {'MedalId': 2896365521, 'Count': 52},
#       {'MedalId': 285057226, 'Count': 34},
#       {'MedalId': 3001183151, 'Count': 37},
#       {'MedalId': 3698887726, 'Count': 29},
#       {'MedalId': 2966496172, 'Count': 21},
#       {'MedalId': 492192256, 'Count': 31},
#       {'MedalId': 3653057799, 'Count': 82},
#       {'MedalId': 515648662, 'Count': 23},
#       {'MedalId': 3354395650, 'Count': 67},
#       {'MedalId': 2494364276, 'Count': 17},
#       {'MedalId': 1326375333, 'Count': 16},
#       {'MedalId': 298813630, 'Count': 18},
#       {'MedalId': 1080468863, 'Count': 15},
#       {'MedalId': 194124164, 'Count': 8},
#       {'MedalId': 2763748638, 'Count': 22},
#       {'MedalId': 3744028405, 'Count': 6},
#       {'MedalId': 3491849182, 'Count': 3},
#       {'MedalId': 2366628262, 'Count': 13},
#       {'MedalId': 2077162827, 'Count': 2},
#       {'MedalId': 2531822079, 'Count': 3},
#       {'MedalId': 1691836029, 'Count': 1},
#       {'MedalId': 3522125871, 'Count': 7},
#       {'MedalId': 2707871298, 'Count': 1},
#       {'MedalId': 2006781774, 'Count': 1},
#       {'MedalId': 352859864, 'Count': 21},
#       {'MedalId': 2251767925, 'Count': 9},
#       {'MedalId': 2766284219, 'Count': 4},
#       {'MedalId': 1618319591, 'Count': 2},
#       {'MedalId': 2683910456, 'Count': 6},
#       {'MedalId': 1792284502, 'Count': 7},
#       {'MedalId': 1219497744, 'Count': 1},
#       {'MedalId': 848240062, 'Count': 46},
#       {'MedalId': 2977773352, 'Count': 3},
#       {'MedalId': 3925170236, 'Count': 95},
#       {'MedalId': 3710519250, 'Count': 1},
#       {'MedalId': 2032512673, 'Count': 1},
#       {'MedalId': 2108880282, 'Count': 1},
#       {'MedalId': 4252521258, 'Count': 8},
#       {'MedalId': 3098362934, 'Count': 1},
#       {'MedalId': 1986137636, 'Count': 6},
#       {'MedalId': 3992195104, 'Count': 3},
#       {'MedalId': 3972445431, 'Count': 2},
#       {'MedalId': 882267095, 'Count': 5},
#       {'MedalId': 2279899989, 'Count': 1},
#       {'MedalId': 3148489433, 'Count': 3},
#       {'MedalId': 2564994165, 'Count': 2}],
#      'DestroyedEnemyVehicles': [{'Enemy': {'BaseId': 1063919886,
#         'Attachments': []},
#        'TotalKills': 23}],
#      'EnemyKills': [],
#      'WeaponStats': [{'WeaponId': {'StockId': 313138863, 'Attachments': []},
#        'TotalShotsFired': 14705,
#        'TotalShotsLanded': 6252,
#        'TotalHeadshots': 0,
#        'TotalKills': 302,
#        'TotalDamageDealt': 44173.87390112877,
#        'TotalPossessionTime': 'PT3H10M25.9507S'},
#       {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 669,
#        'TotalDamageDealt': 72631.15885138512,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 4096745987, 'Attachments': []},
#        'TotalShotsFired': 22402,
#        'TotalShotsLanded': 10861,
#        'TotalHeadshots': 884,
#        'TotalKills': 1187,
#        'TotalDamageDealt': 195387.1124713421,
#        'TotalPossessionTime': 'PT13H48M14.9322S'},
#       {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#        'TotalShotsFired': 7771,
#        'TotalShotsLanded': 3521,
#        'TotalHeadshots': 149,
#        'TotalKills': 197,
#        'TotalDamageDealt': 28790.988925218582,
#        'TotalPossessionTime': 'PT1H56M22.0159S'},
#       {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#        'TotalShotsFired': 1129,
#        'TotalShotsLanded': 519,
#        'TotalHeadshots': 42,
#        'TotalKills': 56,
#        'TotalDamageDealt': 10837.27057170868,
#        'TotalPossessionTime': 'PT47M34.8162S'},
#       {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#        'TotalShotsFired': 1832,
#        'TotalShotsLanded': 1192,
#        'TotalHeadshots': 0,
#        'TotalKills': 98,
#        'TotalDamageDealt': 21550.256593734026,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 3484334713, 'Attachments': []},
#        'TotalShotsFired': 297,
#        'TotalShotsLanded': 246,
#        'TotalHeadshots': 0,
#        'TotalKills': 171,
#        'TotalDamageDealt': 19911.12256169319,
#        'TotalPossessionTime': 'PT45M12.1498S'},
#       {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#        'TotalShotsFired': 1447,
#        'TotalShotsLanded': 596,
#        'TotalHeadshots': 0,
#        'TotalKills': 32,
#        'TotalDamageDealt': 5693.526090621948,
#        'TotalPossessionTime': 'PT14M27.8168S'},
#       {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#        'TotalShotsFired': 626,
#        'TotalShotsLanded': 335,
#        'TotalHeadshots': 34,
#        'TotalKills': 51,
#        'TotalDamageDealt': 8675.386605262756,
#        'TotalPossessionTime': 'PT33M33.6499S'},
#       {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#        'TotalShotsFired': 3651,
#        'TotalShotsLanded': 1271,
#        'TotalHeadshots': 0,
#        'TotalKills': 62,
#        'TotalDamageDealt': 9192.938420772552,
#        'TotalPossessionTime': 'PT30M21.5495S'},
#       {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#        'TotalShotsFired': 1844,
#        'TotalShotsLanded': 838,
#        'TotalHeadshots': 0,
#        'TotalKills': 93,
#        'TotalDamageDealt': 11626.484676361084,
#        'TotalPossessionTime': 'PT25M23.2836S'},
#       {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#        'TotalShotsFired': 178,
#        'TotalShotsLanded': 146,
#        'TotalHeadshots': 5,
#        'TotalKills': 104,
#        'TotalDamageDealt': 11002.534966111183,
#        'TotalPossessionTime': 'PT37M11.9831S'},
#       {'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#        'TotalShotsFired': 387,
#        'TotalShotsLanded': 109,
#        'TotalHeadshots': 0,
#        'TotalKills': 6,
#        'TotalDamageDealt': 951.7000170946121,
#        'TotalPossessionTime': 'PT6M26.1339S'},
#       {'WeaponId': {'StockId': 2492868984, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT2M3.7805S'},
#       {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#        'TotalShotsFired': 2245,
#        'TotalShotsLanded': 1018,
#        'TotalHeadshots': 0,
#        'TotalKills': 61,
#        'TotalDamageDealt': 10487.49755704403,
#        'TotalPossessionTime': 'PT30M39.3999S'},
#       {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#        'TotalShotsFired': 514,
#        'TotalShotsLanded': 253,
#        'TotalHeadshots': 0,
#        'TotalKills': 9,
#        'TotalDamageDealt': 3032.5869002342224,
#        'TotalPossessionTime': 'PT10M51.1332S'},
#       {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#        'TotalShotsFired': 264,
#        'TotalShotsLanded': 37,
#        'TotalHeadshots': 0,
#        'TotalKills': 4,
#        'TotalDamageDealt': 595.2819902896881,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 1609865982, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT2H20M47.2663S'},
#       {'WeaponId': {'StockId': 1063919886, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 24,
#        'TotalDamageDealt': 2910.2465109825134,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 47178948, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 11,
#        'TotalDamageDealt': 19.999998092651367,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#        'TotalShotsFired': 66,
#        'TotalShotsLanded': 39,
#        'TotalHeadshots': 0,
#        'TotalKills': 11,
#        'TotalDamageDealt': 1389.0378499031067,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#        'TotalShotsFired': 339,
#        'TotalShotsLanded': 290,
#        'TotalHeadshots': 0,
#        'TotalKills': 155,
#        'TotalDamageDealt': 17458.48706126213,
#        'TotalPossessionTime': 'PT38M19.6833S'},
#       {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#        'TotalShotsFired': 170,
#        'TotalShotsLanded': 108,
#        'TotalHeadshots': 0,
#        'TotalKills': 2,
#        'TotalDamageDealt': 4327.083476990461,
#        'TotalPossessionTime': 'PT16M13.7999S'},
#       {'WeaponId': {'StockId': 4222743534, 'Attachments': []},
#        'TotalShotsFired': 323,
#        'TotalShotsLanded': 173,
#        'TotalHeadshots': 6,
#        'TotalKills': 8,
#        'TotalDamageDealt': 1417.2379270475358,
#        'TotalPossessionTime': 'PT6M35.2165S'},
#       {'WeaponId': {'StockId': 4108759423, 'Attachments': []},
#        'TotalShotsFired': 309,
#        'TotalShotsLanded': 156,
#        'TotalHeadshots': 7,
#        'TotalKills': 15,
#        'TotalDamageDealt': 2141.7730102837086,
#        'TotalPossessionTime': 'PT10M52.3499S'},
#       {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#        'TotalShotsFired': 993,
#        'TotalShotsLanded': 393,
#        'TotalHeadshots': 0,
#        'TotalKills': 18,
#        'TotalDamageDealt': 2506.712289571762,
#        'TotalPossessionTime': 'PT9M4.2668S'},
#       {'WeaponId': {'StockId': 642449794, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 0.0,
#        'TotalPossessionTime': 'PT0S'},
#       {'WeaponId': {'StockId': 669296699, 'Attachments': []},
#        'TotalShotsFired': 122,
#        'TotalShotsLanded': 54,
#        'TotalHeadshots': 16,
#        'TotalKills': 25,
#        'TotalDamageDealt': 4178.9356689453125,
#        'TotalPossessionTime': 'PT16M0.5667S'},
#       {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#        'TotalShotsFired': 68,
#        'TotalShotsLanded': 62,
#        'TotalHeadshots': 0,
#        'TotalKills': 16,
#        'TotalDamageDealt': 2030.4067971110344,
#        'TotalPossessionTime': 'PT8M11.1837S'},
#       {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#        'TotalShotsFired': 630,
#        'TotalShotsLanded': 554,
#        'TotalHeadshots': 0,
#        'TotalKills': 31,
#        'TotalDamageDealt': 4057.7404108047485,
#        'TotalPossessionTime': 'PT13M52.7832S'},
#       {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#        'TotalShotsFired': 245,
#        'TotalShotsLanded': 92,
#        'TotalHeadshots': 0,
#        'TotalKills': 7,
#        'TotalDamageDealt': 771.571964263916,
#        'TotalPossessionTime': 'PT3M33.9169S'},
#       {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#        'TotalShotsFired': 300,
#        'TotalShotsLanded': 220,
#        'TotalHeadshots': 11,
#        'TotalKills': 24,
#        'TotalDamageDealt': 3266.1460510492325,
#        'TotalPossessionTime': 'PT12M34.6S'},
#       {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 59,
#        'TotalDamageDealt': 5763.878712654114,
#        'TotalPossessionTime': 'PT20M10.2001S'},
#       {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#        'TotalShotsFired': 176,
#        'TotalShotsLanded': 135,
#        'TotalHeadshots': 0,
#        'TotalKills': 19,
#        'TotalDamageDealt': 2956.0806663036346,
#        'TotalPossessionTime': 'PT8M41.2167S'},
#       {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#        'TotalShotsFired': 2982,
#        'TotalShotsLanded': 1313,
#        'TotalHeadshots': 0,
#        'TotalKills': 109,
#        'TotalDamageDealt': 14605.634553909302,
#        'TotalPossessionTime': 'PT30M32.1003S'},
#       {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#        'TotalShotsFired': 471,
#        'TotalShotsLanded': 194,
#        'TotalHeadshots': 0,
#        'TotalKills': 19,
#        'TotalDamageDealt': 2311.1767018437386,
#        'TotalPossessionTime': 'PT7M41.8832S'},
#       {'WeaponId': {'StockId': 723523180, 'Attachments': []},
#        'TotalShotsFired': 261,
#        'TotalShotsLanded': 232,
#        'TotalHeadshots': 0,
#        'TotalKills': 110,
#        'TotalDamageDealt': 13421.093387842178,
#        'TotalPossessionTime': 'PT25M27.5666S'},
#       {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#        'TotalShotsFired': 5783,
#        'TotalShotsLanded': 2106,
#        'TotalHeadshots': 0,
#        'TotalKills': 18,
#        'TotalDamageDealt': 3503.8653013706207,
#        'TotalPossessionTime': 'PT14M23.2329S'},
#       {'WeaponId': {'StockId': 2140505068, 'Attachments': []},
#        'TotalShotsFired': 4924,
#        'TotalShotsLanded': 1022,
#        'TotalHeadshots': 13,
#        'TotalKills': 51,
#        'TotalDamageDealt': 6574.678928375244,
#        'TotalPossessionTime': 'PT20M10.8333S'},
#       {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#        'TotalShotsFired': 118,
#        'TotalShotsLanded': 66,
#        'TotalHeadshots': 21,
#        'TotalKills': 34,
#        'TotalDamageDealt': 4877.919597625732,
#        'TotalPossessionTime': 'PT12M31.05S'},
#       {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#        'TotalShotsFired': 1247,
#        'TotalShotsLanded': 807,
#        'TotalHeadshots': 0,
#        'TotalKills': 129,
#        'TotalDamageDealt': 14108.14743423462,
#        'TotalPossessionTime': 'PT27M12.9831S'},
#       {'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#        'TotalShotsFired': 107,
#        'TotalShotsLanded': 95,
#        'TotalHeadshots': 0,
#        'TotalKills': 15,
#        'TotalDamageDealt': 2455.649806022644,
#        'TotalPossessionTime': 'PT7M43.7999S'},
#       {'WeaponId': {'StockId': 2758094302, 'Attachments': []},
#        'TotalShotsFired': 85,
#        'TotalShotsLanded': 52,
#        'TotalHeadshots': 8,
#        'TotalKills': 8,
#        'TotalDamageDealt': 1520.0,
#        'TotalPossessionTime': 'PT3M27.7334S'},
#       {'WeaponId': {'StockId': 2457457776, 'Attachments': []},
#        'TotalShotsFired': 0,
#        'TotalShotsLanded': 0,
#        'TotalHeadshots': 0,
#        'TotalKills': 0,
#        'TotalDamageDealt': 370.0,
#        'TotalPossessionTime': 'PT0S'}],
#      'Impulses': [{'Id': 2556889090, 'Count': 285},
#       {'Id': 3174430457, 'Count': 108},
#       {'Id': 1408036107, 'Count': 113},
#       {'Id': 3060032974, 'Count': 3}],
#      'TotalSpartanKills': 3995,
#      'FastestMatchWin': 'PT2M12.0207458S'},
#     {'FlexibleStats': {'MedalStatCounts': [{'Id': '10d1690e-9820-4d98-a7a6-361173370f40',
#         'Count': 351},
#        {'Id': 'f2d6cbeb-fbf6-44d5-b321-9edb8cb2e3bc', 'Count': 27}],
#       'ImpulseStatCounts': [{'Id': 'ba327946-418c-495d-90c0-89f084bf7447',
#         'Count': 15662},
#        {'Id': '7dcd7306-f905-401a-97f2-345d4b25170a', 'Count': 7710},
#        {'Id': 'ea38d25f-d887-4bdf-b17b-8e8e649b9a87', 'Count': 10628},
#        {'Id': '3465eba1-608c-47d7-9cb6-ef4c7a55a2dd', 'Count': 6164},
#        {'Id': '7cda10c8-04c4-4916-8d6e-71a426a61de8', 'Count': 300},
#        {'Id': '6e1e4e2c-1a57-4f64-a893-f594974b3f1f', 'Count': 387},
#        {'Id': '5262f1d7-4273-48c3-8d2f-edfcb36a1617', 'Count': 2447},
#        {'Id': '53ea3e8c-ac2a-4644-b6e2-4ac45e721cca', 'Count': 1572},
#        {'Id': 'ded6e97f-575a-4511-833b-62bf5489a2c1', 'Count': 8180},
#        {'Id': 'f12a007b-3f27-45a1-87f5-816b6aca060d', 'Count': 81}],
# ...
#     {'WeaponId': {'StockId': 523953283, 'Attachments': []},
#      'TotalShotsFired': 49887,
#      'TotalShotsLanded': 24768,
#      'TotalHeadshots': 3742,
#      'TotalKills': 4790,
#      'TotalDamageDealt': 529728.7798190713,
#      'TotalPossessionTime': 'P1DT18H12M16.7299S'},
#     {'WeaponId': {'StockId': 3168248199, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 20786,
#      'TotalDamageDealt': 1881878.043956589,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 4222743534, 'Attachments': []},
#      'TotalShotsFired': 156271,
#      'TotalShotsLanded': 73303,
#      'TotalHeadshots': 5777,
#      'TotalKills': 6469,
#      'TotalDamageDealt': 676663.7631220184,
#      'TotalPossessionTime': 'P1DT23H9M37.314S'},
#     {'WeaponId': {'StockId': 313138863, 'Attachments': []},
#      'TotalShotsFired': 333605,
#      'TotalShotsLanded': 143030,
#      'TotalHeadshots': 0,
#      'TotalKills': 7753,
#      'TotalDamageDealt': 1003158.1814604625,
#      'TotalPossessionTime': 'P3DT7H35M13.2346S'},
#     {'WeaponId': {'StockId': 2133511419, 'Attachments': []},
#      'TotalShotsFired': 99076,
#      'TotalShotsLanded': 40589,
#      'TotalHeadshots': 0,
#      'TotalKills': 2323,
#      'TotalDamageDealt': 391208.6356304586,
#      'TotalPossessionTime': 'PT21H17M4.6721S'},
#     {'WeaponId': {'StockId': 3682788176, 'Attachments': []},
#      'TotalShotsFired': 16955,
#      'TotalShotsLanded': 13264,
#      'TotalHeadshots': 554,
#      'TotalKills': 10017,
#      'TotalDamageDealt': 1148918.3489592574,
#      'TotalPossessionTime': 'P2DT3H50M3.9362S'},
#     {'WeaponId': {'StockId': 1390323522, 'Attachments': []},
#      'TotalShotsFired': 11088,
#      'TotalShotsLanded': 9625,
#      'TotalHeadshots': 0,
#      'TotalKills': 2536,
#      'TotalDamageDealt': 352876.58369669644,
#      'TotalPossessionTime': 'PT21H25M20.0501S'},
#     {'WeaponId': {'StockId': 424645655, 'Attachments': []},
#      'TotalShotsFired': 217135,
#      'TotalShotsLanded': 94125,
#      'TotalHeadshots': 6829,
#      'TotalKills': 7730,
#      'TotalDamageDealt': 827376.5069807451,
#      'TotalPossessionTime': 'P2DT21H58M12.3187S'},
#     {'WeaponId': {'StockId': 2681172411, 'Attachments': []},
#      'TotalShotsFired': 69703,
#      'TotalShotsLanded': 32109,
#      'TotalHeadshots': 0,
#      'TotalKills': 1529,
#      'TotalDamageDealt': 209566.02675035596,
#      'TotalPossessionTime': 'PT13H54M39.2826S'},
#     {'WeaponId': {'StockId': 907086443, 'Attachments': []},
#      'TotalShotsFired': 55942,
#      'TotalShotsLanded': 38320,
#      'TotalHeadshots': 2985,
#      'TotalKills': 5298,
#      'TotalDamageDealt': 710220.5719734281,
#      'TotalPossessionTime': 'P1DT7H20M12.4503S'},
#     {'WeaponId': {'StockId': 2862629816, 'Attachments': []},
#      'TotalShotsFired': 15820,
#      'TotalShotsLanded': 7231,
#      'TotalHeadshots': 2644,
#      'TotalKills': 3816,
#      'TotalDamageDealt': 534345.0783450287,
#      'TotalPossessionTime': 'P1DT1H15M15.8302S'},
#     {'WeaponId': {'StockId': 3143603656, 'Attachments': []},
#      'TotalShotsFired': 412239,
#      'TotalShotsLanded': 145205,
#      'TotalHeadshots': 0,
#      'TotalKills': 1459,
#      'TotalDamageDealt': 238378.10350215435,
#      'TotalPossessionTime': 'PT14H24M43.9837S'},
#     {'WeaponId': {'StockId': 4108759423, 'Attachments': []},
#      'TotalShotsFired': 41690,
#      'TotalShotsLanded': 21920,
#      'TotalHeadshots': 1390,
#      'TotalKills': 1975,
#      'TotalDamageDealt': 296726.97887402587,
#      'TotalPossessionTime': 'PT21H49M31.0632S'},
#     {'WeaponId': {'StockId': 1579758889, 'Attachments': []},
#      'TotalShotsFired': 15711,
#      'TotalShotsLanded': 11045,
#      'TotalHeadshots': 0,
#      'TotalKills': 1629,
#      'TotalDamageDealt': 239718.00792281143,
#      'TotalPossessionTime': 'PT14H31M18.3344S'},
#     {'WeaponId': {'StockId': 2902827823, 'Attachments': []},
#      'TotalShotsFired': 27064,
#      'TotalShotsLanded': 21128,
#      'TotalHeadshots': 0,
#      'TotalKills': 10030,
#      'TotalDamageDealt': 1181952.9254407277,
#      'TotalPossessionTime': 'P1DT19H20M27.4167S'},
#     {'WeaponId': {'StockId': 2050745863, 'Attachments': []},
#      'TotalShotsFired': 37549,
#      'TotalShotsLanded': 13121,
#      'TotalHeadshots': 0,
#      'TotalKills': 1146,
#      'TotalDamageDealt': 131540.45438030362,
#      'TotalPossessionTime': 'PT9H57M16.5858S'},
#     {'WeaponId': {'StockId': 723523180, 'Attachments': []},
#      'TotalShotsFired': 29314,
#      'TotalShotsLanded': 25070,
#      'TotalHeadshots': 0,
#      'TotalKills': 12101,
#      'TotalDamageDealt': 1403444.2936725027,
#      'TotalPossessionTime': 'P2DT34M33.2855S'},
#     {'WeaponId': {'StockId': 723388907, 'Attachments': []},
#      'TotalShotsFired': 102202,
#      'TotalShotsLanded': 37201,
#      'TotalHeadshots': 0,
#      'TotalKills': 1915,
#      'TotalDamageDealt': 246929.17362445593,
#      'TotalPossessionTime': 'PT23H3M55.9345S'},
#     {'WeaponId': {'StockId': 4153405209, 'Attachments': []},
#      'TotalShotsFired': 93118,
#      'TotalShotsLanded': 41821,
#      'TotalHeadshots': 0,
#      'TotalKills': 2999,
#      'TotalDamageDealt': 439320.89624381065,
#      'TotalPossessionTime': 'P1DT58M16.6967S'},
#     {'WeaponId': {'StockId': 2650887244, 'Attachments': []},
#      'TotalShotsFired': 4419,
#      'TotalShotsLanded': 3747,
#      'TotalHeadshots': 0,
#      'TotalKills': 7654,
#      'TotalDamageDealt': 794415.6651499122,
#      'TotalPossessionTime': 'P1DT19H16M57.816S'},
#     {'WeaponId': {'StockId': 4086418184, 'Attachments': []},
#      'TotalShotsFired': 109950,
#      'TotalShotsLanded': 64092,
#      'TotalHeadshots': 0,
#      'TotalKills': 10137,
#      'TotalDamageDealt': 1174988.3795013428,
#      'TotalPossessionTime': 'P1DT12H25M10.516S'},
#     {'WeaponId': {'StockId': 2140505068, 'Attachments': []},
#      'TotalShotsFired': 553280,
#      'TotalShotsLanded': 134785,
#      'TotalHeadshots': 3157,
#      'TotalKills': 7288,
#      'TotalDamageDealt': 969377.7277357262,
#      'TotalPossessionTime': 'P1DT17H23.9504S'},
#     {'WeaponId': {'StockId': 2015271382, 'Attachments': []},
#      'TotalShotsFired': 26730,
#      'TotalShotsLanded': 12841,
#      'TotalHeadshots': 0,
#      'TotalKills': 294,
#      'TotalDamageDealt': 150053.05589655042,
#      'TotalPossessionTime': 'PT10H42M8.8962S'},
#     {'WeaponId': {'StockId': 4054937266, 'Attachments': []},
#      'TotalShotsFired': 74023,
#      'TotalShotsLanded': 23737,
#      'TotalHeadshots': 0,
#      'TotalKills': 2352,
#      'TotalDamageDealt': 340974.2222749839,
#      'TotalPossessionTime': 'PT17H10M32.5027S'},
#     {'WeaponId': {'StockId': 2670072722, 'Attachments': []},
#      'TotalShotsFired': 10649,
#      'TotalShotsLanded': 8874,
#      'TotalHeadshots': 0,
#      'TotalKills': 2485,
#      'TotalDamageDealt': 310440.39480503846,
#      'TotalPossessionTime': 'PT14H22M43.8988S'},
#     {'WeaponId': {'StockId': 2278207101, 'Attachments': []},
#      'TotalShotsFired': 343671,
#      'TotalShotsLanded': 146527,
#      'TotalHeadshots': 0,
#      'TotalKills': 11145,
#      'TotalDamageDealt': 1505496.6145395786,
#      'TotalPossessionTime': 'P2DT10H38M29.9833S'},
#     {'WeaponId': {'StockId': 2899979324, 'Attachments': []},
#      'TotalShotsFired': 74966,
#      'TotalShotsLanded': 61502,
#      'TotalHeadshots': 0,
#      'TotalKills': 4885,
#      'TotalDamageDealt': 580072.8239779416,
#      'TotalPossessionTime': 'P1DT4H5M51.099S'},
#     {'WeaponId': {'StockId': 4106030681, 'Attachments': []},
#      'TotalShotsFired': 66146,
#      'TotalShotsLanded': 41164,
#      'TotalHeadshots': 0,
#      'TotalKills': 3459,
#      'TotalDamageDealt': 820784.2858174226,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2758094302, 'Attachments': []},
#      'TotalShotsFired': 27205,
#      'TotalShotsLanded': 13599,
#      'TotalHeadshots': 3338,
#      'TotalKills': 3964,
#      'TotalDamageDealt': 373630.29210567474,
#      'TotalPossessionTime': 'P1DT4H9M52.8834S'},
#     {'WeaponId': {'StockId': 524558978, 'Attachments': []},
#      'TotalShotsFired': 10479,
#      'TotalShotsLanded': 5951,
#      'TotalHeadshots': 0,
#      'TotalKills': 245,
#      'TotalDamageDealt': 182925.92852115585,
#      'TotalPossessionTime': 'PT16H2M53.4816S'},
#     {'WeaponId': {'StockId': 3808094875, 'Attachments': []},
#      'TotalShotsFired': 83952,
#      'TotalShotsLanded': 35627,
#      'TotalHeadshots': 0,
#      'TotalKills': 3801,
#      'TotalDamageDealt': 494716.9092615247,
#      'TotalPossessionTime': 'PT23H17M57.1785S'},
#     {'WeaponId': {'StockId': 3885603197, 'Attachments': []},
#      'TotalShotsFired': 81796,
#      'TotalShotsLanded': 21498,
#      'TotalHeadshots': 0,
#      'TotalKills': 1610,
#      'TotalDamageDealt': 211609.7801451683,
#      'TotalPossessionTime': 'PT11H40M28.3681S'},
#     {'WeaponId': {'StockId': 2492868984, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT1H7M34.2438S'},
#     {'WeaponId': {'StockId': 2988661926, 'Attachments': []},
#      'TotalShotsFired': 2781,
#      'TotalShotsLanded': 1025,
#      'TotalHeadshots': 0,
#      'TotalKills': 52,
#      'TotalDamageDealt': 10199.207462310791,
#      'TotalPossessionTime': 'PT21M24.25S'},
#     {'WeaponId': {'StockId': 2511447508, 'Attachments': []},
#      'TotalShotsFired': 54974,
#      'TotalShotsLanded': 29497,
#      'TotalHeadshots': 2743,
#      'TotalKills': 4726,
#      'TotalDamageDealt': 746103.4150521159,
#      'TotalPossessionTime': 'P1DT18H46M24.1001S'},
#     {'WeaponId': {'StockId': 2244200496, 'Attachments': []},
#      'TotalShotsFired': 4600,
#      'TotalShotsLanded': 2034,
#      'TotalHeadshots': 176,
#      'TotalKills': 238,
#      'TotalDamageDealt': 35489.12727570534,
#      'TotalPossessionTime': 'PT6H35M45.3S'},
#     {'WeaponId': {'StockId': 47178948, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 251,
#      'TotalDamageDealt': 1356.7413923740387,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2460880172, 'Attachments': []},
#      'TotalShotsFired': 6685,
#      'TotalShotsLanded': 3840,
#      'TotalHeadshots': 0,
#      'TotalKills': 1105,
#      'TotalDamageDealt': 189022.90013977885,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 3190813201, 'Attachments': []},
#      'TotalShotsFired': 39775,
#      'TotalShotsLanded': 6043,
#      'TotalHeadshots': 0,
#      'TotalKills': 406,
#      'TotalDamageDealt': 67339.1376426376,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 393532233, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 49,
#      'TotalDamageDealt': 6710.608402816579,
#      'TotalPossessionTime': 'PT2H28M55.8312S'},
#     {'WeaponId': {'StockId': 409331533, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 78,
#      'TotalDamageDealt': 9679.955957174301,
#      'TotalPossessionTime': 'PT2H1M7.9333S'},
#     {'WeaponId': {'StockId': 1259783693, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT35M44.2167S'},
#     {'WeaponId': {'StockId': 1063919886, 'Attachments': []},
#      'TotalShotsFired': 9,
#      'TotalShotsLanded': 4,
#      'TotalHeadshots': 0,
#      'TotalKills': 25,
#      'TotalDamageDealt': 3344.7039980888367,
#      'TotalPossessionTime': 'PT22.6333S'},
#     {'WeaponId': {'StockId': 4028516791, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 6,
#      'TotalDamageDealt': 2106.5131072998047,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 642449794, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 29.273183822631836,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 2907783784, 'Attachments': []},
#      'TotalShotsFired': 185,
#      'TotalShotsLanded': 108,
#      'TotalHeadshots': 0,
#      'TotalKills': 14,
#      'TotalDamageDealt': 2679.4057426452637,
#      'TotalPossessionTime': 'PT3M55.6167S'},
#     {'WeaponId': {'StockId': 1609865982, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 0.0,
#      'TotalPossessionTime': 'PT2H22M48.383S'},
#     {'WeaponId': {'StockId': 3227919741, 'Attachments': []},
#      'TotalShotsFired': 15586,
#      'TotalShotsLanded': 6609,
#      'TotalHeadshots': 0,
#      'TotalKills': 229,
#      'TotalDamageDealt': 94741.98134076595,
#      'TotalPossessionTime': 'PT2H36M3.9169S'},
#     {'WeaponId': {'StockId': 1206711506, 'Attachments': []},
#      'TotalShotsFired': 78,
#      'TotalShotsLanded': 46,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 1144.5907192230225,
#      'TotalPossessionTime': 'PT1M12.4333S'},
#     {'WeaponId': {'StockId': 3010146366, 'Attachments': []},
#      'TotalShotsFired': 4934,
#      'TotalShotsLanded': 1141,
#      'TotalHeadshots': 0,
#      'TotalKills': 72,
#      'TotalDamageDealt': 15324.30478644371,
#      'TotalPossessionTime': 'PT55M7.6164S'},
#     {'WeaponId': {'StockId': 1749823285, 'Attachments': []},
#      'TotalShotsFired': 203,
#      'TotalShotsLanded': 28,
#      'TotalHeadshots': 0,
#      'TotalKills': 4,
#      'TotalDamageDealt': 1440.897964477539,
#      'TotalPossessionTime': 'PT2M26.3168S'},
#     {'WeaponId': {'StockId': 1730553442, 'Attachments': []},
#      'TotalShotsFired': 132,
#      'TotalShotsLanded': 48,
#      'TotalHeadshots': 0,
#      'TotalKills': 6,
#      'TotalDamageDealt': 1527.4526672363281,
#      'TotalPossessionTime': 'PT2M7.6833S'},
#     {'WeaponId': {'StockId': 3207900961, 'Attachments': []},
#      'TotalShotsFired': 1206,
#      'TotalShotsLanded': 401,
#      'TotalHeadshots': 0,
#      'TotalKills': 9,
#      'TotalDamageDealt': 1374.5125741958618,
#      'TotalPossessionTime': 'PT5M14.2166S'},
#     {'WeaponId': {'StockId': 3218397906, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 2.314465045928955,
#      'TotalPossessionTime': 'PT0S'},
#     {'WeaponId': {'StockId': 419783896, 'Attachments': []},
#      'TotalShotsFired': 26,
#      'TotalShotsLanded': 3,
#      'TotalHeadshots': 0,
#      'TotalKills': 2,
#      'TotalDamageDealt': 244.0,
#      'TotalPossessionTime': 'PT32.65S'},
#     {'WeaponId': {'StockId': 4233134183, 'Attachments': []},
#      'TotalShotsFired': 899,
#      'TotalShotsLanded': 82,
#      'TotalHeadshots': 0,
#      'TotalKills': 38,
#      'TotalDamageDealt': 5053.787853240967,
#      'TotalPossessionTime': 'PT10M17.1832S'},
#     {'WeaponId': {'StockId': 2457457776, 'Attachments': []},
#      'TotalShotsFired': 0,
#      'TotalShotsLanded': 0,
#      'TotalHeadshots': 0,
#      'TotalKills': 0,
#      'TotalDamageDealt': 370.0,
#      'TotalPossessionTime': 'PT0S'}],
#    'Impulses': [{'Id': 2556889090, 'Count': 13202},
#     {'Id': 1408036107, 'Count': 1240},
#     {'Id': 3174430457, 'Count': 4187},
#     {'Id': 540014008, 'Count': 7348},
#     {'Id': 4191318012, 'Count': 6317},
#     {'Id': 3060032974, 'Count': 8284},
#     {'Id': 415845940, 'Count': 2046},
#     {'Id': 1039658009, 'Count': 2212},
#     {'Id': 3435524855, 'Count': 4770},
#     {'Id': 3514632335, 'Count': 262},
#     {'Id': 2944278681, 'Count': 1118},
#     {'Id': 938151029, 'Count': 507},
#     {'Id': 2512065773, 'Count': 1572},
#     {'Id': 2299858338, 'Count': 1524},
#     {'Id': 3930101026, 'Count': 2447},
#     {'Id': 4040349679, 'Count': 65},
#     {'Id': 588422610, 'Count': 19849},
#     {'Id': 2192206750, 'Count': 420},
#     {'Id': 2664358695, 'Count': 38},
#     {'Id': 365321763, 'Count': 176},
#     {'Id': 472607776, 'Count': 48},
#     {'Id': 2483589021, 'Count': 8682},
#     {'Id': 1063951891, 'Count': 821}],
#    'TotalSpartanKills': 239870,
#    'FastestMatchWin': 'PT24.3252034S'},
#   'PlayerId': {'Gamertag': 'supersaiyan245', 'Xuid': None},
#   'SpartanRank': 152,
#   'Xp': 52957173}}

# %%
variant_id = match_results['GameBaseVariantId']

def build_history_dataframe(player_history, variant_id):
    vdf_columns = [
        'Gamertag',
        'TotalTimePlayed',
        'K/D',
        'Accuracy',
        'WinRate',
    ]

    vdf = pd.DataFrame(columns = vdf_columns)

    i = 0
    for player in player_history['Results']:
        for variant in player['Result']['ArenaStats']['ArenaGameBaseVariantStats']:
            if variant['GameBaseVariantId'] == variant_id:
                variant_stats = variant

        variant_dic = {}
        variant_dic['Gamertag'] = player_history['Results'][i]['Id']
        variant_dic['TotalTimePlayed']= isodate.parse_duration(variant_stats['TotalTimePlayed']).total_seconds() / 3600
        variant_dic['K/D'] = variant_stats['TotalKills'] / variant_stats['TotalDeaths']
        variant_dic['Accuracy'] = variant_stats['TotalShotsLanded'] / variant_stats['TotalShotsFired']
        variant_dic['WinRate'] = variant_stats['TotalGamesWon'] / variant_stats['TotalGamesLost']
        vdf = vdf.append(variant_dic, True)

        i += 1
        
    return vdf
    
build_history_dataframe(player_history, variant_id)
# Out:
#           Gamertag  TotalTimePlayed       K/D  Accuracy   WinRate
# 0      Dirus Lupus       564.478813  1.773653  0.504621  1.967742
# 1   supersaiyan245      1532.363462  1.542768  0.431750  2.368981
# 2        Drymander       289.925244  1.026587  0.320711  0.995902
# 3      J05EY WALES      3056.421148  1.180664  0.378598  1.894084
# 4  XxMegaManxX8196       269.611740  1.803473  0.329155  1.196687
# 5    TyrannicJonas       427.144771  0.900749  0.324151  1.102951
# 6          Kal LP2       460.744407  1.123812  0.365570  0.995134
# 7    LIL CALIFOOYA         7.939559  1.066826  0.366143  0.780488

# %% [markdown]
# # Merge Match and Game Variant Dataframes

# %%
df_stats = pd.merge(df_match, vdf, how='inner', on = 'Gamertag')

df_stats
# Out:
#   TeamId   Winner TeamColor         Gamertag SpartanRank PrevTotalXP  \
# 0      1  Victory      Blue      Dirus Lupus         149    22705290
# 1      1  Victory      Blue   supersaiyan245         152    52942362
# 2      1  Victory      Blue        Drymander         148    15159025
# 3      1  Victory      Blue      J05EY WALES         152    84606732
# 4      0   Defeat       Red  XxMegaManxX8196         149    22508753
# 5      0   Defeat       Red    TyrannicJonas         147    12510383
# 6      0   Defeat       Red          Kal LP2         152    59105130
# 7      0   Defeat       Red    LIL CALIFOOYA          36      441397
#
#    TotalTimePlayed       K/D  Accuracy   WinRate
# 0       564.478813  1.773653  0.504621  1.967742
# 1      1532.363462  1.542768  0.431750  2.368981
# 2       289.925244  1.026587  0.320711  0.995902
# 3      3056.421148  1.180664  0.378598  1.894084
# 4       269.611740  1.803473  0.329155  1.196687
# 5       427.144771  0.900749  0.324151  1.102951
# 6       460.744407  1.123812  0.365570  0.995134
# 7         7.939559  1.066826  0.366143  0.780488

# %%
# player_df_spartanrank = player_df.copy()

row_count = 0

for match in tqdm(match_details):
# for match in tqdm(mds):
    
#     try:
        data = match
        df_match = pd.DataFrame()
        columns = [
            'TeamId',
            'Gamertag',
            'SpartanRank',
            'PrevTotalXP',
        ]
        df_match = pd.DataFrame(columns = columns)
        i = 0

        if len(data['PlayerStats']) != 8:
            continue

        for player in data['PlayerStats']:

            player_dic = {}
            # Team ID
            player_dic['TeamId'] = data['PlayerStats'][i]['TeamId']
            if player_dic['TeamId'] not in (0, 1):
                continue
            # Gamer Tag
            player_dic['Gamertag'] = data['PlayerStats'][i]['Player']['Gamertag']
            # Spartan Rank
            player_dic['SpartanRank'] = data['PlayerStats'][i]['XpInfo']['SpartanRank']
            # Previous Total XP
            player_dic['PrevTotalXP'] = data['PlayerStats'][i]['XpInfo']['PrevTotalXP']
            df_match = df_match.append(player_dic, ignore_index=True)
            i += 1

            playerteam = df_match.loc[df_match['Gamertag'] == user, 'TeamId'].values[0]

            if data['TeamStats'][0]['Rank'] == 1:
                winner = 0
            else: winner = 1

            if winner == playerteam:
                player_win = 1
            else:
                player_win = 0
            
        player_df = df_match.loc[df_match['TeamId'] == playerteam]
        enemy_df = df_match.loc[df_match['TeamId'] != playerteam]

        row_list = []
        row_list.append(match['MatchId'])
        row_list.append(player_win)
        for row in range(len(player_df)):
            row_list.extend(list(player_df.iloc[row].values[1:]))
        for row in range(len(enemy_df)):
            row_list.extend(list(enemy_df.iloc[row].values[1:]))

        match_details_df.loc[row_count] = row_list
#         print(row_list)
        row_count += 1
 
#     except:
#         continue
    
match_details_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-286-74a736435196> in <module>
#       3 row_count = 0
#       4
# ----> 5 for match in tqdm(match_details):
#       6 # for match in tqdm(mds):
#       7
#
# NameError: name 'match_details' is not defined

# %% [markdown]
# # Unused Code

# %%
for variant in players_stats['Results'][0]['Result']['ArenaStats']['ArenaGameBaseVariantStats']:
    if variant['GameBaseVariantId'] == variant_id:
        variant_stats = variant
    else:
        continue
        
variant_stats['TotalKills']

# %% [markdown]
# ## All stats

# %%
# pip install isodate

import isodate

variant_dic = {}
variant_dic['Gamertag'] = players_stats['Results'][0]['Id']
variant_dic['TotalTimePlayed']= isodate.parse_duration(variant_stats['TotalTimePlayed']).total_seconds() / 3600
variant_dic['K/D'] = variant_stats['TotalKills'] / variant_stats['TotalDeaths']
variant_dic['Accuracy'] = variant_stats['TotalShotsLanded'] / variant_stats['TotalShotsFired']
variant_dic['WinRate'] = variant_stats['TotalGamesWon'] / variant_stats['TotalGamesLost']

variant_dic

# %%
vdf.append(variant_dic, ignore_index=True)

# %% [markdown]
# ## Additional Player History Stats

# %%
# variant_dic['TotalHeadshots']= variant_stats['TotalHeadshots']
# variant_dic['TotalWeaponDamage']= variant_stats['TotalWeaponDamage']
# variant_dic['TotalShotsFired']= variant_stats['TotalShotsFired']
# variant_dic['TotalShotsLanded']= variant_stats['TotalShotsLanded']
# variant_dic['TotalMeleeKills']= variant_stats['TotalMeleeKills']
# variant_dic['TotalMeleeDamage']= variant_stats['TotalMeleeDamage']
# variant_dic['TotalAssassinations']= variant_stats['TotalAssassinations']
# variant_dic['TotalGroundPoundKills']= variant_stats['TotalGroundPoundKills']
# variant_dic['TotalGroundPoundDamage']= variant_stats['TotalGroundPoundDamage']
# variant_dic['TotalShoulderBashKills']= variant_stats['TotalShoulderBashKills']
# variant_dic['TotalShoulderBashDamage']= variant_stats['TotalShoulderBashDamage']
# variant_dic['TotalGrenadeDamage']= variant_stats['TotalGrenadeDamage']
# variant_dic['TotalPowerWeaponKills']= variant_stats['TotalPowerWeaponKills']
# variant_dic['TotalPowerWeaponDamage']= variant_stats['TotalPowerWeaponDamage']
# variant_dic['TotalPowerWeaponGrabs']= variant_stats['TotalPowerWeaponGrabs']
# variant_dic['TotalPowerWeaponPossessionTime']= isodate.parse_duration(variant_stats['TotalPowerWeaponPossessionTime']).total_seconds() / 3600
# variant_dic['TotalDeaths']= variant_stats['TotalDeaths']
# variant_dic['TotalAssists']= variant_stats['TotalAssists']
# variant_dic['TotalGamesCompleted']= variant_stats['TotalGamesCompleted']
# variant_dic['TotalGamesWon']= variant_stats['TotalGamesWon']
# variant_dic['TotalGamesLost']= variant_stats['TotalGamesLost']
# variant_dic['TotalGamesTied']= variant_stats['TotalGamesTied']
# variant_dic['TotalGrenadeKills']= variant_stats['TotalGrenadeKills']
# variant_dic['TotalKills']= variant_stats['TotalKills']

# %% [markdown]
# ## Build base match dataframe from pull_recent_match

# %%
match_results = pull_recent_match(2494)

i = 0

df_match = pd.DataFrame()
columns = [
    'TeamId',
    'Gamertag',
    'SpartanRank',
    'PrevTotalXP',
]
df_match = pd.DataFrame(columns = columns)

for player in match_results['PlayerStats']:

    player_dic = {}
    # Team ID
    player_dic['TeamId'] = match_results['PlayerStats'][i]['TeamId']
    # Gamer Tag
    player_dic['Gamertag'] = match_results['PlayerStats'][i]['Player']['Gamertag']
    # Spartan Rank
    player_dic['SpartanRank'] = match_results['PlayerStats'][i]['XpInfo']['SpartanRank']
    # Previous Total XP
    player_dic['PrevTotalXP'] = match_results['PlayerStats'][i]['XpInfo']['PrevTotalXP']
    df_match = df_match.append(player_dic, ignore_index=True)
    i += 1

# Define winner

playerteam = df_match.loc[df_match['Gamertag'] == user, 'TeamId'].values[0]

if match_results['TeamStats'][0]['TeamId'] == playerteam:
    playerteam_stats = match_results['TeamStats'][0]
    enemyteam_stats = match_results['TeamStats'][1]
else: 
    playerteam_stats = match_results['TeamStats'][1]
    enemyteam_stats = match_results['TeamStats'][0]

print(playerteam_stats['Rank'])
print(enemyteam_stats['Rank'])

# Tie
if playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 1:
    winner = 'Tie'
# Player wins
elif playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 2:
    winner = 'Player'
# Enemy wins
elif playerteam_stats['Rank'] == 2 and enemyteam_stats['Rank'] == 1:
    winner = 'Enemy'
# Error handling
else:
    winner = 'Error determining winner'

print(f'{winner} won the game')

df_match

# %% [markdown]
# ## Player History Base Code

# %%
vdf_columns = [
    'Gamertag',
    'TotalTimePlayed',
    'K/D',
    'Accuracy',
    'WinRate',
]

vdf = pd.DataFrame(columns = vdf_columns)

i = 0

for player in player_history['Results']:

    
    for variant in player['Result']['ArenaStats']['ArenaGameBaseVariantStats']:
        if variant['GameBaseVariantId'] == variant_id:
            variant_stats = variant
#         else:
#             continue
            
    variant_dic = {}
    variant_dic['Gamertag'] = player_history['Results'][i]['Id']
    variant_dic['TotalTimePlayed']= isodate.parse_duration(variant_stats['TotalTimePlayed']).total_seconds() / 3600
    variant_dic['K/D'] = variant_stats['TotalKills'] / variant_stats['TotalDeaths']
    variant_dic['Accuracy'] = variant_stats['TotalShotsLanded'] / variant_stats['TotalShotsFired']
    variant_dic['WinRate'] = variant_stats['TotalGamesWon'] / variant_stats['TotalGamesLost']
    vdf = vdf.append(variant_dic, True)
    
    i += 1
    
vdf
# Out:
#           Gamertag  TotalTimePlayed       K/D  Accuracy   WinRate
# 0      Dirus Lupus       564.478813  1.773653  0.504621  1.967742
# 1   supersaiyan245      1532.363462  1.542768  0.431750  2.368981
# 2        Drymander       289.925244  1.026587  0.320711  0.995902
# 3      J05EY WALES      3056.421148  1.180664  0.378598  1.894084
# 4  XxMegaManxX8196       269.611740  1.803473  0.329155  1.196687
# 5    TyrannicJonas       427.144771  0.900749  0.324151  1.102951
# 6          Kal LP2       460.744407  1.123812  0.365570  0.995134
# 7    LIL CALIFOOYA         7.939559  1.066826  0.366143  0.780488
