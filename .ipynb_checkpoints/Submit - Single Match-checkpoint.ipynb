# %%
# import jupyterthemes as jt

# !jt -t chesterish

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

import json
def get_keys(path):
    with open(path) as f:
        return json.load(f)
# keys = get_keys("/Users/Johnny/.secret/yelp_api.json")
# api_key = keys['api_key']
# pip install tmdbsimple #Ctrl+? this line to install tmdbsimple
import tmdbsimple as tmdb
# tmdb.API_KEY = api_key

scrape = False

import ast
import time
import http.client, urllib.request, urllib.parse, urllib.error, base64

api_key = 'b73b371a458a4cb78d9c68902188098a'


# user = 'Drymander'

import pickle
from tqdm import tqdm

# pip install isodate

import isodate

# %%
#Standard python libraries
import pandas as pd
import seaborn as sns
# sns.set_context('talk')
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings(action='ignore') 

# Preprocessing tools
from sklearn.model_selection import train_test_split,cross_val_predict,cross_validate
from sklearn.preprocessing import MinMaxScaler,StandardScaler,OneHotEncoder
scaler = StandardScaler()
from sklearn import metrics

# Models & Utilities
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score

# Warnings
import warnings
warnings.filterwarnings(action='ignore') 

# NLP Libraries
import nltk
import collections
# nltk.download('punkt')
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
from nltk import regexp_tokenize
import re
from nltk.corpus import stopwords
from nltk.collocations import *
from nltk import FreqDist
from nltk import word_tokenize
from nltk import ngrams
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('stopwords')
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\johnn\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Pull Most Recent Match Details
#
# This is a combination of two API calls - the first is to pull the latest match for a given player based on their gamertag.  This provides the Match ID, and the second API call pulls the data using the Match ID.

# %%
# Prepare gamertag for API

def gamertag_for_api(gamertag):
    gamertag = gamertag.replace(' ','+')
    return gamertag

gamertag_for_api('this is a test')
# Out:
# 'this+is+a+test'

# %%
def pull_recent_match(how_recent, api_key=api_key, explore=False, gamertag='Drymander'):
    
    gamertag = gamertag_for_api(gamertag)
    
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': api_key,
    }

    params = urllib.parse.urlencode({
        # Request parameters
        'modes': 'arena',
        'start': how_recent,
        'count': 1,
        'include-times': True,
    })

    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/players/{gamertag}/matches?%s" % params, "{body}", headers)
        response = conn.getresponse()
        latest_match = json.loads(response.read())

        match_id = latest_match['Results'][0]['Id']['MatchId']
        match_date = latest_match['Results'][0]['MatchCompletedDate']['ISO8601Date']

        time.sleep(1.01)

        conn.request("GET", f"/stats/h5/arena/matches/{match_id}?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        
        if explore == True:
            print(data)
        else:
            match_results = json.loads(data)
            match_results['MatchId'] = match_id
            match_results['Date'] = match_date
        conn.close()
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    return match_results

####################################

# match_results = pull_recent_match(5, explore=True)
match_results = pull_recent_match(0, explore=True, gamertag='zambiekiller65')
# Out:
# b'{"PlayerStats":[{"XpInfo":{"PrevSpartanRank":147,"SpartanRank":147,"PrevTotalXP":11103705,"TotalXP":11105577,"SpartanRankMatchXPScalar":2.247,"PlayerTimePerformanceXPAward":534,"PerformanceXP":99,"PlayerRankXPAward":200,"BoostAmount":0,"MatchSpeedWinAmount":0,"ObjectivesCompletedAmount":0},"PreviousCsr":null,"CurrentCsr":null,"MeasurementMatchesLeft":10,"RewardSets":[],"KilledOpponentDetails":[{"GamerTag":"GalaxisNXR2","TotalKills":6},{"GamerTag":"Markswoaw 19","TotalKills":6},{"GamerTag":"ItsDevDaBurgh","TotalKills":4},{"GamerTag":"Lughcult","TotalKills":5}],"KilledByOpponentDetails":[{"GamerTag":"Lughcult","TotalKills":5},{"GamerTag":"GalaxisNXR2","TotalKills":4},{"GamerTag":"Markswoaw 19","TotalKills":2},{"GamerTag":"ItsDevDaBurgh","TotalKills":1}],"FlexibleStats":{"MedalStatCounts":[],"ImpulseStatCounts":[{"Id":"7cda10c8-04c4-4916-8d6e-71a426a61de8","Count":1},{"Id":"fc7095af-dec5-419f-836d-fdd27836aa65","Count":0},{"Id":"0a719185-4780-4706-b9e6-f679fcbc65d6","Count":1},{"Id":"6e1e4e2c-1a57-4f64-a893-f594974b3f1f","Count":1},{"Id":"ba327946-418c-495d-90c0-89f084bf7447","Count":21},{"Id":"7dcd7306-f905-401a-97f2-345d4b25170a","Count":5},{"Id":"ea38d25f-d887-4bdf-b17b-8e8e649b9a87","Count":12},{"Id":"780104cb-5b86-4ed9-8fb1-40b919de0766","Count":0},{"Id":"f12a007b-3f27-45a1-87f5-816b6aca060d","Count":0}],"MedalTimelapses":[],"ImpulseTimelapses":[{"Id":"a3fd8c22-a921-4662-a92b-1f7e965df8fd","Timelapse":"PT26.0685332S"},{"Id":"f1c317ee-1ac4-4089-85e8-a9c536c6cf18","Timelapse":"PT6M32.6370554S"}]},"CreditsEarned":{"Result":2,"TotalCreditsEarned":879,"SpartanRankModifier":1.0,"PlayerRankAmount":375,"TimePlayedAmount":503.42298636160569,"BoostAmount":0,"MatchSpeedWinAmount":0,"ObjectivesCompletedAmount":0},"MetaCommendationDeltas":[],"ProgressiveCommendationDeltas":[{"Id":"20dc7d74-be8f-4a60-ae4f-15230855cced","PreviousProgress":83515,"Progress":83536},{"Id":"73d0b012-4747-4fe3-90b7-04818ec3d807","PreviousProgress":4484,"Progress":4487},{"Id":"1d32707e-9bbc-4cbe-af33-fdc0c8bd64b2","PreviousProgress":6519,"Progress":6525},{"Id":"e1203a73-2067-4479-9a47-2abccb0069ae","PreviousProgress":9509,"Progress":9513},{"Id":"80a19ac7-8150-49f9-96c7-3bab7a04829c","PreviousProgress":637,"Progress":638},{"Id":"07653860-9949-4a12-b341-90c8b9653165","PreviousProgress":2806,"Progress":2807},{"Id":"2d5080e0-62ee-42d9-a2dd-364d101832ea","PreviousProgress":1873,"Progress":1874},{"Id":"c43149a6-7b14-4cfd-8d4e-4b5f0b1c91bd","PreviousProgress":1198,"Progress":1199},{"Id":"57af1780-0f64-4fba-ae4e-201760d83611","PreviousProgress":7029,"Progress":7032},{"Id":"24e0ba42-59df-4c45-9fe6-d4fb739aeadc","PreviousProgress":3183,"Progress":3184},{"Id":"750783af-3332-4c7d-b5b5-26aa8800655a","PreviousProgress":3445,"Progress":3446},{"Id":"0007253f-ac80-4ed8-bfa9-8690a1b49cae","PreviousProgress":6229,"Progress":6233},{"Id":"43488c0a-fa44-4cb9-a905-3902faf7b741","PreviousProgress":4154,"Progress":4155},{"Id":"7d05bc12-7328-44fe-913e-1a64fe6a2a64","PreviousProgress":4092,"Progress":4096},{"Id":"b2aa723e-5208-451d-81ce-44adc687acd1","PreviousProgress":846,"Progress":847},{"Id":"4f65785e-78e0-4296-80d4-55b316f60ec5","PreviousProgress":1531,"Progress":1532},{"Id":"af609abb-c6e2-4e97-826f-5aca4fccf70c","PreviousProgress":3326,"Progress":3327},{"Id":"912d83d2-5f91-4f3e-8c47-3ddcbbdaedc2","PreviousProgress":803,"Progress":804},{"Id":"be522e1e-eada-4ec7-aba9-7ee0c0d6732a","PreviousProgress":2,"Progress":3},{"Id":"a61833aa-b90a-4fa8-83d3-b6a0e94d2866","PreviousProgress":1885,"Progress":1886}],"BoostInfo":null,"Player":{"Gamertag":"zambiekiller65","Xuid":null},"TeamId":0,"Rank":1,"DNF":false,"AvgLifeTimeOfPlayer":"PT23.0745832S","PreMatchRatings":null,"PostMatchRatings":null,"PlayerScore":0,"GameEndStatus":3,"TotalKills":21,"TotalHeadshots":1,"TotalWeaponDamage":2578.4670629501343,"TotalShotsFired":491,"TotalShotsLanded":265,"WeaponWithMostKills":{"WeaponId":{"StockId":4054937266,"Attachments":[]},"TotalShotsFired":30,"TotalShotsLanded":19,"TotalHeadshots":0,"TotalKills":4,"Tot ...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-6-f8588ae3bc69> in <module>
#      46
#      47 # match_results = pull_recent_match(5, explore=True)
# ---> 48 match_results = pull_recent_match(0, explore=True, gamertag='zambiekiller65')
#
# <ipython-input-6-f8588ae3bc69> in pull_recent_match(how_recent, api_key, explore, gamertag)
#      41         print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
#      42
# ---> 43     return match_results
#      44
#      45 ####################################
#
# UnboundLocalError: local variable 'match_results' referenced before assignment

# %%
match_results

# %% [markdown]
# # Pull Any Match

# %%
explore = True
matchId = '0bbc809c-87d8-423f-88a4-ffb9fc782fd6'

def pull_match(matchId, api_key=api_key, explore=False):

    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': api_key,
    }

    params = urllib.parse.urlencode({
    })

    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/arena/matches/{matchId}?%s" % params, "{body}", headers)
        response = conn.getresponse()
        if explore == True:
            data = response.read()
            print(data)
        else:
            data = response.read()
            data = json.loads(data)
        conn.close()
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    return data

        
pull_match('d8964123-992f-4dd9-8555-40b76a98d4e1', explore=False)

# %% [markdown]
# # Build Match Dataframe

# %% [markdown]
# ### Notes
#
# Red team is team ID 0
#
# Blue team is team ID 1

# %%
# match_results = pull_recent_match(0, explore=False, gamertag='thefishhawk88')
def build_base_dataframe(match_results, gamertag):
    
    # Build empty base match dataframe
    df = pd.DataFrame()
    columns = [
        'Finished'
        'TeamId',
        'Gamertag',
        'SpartanRank',
        'PrevTotalXP',
    ]
    df = pd.DataFrame(columns = columns)
    
    # Populate base match dataframe with player stats for each player
    i = 0
    for player in match_results['PlayerStats']:

        player_dic = {}
        # Team ID
        player_dic['DNF'] = match_results['PlayerStats'][i]['DNF']
        player_dic['TeamId'] = match_results['PlayerStats'][i]['TeamId']
        # Team Color
        player_dic['TeamColor'] = match_results['PlayerStats'][i]['TeamId']
        # Gamer Tag
        player_dic['Gamertag'] = match_results['PlayerStats'][i]['Player']['Gamertag']
        # Spartan Rank
        player_dic['SpartanRank'] = match_results['PlayerStats'][i]['XpInfo']['SpartanRank']
        # Previous Total XP
        player_dic['PrevTotalXP'] = match_results['PlayerStats'][i]['XpInfo']['PrevTotalXP']
        df = df.append(player_dic, ignore_index=True)
        i += 1
    
    ########## DATE, GAME VARIANT, MAP ID, MATCH ID, PLAYLIST ID ##########
    df['Date'] = match_results['Date']
    df['Date'] = pd.to_datetime(df['Date']).dt.tz_convert(None)
#     df['Date'] = df['Date'].floor('T')
    df['MatchId'] = match_results['MatchId']
    df['GameBaseVariantId'] = match_results['GameBaseVariantId']
    df['MapVariantId'] = match_results['MapVariantId']
    df['PlaylistId'] = match_results['PlaylistId']
    
    ########## DEFINE PLAYER TEAM ##########
    playerteam = df.loc[df['Gamertag'] == gamertag, 'TeamId'].values[0]
    if playerteam == 0:
        enemyteam = 1   
    else:
        enemyteam = 0
        
    df['PlayerTeam'] = df['TeamId'].map({playerteam:'Player', enemyteam:'Enemy'})
    
    if match_results['TeamStats'][0]['TeamId'] == playerteam:
        playerteam_stats = match_results['TeamStats'][0]
        enemyteam_stats = match_results['TeamStats'][1]
    else: 
        playerteam_stats = match_results['TeamStats'][1]
        enemyteam_stats = match_results['TeamStats'][0]
    
    ########## DETERMINE WINNER ##########
    # Tie
    if playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 1:
        df['Winner'] = 'Tie'
    # Player wins
    elif playerteam_stats['Rank'] == 1 and enemyteam_stats['Rank'] == 2:
        df['Winner'] = df['TeamId'].map({playerteam:'Victory', enemyteam:'Defeat'})
    # Enemy wins
    elif playerteam_stats['Rank'] == 2 and enemyteam_stats['Rank'] == 1:
        df['Winner'] = df['TeamId'].map({enemyteam:'Victory', playerteam:'Defeat'})
    # Error handling
    else:
        winner = 'Error determining winner'
    
    ########## TEAM COLOR ##########
    df['TeamColor'] = df['TeamId'].map({0:'Red', 1:'Blue'})
    
    # Set columns
    df = df[['Date', 'MatchId', 'GameBaseVariantId', 'PlaylistId', 'MapVariantId', 'DNF',
             'TeamId', 'PlayerTeam', 'Winner', 'TeamColor', 
             'Gamertag', 'SpartanRank', 'PrevTotalXP',
            ]]
    # Sort match by winning team
    df = df.sort_values(by=['Winner'], ascending=False)
    
    return df

df = build_base_dataframe(pull_recent_match(8), 'Drymander')
# playerteam = 0
# enemyteam = 1
# df['PlayerTeam'] = df['TeamId'].map({playerteam:'Player', enemyteam:'Enemy'})
df
# df.loc['TeamId'] 
# # df.loc[df['TeamId'] == 0]
# df
# build_base_dataframe(pull_recent_match(0, explore=False, gamertag='thefishhawk88'), gamertag='thefishhawk88')

# %%
1 in df['DNF']

# %%
# playerteam = 0

# df['TeamColor'] = df['TeamId'].map({0:'Red', 1:'Blue'})
# df['Winner'] = df['TeamId'].map({playerteam:'Victory', 1:'Defeat'})
# df

# %%
# # Red victory
# build_base_dataframe(pull_recent_match(0, gamertag='thefishhawk88'), gamertag='thefishhawk88')

# %%
# # Blue loss
# build_base_dataframe(pull_recent_match(1, gamertag='thefishhawk88'), gamertag='thefishhawk88')

# %%
# # Blue tie
# build_base_dataframe(pull_recent_match(2, gamertag='thefishhawk88'), gamertag='thefishhawk88')

# %%
# # Red victory
# build_base_dataframe(pull_recent_match(3, gamertag='thefishhawk88'), gamertag='thefishhawk88')

# %%
# # Red DNF
# build_base_dataframe(pull_recent_match(6, gamertag='thefishhawk88'))

# %%
# # Blue victory
# build_base_dataframe(pull_recent_match(7))

# %% [markdown]
# # Pull Game Base Variant Stats for All Players in Match
#
# Using the match details, we will compile everyone's gamertags into a list and pull more specific information for each player.  We can get statistics on every game mode (or "Game Base Variant" as it is referred to in the API).

# %% [markdown]
# ## Player List

# %%
# df_match = build_base_dataframe(pull_recent_match(5, gamertag='thefishhawk88'), gamertag='thefishhawk88')

def get_player_list(df):
    player_list = str(list(df['Gamertag']))[1:-1]

    player_list
    player_list = player_list.replace(', ',',')
    player_list = player_list.replace("'",'')
    player_list = player_list.replace(' ','+')

    return player_list


# get_player_list(df_match)

# %%
def get_player_history(df, readable=False):
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': str(api_key),
    }
    params = urllib.parse.urlencode({
    })
    player_list_api = get_player_list(df)
    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/servicerecords/arena?players={player_list_api}&%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        player_history = json.loads(data)
    #     print(data)
        conn.close()
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))

    if readable == False:
        return player_history
    else:
        return data

player_history = get_player_history(df, readable=False)

# player_history['Results'][1]

# %%
player_history

# %% [markdown]
# ## Compile Individual Stats into Dataframe

# %%
# player_history['Results'][2]

# %%
# variant_id = match_results['GameBaseVariantId']

def build_history_dataframe(player_history, variant_id, streamlit=False):
    if streamlit == True:
        vdf_columns = ['Gamertag','TotalTimePlayed','K/D','Accuracy','WinRate']
        vdf = pd.DataFrame(columns = vdf_columns)
    else:
        stat_list = ['Gamertag', 'TotalKills', 'TotalHeadshots', 'TotalWeaponDamage', 'TotalShotsFired',
                    'TotalShotsLanded', 'TotalMeleeKills', 'TotalMeleeDamage', 'TotalAssassinations',
                    'TotalGroundPoundKills', 'TotalGroundPoundDamage', 'TotalShoulderBashKills',
                    'TotalShoulderBashDamage', 'TotalGrenadeDamage', 'TotalPowerWeaponKills',
                    'TotalPowerWeaponDamage', 'TotalPowerWeaponGrabs', 'TotalPowerWeaponPossessionTime',
                    'TotalDeaths', 'TotalAssists', 'TotalGamesCompleted', 'TotalGamesWon',
                    'TotalGamesLost', 'TotalGamesTied', 'TotalTimePlayed','TotalGrenadeKills']
        vdf = pd.DataFrame(columns = stat_list)

    i = 0
    for player in player_history['Results']:
        for variant in player['Result']['ArenaStats']['ArenaGameBaseVariantStats']:
            if variant['GameBaseVariantId'] == variant_id:
                variant_stats = variant

        variant_dic = {}
        if streamlit == True:
            variant_dic['Gamertag'] = player_history['Results'][i]['Id']
            variant_dic['TotalTimePlayed']= isodate.parse_duration(variant_stats['TotalTimePlayed']).total_seconds() / 3600
            variant_dic['K/D'] = variant_stats['TotalKills'] / variant_stats['TotalDeaths']
            variant_dic['Accuracy'] = variant_stats['TotalShotsLanded'] / variant_stats['TotalShotsFired']
            variant_dic['WinRate'] = variant_stats['TotalGamesWon'] / variant_stats['TotalGamesLost']
            vdf = vdf.append(variant_dic, True)
            i += 1
        else:
            variant_dic['Gamertag'] = player_history['Results'][i]['Id']
            for stat in stat_list[1:]:
                
                variant_dic[stat] = variant_stats[stat]
            variant_dic['TotalTimePlayed']= isodate.parse_duration(variant_stats['TotalTimePlayed']).total_seconds() / 3600
            vdf = vdf.append(variant_dic, True)
            i += 1
    return vdf
    
build_history_dataframe(player_history, '1571fdac-e0b4-4ebc-a73a-6e13001b71d3', streamlit=False)

# %% [markdown]
# # Merge Match and Game Variant Dataframes

# %%
# df_stats = pd.merge(df_match, vdf, how='inner', on = 'Gamertag')

# df_stats

# %% [markdown]
# # Master Function

# %%
# gamertag = 'Drymander'

def specific_match_stats(match_id, gamertag):
    match_results = pull_match(match_id, explore=False)
    base_df = build_base_dataframe(match_results, gamertag=gamertag)
    time.sleep(1.01)
    
    player_list = get_player_list(base_df)
    
    player_history = get_player_history(base_df)
    
    history_df = build_history_dataframe(player_history, match_results['GameBaseVariantId'])
    full_stats_df = pd.merge(base_df, history_df, how='inner', on = 'Gamertag')
    
    return full_stats_df
#     return base_df, history_df, player_list, player_history, full_stats_df
# base_df, history_df, player_list, player_history, full_stats_df = recent_match_stats('thefishhawk88', back_count=20)
# 
# stats_df = recent_match_stats('Drymander', back_count=0)

specific_match_stats('10010481-1be2-462b-9774-eac5ee152045', 'Drymander')

# %%
# gamertag = 'Drymander'

def recent_match_stats(gamertag, back_count=0):
    match_results = pull_recent_match(back_count, explore=False, gamertag=gamertag)
    base_df = build_base_dataframe(match_results, gamertag=gamertag)
    time.sleep(1.01)
    
    player_list = get_player_list(base_df)
    
    player_history = get_player_history(base_df)
    
    history_df = build_history_dataframe(player_history, match_results['GameBaseVariantId'])
    full_stats_df = pd.merge(base_df, history_df, how='inner', on = 'Gamertag')
    
    return full_stats_df
#     return base_df, history_df, player_list, player_history, full_stats_df
# base_df, history_df, player_list, player_history, full_stats_df = recent_match_stats('thefishhawk88', back_count=20)
# 
stats_df = recent_match_stats('Drymander', back_count=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-afe39227821d> in <module>
#      17 # base_df, history_df, player_list, player_history, full_stats_df = recent_match_stats('thefishhawk88', back_count=20)
#      18 #
# ---> 19 stats_df = recent_match_stats('Drymander', back_count=0)
#
# <ipython-input-1-afe39227821d> in recent_match_stats(gamertag, back_count)
#       2
#       3 def recent_match_stats(gamertag, back_count=0):
# ----> 4     match_results = pull_recent_match(back_count, explore=False, gamertag=gamertag)
#       5     base_df = build_base_dataframe(match_results, gamertag=gamertag)
#       6     time.sleep(1.01)
#
# NameError: name 'pull_recent_match' is not defined

# %%
stats_df
# Out:
#                      Date                               MatchId  \
# 0 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
# 1 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
# 2 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
# 3 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
# 4 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
# 5 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
# 6 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
# 7 2021-07-20 05:33:40.029  e1947e3f-0939-45b1-8025-9630213af5ff
#
#                       GameBaseVariantId                            PlaylistId  \
# 0  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 1  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 2  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 3  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 4  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 5  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 6  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 7  a2949322-dc84-45ab-8454-cf94fb28c189  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
#
#                            MapVariantId  DNF  TeamId PlayerTeam   Winner  \
# 0  353f70fa-bd08-41cd-9d39-87e3e3967908  0.0     1.0      Enemy  Victory
# 1  353f70fa-bd08-41cd-9d39-87e3e3967908  0.0     1.0      Enemy  Victory
# 2  353f70fa-bd08-41cd-9d39-87e3e3967908  0.0     1.0      Enemy  Victory
# 3  353f70fa-bd08-41cd-9d39-87e3e3967908  0.0     1.0      Enemy  Victory
# 4  353f70fa-bd08-41cd-9d39-87e3e3967908  0.0     0.0     Player   Defeat
# 5  353f70fa-bd08-41cd-9d39-87e3e3967908  0.0     0.0     Player   Defeat
# 6  353f70fa-bd08-41cd-9d39-87e3e3967908  0.0     0.0     Player   Defeat
# 7  353f70fa-bd08-41cd-9d39-87e3e3967908  1.0     0.0     Player   Defeat
#
#   TeamColor  ... TotalPowerWeaponGrabs TotalPowerWeaponPossessionTime  \
# 0      Blue  ...                     3             P6DT10H15M30.4391S
# 1      Blue  ...                    11                P4DT24M57.3675S
# 2      Blue  ...                    63              P4DT5H48M58.6944S
# 3      Blue  ...                     3              P2DT12H39M4.6711S
# 4       Red  ...                    16             P6DT14H27M26.5297S
# 5       Red  ...                   215              P1DT6H58M16.2378S
# 6       Red  ...                   415             P1DT13H54M29.4448S
# 7       Red  ...                     1              P4DT1H30M27.5389S
#
#   TotalDeaths TotalAssists TotalGamesCompleted  TotalGamesWon TotalGamesLost  \
# 0       52390        20046                2776           1379           1025
# 1       20794        13778                1741            807            699
# 2       39568        11506                2378           1340            836
# 3       21095         6167                1276            742            426
# 4       44706        15073                3065           1600           1204
# 5       18663         6121                1276            551            650
# 6       26417        13107                1938            874            963
# 7       41902        12440                2154           1018            894
#
#   TotalGamesTied TotalTimePlayed  TotalGrenadeKills
# 0            372      306.397416               1139
# 1            235      178.607888               1307
# 2            202      228.258400                655
# 3            108      120.385641                150
# 4            261      289.496851                692
# 5             75      150.385630                468
# 6            101      236.062764                911
# 7            242      211.124130               1514
#
# [8 rows x 38 columns]

# %% [markdown]
# # One Line for Modeling

# %%
df_base = recent_match_stats('ubseen817', back_count=6)
# df_base.to_csv('df_base_check.csv')
# 0 in df_base['DNF'].values
df_base

# %%
len(df_base.index)

# %%
df_base.iloc[0:1,0:4]

# %%
df_base.sort_values(by=['PlayerTeam', 'TotalTimePlayed'], ascending=(False, False))

# %%
df_row

# %%
df_player = df_base.loc[df_base['PlayerTeam'] == 'Player']

# %%
df = recent_match_stats('Drymander', back_count=6)
# fishhawk = drymander = recent_match_stats('thefishhawk88', back_count=6)

def one_row(df, for_model=False):
    
    if ((for_model==True) and ((len(df.index) != 8) or (1 in df['DNF'].values))):
        df = pd.DataFrame()
#     if for_model==True:
#         print('for model is set to true')
#     if len(df.index) != 8:
#         print('there are not exactly 8 players in this match')
#     if 1 in df['DNF'].values:
#         print('one or more players did not finish')
    else:
        df = df.sort_values(by=['PlayerTeam', 'TotalTimePlayed'], ascending=(False, False))
    #     if dnf == True:
    #         if 1 in df['DNF']:
    #             return
        df = df.reset_index()
        df_row = df.iloc[0:1,1:6]
        df_player = df.loc[df['PlayerTeam'] == 'Player']
        if df_player['Winner'].str.contains('Victory').any():
            df_row['WinLoseTie'] = 'Victory'
        elif df_player['Winner'].str.contains('Defeat').any():
            df_row['WinLoseTie'] = 'Defeat'
        elif df_player['Winner'].str.contains('Tie').any():
            df_row['WinLoseTie'] = 'Tie'
        else: 
            df_row['WinLoseTie'] = 'Error Determining Victor'

        column_list = df.columns.to_list()
        columns_converted = []
        df = df.drop(df.iloc[:, 0:11], axis = 1)
        df = df.stack().to_frame().T
        df.columns = ['{}_{}'.format(*c) for c in df.columns]

        column_convert_dic = {"0_":"P1-", "1_":"P2-","2_":"P3-","3_":"P4-",
                              "4_":"E1-","5_":"E2-","6_":"E3-","7_":"E4-",}

        # df.rename(columns=column_convert_dic)
        for k, v in column_convert_dic.items():
            df.columns = df.columns.str.replace(k, v)
        df.columns = df.columns.str.replace('-', '_')
        df = df_row.join(df, how='outer')
    
    return df

one_row(df, for_model=True)
# Out:
#                      Date                               MatchId  \
# 0 2021-07-18 23:48:37.862  e1ab0c02-0f9f-42ea-ad5c-4bc23163e266
#
#                       GameBaseVariantId                            PlaylistId  \
# 0  257a305e-4dd3-41f1-9824-dfe7e8bd59e1  f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
#
#                            MapVariantId WinLoseTie P1_Gamertag P1_SpartanRank  \
# 0  d5f2d94f-b51f-4a0c-8c35-af99426bf14d     Defeat   Drymander            148
#
#   P1_PrevTotalXP P1_TotalKills  ... E4_TotalPowerWeaponGrabs  \
# 0       15335546         28246  ...                      118
#
#   E4_TotalPowerWeaponPossessionTime E4_TotalDeaths E4_TotalAssists  \
# 0                 P1DT19H53M52.534S          12050            2491
#
#   E4_TotalGamesCompleted E4_TotalGamesWon E4_TotalGamesLost E4_TotalGamesTied  \
# 0                   1164              578               586                 0
#
#   E4_TotalTimePlayed E4_TotalGrenadeKills
# 0            122.781                  185
#
# [1 rows x 230 columns]

# %% [markdown]
# ## Modified Pull multiple matches

# %%
def model_pull_matches(how_recent, api_key=api_key, 
                       gamertag='Drymander', count=25):
    
    gamertag = gamertag_for_api(gamertag)
    
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': api_key,
    }

    params = urllib.parse.urlencode({
        # Request parameters
        'modes': 'arena',
        'start': 0,
        'count': count,
        'include-times': True,
    })

    try:
        conn = http.client.HTTPSConnection('www.haloapi.com')
        conn.request("GET", f"/stats/h5/players/{gamertag}/matches?%s" % params, "{body}", headers)
        time.sleep(1.01)
        response = conn.getresponse()
        data = response.read()
        history_pull = json.loads(data)
        print(history_pull['ResultCount'])
        
        i = 0
        latest_count_matches = []
        for match in history_pull['Results']:
            match_id = match['Id']['MatchId']
            match_date = match['MatchCompletedDate']['ISO8601Date']
            conn.request("GET", f"/stats/h5/arena/matches/{match_id}?%s" % params, "{body}", headers)
            time.sleep(1.1)
            response = conn.getresponse()
            data = response.read()
            

            match_results = json.loads(data)
            match_results['MatchId'] = match_id
            match_results['Date'] = match_date
            latest_count_matches.append(match_results)
            conn.close()
            i += 1
            print(f'{i} matches appended')
    except Exception as e:
        print(f"[Errno {0}] {1}".format(e.errno, e.strerror))
    
    return latest_count_matches

####################################

# match_results = pull_recent_match(5, explore=True)
latest_count_matches = model_pull_matches(0, gamertag='zambiekiller65', count=5)
# Out:
# 5
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended

# %%
latest_count_matches[4]

# %% [markdown]
# ## Modified recent match stats function

# %%
with open('unique_gamertags.pkl', 'rb') as unique_gamertags_pickle:
    unique_gamertags = pickle.load(unique_gamertags_pickle)
    
len(unique_gamertags[0:100])
# Out:
# 100

# %%
model_dataframe = pd.DataFrame()

# %%
unique_gamertags[102:104]
# Out:
# ['X1xASESINOx1X', 'Warlord the 5th']

# %%
# gamertag_list = ['Drymander']
gamertag_list = unique_gamertags[604:650]

def model_recent_match_stats(gamertag_list, back_count=0, count=25):
    df = pd.DataFrame()
    gamertag_count = 0
    for gamertag in tqdm(gamertag_list):
        try:
            latest_count_matches = model_pull_matches(0, gamertag=gamertag, count=count)
            time.sleep(1.1)

            error_count = 0
            i = 0
            for match in latest_count_matches:

                try:

                    base_df = build_base_dataframe(match, gamertag=gamertag)

                    player_list = get_player_list(base_df)

                    player_history = get_player_history(base_df)

                    history_df = build_history_dataframe(player_history, match_results['GameBaseVariantId'])
                    full_stats_df = pd.merge(base_df, history_df, how='inner', on = 'Gamertag')
                    row = one_row(full_stats_df, for_model=True)
                    row.to_csv('MODEL_PULL.csv', mode ='a', date_format='%Y-%m-%d %H:%M:%S', header=False)
                    df = df.append(row)
                    i += 1
                    print(f'{i} rows added to model dataframe')

                    time.sleep(1.1)
                except:
                    error_count += 1
                    print(f'{error_count} rows returned error when getting player history')
                    time.sleep(1.1)
                    error_count += 1
                    continue
            gamertag_count += 1
            print(f'{gamertag_count} completed')
        except:
            print('gamertag skipped due to error')
    return df
#     return base_df, history_df, player_list, player_history, full_stats_df
# base_df, history_df, player_list, player_history, full_stats_df = recent_match_stats('thefishhawk88', back_count=20)
# 
model_df = model_recent_match_stats(gamertag_list, back_count=0, count=25)
# model_df.to_csv('model_df_test.csv')
model_df
# Out:
#   0%|          | 0/46 [00:00<?, ?it/s]
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#   2%|▏         | 1/46 [01:31<1:08:36, 91.48s/it]
# 1 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 1 rows returned error when getting player history
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
#   4%|▍         | 2/46 [02:58<1:06:02, 90.06s/it]
# 2 completed
#   7%|▋         | 3/46 [02:59<45:25, 63.38s/it]
# gamertag skipped due to error
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#   9%|▊         | 4/46 [04:25<49:10, 70.26s/it]
# 3 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 1 rows returned error when getting player history
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
#  11%|█         | 5/46 [06:06<54:11, 79.30s/it]
# 4 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows returned error when getting player history
# 3 rows returned error when getting player history
# 5 rows returned error when getting player history
# 7 rows returned error when getting player history
# 9 rows returned error when getting player history
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 11 rows returned error when getting player history
# 13 rows returned error when getting player history
# 15 rows returned error when getting player history
# 4 rows added to model dataframe
# 17 rows returned error when getting player history
# 19 rows returned error when getting player history
# 5 rows added to model dataframe
# 21 rows returned error when getting player history
# 23 rows returned error when getting player history
# 6 rows added to model dataframe
# 25 rows returned error when getting player history
# 27 rows returned error when getting player history
# 29 rows returned error when getting player history
# 31 rows returned error when getting player history
# 7 rows added to model dataframe
# 33 rows returned error when getting player history
# 8 rows added to model dataframe
#  13%|█▎        | 6/46 [07:19<51:38, 77.46s/it]
# 5 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  15%|█▌        | 7/46 [08:43<51:40, 79.51s/it]
# 6 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 1 rows returned error when getting player history
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 3 rows returned error when getting player history
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 5 rows returned error when getting player history
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
#  17%|█▋        | 8/46 [10:08<51:20, 81.06s/it]
# 7 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  20%|█▉        | 9/46 [11:37<51:28, 83.47s/it]
# 8 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  22%|██▏       | 10/46 [13:02<50:19, 83.88s/it]
# 9 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows returned error when getting player history
# 5 rows returned error when getting player history
# 7 rows returned error when getting player history
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 9 rows returned error when getting player history
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
#  24%|██▍       | 11/46 [14:24<48:43, 83.52s/it]
# 10 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  26%|██▌       | 12/46 [15:52<48:01, 84.75s/it]
# 11 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  28%|██▊       | 13/46 [17:22<47:27, 86.29s/it]
# 12 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  30%|███       | 14/46 [18:54<46:56, 88.03s/it]
# 13 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows returned error when getting player history
# 3 rows returned error when getting player history
# 5 rows returned error when getting player history
# 7 rows returned error when getting player history
# 1 rows added to model dataframe
# 9 rows returned error when getting player history
# 11 rows returned error when getting player history
# 13 rows returned error when getting player history
# 15 rows returned error when getting player history
# 17 rows returned error when getting player history
# 19 rows returned error when getting player history
# 21 rows returned error when getting player history
# 23 rows returned error when getting player history
# 25 rows returned error when getting player history
# 27 rows returned error when getting player history
# 29 rows returned error when getting player history
# 31 rows returned error when getting player history
# 33 rows returned error when getting player history
# 35 rows returned error when getting player history
# 37 rows returned error when getting player history
# 39 rows returned error when getting player history
# 41 rows returned error when getting player history
# 43 rows returned error when getting player history
# 45 rows returned error when getting player history
# 47 rows returned error when getting player history
#  33%|███▎      | 15/46 [19:57<41:36, 80.53s/it]
# 14 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  35%|███▍      | 16/46 [21:22<40:56, 81.87s/it]
# 15 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  37%|███▋      | 17/46 [22:47<40:00, 82.79s/it]
# 16 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows returned error when getting player history
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows returned error when getting player history
# 5 rows returned error when getting player history
# 7 rows returned error when getting player history
# 9 rows returned error when getting player history
# 11 rows returned error when getting player history
# 13 rows returned error when getting player history
# 15 rows returned error when getting player history
# 17 rows returned error when getting player history
# 19 rows returned error when getting player history
# 21 rows returned error when getting player history
# 23 rows returned error when getting player history
# 25 rows returned error when getting player history
# 27 rows returned error when getting player history
# 29 rows returned error when getting player history
# 31 rows returned error when getting player history
# 33 rows returned error when getting player history
# 35 rows returned error when getting player history
# 37 rows returned error when getting player history
# 39 rows returned error when getting player history
# 41 rows returned error when getting player history
# 43 rows returned error when getting player history
# 45 rows returned error when getting player history
#  39%|███▉      | 18/46 [23:51<36:04, 77.31s/it]
# 17 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  41%|████▏     | 19/46 [25:22<36:36, 81.34s/it]
# 18 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
#  43%|████▎     | 20/46 [26:49<35:59, 83.05s/it]
# 19 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows added to model dataframe
# 3 rows returned error when getting player history
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
#  46%|████▌     | 21/46 [28:11<34:30, 82.81s/it]
# 20 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 1 rows returned error when getting player history
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
#  48%|████▊     | 22/46 [29:35<33:12, 83.01s/it]
# 21 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
#  50%|█████     | 23/46 [31:01<32:12, 84.00s/it]
# 22 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  52%|█████▏    | 24/46 [32:27<31:00, 84.55s/it]
# 23 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  54%|█████▍    | 25/46 [33:50<29:25, 84.09s/it]
# 24 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  57%|█████▋    | 26/46 [35:17<28:20, 85.05s/it]
# 25 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  59%|█████▊    | 27/46 [36:45<27:12, 85.95s/it]
# 26 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  61%|██████    | 28/46 [38:11<25:43, 85.76s/it]
# 27 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  63%|██████▎   | 29/46 [39:33<24:02, 84.83s/it]
# 28 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 1 rows returned error when getting player history
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
#  65%|██████▌   | 30/46 [40:58<22:38, 84.91s/it]
# 29 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  67%|██████▋   | 31/46 [42:30<21:43, 86.92s/it]
# 30 completed
# 6
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows returned error when getting player history
#  70%|██████▉   | 32/46 [42:49<15:32, 66.63s/it]
# 31 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows returned error when getting player history
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 5 rows returned error when getting player history
# 22 rows added to model dataframe
#  72%|███████▏  | 33/46 [44:11<15:24, 71.13s/it]
# 32 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  74%|███████▍  | 34/46 [45:36<15:01, 75.16s/it]
# 33 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  76%|███████▌  | 35/46 [47:07<14:41, 80.16s/it]
# 34 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# ...
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  85%|████████▍ | 39/46 [52:49<09:52, 84.66s/it]
# 38 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  87%|████████▋ | 40/46 [54:15<08:28, 84.82s/it]
# 39 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 3 rows returned error when getting player history
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 5 rows returned error when getting player history
#  89%|████████▉ | 41/46 [55:41<07:05, 85.15s/it]
# 40 completed
#  91%|█████████▏| 42/46 [55:42<03:59, 59.94s/it]
# gamertag skipped due to error
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
#  93%|█████████▎| 43/46 [57:10<03:25, 68.55s/it]
# 41 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
#  96%|█████████▌| 44/46 [58:35<02:27, 73.53s/it]
# 42 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 1 rows returned error when getting player history
# 3 rows returned error when getting player history
# 13 rows added to model dataframe
# 5 rows returned error when getting player history
# 7 rows returned error when getting player history
# 9 rows returned error when getting player history
# 11 rows returned error when getting player history
# 13 rows returned error when getting player history
# 15 rows returned error when getting player history
# 17 rows returned error when getting player history
# 19 rows returned error when getting player history
# 14 rows added to model dataframe
# 15 rows added to model dataframe
#  98%|█████████▊| 45/46 [59:51<01:14, 74.03s/it]
# 43 completed
# 25
# 1 matches appended
# 2 matches appended
# 3 matches appended
# 4 matches appended
# 5 matches appended
# 6 matches appended
# 7 matches appended
# 8 matches appended
# 9 matches appended
# 10 matches appended
# 11 matches appended
# 12 matches appended
# 13 matches appended
# 14 matches appended
# 15 matches appended
# 16 matches appended
# 17 matches appended
# 18 matches appended
# 19 matches appended
# 20 matches appended
# 21 matches appended
# 22 matches appended
# 23 matches appended
# 24 matches appended
# 25 matches appended
# 1 rows added to model dataframe
# 2 rows added to model dataframe
# 3 rows added to model dataframe
# 4 rows added to model dataframe
# 5 rows added to model dataframe
# 6 rows added to model dataframe
# 7 rows added to model dataframe
# 8 rows added to model dataframe
# 9 rows added to model dataframe
# 10 rows added to model dataframe
# 11 rows added to model dataframe
# 12 rows added to model dataframe
# 13 rows added to model dataframe
# 14 rows added to model dataframe
# 15 rows added to model dataframe
# 16 rows added to model dataframe
# 17 rows added to model dataframe
# 18 rows added to model dataframe
# 19 rows added to model dataframe
# 20 rows added to model dataframe
# 21 rows added to model dataframe
# 22 rows added to model dataframe
# 23 rows added to model dataframe
# 24 rows added to model dataframe
# 25 rows added to model dataframe
# 100%|██████████| 46/46 [1:01:15<00:00, 79.90s/it]
# 44 completed
#                       Date                               MatchId  \
# 0  2021-04-16 00:47:21.427  84a42203-e565-4305-850b-9196d19c4c2a
# 0  2021-04-11 19:43:07.792  270d3b20-c815-4e4c-95b5-fa253d4fb214
# 0  2021-04-04 23:08:18.793  d369ef33-1bb6-4659-ac04-e395c637832d
# 0  2021-04-04 23:00:14.093  8e6c0c70-0d6f-4b89-93ce-b63eac5c5477
# 0  2021-04-04 22:47:51.753  4e50acf0-3b0f-4ce0-9159-98d8b21489cf
# ..                     ...                                   ...
# 0  2021-07-20 04:42:53.437  67fdd7d7-0dc0-48be-adf5-650c42a76c2b
# 0  2021-07-20 04:35:27.401  eada6044-f39d-4ccf-a55f-535692c087d1
# 0  2021-07-20 04:28:58.648  ac569a6a-851d-4aa5-addc-aa8df2165c68
# 0  2021-07-20 04:20:54.476  914a6cdc-2ce9-4861-95c3-5bdf145016c0
# 0  2021-07-20 04:13:12.260  0fcda99e-ca3b-417e-9aa3-af6f89ac137c
#
#                        GameBaseVariantId  \
# 0   a2949322-dc84-45ab-8454-cf94fb28c189
# 0   a2949322-dc84-45ab-8454-cf94fb28c189
# 0   257a305e-4dd3-41f1-9824-dfe7e8bd59e1
# 0   257a305e-4dd3-41f1-9824-dfe7e8bd59e1
# 0   257a305e-4dd3-41f1-9824-dfe7e8bd59e1
# ..                                   ...
# 0   257a305e-4dd3-41f1-9824-dfe7e8bd59e1
# 0   257a305e-4dd3-41f1-9824-dfe7e8bd59e1
# 0   9bb6fde8-ac5b-4d45-96eb-0acc6980722a
# 0   a2949322-dc84-45ab-8454-cf94fb28c189
# 0   a2949322-dc84-45ab-8454-cf94fb28c189
#
#                               PlaylistId  \
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   d36f4f4b-2737-4f45-97dd-c10fbe460a11
# ..                                   ...
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
# 0   f0c9ef9a-48bd-4b24-9db3-2c76b4e23450
#
#                             MapVariantId WinLoseTie      P1_Gamertag  \
# 0   48a9e809-9a44-4755-8649-2e952470858c     Defeat       jstchiefd1
# 0   419d96d3-a2e4-4a6c-8cd1-4211743cde07     Defeat  ExistingChicken
# 0   e669aabf-1a6f-4b77-b79c-e9c03a1fbb54     Defeat        Drymander
# 0   de8faf3e-ce14-4dfc-b71b-929e844488e1    Victory  MetroGoldfish75
# 0   501e4a84-522e-44e2-b9da-5c63195674ed    Victory        YagerX117
# ..                                   ...        ...              ...
# 0   d253e923-dc79-4426-acb0-c9e5ca536c11    Victory          DEEPKUL
# 0   d5f2d94f-b51f-4a0c-8c35-af99426bf14d    Victory          DEEPKUL
# 0   6f5c7191-c4c1-4f18-9943-64ffefa7260c     Defeat          DEEPKUL
# 0   aeae8d15-bc58-4fa2-8e38-6d90efcb2e90    Victory          DEEPKUL
# 0   056a24be-7cde-4af2-a062-d877a54a4384        Tie          DEEPKUL
#
#    P1_SpartanRank P1_PrevTotalXP P1_TotalKills  ... E4_TotalPowerWeaponGrabs  \
# 0             151       37550672         51745  ...                       90
# 0             148       15236572         18898  ...                        0
# 0             147       11397828         39610  ...                        9
# 0             149       18900549         20826  ...                       10
# 0             147       13982158          9801  ...                       23
# ..            ...            ...           ...  ...                      ...
# 0             151       38897336         91897  ...                        0
# 0             151       38893423         91897  ...                       16
# 0             151       38889956         91897  ...                       16
# 0             151       38887855         91897  ...                        0
# 0             151       38885889         91897  ...                        0
#
#    E4_TotalPowerWeaponPossessionTime E4_TotalDeaths E4_TotalAssists  \
# 0                  P1DT21H20M55.029S          15930            6608
# 0                  P3DT5H53M26.4087S          16442            6710
# 0                   PT10H38M36.7646S           3171            1236
# 0                   PT20H46M34.7855S           4636            1831
# 0                    PT6H23M16.8834S           1512             476
# ..                               ...            ...             ...
# 0                      PT11M47.3002S             67              35
# 0                  P2DT2H22M57.3359S          21773            7635
# 0                    PT3H29M32.6341S            991             577
# 0                    P1DT16H7M7.017S          12074            4933
# 0                    P1DT16H7M7.017S          12074            4933
#
#    E4_TotalGamesCompleted E4_TotalGamesWon E4_TotalGamesLost  \
# 0                    1009              542               362
# 0                    1254              539               555
# 0                     220               90               109
# 0                     362              150               161
# 0                      96               42                39
# ..                    ...              ...               ...
# 0                       4                1                 2
# 0                    1095              478               483
# 0                      99               49                42
# 0                     801              387               332
# 0                     801              387               332
#
#    E4_TotalGamesTied E4_TotalTimePlayed E4_TotalGrenadeKills
# 0                105            105.479                  539
# 0                160            127.511                  149
# 0                 21             24.193                  170
# 0                 51            36.7069                  192
# 0                 15            12.5052                   17
# ..               ...                ...                  ...
# 0                  1           0.401617                    3
# 0                134            112.485                  410
# 0                  8            11.1469                   74
# 0                 82            79.3455                  170
# 0                 82            79.3455                  170
#
# [605 rows x 230 columns]

# %%
model_df.to_csv('model_df_test 100-200.csv')

# %% [markdown]
# ## Full Pull with Player List

# %%
gamertag_list = ['thefishhawk88', 'Drymander', 'ATLkrunk420']
gamertag_errors = []

def pull_model_rows(gamertag_list):
    df = pd.DataFrame()
    for gamertag in gamertag_list:
#         try:
            match = recent_match_stats(gamertag, back_count=0)
            row = one_row(match, for_model=True)
            df = df.append(row)
            time.sleep(1.01)
#         except:
#             continue
        
    return df
    
df_append = pull_model_rows(gamertag_list)
df_append

# %%
recent_match_stats('ATLkrunk420', back_count=0)

# %%
# df = pd.DataFrame()
test

# %%
pull_model_rows(['thefishhawk88'])

# %%
model_df = pd.DataFrame()
model_df.append(pull_model_rows(gamertag_list))

# %%
first = one_row(recent_match_stats('Drymander', back_count=0))
second = one_row(recent_match_stats('thefishhawk88', back_count=0))
first.append(second)

# %%
second = one_row(recent_match_stats('thefishhawk88', back_count=0))
second

# %%
df_player

if df_player['Winner'].str.contains('Defeat').any():
    print ("Mel is there")

# %% [markdown]
# # Plotting Graphs

# %%
import plotly.express as px
# df = df
fig = px.bar(df, x='TotalTimePlayed', y='Gamertag', orientation='h')
fig.show()

# %%
df = recent_match_stats('Drymander', 2)

# %%
df

# %%
df.to_csv('match.csv')

# %%
# %%writefile 'filename.py'
#
# fname = 'generated.py'
# data = 5
#
# with open(fname, 'w') as f:
#     f.write('data = [{}]'.format(data))
#
# import generated
# print(generated.data)
#
# print('test')

# %%
df = recent_match_stats('Drymander', 4)

# %%
# %%writefile compare_stat.py

df = recent_match_stats('Drymander', 0)

import plotly.graph_objects as go
# from plotly.subplots import make_subplots
from plotly.subplots import make_subplots
def compare_stat(df, column_name):

    # Separate player and enemy teams
    df_player = df.loc[df['PlayerTeam'] == 'Player']
    df_enemy = df.loc[df['PlayerTeam'] == 'Enemy']

    # Sort total time played by descending
    df_player = df_player.sort_values(by=[column_name])
    df_enemy = df_enemy.sort_values(by=[column_name])

    # Assign player / enemy colors
    if df_player['TeamColor'].iloc[0] == 'Blue':
        player_color = 'Blue'
        enemy_color = 'Red'
    else:
        player_color = 'Red'
        enemy_color = 'Blue'
    
    # Make subplot and X axis range
    fig = make_subplots(rows=2, cols=1, subplot_titles=['Player Team', 'Enemy Team'])
    x_range = df[column_name].max()
    
    # Player team sub plot
    fig.add_trace(go.Bar(
                x=df_player[column_name],
                y=df_player['Gamertag'],
                orientation='h',
                text=df_player[column_name].round(2),
                textposition='auto',
                marker_color=player_color),
                    row=1, col=1)
    fig.update_xaxes(range=[0, x_range], row=1, col=1)
    
    # Enemy team sub plot
    fig.add_trace(go.Bar(
                x=df_enemy[column_name],
                y=df_enemy['Gamertag'],
                orientation='h',
                text=df_enemy[column_name].round(2),
                textposition='auto',
                marker_color=enemy_color),
                    row=2, col=1)
    fig.update_xaxes(range=[0, x_range], row=2, col=1)
    fig.update_layout(title_text='test')
    return fig

compare_stat(df, 'TotalTimePlayed')

# %%
compare_stat(df, 'TotalTimePlayed')
compare_stat(df, 'WinRate')

# %%
compare_stat(df, 'K/D')

# %%
compare_stat(df, 'Accuracy')

# %% [markdown]
# # Streamlit

# %%
# !pip install streamlit

# !pip install --upgrade protobuf

# %%
import streamlit as st

# %%
st.title('My first fdsfdsa app')

st.write("Here's our first attempt at using data to create a table:")
st.write(pd.DataFrame({
    'first column': [1, 2, 3, 4],
    'second column': [10, 20, 30, 40]
    }))

# %%
chart_data = pd.DataFrame(
     np.random.randn(20, 3),
     columns=['a', 'b', 'c'])

st.line_chart(chart_data)
